# %% [markdown]
# # 0. Libraries and importing the data
# In this case, we will only import the training data, as this step in the machine learning pipeline involves feature selection and hyperparameter tuning.

# %%
import pandas as pd
import numpy as np

# Graphical tools
import plotly.express as px

# Hyperparameter tuning and cross-validation
from sklearn.model_selection import RandomizedSearchCV

# For creating a pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline as ImbPipeline

# For preprocessing
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.preprocessing import StandardScaler

# Models
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from lightgbm import LGBMClassifier

# Classes for dealing with imbalanced datasets
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler, SMOTE

# Utilities
from scipy.stats import uniform, randint, loguniform
import pickle
import os

# %% [markdown]
# ## Preprocessed dataset version 3

# %%
csv_path = os.path.join("preprocessed_datasets", "06_train_dataset_v3.csv")
dfv3 = pd.read_csv(csv_path)

dfv3.head()
# Out:
#    HOSPITAL_EXPIRE_FLAG  subject_id  hadm_id  icustay_id  HeartRate_Min  \
# 0                   0.0       77502   151200      299699           89.0
# 1                   0.0       44346   140114      250021           74.0
# 2                   0.0       92438   118589      288511           59.0
# 3                   1.0       83663   125553      278204           75.0
# 4                   0.0       85941   181409      292581           77.0
#
#    HeartRate_Max  HeartRate_Mean  SysBP_Min  SysBP_Max  SysBP_Mean  ...  \
# 0          116.0      102.677419       97.0      150.0  126.000000  ...
# 1          114.0       92.204082       87.0      160.0  122.000000  ...
# 2           89.0       70.581395       88.0      160.0  120.933333  ...
# 3           86.0       80.400000       74.0      102.0   85.227273  ...
# 4          107.0       91.020408       95.0      150.0  108.625000  ...
#
#    MARITAL_STATUS_MARRIED  MARITAL_STATUS_SEPARATED  MARITAL_STATUS_SINGLE  \
# 0                   False                     False                  False
# 1                   False                     False                  False
# 2                    True                     False                  False
# 3                    True                     False                  False
# 4                   False                     False                  False
#
#    MARITAL_STATUS_UNKNOWN (DEFAULT)  MARITAL_STATUS_WIDOWED  \
# 0                             False                   False
# 1                             False                   False
# 2                             False                   False
# 3                             False                   False
# 4                             False                   False
#
#    FIRST_CAREUNIT_CCU  FIRST_CAREUNIT_CSRU  FIRST_CAREUNIT_MICU  \
# 0               False                False                 True
# 1               False                False                False
# 2               False                 True                False
# 3               False                False                 True
# 4               False                False                 True
#
#    FIRST_CAREUNIT_SICU  FIRST_CAREUNIT_TSICU
# 0                False                 False
# 1                False                  True
# 2                False                 False
# 3                False                 False
# 4                False                 False
#
# [5 rows x 56 columns]

# %%
dfv3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 56 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   HOSPITAL_EXPIRE_FLAG              8000 non-null   float64
#  1   subject_id                        8000 non-null   int64
#  2   hadm_id                           8000 non-null   int64
#  3   icustay_id                        8000 non-null   int64
#  4   HeartRate_Min                     7167 non-null   float64
#  5   HeartRate_Max                     7167 non-null   float64
#  6   HeartRate_Mean                    7167 non-null   float64
#  7   SysBP_Min                         7160 non-null   float64
#  8   SysBP_Max                         7160 non-null   float64
#  9   SysBP_Mean                        7160 non-null   float64
#  10  DiasBP_Min                        7160 non-null   float64
#  11  DiasBP_Max                        7160 non-null   float64
#  12  DiasBP_Mean                       7160 non-null   float64
#  13  MeanBP_Min                        7167 non-null   float64
#  14  MeanBP_Max                        7167 non-null   float64
#  15  MeanBP_Mean                       7167 non-null   float64
#  16  RespRate_Min                      7167 non-null   float64
#  17  RespRate_Max                      7167 non-null   float64
#  18  RespRate_Mean                     7167 non-null   float64
#  19  TempC_Min                         7054 non-null   float64
#  20  TempC_Max                         7054 non-null   float64
#  21  TempC_Mean                        7054 non-null   float64
#  22  SpO2_Min                          7159 non-null   float64
#  23  SpO2_Max                          7159 non-null   float64
#  24  SpO2_Mean                         7159 non-null   float64
#  25  Glucose_Min                       7902 non-null   float64
#  26  Glucose_Max                       7902 non-null   float64
#  27  Glucose_Mean                      7902 non-null   float64
#  28  train                             8000 non-null   int64
#  29  cci_index                         8000 non-null   int64
#  30  icustays_per_hospstay             8000 non-null   int64
#  31  icustays_per_subject              8000 non-null   int64
#  32  number_comorbidities              8000 non-null   int64
#  33  age_admission                     8000 non-null   int64
#  34  GENDER_F                          8000 non-null   bool
#  35  GENDER_M                          8000 non-null   bool
#  36  ADMISSION_TYPE_ELECTIVE           8000 non-null   bool
#  37  ADMISSION_TYPE_EMERGENCY          8000 non-null   bool
#  38  ADMISSION_TYPE_URGENT             8000 non-null   bool
#  39  INSURANCE_Government              8000 non-null   bool
#  40  INSURANCE_Medicaid                8000 non-null   bool
#  41  INSURANCE_Medicare                8000 non-null   bool
#  42  INSURANCE_Private                 8000 non-null   bool
#  43  INSURANCE_Self Pay                8000 non-null   bool
#  44  MARITAL_STATUS_DIVORCED           8000 non-null   bool
#  45  MARITAL_STATUS_LIFE PARTNER       8000 non-null   bool
#  46  MARITAL_STATUS_MARRIED            8000 non-null   bool
#  47  MARITAL_STATUS_SEPARATED          8000 non-null   bool
#  48  MARITAL_STATUS_SINGLE             8000 non-null   bool
#  49  MARITAL_STATUS_UNKNOWN (DEFAULT)  8000 non-null   bool
#  50  MARITAL_STATUS_WIDOWED            8000 non-null   bool
#  51  FIRST_CAREUNIT_CCU                8000 non-null   bool
#  52  FIRST_CAREUNIT_CSRU               8000 non-null   bool
#  53  FIRST_CAREUNIT_MICU               8000 non-null   bool
#  54  FIRST_CAREUNIT_SICU               8000 non-null   bool
#  55  FIRST_CAREUNIT_TSICU              8000 non-null   bool
# dtypes: bool(22), float64(25), int64(9)
# memory usage: 2.2 MB

# %% [markdown]
# ## Lists of features

# %%
# Categorical features

categorical_features = dfv3.select_dtypes(include=['bool']).columns.tolist()

# Numerical features

all_numerical_features= dfv3.select_dtypes(include=['number']).columns.tolist()

not_numerical = ['HOSPITAL_EXPIRE_FLAG', 'subject_id', 'hadm_id', 'icustay_id', 'train'] 

numerical_features = [col for col in all_numerical_features if col not in not_numerical + categorical_features]

print(f'Number of numerical features: {len(numerical_features)}\n', numerical_features, '\n')

print(f'Number of categorical features: {len(categorical_features)}\n', categorical_features, '\n')

print(f'Total number of features: {len(numerical_features) + len(categorical_features)}')
# Out:
# Number of numerical features: 29
#  ['HeartRate_Min', 'HeartRate_Max', 'HeartRate_Mean', 'SysBP_Min', 'SysBP_Max', 'SysBP_Mean', 'DiasBP_Min', 'DiasBP_Max', 'DiasBP_Mean', 'MeanBP_Min', 'MeanBP_Max', 'MeanBP_Mean', 'RespRate_Min', 'RespRate_Max', 'RespRate_Mean', 'TempC_Min', 'TempC_Max', 'TempC_Mean', 'SpO2_Min', 'SpO2_Max', 'SpO2_Mean', 'Glucose_Min', 'Glucose_Max', 'Glucose_Mean', 'cci_index', 'icustays_per_hospstay', 'icustays_per_subject', 'number_comorbidities', 'age_admission']
#
# Number of categorical features: 22
#  ['GENDER_F', 'GENDER_M', 'ADMISSION_TYPE_ELECTIVE', 'ADMISSION_TYPE_EMERGENCY', 'ADMISSION_TYPE_URGENT', 'INSURANCE_Government', 'INSURANCE_Medicaid', 'INSURANCE_Medicare', 'INSURANCE_Private', 'INSURANCE_Self Pay', 'MARITAL_STATUS_DIVORCED', 'MARITAL_STATUS_LIFE PARTNER', 'MARITAL_STATUS_MARRIED', 'MARITAL_STATUS_SEPARATED', 'MARITAL_STATUS_SINGLE', 'MARITAL_STATUS_UNKNOWN (DEFAULT)', 'MARITAL_STATUS_WIDOWED', 'FIRST_CAREUNIT_CCU', 'FIRST_CAREUNIT_CSRU', 'FIRST_CAREUNIT_MICU', 'FIRST_CAREUNIT_SICU', 'FIRST_CAREUNIT_TSICU']
#
# Total number of features: 51

# %% [markdown]
# Remember: here I have included all of the dummies of the categorical variables, but for models with linearities (e.g., logistic regression) one of these should be dropped.

# %% [markdown]
# ## Preliminary considerations: class imbalance
# First of all, for evaluating the model it is worth noticing, again, that the dataset is highly imbalanced. The plots below show this characteristic of the dataset, where the first plot shows the relative frequencies of the outcome.

# %% [markdown]
# ### Imbalancing in the training dataset

# %%
# We save the relative frequencies of the 'position_grouped' column
relative_freq = dfv3['HOSPITAL_EXPIRE_FLAG'].value_counts(normalize=True).reset_index()

# We change the naming of the columns
relative_freq.columns = ['Outcome', 'Relative Frequency']

# Create a bar plot with Plotly
fig = px.bar(relative_freq, x='Outcome', y='Relative Frequency',
                title=f'Relative Frequency Barplot of the outcome variable')

# Show the plot
fig.show()

# %% [markdown]
# As already shown in the EDA, compared to deaths during the ICU stay, survival (0) is more prevalent. This can be problematic if the relative frequency of the outcome in the test dataset is significantly different.

# %% [markdown]
# # 4. Feature and model selection and evaluation
# Tasks to do in this section:
# 1. **Split** the data.
# 2. Impute **missing values** (if there is no listwise deletion).
# 3. Clean **outliers** (imputation or deletion).
# 4. **Standardization** of numerical variables (in case a model needs it, like linear SVM). Apply same standardization to validation data. No further transformations will be needed if categorical variables have been OHE or encoded in some other way.
# 5. Deal with **class imbalancing** for the training data (from `imblearn` - `over_sampling`, `under_sampling`, import `RandomUnderSampler`, `RandomOverSampler` and `SMOTE`).
# 6. **Hyperparameter tuning** (grid search or randomized search - `RandomizedSearchCV`).
# 7. Evaluate model through **cross-validation** (considering class imbalancing, stratified cross-validation can be a good option).
# 8. Rank models with **evaluation metrics** (mainly: AUC, but could also use precision, recall and F1-score).
# 9. After finding the best-performing model (in this case, guided by the best AUC), train the best model with the whole training dataset and the optimal hyperparameters.

# %% [markdown]
# ## Some tips
#
# How and when to apply resampling methodologies:
# - Resampling methodologies should be applied after the train-validation split.
# - Explanation:
#     - Avoid information leakage: Resampling before splitting can cause synthetic data (oversampling) or missing data (undersampling) from the same original observations to appear in both train and validation sets. This results in overly optimistic validation performance.
#     - True model evaluation: Resampling alters the class distribution, which should only affect the training data. The validation set should reflect the original distribution for an accurate evaluation of how the model would perform in the real world.
# - Process:
#     - Split the data into training and validation sets.
#     - Preprocessing and feature engineering (so cleaning missing values, outliers and standardizing come BEFORE the application of resampling techniques, which can be affected if these transformations are not applied before). Concretely, the application of SMOTE would be biased if numerical features are not scaled beforehand.
#     - Apply resampling techniques (oversampling, undersampling, or SMOTE) only on the training set (as a reference, see https://imbalanced-learn.org/stable/common_pitfalls.html).
#     - Train the model on the resampled training set.
#     - Evaluate the model on the original, untouched validation set.
#
# Stratified cross-validation and resampling. Does it make sense to apply both of them?
# - Without Resampling: Stratified cross-validation is ideal for imbalanced datasets because it ensures that each fold maintains the same class distribution as the original dataset.
# - With Resampling: Stratification is less relevant because the class distribution in the training folds will be altered by resampling. However, you can still use stratified cross-validation on the unresampled validation set to evaluate the model. The goal here is to maintain the real-world class distribution in the validation set while resampling the training data within each fold.
# - Suggested Strategy:
#     - Use stratified splits for train-validation splitting.
#     - Apply resampling within the training folds during each iteration of cross-validation.

# %% [markdown]
# ## General training function

# %%
def baseline_models(
        df: pd.DataFrame, numerical_features: list[str], categorical_features: list[str], 
        target: str, model, ada_boost: bool = False, n_hyper_comb: int = 10, num_imputer: str = "median",
        refit_score: str = 'roc_auc', resampling_method: str = 'none'
):
    
    """
    Function to evaluate baseline machine learning models for a classification task, 
    with hyperparameter tuning using RandomizedSearchCV. It preprocesses numerical and 
    categorical features, performs model fitting, and evaluates performance on the entire 
    dataset. Additionally, it supports handling of class imbalance through various resampling 
    methods (oversampling, undersampling, SMOTE).

    Parameters:
    -----------
    df : pd.DataFrame
        The input dataset containing both numerical and categorical features as well as the target variable.
        
    numerical_features : list[str]
        List of column names representing numerical features in the dataset.

    categorical_features : list[str]
        List of column names representing categorical features in the dataset.
        
    target : str
        The name of the target variable (i.e., the variable to be predicted).
    
    model : class
        The model class to be used for training and evaluation (DecisionTreeClassifier, 
        SVC, RandomForestClassifier, GradientBoostingClassifier, LGBMClassifier).
    
    ada_boost : bool, default = False
        Implement adaptive boosting (can only be applied to decision trees).  

    n_hyper_comb : int, default=10
        The number of hyperparameter combinations to sample for RandomizedSearchCV.
        
    num_imputer : str, default="median"
        The strategy to use for imputing missing values in numerical features (e.g., "mean", "median").
    
    refit_score : str, default="roc_auc"
        Score based on which the RandomizedSearchCV selects the optimal hyperparameters.
        Allowed scores are: ('f1_weighted', 'f1_micro', 'f1_macro', 'roc_auc').
        
    resampling_method : str, default='none'
        Method used to address class imbalance:
        - 'oversample' for RandomOverSampler
        - 'undersample' for RandomUnderSampler
        - 'smote' for SMOTE (Synthetic Minority Over-sampling Technique)
        - 'none' for no resampling.

    Returns:
    --------

    optimal_hyperparameters : dict
        A dictionary of the optimal hyperparameters found by RandomizedSearchCV.

    cv_best_scores : dict
        A dictionary of best cross-validation scores for the model. Includes:
        - 'f1_micro': Micro-average F1 score (global metric with total TP, FN and FP)
        - 'f1_macro': Macro-average F1 score (metric for each class, find unweighted mean - 
        doesn't take label imbalance into account)
        - 'roc_auc': non-weighted ROC AUC score
    """

    ###########################################################################

    # First, we create the pipeline for preprocessing numerical and categorical transformers

    # For numerical variables, we do simple imputation
    num_prepr = [
        ("imputer", SimpleImputer(strategy = num_imputer))
    ]

    # We add standardization for certain models that benefit from it
    if model == SVC or resampling_method == 'smote':
        num_prepr.append(("standardize", StandardScaler()))

    # For categorical variables, for now, we don't do anything (pass through)
    cat_prepr = [
        ("passthrough", "passthrough")
    ]

    # Create the ColumnTransformer to apply different transformations to numerical
    # and categorical variables
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', Pipeline(num_prepr), numerical_features),
            ('cat', Pipeline(cat_prepr), categorical_features),
        ]
    )

    # Create steps of the pipeline, which begins with the preprocessor. 
    steps = [('preprocessor', preprocessor)]

    ###########################################################################

    # Second, we add the resampling step based on the chosen method (resampling after 
    # preprocessing and feature engineering)
    if resampling_method == 'oversample':
        resampling = RandomOverSampler(sampling_strategy = 'auto', random_state=17)
    elif resampling_method == 'undersample':
        resampling = RandomUnderSampler(sampling_strategy = 'auto', random_state=17)
    elif resampling_method == 'smote':
        resampling = SMOTE(sampling_strategy = 'auto', random_state=17)
    elif resampling_method == 'none':
        resampling = None  # No resampling
    else:
        raise ValueError('Invalid resampling type. Insert resampling method "oversample", "undersample", "smote" or "none" for no resampling.')

    if resampling:
        steps.append(('resampling', resampling))

    ###########################################################################

    # Third, depending on the model that has been chosen, we append one model
    # or another, and define the set of hyperparameters accordingly

    # We check if the model is one of the allowed model classes
    allowed_models = (DecisionTreeClassifier, SVC,
                      RandomForestClassifier, GradientBoostingClassifier, LGBMClassifier)

    # We consider the possibility of applying adaptive boosting to the chosen model

    if ada_boost == False:
        
        if model == SVC:
            steps.append(('svc', 
                        model(
                            random_state = 17,
                            class_weight = None,
                            probability = False  # In the hyperparameter tuning stage, we won't predict probabilities (as it significantly slows down training)
                        )))
            
            distributions = {
                'svc__C': loguniform(1e-3, 1e3),  # Regularization parameter: smaller values allow more margin violations (simpler, potentially underfitting model), larger values enforce stricter separation.
                'svc__kernel': ['linear', 'rbf', 'poly', 'sigmoid'],  # Choice of kernel function: it is used to transform data into a higher-dimensional space
                'svc__gamma': loguniform(1e-4, 1e1),  # Defines how far the influence of a single training example reaches. A lower value considers more distant points, while a higher value focuses on near points (only for ‘rbf’, ‘poly’, and ‘sigmoid’)
                'svc__degree': randint(2, 5),  # Degree of polynomial kernel (only used if kernel='poly')
                'svc__coef0': uniform(loc=0.0, scale=1.0),  # Used in 'poly' and 'sigmoid' kernels, controls the influence of higher-order terms
                'svc__tol': loguniform(1e-5, 1e-1),  # Tolerance for stopping criterion: lower values make the optimization stricter.
            }

        elif model == DecisionTreeClassifier:
            steps.append(('dtc', 
                                    model(
                                    random_state = 17,
                                    class_weight = None
                                    )))
            distributions = {
            'dtc__max_depth': randint(low = 1, high = 100),
            'dtc__max_features': randint(low = 1, high = (len(df[numerical_features + categorical_features].columns))),
            'dtc__max_leaf_nodes': randint(low = 1, high = 5000),
            'dtc__min_samples_leaf': uniform(loc=0.001, scale=0.199),
            'dtc__min_samples_split': uniform(loc=0.001, scale=0.199),            
            }
        
        elif model == RandomForestClassifier:
            steps.append(('rfc', 
                                    model(
                                    n_estimators = 1000,
                                    random_state = 17,
                                    oob_score = False,
                                    class_weight = None,
                                    n_jobs = -1
                                    )))
            distributions = {
            'rfc__max_depth': randint(low = 1, high = 300),
            'rfc__max_features': randint(low = 1, high = (len(df[numerical_features + categorical_features].columns))),
            'rfc__max_leaf_nodes': randint(low = 1, high = 5000),
            'rfc__min_samples_leaf': uniform(loc=0.001, scale=0.199),
            'rfc__min_samples_split': uniform(loc=0.001, scale=0.199),
            }
        
        elif model == GradientBoostingClassifier:
            steps.append(('gbc', 
                        model(
                            loss = 'log_loss',
                            random_state=17
                        )))
            distributions = {
                'gbc__learning_rate': [0.1, 0.5, 1.0],
                'gbc__max_depth': randint(low = 1, high = 300),
                'gbc__max_features': randint(low = 1, high = (len(df[numerical_features + categorical_features].columns))),
                'gbc__max_leaf_nodes': randint(low = 1, high = 5000),
                'gbc__min_samples_leaf': uniform(loc=0.001, scale=0.199),
                'gbc__min_samples_split': uniform(loc=0.001, scale=0.199),
                'gbc__n_estimators': [50, 100, 500],
                'gbc__subsample': uniform(loc=0.7, scale=0.3) # Subsample ratio (proportion of training samples to be used for training each estimator)
            }

        elif model == LGBMClassifier:
            steps.append(('lgb',
                        model(
                            objective = 'binary',
                            n_estimators = 100, # Number of boosting iterations (since LightGBM uses decision trees as the learners, this can also be thought of as “number of trees”. Same as n_estimators)
                            max_depth = -1, # No limit max_depth (default), set to this value as LightGBM focuses on leaf-wise tree growth algorithm
                            subsample = 1.0,  # In each iteration, train with all the training instances (since we already do CV)
                            device_type = 'cpu', # Change this parameter if prefer CPU to run the algorithm over GPU (though, since the dataset is small, in this case CPU might perform better)
                            verbosity = -1 # We disable all the information except for fatal messages
                    )))
            distributions = {
                'lgb__boosting_type': ['gbdt', 'rf'], # 'gbdt': Gradient Boosting Decision Tree. For boosting with Random Forests: 'rf' instead.
                'lgb__feature_fraction': uniform(loc = 0.5, scale = 0.5), # LightGBM will randomly select a subset of features on each iteration (tree) if feature_fraction is smaller than 1.0. Speeds up training and deals with overfitting
                'lgb__learning_rate': [0.01, 0.15, 0.3], # Lower values (e.g., 0.01) often yield better performance but require more iterations.
                'lgb__min_child_samples': randint(low = 5, high = 30), # Higher values prevent overfitting by ensuring leaves have enough data.
                'lgb__min_split_gain': uniform(loc = 0.0, scale = 0.1), # Minimum loss reduction required to make a further partition on a leaf node of the tree.
                'lgb__num_leaves': [15, 31, 63, 127], # Larger values increase model complexity and the risk of overfitting.
                'lgb__reg_lambda': uniform(loc = 0.0, scale = 1.0) # Ridge regularization parameter (alpha, default is 0)
            }

        else:
            raise ValueError(f"Invalid model type. Allowed models are: {allowed_models}")
    
    else:  # Apply adaptive boosting (only to DecisionTreeClassifier)

        if model == DecisionTreeClassifier:
            base_estimator = model(
                random_state = 17,
                class_weight = None
            )
            ada_boost = AdaBoostClassifier(
                estimator = base_estimator,
                algorithm = 'SAMME',
                random_state = 17
            )
            steps.append(('adaboost', ada_boost))
            distributions = {
            'adaboost__estimator__max_depth': randint(low = 1, high = 100),
            'adaboost__estimator__max_features': randint(low = 1, high = (len(df[numerical_features + categorical_features].columns))),
            'adaboost__estimator__max_leaf_nodes': randint(low = 1, high = 5000),
            'adaboost__estimator__min_samples_leaf': uniform(loc=0.001, scale=0.199),
            'adaboost__estimator__min_samples_split': uniform(loc=0.001, scale=0.199),
            'adaboost__learning_rate': [0.1, 0.5, 1.0],
            'adaboost__n_estimators': [50, 100, 500]
            }

        else:
            raise ValueError("Only Decision Trees are allowed for AdaBoost (Random Forests are not due to use of computing resources).")
    
    ###########################################################################

    # Fourth, we create the pipeline with the preprocessing, resampling and the model
    pipeline = ImbPipeline(steps) # We use Pipeline from imblearn instead of sklearn's

    ###########################################################################

    # Fifth, we split the dataset into features and outcome

    # We divide the data frames depending on the variables

    X = df[numerical_features + categorical_features]
    y = df[target]

    ###########################################################################

    # Sixth, we do the randomized search with the model
    
    scoring_metrics = ['f1_micro', 'f1_macro', 'roc_auc']

    # Raise an exception if the refit_score is not one of the scoring_metrics
    if refit_score not in scoring_metrics:
        raise ValueError(f"Invalid score for finding optimal hyperparameters. Allowed scores are: {scoring_metrics}")

    clf = RandomizedSearchCV(
        estimator = pipeline, 
        param_distributions = distributions,
        n_iter = n_hyper_comb, # Default is 10
        scoring = scoring_metrics,
        n_jobs = -1, # We use all available processors
        cv = 5, # Use 5 stratified cross-validation folds
        verbose = 3, # Show computation time and score for each fold and parameter candidate
        refit = refit_score, # Refit an estimator using the best found parameters on the whole dataset with the best score found (by default, roc_auc)
        random_state = 17, 
        error_score = np.nan, 
        return_train_score = False)

    search = clf.fit(X, y)

    ###########################################################################

    # Seventh, we save the main results from the search

    # Best scores obtained with best hyperparameters through stratified cross-val
    cv_best_scores = {
        'f1_micro': search.cv_results_['mean_test_f1_micro'][search.best_index_], # Calculates metrics globally by counting total true positives, false negatives, and false positives
        'f1_macro': search.cv_results_['mean_test_f1_macro'][search.best_index_], # Calculates metrics for each class independently and averages them without considering class imbalance
        'roc_auc': search.cv_results_['mean_test_roc_auc'][search.best_index_]
    }

    # Best hyperparameters from the search
    optimal_hyperparameters = search.best_params_

    ###########################################################################

    # Eigth, we return the results (metrics for classes computed for the training
    # set), including the best hyperparameters found

    return optimal_hyperparameters, cv_best_scores

# %% [markdown]
# Useful documentation:
# - Randomized Search: https://scikit-learn.org/1.5/modules/generated/sklearn.model_selection.RandomizedSearchCV.html
# - Scoring: https://scikit-learn.org/1.5/modules/model_evaluation.html#scoring-parameter. See also different types of f1 scores in: https://scikit-learn.org/1.5/modules/generated/sklearn.metrics.f1_score.html#sklearn.metrics.f1_score
# - Pipeline:
#     - sklearn pipeline: https://scikit-learn.org/1.5/modules/generated/sklearn.pipeline.Pipeline.html#sklearn.pipeline.Pipeline
#     - imblearn pipeline: https://imbalanced-learn.org/stable/references/generated/imblearn.pipeline.Pipeline.html#imblearn.pipeline.Pipeline. This is the pipeline that has been used to integrate the preprocessing with the imbalancing classes from imblearn and the model fitting of sklearn, to guarantee compatibility and correct application of resampling techniques. In the function above:
#         1. Resampling is applied to the training data (before fitting the model).
#         2. Preprocessing (imputation, scaling, etc.) comes after resampling, and it should be applied to the training data after resampling and to the test data without resampling.
#         3. Model fitting occurs after the data is both resampled and preprocessed.
# - Models:
#     - Support Vector Classifier: https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
#     - Decision trees in sklearn: https://scikit-learn.org/1.5/modules/tree.html. Also, see https://scikit-learn.org/1.5/modules/generated/sklearn.tree.DecisionTreeClassifier.html
#     - Boosting:
#         - AdaBoostClassifier: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html
#         - GradientBoostingClassifier: https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html#sklearn.ensemble.GradientBoostingClassifier. No need for standardization as it is based on decision trees.
#         - LightGBM: https://lightgbm.readthedocs.io/en/stable/. No need for standardization as it is based on decision trees. Some interesting features:
#             - It can work directly with categorical features w/o OHE (higher speed of training).
#             - Parameters for LGBMClassifier: https://lightgbm.readthedocs.io/en/stable/pythonapi/lightgbm.LGBMClassifier.html#lightgbm.LGBMClassifier
#             - Additional parameters: https://lightgbm.readthedocs.io/en/stable/Parameters.html
#             - Tips for parameter-tuning: https://lightgbm.readthedocs.io/en/stable/Parameters-Tuning.html
# - Dealing with class imbalancing: https://imbalanced-learn.org/stable/index.html. See [RandomOverSampler](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.RandomOverSampler.html), [RandomUnderSampler](https://imbalanced-learn.org/stable/references/generated/imblearn.under_sampling.RandomUnderSampler.html#randomundersampler) and [SMOTE](https://imbalanced-learn.org/stable/references/generated/imblearn.over_sampling.SMOTE.html).

# %% [markdown]
# ## Support Vector Machines
#
# Note that in this case we cannot use linear SVMs, which don't allow for probability prediction. If we want a close-to-linear SVM, we should use the `'linear'` kernel from the `SVC` class. Also, consider that the SVC model scales very  badly as the number of training instances increases, which makes the hyperparameter tuning below significantly slow.

# %% [markdown]
# #### A. No resampling (without considering class imbalance)

# %%
# best_params_svc, best_scores_svc = baseline_models(
#         df=dfv3, numerical_features=numerical_features, categorical_features=categorical_features,
#         target='HOSPITAL_EXPIRE_FLAG', model=SVC, ada_boost = False, 
#         n_hyper_comb = 50, num_imputer = "median", refit_score = 'roc_auc', resampling_method = 'none'
# )

# # Combine dictionaries into a list
# combined_svc = [best_params_svc, best_scores_svc]

# # Save into a pickle (name of file states model, if resampling technique was
# # applied and the number of hyperparameter combinations tried)
# with open('hyperparameter_tuning/svc/svc_noresampling_50comb.pkl', 'wb') as f:
#     pickle.dump(combined_svc, f)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 1/5] END svc__C=2.0441285868166177, svc__coef0=0.597513253239051, svc__degree=2, svc__gamma=0.007749439531247432, svc__kernel=poly, svc__tol=0.00015520398687464502; f1_macro: (test=0.576) f1_micro: (test=0.896) roc_auc: (test=0.813) total time=   2.3s
# [CV 2/5] END svc__C=8.669641328354105, svc__coef0=0.6375208960436358, svc__degree=3, svc__gamma=0.00015678863564170365, svc__kernel=rbf, svc__tol=1.4624810965454257e-05; f1_macro: (test=0.481) f1_micro: (test=0.887) roc_auc: (test=0.826) total time=   2.4s
# [CV 2/5] END svc__C=28.536277882830053, svc__coef0=0.5704173584583558, svc__degree=4, svc__gamma=0.001195545404013359, svc__kernel=rbf, svc__tol=0.0040707502841458585; f1_macro: (test=0.577) f1_micro: (test=0.899) roc_auc: (test=0.831) total time=   2.4s
# [CV 3/5] END svc__C=8.669641328354105, svc__coef0=0.6375208960436358, svc__degree=3, svc__gamma=0.00015678863564170365, svc__kernel=rbf, svc__tol=1.4624810965454257e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.803) total time=   2.4s
# [CV 4/5] END svc__C=8.669641328354105, svc__coef0=0.6375208960436358, svc__degree=3, svc__gamma=0.00015678863564170365, svc__kernel=rbf, svc__tol=1.4624810965454257e-05; f1_macro: (test=0.475) f1_micro: (test=0.886) roc_auc: (test=0.817) total time=   2.6s
# [CV 1/5] END svc__C=8.669641328354105, svc__coef0=0.6375208960436358, svc__degree=3, svc__gamma=0.00015678863564170365, svc__kernel=rbf, svc__tol=1.4624810965454257e-05; f1_macro: (test=0.475) f1_micro: (test=0.886) roc_auc: (test=0.775) total time=   2.7s
# [CV 5/5] END svc__C=8.669641328354105, svc__coef0=0.6375208960436358, svc__degree=3, svc__gamma=0.00015678863564170365, svc__kernel=rbf, svc__tol=1.4624810965454257e-05; f1_macro: (test=0.486) f1_micro: (test=0.887) roc_auc: (test=0.766) total time=   2.8s
# [CV 3/5] END svc__C=28.536277882830053, svc__coef0=0.5704173584583558, svc__degree=4, svc__gamma=0.001195545404013359, svc__kernel=rbf, svc__tol=0.0040707502841458585; f1_macro: (test=0.569) f1_micro: (test=0.896) roc_auc: (test=0.814) total time=   2.7s
# [CV 1/5] END svc__C=28.536277882830053, svc__coef0=0.5704173584583558, svc__degree=4, svc__gamma=0.001195545404013359, svc__kernel=rbf, svc__tol=0.0040707502841458585; f1_macro: (test=0.577) f1_micro: (test=0.896) roc_auc: (test=0.813) total time=   2.8s
# [CV 5/5] END svc__C=28.536277882830053, svc__coef0=0.5704173584583558, svc__degree=4, svc__gamma=0.001195545404013359, svc__kernel=rbf, svc__tol=0.0040707502841458585; f1_macro: (test=0.575) f1_micro: (test=0.897) roc_auc: (test=0.799) total time=   3.4s
# [CV 4/5] END svc__C=28.536277882830053, svc__coef0=0.5704173584583558, svc__degree=4, svc__gamma=0.001195545404013359, svc__kernel=rbf, svc__tol=0.0040707502841458585; f1_macro: (test=0.569) f1_micro: (test=0.896) roc_auc: (test=0.848) total time=   3.8s
# [CV 2/5] END svc__C=2.0441285868166177, svc__coef0=0.597513253239051, svc__degree=2, svc__gamma=0.007749439531247432, svc__kernel=poly, svc__tol=0.00015520398687464502; f1_macro: (test=0.584) f1_micro: (test=0.899) roc_auc: (test=0.820) total time=   2.3s
# [CV 3/5] END svc__C=2.0441285868166177, svc__coef0=0.597513253239051, svc__degree=2, svc__gamma=0.007749439531247432, svc__kernel=poly, svc__tol=0.00015520398687464502; f1_macro: (test=0.573) f1_micro: (test=0.896) roc_auc: (test=0.806) total time=   2.4s
# [CV 3/5] END svc__C=2.339125007319943, svc__coef0=0.3960474360470265, svc__degree=2, svc__gamma=0.0042213133076258996, svc__kernel=sigmoid, svc__tol=3.7637059282090934e-05; f1_macro: (test=0.576) f1_micro: (test=0.882) roc_auc: (test=0.700) total time=   2.3s
# [CV 5/5] END svc__C=2.0441285868166177, svc__coef0=0.597513253239051, svc__degree=2, svc__gamma=0.007749439531247432, svc__kernel=poly, svc__tol=0.00015520398687464502; f1_macro: (test=0.578) f1_micro: (test=0.897) roc_auc: (test=0.802) total time=   2.6s
# [CV 5/5] END svc__C=2.339125007319943, svc__coef0=0.3960474360470265, svc__degree=2, svc__gamma=0.0042213133076258996, svc__kernel=sigmoid, svc__tol=3.7637059282090934e-05; f1_macro: (test=0.573) f1_micro: (test=0.879) roc_auc: (test=0.699) total time=   2.3s
# [CV 4/5] END svc__C=2.0441285868166177, svc__coef0=0.597513253239051, svc__degree=2, svc__gamma=0.007749439531247432, svc__kernel=poly, svc__tol=0.00015520398687464502; f1_macro: (test=0.550) f1_micro: (test=0.893) roc_auc: (test=0.848) total time=   2.8s
# [CV 1/5] END svc__C=2.339125007319943, svc__coef0=0.3960474360470265, svc__degree=2, svc__gamma=0.0042213133076258996, svc__kernel=sigmoid, svc__tol=3.7637059282090934e-05; f1_macro: (test=0.608) f1_micro: (test=0.891) roc_auc: (test=0.700) total time=   2.7s
# [CV 2/5] END svc__C=2.339125007319943, svc__coef0=0.3960474360470265, svc__degree=2, svc__gamma=0.0042213133076258996, svc__kernel=sigmoid, svc__tol=3.7637059282090934e-05; f1_macro: (test=0.613) f1_micro: (test=0.883) roc_auc: (test=0.708) total time=   2.8s
# [CV 4/5] END svc__C=2.339125007319943, svc__coef0=0.3960474360470265, svc__degree=2, svc__gamma=0.0042213133076258996, svc__kernel=sigmoid, svc__tol=3.7637059282090934e-05; f1_macro: (test=0.599) f1_micro: (test=0.886) roc_auc: (test=0.721) total time=   3.0s
# [CV 1/5] END svc__C=0.008043409255258087, svc__coef0=0.05524135021582377, svc__degree=4, svc__gamma=0.0028945881012154345, svc__kernel=sigmoid, svc__tol=0.0011219400933515757; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.703) total time=   2.3s
# [CV 2/5] END svc__C=0.008043409255258087, svc__coef0=0.05524135021582377, svc__degree=4, svc__gamma=0.0028945881012154345, svc__kernel=sigmoid, svc__tol=0.0011219400933515757; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.678) total time=   2.0s
# [CV 3/5] END svc__C=0.05861246900985804, svc__coef0=0.5305867556052941, svc__degree=4, svc__gamma=2.78178855478573, svc__kernel=rbf, svc__tol=0.014058592411732856; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.663) total time=   6.3s
# [CV 4/5] END svc__C=0.05861246900985804, svc__coef0=0.5305867556052941, svc__degree=4, svc__gamma=2.78178855478573, svc__kernel=rbf, svc__tol=0.014058592411732856; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.669) total time=   6.8s
# [CV 1/5] END svc__C=0.05861246900985804, svc__coef0=0.5305867556052941, svc__degree=4, svc__gamma=2.78178855478573, svc__kernel=rbf, svc__tol=0.014058592411732856; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.657) total time=   6.8s
# [CV 3/5] END svc__C=0.008043409255258087, svc__coef0=0.05524135021582377, svc__degree=4, svc__gamma=0.0028945881012154345, svc__kernel=sigmoid, svc__tol=0.0011219400933515757; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.703) total time=   2.2s
# [CV 5/5] END svc__C=0.05861246900985804, svc__coef0=0.5305867556052941, svc__degree=4, svc__gamma=2.78178855478573, svc__kernel=rbf, svc__tol=0.014058592411732856; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.663) total time=   7.2s
# [CV 4/5] END svc__C=0.008043409255258087, svc__coef0=0.05524135021582377, svc__degree=4, svc__gamma=0.0028945881012154345, svc__kernel=sigmoid, svc__tol=0.0011219400933515757; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.719) total time=   2.6s
# [CV 5/5] END svc__C=0.008043409255258087, svc__coef0=0.05524135021582377, svc__degree=4, svc__gamma=0.0028945881012154345, svc__kernel=sigmoid, svc__tol=0.0011219400933515757; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.682) total time=   2.7s
# [CV 2/5] END svc__C=0.05861246900985804, svc__coef0=0.5305867556052941, svc__degree=4, svc__gamma=2.78178855478573, svc__kernel=rbf, svc__tol=0.014058592411732856; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.654) total time=   8.0s
# [CV 1/5] END svc__C=0.018992941688090882, svc__coef0=0.177466204590906, svc__degree=4, svc__gamma=1.4012764379723297, svc__kernel=sigmoid, svc__tol=0.02054805154678844; f1_macro: (test=0.513) f1_micro: (test=0.838) roc_auc: (test=0.595) total time=   1.9s
# [CV 1/5] END svc__C=57.825564999405564, svc__coef0=0.6136159679467957, svc__degree=4, svc__gamma=0.05308757281199902, svc__kernel=rbf, svc__tol=0.0014662506841894422; f1_macro: (test=0.607) f1_micro: (test=0.871) roc_auc: (test=0.787) total time=   5.9s
# [CV 3/5] END svc__C=57.825564999405564, svc__coef0=0.6136159679467957, svc__degree=4, svc__gamma=0.05308757281199902, svc__kernel=rbf, svc__tol=0.0014662506841894422; f1_macro: (test=0.632) f1_micro: (test=0.879) roc_auc: (test=0.791) total time=   5.8s
# [CV 4/5] END svc__C=57.825564999405564, svc__coef0=0.6136159679467957, svc__degree=4, svc__gamma=0.05308757281199902, svc__kernel=rbf, svc__tol=0.0014662506841894422; f1_macro: (test=0.614) f1_micro: (test=0.880) roc_auc: (test=0.768) total time=   5.8s
# [CV 2/5] END svc__C=57.825564999405564, svc__coef0=0.6136159679467957, svc__degree=4, svc__gamma=0.05308757281199902, svc__kernel=rbf, svc__tol=0.0014662506841894422; f1_macro: (test=0.600) f1_micro: (test=0.864) roc_auc: (test=0.806) total time=   6.2s
# [CV 5/5] END svc__C=57.825564999405564, svc__coef0=0.6136159679467957, svc__degree=4, svc__gamma=0.05308757281199902, svc__kernel=rbf, svc__tol=0.0014662506841894422; f1_macro: (test=0.600) f1_micro: (test=0.877) roc_auc: (test=0.774) total time=   6.0s
# [CV 5/5] END svc__C=0.018992941688090882, svc__coef0=0.177466204590906, svc__degree=4, svc__gamma=1.4012764379723297, svc__kernel=sigmoid, svc__tol=0.02054805154678844; f1_macro: (test=0.542) f1_micro: (test=0.843) roc_auc: (test=0.610) total time=   2.2s
# [CV 2/5] END svc__C=0.018992941688090882, svc__coef0=0.177466204590906, svc__degree=4, svc__gamma=1.4012764379723297, svc__kernel=sigmoid, svc__tol=0.02054805154678844; f1_macro: (test=0.536) f1_micro: (test=0.863) roc_auc: (test=0.642) total time=   3.5s
# [CV 1/5] END svc__C=0.05367771070335083, svc__coef0=0.9522682541656126, svc__degree=4, svc__gamma=0.02913153511642921, svc__kernel=sigmoid, svc__tol=0.04907346690079479; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.520) total time=   2.3s
# [CV 2/5] END svc__C=0.05367771070335083, svc__coef0=0.9522682541656126, svc__degree=4, svc__gamma=0.02913153511642921, svc__kernel=sigmoid, svc__tol=0.04907346690079479; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.476) total time=   2.3s
# [CV 4/5] END svc__C=0.018992941688090882, svc__coef0=0.177466204590906, svc__degree=4, svc__gamma=1.4012764379723297, svc__kernel=sigmoid, svc__tol=0.02054805154678844; f1_macro: (test=0.527) f1_micro: (test=0.841) roc_auc: (test=0.609) total time=   2.8s
# [CV 1/5] END svc__C=0.574433758827445, svc__coef0=0.7631882850766584, svc__degree=3, svc__gamma=0.39253683469352824, svc__kernel=rbf, svc__tol=1.0953482991595066e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.742) total time=   7.4s
# [CV 4/5] END svc__C=0.574433758827445, svc__coef0=0.7631882850766584, svc__degree=3, svc__gamma=0.39253683469352824, svc__kernel=rbf, svc__tol=1.0953482991595066e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.747) total time=   7.8s
# [CV 3/5] END svc__C=0.05367771070335083, svc__coef0=0.9522682541656126, svc__degree=4, svc__gamma=0.02913153511642921, svc__kernel=sigmoid, svc__tol=0.04907346690079479; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.523) total time=   2.0s
# [CV 3/5] END svc__C=0.574433758827445, svc__coef0=0.7631882850766584, svc__degree=3, svc__gamma=0.39253683469352824, svc__kernel=rbf, svc__tol=1.0953482991595066e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.753) total time=   8.1s
# [CV 5/5] END svc__C=0.574433758827445, svc__coef0=0.7631882850766584, svc__degree=3, svc__gamma=0.39253683469352824, svc__kernel=rbf, svc__tol=1.0953482991595066e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.716) total time=   7.9s
# [CV 4/5] END svc__C=0.05367771070335083, svc__coef0=0.9522682541656126, svc__degree=4, svc__gamma=0.02913153511642921, svc__kernel=sigmoid, svc__tol=0.04907346690079479; f1_macro: (test=0.521) f1_micro: (test=0.882) roc_auc: (test=0.611) total time=   2.4s
# [CV 2/5] END svc__C=0.574433758827445, svc__coef0=0.7631882850766584, svc__degree=3, svc__gamma=0.39253683469352824, svc__kernel=rbf, svc__tol=1.0953482991595066e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.758) total time=   8.9s
# [CV 5/5] END svc__C=0.05367771070335083, svc__coef0=0.9522682541656126, svc__degree=4, svc__gamma=0.02913153511642921, svc__kernel=sigmoid, svc__tol=0.04907346690079479; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.524) total time=   2.3s
# [CV 3/5] END svc__C=0.018992941688090882, svc__coef0=0.177466204590906, svc__degree=4, svc__gamma=1.4012764379723297, svc__kernel=sigmoid, svc__tol=0.02054805154678844; f1_macro: (test=0.526) f1_micro: (test=0.858) roc_auc: (test=0.594) total time=   5.3s
# [CV 1/5] END svc__C=0.02258072566171928, svc__coef0=0.9573027408410922, svc__degree=2, svc__gamma=0.00011980666104537772, svc__kernel=sigmoid, svc__tol=0.08072443888637355; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.670) total time=   2.0s
# [CV 5/5] END svc__C=0.02258072566171928, svc__coef0=0.9573027408410922, svc__degree=2, svc__gamma=0.00011980666104537772, svc__kernel=sigmoid, svc__tol=0.08072443888637355; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.679) total time=   1.7s
# [CV 2/5] END svc__C=0.02258072566171928, svc__coef0=0.9573027408410922, svc__degree=2, svc__gamma=0.00011980666104537772, svc__kernel=sigmoid, svc__tol=0.08072443888637355; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.724) total time=   2.1s
# [CV 3/5] END svc__C=0.02258072566171928, svc__coef0=0.9573027408410922, svc__degree=2, svc__gamma=0.00011980666104537772, svc__kernel=sigmoid, svc__tol=0.08072443888637355; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.710) total time=   2.0s
# [CV 4/5] END svc__C=0.02258072566171928, svc__coef0=0.9573027408410922, svc__degree=2, svc__gamma=0.00011980666104537772, svc__kernel=sigmoid, svc__tol=0.08072443888637355; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.700) total time=   2.1s
# [CV 1/5] END svc__C=0.5109026444627892, svc__coef0=0.6671528660961247, svc__degree=3, svc__gamma=0.17752255001999356, svc__kernel=sigmoid, svc__tol=0.00017461412602836994; f1_macro: (test=0.529) f1_micro: (test=0.807) roc_auc: (test=0.585) total time=   1.7s
# [CV 2/5] END svc__C=0.0011592412341549646, svc__coef0=0.3721700204855507, svc__degree=4, svc__gamma=0.08014457411723197, svc__kernel=rbf, svc__tol=1.728539619548917e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.833) total time=   4.5s
# [CV 3/5] END svc__C=0.0011592412341549646, svc__coef0=0.3721700204855507, svc__degree=4, svc__gamma=0.08014457411723197, svc__kernel=rbf, svc__tol=1.728539619548917e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.822) total time=   4.2s
# [CV 1/5] END svc__C=0.0011592412341549646, svc__coef0=0.3721700204855507, svc__degree=4, svc__gamma=0.08014457411723197, svc__kernel=rbf, svc__tol=1.728539619548917e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.787) total time=   4.7s
# [CV 2/5] END svc__C=0.5109026444627892, svc__coef0=0.6671528660961247, svc__degree=3, svc__gamma=0.17752255001999356, svc__kernel=sigmoid, svc__tol=0.00017461412602836994; f1_macro: (test=0.565) f1_micro: (test=0.831) roc_auc: (test=0.629) total time=   1.5s
# [CV 3/5] END svc__C=0.5109026444627892, svc__coef0=0.6671528660961247, svc__degree=3, svc__gamma=0.17752255001999356, svc__kernel=sigmoid, svc__tol=0.00017461412602836994; f1_macro: (test=0.552) f1_micro: (test=0.815) roc_auc: (test=0.615) total time=   1.7s
# [CV 4/5] END svc__C=0.0011592412341549646, svc__coef0=0.3721700204855507, svc__degree=4, svc__gamma=0.08014457411723197, svc__kernel=rbf, svc__tol=1.728539619548917e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.792) total time=   4.3s
# [CV 4/5] END svc__C=0.5109026444627892, svc__coef0=0.6671528660961247, svc__degree=3, svc__gamma=0.17752255001999356, svc__kernel=sigmoid, svc__tol=0.00017461412602836994; f1_macro: (test=0.536) f1_micro: (test=0.814) roc_auc: (test=0.584) total time=   1.8s
# [CV 5/5] END svc__C=0.0011592412341549646, svc__coef0=0.3721700204855507, svc__degree=4, svc__gamma=0.08014457411723197, svc__kernel=rbf, svc__tol=1.728539619548917e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.774) total time=   4.4s
# [CV 5/5] END svc__C=0.5109026444627892, svc__coef0=0.6671528660961247, svc__degree=3, svc__gamma=0.17752255001999356, svc__kernel=sigmoid, svc__tol=0.00017461412602836994; f1_macro: (test=0.526) f1_micro: (test=0.813) roc_auc: (test=0.582) total time=   1.9s
# [CV 1/5] END svc__C=51.345471652714586, svc__coef0=0.35328125178061953, svc__degree=4, svc__gamma=0.001423468542023391, svc__kernel=rbf, svc__tol=0.008121758325541484; f1_macro: (test=0.589) f1_micro: (test=0.897) roc_auc: (test=0.808) total time=   2.8s
# [CV 1/5] END svc__C=0.0024253065374320445, svc__coef0=0.4537374619422069, svc__degree=3, svc__gamma=0.0006192700338471284, svc__kernel=linear, svc__tol=2.658737183888444e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.765) total time=   1.8s
# [CV 2/5] END svc__C=51.345471652714586, svc__coef0=0.35328125178061953, svc__degree=4, svc__gamma=0.001423468542023391, svc__kernel=rbf, svc__tol=0.008121758325541484; f1_macro: (test=0.610) f1_micro: (test=0.903) roc_auc: (test=0.826) total time=   2.5s
# [CV 5/5] END svc__C=51.345471652714586, svc__coef0=0.35328125178061953, svc__degree=4, svc__gamma=0.001423468542023391, svc__kernel=rbf, svc__tol=0.008121758325541484; f1_macro: (test=0.597) f1_micro: (test=0.898) roc_auc: (test=0.793) total time=   2.3s
# [CV 3/5] END svc__C=51.345471652714586, svc__coef0=0.35328125178061953, svc__degree=4, svc__gamma=0.001423468542023391, svc__kernel=rbf, svc__tol=0.008121758325541484; f1_macro: (test=0.577) f1_micro: (test=0.896) roc_auc: (test=0.811) total time=   2.6s
# [CV 4/5] END svc__C=51.345471652714586, svc__coef0=0.35328125178061953, svc__degree=4, svc__gamma=0.001423468542023391, svc__kernel=rbf, svc__tol=0.008121758325541484; f1_macro: (test=0.586) f1_micro: (test=0.897) roc_auc: (test=0.845) total time=   2.6s
# [CV 2/5] END svc__C=0.0024253065374320445, svc__coef0=0.4537374619422069, svc__degree=3, svc__gamma=0.0006192700338471284, svc__kernel=linear, svc__tol=2.658737183888444e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.780) total time=   1.6s
# [CV 4/5] END svc__C=0.0024253065374320445, svc__coef0=0.4537374619422069, svc__degree=3, svc__gamma=0.0006192700338471284, svc__kernel=linear, svc__tol=2.658737183888444e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.802) total time=   1.5s
# [CV 3/5] END svc__C=0.0024253065374320445, svc__coef0=0.4537374619422069, svc__degree=3, svc__gamma=0.0006192700338471284, svc__kernel=linear, svc__tol=2.658737183888444e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.788) total time=   1.7s
# [CV 5/5] END svc__C=0.0024253065374320445, svc__coef0=0.4537374619422069, svc__degree=3, svc__gamma=0.0006192700338471284, svc__kernel=linear, svc__tol=2.658737183888444e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=   1.9s
# [CV 2/5] END svc__C=2.764773936999455, svc__coef0=0.9603457940240444, svc__degree=2, svc__gamma=1.7345148528529044, svc__kernel=rbf, svc__tol=0.08954197026447562; f1_macro: (test=0.469) f1_micro: (test=0.885) roc_auc: (test=0.720) total time=   6.2s
# [CV 1/5] END svc__C=2.764773936999455, svc__coef0=0.9603457940240444, svc__degree=2, svc__gamma=1.7345148528529044, svc__kernel=rbf, svc__tol=0.08954197026447562; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.705) total time=   7.1s
# [CV 5/5] END svc__C=2.764773936999455, svc__coef0=0.9603457940240444, svc__degree=2, svc__gamma=1.7345148528529044, svc__kernel=rbf, svc__tol=0.08954197026447562; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.692) total time=   5.8s
# [CV 4/5] END svc__C=2.764773936999455, svc__coef0=0.9603457940240444, svc__degree=2, svc__gamma=1.7345148528529044, svc__kernel=rbf, svc__tol=0.08954197026447562; f1_macro: (test=0.469) f1_micro: (test=0.885) roc_auc: (test=0.714) total time=   6.0s
# [CV 3/5] END svc__C=2.764773936999455, svc__coef0=0.9603457940240444, svc__degree=2, svc__gamma=1.7345148528529044, svc__kernel=rbf, svc__tol=0.08954197026447562; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.725) total time=   6.2s
# [CV 2/5] END svc__C=19.67249997865535, svc__coef0=0.08273548925340335, svc__degree=4, svc__gamma=0.2367435565162746, svc__kernel=linear, svc__tol=0.005910000756413033; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.796) total time=  22.4s
# [CV 4/5] END svc__C=19.67249997865535, svc__coef0=0.08273548925340335, svc__degree=4, svc__gamma=0.2367435565162746, svc__kernel=linear, svc__tol=0.005910000756413033; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.799) total time=  26.1s
# [CV 5/5] END svc__C=19.67249997865535, svc__coef0=0.08273548925340335, svc__degree=4, svc__gamma=0.2367435565162746, svc__kernel=linear, svc__tol=0.005910000756413033; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.755) total time=  26.7s
# [CV 3/5] END svc__C=19.67249997865535, svc__coef0=0.08273548925340335, svc__degree=4, svc__gamma=0.2367435565162746, svc__kernel=linear, svc__tol=0.005910000756413033; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.780) total time=  27.2s
# [CV 1/5] END svc__C=19.67249997865535, svc__coef0=0.08273548925340335, svc__degree=4, svc__gamma=0.2367435565162746, svc__kernel=linear, svc__tol=0.005910000756413033; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.766) total time=  28.7s
# [CV 1/5] END svc__C=24.698595707823127, svc__coef0=0.8236199870200153, svc__degree=3, svc__gamma=0.021070507135441306, svc__kernel=linear, svc__tol=0.02433133736552284; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.765) total time=  32.1s
# [CV 2/5] END svc__C=24.698595707823127, svc__coef0=0.8236199870200153, svc__degree=3, svc__gamma=0.021070507135441306, svc__kernel=linear, svc__tol=0.02433133736552284; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.791) total time=  25.0s
# [CV 3/5] END svc__C=24.698595707823127, svc__coef0=0.8236199870200153, svc__degree=3, svc__gamma=0.021070507135441306, svc__kernel=linear, svc__tol=0.02433133736552284; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.782) total time=  29.6s
# [CV 4/5] END svc__C=24.698595707823127, svc__coef0=0.8236199870200153, svc__degree=3, svc__gamma=0.021070507135441306, svc__kernel=linear, svc__tol=0.02433133736552284; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.796) total time=  29.4s
# [CV 5/5] END svc__C=24.698595707823127, svc__coef0=0.8236199870200153, svc__degree=3, svc__gamma=0.021070507135441306, svc__kernel=linear, svc__tol=0.02433133736552284; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.754) total time=  31.6s
# [CV 1/5] END svc__C=241.94889867657716, svc__coef0=0.49310233858652663, svc__degree=3, svc__gamma=0.006692960269245887, svc__kernel=poly, svc__tol=0.002149414095377744; f1_macro: (test=0.614) f1_micro: (test=0.871) roc_auc: (test=0.776) total time=   3.3s
# [CV 2/5] END svc__C=241.94889867657716, svc__coef0=0.49310233858652663, svc__degree=3, svc__gamma=0.006692960269245887, svc__kernel=poly, svc__tol=0.002149414095377744; f1_macro: (test=0.644) f1_micro: (test=0.874) roc_auc: (test=0.727) total time=   3.3s
# [CV 3/5] END svc__C=241.94889867657716, svc__coef0=0.49310233858652663, svc__degree=3, svc__gamma=0.006692960269245887, svc__kernel=poly, svc__tol=0.002149414095377744; f1_macro: (test=0.666) f1_micro: (test=0.882) roc_auc: (test=0.759) total time=   3.3s
# [CV 4/5] END svc__C=241.94889867657716, svc__coef0=0.49310233858652663, svc__degree=3, svc__gamma=0.006692960269245887, svc__kernel=poly, svc__tol=0.002149414095377744; f1_macro: (test=0.645) f1_micro: (test=0.880) roc_auc: (test=0.745) total time=   3.2s
# [CV 5/5] END svc__C=241.94889867657716, svc__coef0=0.49310233858652663, svc__degree=3, svc__gamma=0.006692960269245887, svc__kernel=poly, svc__tol=0.002149414095377744; f1_macro: (test=0.624) f1_micro: (test=0.874) roc_auc: (test=0.745) total time=   2.8s
# [CV 1/5] END svc__C=552.6422751346594, svc__coef0=0.6606496249222209, svc__degree=3, svc__gamma=0.01693273711675899, svc__kernel=poly, svc__tol=0.07353949057585128; f1_macro: (test=0.611) f1_micro: (test=0.842) roc_auc: (test=0.699) total time=   2.9s
# [CV 2/5] END svc__C=552.6422751346594, svc__coef0=0.6606496249222209, svc__degree=3, svc__gamma=0.01693273711675899, svc__kernel=poly, svc__tol=0.07353949057585128; f1_macro: (test=0.612) f1_micro: (test=0.842) roc_auc: (test=0.701) total time=   3.0s
# [CV 3/5] END svc__C=552.6422751346594, svc__coef0=0.6606496249222209, svc__degree=3, svc__gamma=0.01693273711675899, svc__kernel=poly, svc__tol=0.07353949057585128; f1_macro: (test=0.657) f1_micro: (test=0.861) roc_auc: (test=0.703) total time=   2.9s
# [CV 4/5] END svc__C=552.6422751346594, svc__coef0=0.6606496249222209, svc__degree=3, svc__gamma=0.01693273711675899, svc__kernel=poly, svc__tol=0.07353949057585128; f1_macro: (test=0.625) f1_micro: (test=0.852) roc_auc: (test=0.699) total time=   3.1s
# [CV 5/5] END svc__C=552.6422751346594, svc__coef0=0.6606496249222209, svc__degree=3, svc__gamma=0.01693273711675899, svc__kernel=poly, svc__tol=0.07353949057585128; f1_macro: (test=0.649) f1_micro: (test=0.858) roc_auc: (test=0.730) total time=   2.9s
# [CV 1/5] END svc__C=0.789092740531096, svc__coef0=0.5407474451942931, svc__degree=3, svc__gamma=0.010420054127873233, svc__kernel=sigmoid, svc__tol=1.4056480364207874e-05; f1_macro: (test=0.488) f1_micro: (test=0.880) roc_auc: (test=0.559) total time=   1.3s
# [CV 2/5] END svc__C=0.789092740531096, svc__coef0=0.5407474451942931, svc__degree=3, svc__gamma=0.010420054127873233, svc__kernel=sigmoid, svc__tol=1.4056480364207874e-05; f1_macro: (test=0.620) f1_micro: (test=0.863) roc_auc: (test=0.700) total time=   1.1s
# [CV 3/5] END svc__C=0.789092740531096, svc__coef0=0.5407474451942931, svc__degree=3, svc__gamma=0.010420054127873233, svc__kernel=sigmoid, svc__tol=1.4056480364207874e-05; f1_macro: (test=0.497) f1_micro: (test=0.880) roc_auc: (test=0.561) total time=   1.7s
# [CV 4/5] END svc__C=0.789092740531096, svc__coef0=0.5407474451942931, svc__degree=3, svc__gamma=0.010420054127873233, svc__kernel=sigmoid, svc__tol=1.4056480364207874e-05; f1_macro: (test=0.500) f1_micro: (test=0.884) roc_auc: (test=0.543) total time=   1.5s
# [CV 5/5] END svc__C=0.789092740531096, svc__coef0=0.5407474451942931, svc__degree=3, svc__gamma=0.010420054127873233, svc__kernel=sigmoid, svc__tol=1.4056480364207874e-05; f1_macro: (test=0.508) f1_micro: (test=0.883) roc_auc: (test=0.557) total time=   1.4s
# [CV 1/5] END svc__C=142.289332186713, svc__coef0=0.3105036139431915, svc__degree=2, svc__gamma=0.05882630389250084, svc__kernel=poly, svc__tol=0.0006248852494699558; f1_macro: (test=0.603) f1_micro: (test=0.859) roc_auc: (test=0.740) total time= 1.4min
# [CV 2/5] END svc__C=142.289332186713, svc__coef0=0.3105036139431915, svc__degree=2, svc__gamma=0.05882630389250084, svc__kernel=poly, svc__tol=0.0006248852494699558; f1_macro: (test=0.643) f1_micro: (test=0.864) roc_auc: (test=0.713) total time= 1.4min
# [CV 4/5] END svc__C=142.289332186713, svc__coef0=0.3105036139431915, svc__degree=2, svc__gamma=0.05882630389250084, svc__kernel=poly, svc__tol=0.0006248852494699558; f1_macro: (test=0.653) f1_micro: (test=0.874) roc_auc: (test=0.724) total time= 1.3min
# [CV 3/5] END svc__C=142.289332186713, svc__coef0=0.3105036139431915, svc__degree=2, svc__gamma=0.05882630389250084, svc__kernel=poly, svc__tol=0.0006248852494699558; f1_macro: (test=0.668) f1_micro: (test=0.878) roc_auc: (test=0.721) total time= 1.6min
# [CV 5/5] END svc__C=142.289332186713, svc__coef0=0.3105036139431915, svc__degree=2, svc__gamma=0.05882630389250084, svc__kernel=poly, svc__tol=0.0006248852494699558; f1_macro: (test=0.634) f1_micro: (test=0.863) roc_auc: (test=0.732) total time= 1.5min
# [CV 1/5] END svc__C=99.36320935011251, svc__coef0=0.4981436821039962, svc__degree=4, svc__gamma=0.02095812349442603, svc__kernel=linear, svc__tol=0.007117797626237784; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.767) total time= 3.8min
# [CV 5/5] END svc__C=99.36320935011251, svc__coef0=0.4981436821039962, svc__degree=4, svc__gamma=0.02095812349442603, svc__kernel=linear, svc__tol=0.007117797626237784; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.753) total time= 3.8min
# [CV 4/5] END svc__C=99.36320935011251, svc__coef0=0.4981436821039962, svc__degree=4, svc__gamma=0.02095812349442603, svc__kernel=linear, svc__tol=0.007117797626237784; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.800) total time= 5.2min
# [CV 3/5] END svc__C=99.36320935011251, svc__coef0=0.4981436821039962, svc__degree=4, svc__gamma=0.02095812349442603, svc__kernel=linear, svc__tol=0.007117797626237784; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.789) total time= 5.5min
# [CV 2/5] END svc__C=99.36320935011251, svc__coef0=0.4981436821039962, svc__degree=4, svc__gamma=0.02095812349442603, svc__kernel=linear, svc__tol=0.007117797626237784; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.782) total time= 6.3min
# [CV 1/5] END svc__C=0.23503244869734471, svc__coef0=0.6902722312738483, svc__degree=4, svc__gamma=0.0006110091474964659, svc__kernel=sigmoid, svc__tol=0.059356558155333375; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.684) total time=   1.1s
# [CV 2/5] END svc__C=0.23503244869734471, svc__coef0=0.6902722312738483, svc__degree=4, svc__gamma=0.0006110091474964659, svc__kernel=sigmoid, svc__tol=0.059356558155333375; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.742) total time=   1.1s
# [CV 3/5] END svc__C=0.23503244869734471, svc__coef0=0.6902722312738483, svc__degree=4, svc__gamma=0.0006110091474964659, svc__kernel=sigmoid, svc__tol=0.059356558155333375; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.698) total time=   1.1s
# [CV 4/5] END svc__C=0.23503244869734471, svc__coef0=0.6902722312738483, svc__degree=4, svc__gamma=0.0006110091474964659, svc__kernel=sigmoid, svc__tol=0.059356558155333375; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.721) total time=   1.1s
# [CV 5/5] END svc__C=0.23503244869734471, svc__coef0=0.6902722312738483, svc__degree=4, svc__gamma=0.0006110091474964659, svc__kernel=sigmoid, svc__tol=0.059356558155333375; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.705) total time=   1.2s
# [CV 1/5] END svc__C=0.16689575530001152, svc__coef0=0.0262549322888882, svc__degree=2, svc__gamma=0.0006988230828829675, svc__kernel=poly, svc__tol=0.000592437810001009; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.788) total time=   0.9s
# [CV 2/5] END svc__C=0.16689575530001152, svc__coef0=0.0262549322888882, svc__degree=2, svc__gamma=0.0006988230828829675, svc__kernel=poly, svc__tol=0.000592437810001009; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.826) total time=   0.9s
# [CV 3/5] END svc__C=0.16689575530001152, svc__coef0=0.0262549322888882, svc__degree=2, svc__gamma=0.0006988230828829675, svc__kernel=poly, svc__tol=0.000592437810001009; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.802) total time=   0.8s
# [CV 4/5] END svc__C=0.16689575530001152, svc__coef0=0.0262549322888882, svc__degree=2, svc__gamma=0.0006988230828829675, svc__kernel=poly, svc__tol=0.000592437810001009; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.815) total time=   0.9s
# [CV 5/5] END svc__C=0.16689575530001152, svc__coef0=0.0262549322888882, svc__degree=2, svc__gamma=0.0006988230828829675, svc__kernel=poly, svc__tol=0.000592437810001009; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.786) total time=   0.8s
# [CV 1/5] END svc__C=993.8848383663341, svc__coef0=0.31771201485178846, svc__degree=4, svc__gamma=0.0006648164919025589, svc__kernel=poly, svc__tol=0.011397000364126018; f1_macro: (test=0.584) f1_micro: (test=0.896) roc_auc: (test=0.803) total time=   1.0s
# [CV 2/5] END svc__C=993.8848383663341, svc__coef0=0.31771201485178846, svc__degree=4, svc__gamma=0.0006648164919025589, svc__kernel=poly, svc__tol=0.011397000364126018; f1_macro: (test=0.618) f1_micro: (test=0.904) roc_auc: (test=0.822) total time=   1.2s
# [CV 3/5] END svc__C=993.8848383663341, svc__coef0=0.31771201485178846, svc__degree=4, svc__gamma=0.0006648164919025589, svc__kernel=poly, svc__tol=0.011397000364126018; f1_macro: (test=0.573) f1_micro: (test=0.896) roc_auc: (test=0.802) total time=   1.1s
# [CV 4/5] END svc__C=993.8848383663341, svc__coef0=0.31771201485178846, svc__degree=4, svc__gamma=0.0006648164919025589, svc__kernel=poly, svc__tol=0.011397000364126018; f1_macro: (test=0.579) f1_micro: (test=0.895) roc_auc: (test=0.840) total time=   1.1s
# [CV 5/5] END svc__C=993.8848383663341, svc__coef0=0.31771201485178846, svc__degree=4, svc__gamma=0.0006648164919025589, svc__kernel=poly, svc__tol=0.011397000364126018; f1_macro: (test=0.605) f1_micro: (test=0.899) roc_auc: (test=0.787) total time=   1.0s
# [CV 1/5] END svc__C=0.012775074486347507, svc__coef0=0.35145592428815686, svc__degree=4, svc__gamma=0.3495733529173189, svc__kernel=linear, svc__tol=0.0002241086763973859; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.765) total time=   0.9s
# [CV 2/5] END svc__C=0.012775074486347507, svc__coef0=0.35145592428815686, svc__degree=4, svc__gamma=0.3495733529173189, svc__kernel=linear, svc__tol=0.0002241086763973859; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.791) total time=   0.8s
# [CV 3/5] END svc__C=0.012775074486347507, svc__coef0=0.35145592428815686, svc__degree=4, svc__gamma=0.3495733529173189, svc__kernel=linear, svc__tol=0.0002241086763973859; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.782) total time=   0.9s
# [CV 4/5] END svc__C=0.012775074486347507, svc__coef0=0.35145592428815686, svc__degree=4, svc__gamma=0.3495733529173189, svc__kernel=linear, svc__tol=0.0002241086763973859; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.799) total time=   0.9s
# [CV 5/5] END svc__C=0.012775074486347507, svc__coef0=0.35145592428815686, svc__degree=4, svc__gamma=0.3495733529173189, svc__kernel=linear, svc__tol=0.0002241086763973859; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.755) total time=   0.9s
# [CV 1/5] END svc__C=0.21789021927224606, svc__coef0=0.8587971938450034, svc__degree=3, svc__gamma=0.01345197442275327, svc__kernel=rbf, svc__tol=0.05532670999192686; f1_macro: (test=0.502) f1_micro: (test=0.889) roc_auc: (test=0.796) total time=   1.1s
# [CV 2/5] END svc__C=0.21789021927224606, svc__coef0=0.8587971938450034, svc__degree=3, svc__gamma=0.01345197442275327, svc__kernel=rbf, svc__tol=0.05532670999192686; f1_macro: (test=0.481) f1_micro: (test=0.887) roc_auc: (test=0.833) total time=   1.1s
# [CV 3/5] END svc__C=0.21789021927224606, svc__coef0=0.8587971938450034, svc__degree=3, svc__gamma=0.01345197442275327, svc__kernel=rbf, svc__tol=0.05532670999192686; f1_macro: (test=0.486) f1_micro: (test=0.887) roc_auc: (test=0.813) total time=   1.1s
# [CV 4/5] END svc__C=0.21789021927224606, svc__coef0=0.8587971938450034, svc__degree=3, svc__gamma=0.01345197442275327, svc__kernel=rbf, svc__tol=0.05532670999192686; f1_macro: (test=0.481) f1_micro: (test=0.886) roc_auc: (test=0.812) total time=   1.1s
# [CV 5/5] END svc__C=0.21789021927224606, svc__coef0=0.8587971938450034, svc__degree=3, svc__gamma=0.01345197442275327, svc__kernel=rbf, svc__tol=0.05532670999192686; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.769) total time=   1.0s
# [CV 1/5] END svc__C=0.9082963973675794, svc__coef0=0.600518275557823, svc__degree=3, svc__gamma=6.038670878831571, svc__kernel=sigmoid, svc__tol=0.015553520030432408; f1_macro: (test=0.531) f1_micro: (test=0.813) roc_auc: (test=0.580) total time=   1.4s
# [CV 2/5] END svc__C=0.9082963973675794, svc__coef0=0.600518275557823, svc__degree=3, svc__gamma=6.038670878831571, svc__kernel=sigmoid, svc__tol=0.015553520030432408; f1_macro: (test=0.529) f1_micro: (test=0.804) roc_auc: (test=0.590) total time=   1.0s
# [CV 3/5] END svc__C=0.9082963973675794, svc__coef0=0.600518275557823, svc__degree=3, svc__gamma=6.038670878831571, svc__kernel=sigmoid, svc__tol=0.015553520030432408; f1_macro: (test=0.532) f1_micro: (test=0.801) roc_auc: (test=0.589) total time=   1.1s
# [CV 4/5] END svc__C=0.9082963973675794, svc__coef0=0.600518275557823, svc__degree=3, svc__gamma=6.038670878831571, svc__kernel=sigmoid, svc__tol=0.015553520030432408; f1_macro: (test=0.541) f1_micro: (test=0.809) roc_auc: (test=0.613) total time=   1.1s
# [CV 5/5] END svc__C=0.9082963973675794, svc__coef0=0.600518275557823, svc__degree=3, svc__gamma=6.038670878831571, svc__kernel=sigmoid, svc__tol=0.015553520030432408; f1_macro: (test=0.557) f1_micro: (test=0.822) roc_auc: (test=0.596) total time=   0.9s
# [CV 1/5] END svc__C=0.0010889557110635804, svc__coef0=0.19498122545732266, svc__degree=2, svc__gamma=0.0037105427965741546, svc__kernel=poly, svc__tol=1.833794272965047e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.790) total time=   0.9s
# [CV 2/5] END svc__C=0.0010889557110635804, svc__coef0=0.19498122545732266, svc__degree=2, svc__gamma=0.0037105427965741546, svc__kernel=poly, svc__tol=1.833794272965047e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.829) total time=   0.9s
# [CV 3/5] END svc__C=0.0010889557110635804, svc__coef0=0.19498122545732266, svc__degree=2, svc__gamma=0.0037105427965741546, svc__kernel=poly, svc__tol=1.833794272965047e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.807) total time=   0.8s
# [CV 4/5] END svc__C=0.0010889557110635804, svc__coef0=0.19498122545732266, svc__degree=2, svc__gamma=0.0037105427965741546, svc__kernel=poly, svc__tol=1.833794272965047e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.818) total time=   0.8s
# [CV 5/5] END svc__C=0.0010889557110635804, svc__coef0=0.19498122545732266, svc__degree=2, svc__gamma=0.0037105427965741546, svc__kernel=poly, svc__tol=1.833794272965047e-05; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.787) total time=   0.8s
# [CV 5/5] END svc__C=67.52524975922935, svc__coef0=0.22308384213593646, svc__degree=3, svc__gamma=2.753671760310971, svc__kernel=linear, svc__tol=0.0002045276115807183; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.755) total time=42.6min
# [CV 5/5] END svc__C=213.3159824802431, svc__coef0=0.18858420803313158, svc__degree=2, svc__gamma=3.778240684045574, svc__kernel=linear, svc__tol=0.0008741700930590696; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.755) total time=41.1min
# [CV 1/5] END svc__C=213.3159824802431, svc__coef0=0.18858420803313158, svc__degree=2, svc__gamma=3.778240684045574, svc__kernel=linear, svc__tol=0.0008741700930590696; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.767) total time=42.6min
# [CV 1/5] END svc__C=67.52524975922935, svc__coef0=0.22308384213593646, svc__degree=3, svc__gamma=2.753671760310971, svc__kernel=linear, svc__tol=0.0002045276115807183; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.766) total time=45.2min
# [CV 3/5] END svc__C=67.52524975922935, svc__coef0=0.22308384213593646, svc__degree=3, svc__gamma=2.753671760310971, svc__kernel=linear, svc__tol=0.0002045276115807183; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.786) total time=50.9min
# [CV 1/5] END svc__C=0.007043435259910956, svc__coef0=0.569004804913435, svc__degree=2, svc__gamma=0.010025823422809053, svc__kernel=linear, svc__tol=0.0017856333451726984; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.766) total time=   0.7s
# [CV 2/5] END svc__C=0.007043435259910956, svc__coef0=0.569004804913435, svc__degree=2, svc__gamma=0.010025823422809053, svc__kernel=linear, svc__tol=0.0017856333451726984; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.786) total time=   0.6s
# [CV 3/5] END svc__C=0.007043435259910956, svc__coef0=0.569004804913435, svc__degree=2, svc__gamma=0.010025823422809053, svc__kernel=linear, svc__tol=0.0017856333451726984; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.772) total time=   0.7s
# [CV 4/5] END svc__C=0.007043435259910956, svc__coef0=0.569004804913435, svc__degree=2, svc__gamma=0.010025823422809053, svc__kernel=linear, svc__tol=0.0017856333451726984; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.800) total time=   0.7s
# [CV 5/5] END svc__C=0.007043435259910956, svc__coef0=0.569004804913435, svc__degree=2, svc__gamma=0.010025823422809053, svc__kernel=linear, svc__tol=0.0017856333451726984; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.755) total time=   0.7s
# [CV 1/5] END svc__C=153.12798092367782, svc__coef0=0.40399022842041443, svc__degree=4, svc__gamma=0.00011983292508700941, svc__kernel=rbf, svc__tol=6.315981223602755e-05; f1_macro: (test=0.527) f1_micro: (test=0.891) roc_auc: (test=0.799) total time=   1.1s
# [CV 2/5] END svc__C=153.12798092367782, svc__coef0=0.40399022842041443, svc__degree=4, svc__gamma=0.00011983292508700941, svc__kernel=rbf, svc__tol=6.315981223602755e-05; f1_macro: (test=0.518) f1_micro: (test=0.892) roc_auc: (test=0.830) total time=   1.1s
# [CV 3/5] END svc__C=153.12798092367782, svc__coef0=0.40399022842041443, svc__degree=4, svc__gamma=0.00011983292508700941, svc__kernel=rbf, svc__tol=6.315981223602755e-05; f1_macro: (test=0.491) f1_micro: (test=0.887) roc_auc: (test=0.811) total time=   1.0s
# [CV 4/5] END svc__C=153.12798092367782, svc__coef0=0.40399022842041443, svc__degree=4, svc__gamma=0.00011983292508700941, svc__kernel=rbf, svc__tol=6.315981223602755e-05; f1_macro: (test=0.502) f1_micro: (test=0.889) roc_auc: (test=0.835) total time=   1.1s
# [CV 5/5] END svc__C=153.12798092367782, svc__coef0=0.40399022842041443, svc__degree=4, svc__gamma=0.00011983292508700941, svc__kernel=rbf, svc__tol=6.315981223602755e-05; f1_macro: (test=0.518) f1_micro: (test=0.891) roc_auc: (test=0.783) total time=   1.0s
# [CV 1/5] END svc__C=0.006236036992633183, svc__coef0=0.045363829954592316, svc__degree=4, svc__gamma=3.685654318322708, svc__kernel=linear, svc__tol=0.0002162832573267; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.765) total time=   0.7s
# [CV 2/5] END svc__C=0.006236036992633183, svc__coef0=0.045363829954592316, svc__degree=4, svc__gamma=3.685654318322708, svc__kernel=linear, svc__tol=0.0002162832573267; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.784) total time=   0.7s
# [CV 3/5] END svc__C=0.006236036992633183, svc__coef0=0.045363829954592316, svc__degree=4, svc__gamma=3.685654318322708, svc__kernel=linear, svc__tol=0.0002162832573267; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.777) total time=   0.7s
# [CV 4/5] END svc__C=0.006236036992633183, svc__coef0=0.045363829954592316, svc__degree=4, svc__gamma=3.685654318322708, svc__kernel=linear, svc__tol=0.0002162832573267; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.804) total time=   0.7s
# [CV 5/5] END svc__C=0.006236036992633183, svc__coef0=0.045363829954592316, svc__degree=4, svc__gamma=3.685654318322708, svc__kernel=linear, svc__tol=0.0002162832573267; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.755) total time=   0.7s
# [CV 1/5] END svc__C=0.10741530145587276, svc__coef0=0.11633567689691526, svc__degree=4, svc__gamma=4.064673969508571, svc__kernel=poly, svc__tol=0.004401531275244133; f1_macro: (test=0.600) f1_micro: (test=0.821) roc_auc: (test=0.626) total time=   1.0s
# [CV 2/5] END svc__C=0.10741530145587276, svc__coef0=0.11633567689691526, svc__degree=4, svc__gamma=4.064673969508571, svc__kernel=poly, svc__tol=0.004401531275244133; f1_macro: (test=0.620) f1_micro: (test=0.833) roc_auc: (test=0.633) total time=   1.0s
# [CV 3/5] END svc__C=0.10741530145587276, svc__coef0=0.11633567689691526, svc__degree=4, svc__gamma=4.064673969508571, svc__kernel=poly, svc__tol=0.004401531275244133; f1_macro: (test=0.623) f1_micro: (test=0.840) roc_auc: (test=0.619) total time=   1.2s
# [CV 4/5] END svc__C=0.10741530145587276, svc__coef0=0.11633567689691526, svc__degree=4, svc__gamma=4.064673969508571, svc__kernel=poly, svc__tol=0.004401531275244133; f1_macro: (test=0.608) f1_micro: (test=0.831) roc_auc: (test=0.641) total time=   1.2s
# [CV 5/5] END svc__C=0.10741530145587276, svc__coef0=0.11633567689691526, svc__degree=4, svc__gamma=4.064673969508571, svc__kernel=poly, svc__tol=0.004401531275244133; f1_macro: (test=0.605) f1_micro: (test=0.838) roc_auc: (test=0.635) total time=   1.2s
# [CV 1/5] END svc__C=0.05067930446910878, svc__coef0=0.8387800495307534, svc__degree=2, svc__gamma=0.0002825967157342051, svc__kernel=linear, svc__tol=0.07016287959776007; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.765) total time=   0.9s
# [CV 2/5] END svc__C=0.05067930446910878, svc__coef0=0.8387800495307534, svc__degree=2, svc__gamma=0.0002825967157342051, svc__kernel=linear, svc__tol=0.07016287959776007; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.794) total time=   0.7s
# [CV 3/5] END svc__C=0.05067930446910878, svc__coef0=0.8387800495307534, svc__degree=2, svc__gamma=0.0002825967157342051, svc__kernel=linear, svc__tol=0.07016287959776007; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.783) total time=   0.7s
# [CV 4/5] END svc__C=0.05067930446910878, svc__coef0=0.8387800495307534, svc__degree=2, svc__gamma=0.0002825967157342051, svc__kernel=linear, svc__tol=0.07016287959776007; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.794) total time=   0.7s
# [CV 5/5] END svc__C=0.05067930446910878, svc__coef0=0.8387800495307534, svc__degree=2, svc__gamma=0.0002825967157342051, svc__kernel=linear, svc__tol=0.07016287959776007; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=   0.8s
# [CV 1/5] END svc__C=0.0010309332833625233, svc__coef0=0.8311018280041693, svc__degree=3, svc__gamma=0.0004572762640383561, svc__kernel=poly, svc__tol=0.007477647113348422; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.676) total time=   0.6s
# [CV 2/5] END svc__C=0.0010309332833625233, svc__coef0=0.8311018280041693, svc__degree=3, svc__gamma=0.0004572762640383561, svc__kernel=poly, svc__tol=0.007477647113348422; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.709) total time=   0.6s
# [CV 3/5] END svc__C=0.0010309332833625233, svc__coef0=0.8311018280041693, svc__degree=3, svc__gamma=0.0004572762640383561, svc__kernel=poly, svc__tol=0.007477647113348422; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.704) total time=   0.6s
# [CV 4/5] END svc__C=0.0010309332833625233, svc__coef0=0.8311018280041693, svc__degree=3, svc__gamma=0.0004572762640383561, svc__kernel=poly, svc__tol=0.007477647113348422; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.699) total time=   0.6s
# [CV 5/5] END svc__C=0.0010309332833625233, svc__coef0=0.8311018280041693, svc__degree=3, svc__gamma=0.0004572762640383561, svc__kernel=poly, svc__tol=0.007477647113348422; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.681) total time=   0.6s
# [CV 3/5] END svc__C=213.3159824802431, svc__coef0=0.18858420803313158, svc__degree=2, svc__gamma=3.778240684045574, svc__kernel=linear, svc__tol=0.0008741700930590696; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.787) total time=53.0min
# ...
# [CV 4/5] END svc__C=213.3159824802431, svc__coef0=0.18858420803313158, svc__degree=2, svc__gamma=3.778240684045574, svc__kernel=linear, svc__tol=0.0008741700930590696; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.799) total time=56.8min
# [CV 5/5] END svc__C=375.20591009454404, svc__coef0=0.26988141269516275, svc__degree=4, svc__gamma=0.2986829052620763, svc__kernel=linear, svc__tol=0.0006263256026824329; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=53.9min
# [CV 1/5] END svc__C=1.2486464520901221, svc__coef0=0.8494364888772069, svc__degree=4, svc__gamma=1.6062080604824862, svc__kernel=poly, svc__tol=6.641532049038913e-05; f1_macro: (test=0.597) f1_micro: (test=0.820) roc_auc: (test=0.630) total time=   1.2s
# [CV 2/5] END svc__C=1.2486464520901221, svc__coef0=0.8494364888772069, svc__degree=4, svc__gamma=1.6062080604824862, svc__kernel=poly, svc__tol=6.641532049038913e-05; f1_macro: (test=0.607) f1_micro: (test=0.828) roc_auc: (test=0.631) total time=   1.2s
# [CV 3/5] END svc__C=1.2486464520901221, svc__coef0=0.8494364888772069, svc__degree=4, svc__gamma=1.6062080604824862, svc__kernel=poly, svc__tol=6.641532049038913e-05; f1_macro: (test=0.619) f1_micro: (test=0.838) roc_auc: (test=0.627) total time=   1.1s
# [CV 4/5] END svc__C=1.2486464520901221, svc__coef0=0.8494364888772069, svc__degree=4, svc__gamma=1.6062080604824862, svc__kernel=poly, svc__tol=6.641532049038913e-05; f1_macro: (test=0.611) f1_micro: (test=0.830) roc_auc: (test=0.642) total time=   1.3s
# [CV 5/5] END svc__C=1.2486464520901221, svc__coef0=0.8494364888772069, svc__degree=4, svc__gamma=1.6062080604824862, svc__kernel=poly, svc__tol=6.641532049038913e-05; f1_macro: (test=0.606) f1_micro: (test=0.836) roc_auc: (test=0.641) total time=   1.1s
# [CV 1/5] END svc__C=167.31997664140698, svc__coef0=0.6940339916443199, svc__degree=2, svc__gamma=0.050791441096756436, svc__kernel=sigmoid, svc__tol=0.022758259176240688; f1_macro: (test=0.570) f1_micro: (test=0.832) roc_auc: (test=0.648) total time=   0.9s
# [CV 2/5] END svc__C=167.31997664140698, svc__coef0=0.6940339916443199, svc__degree=2, svc__gamma=0.050791441096756436, svc__kernel=sigmoid, svc__tol=0.022758259176240688; f1_macro: (test=0.577) f1_micro: (test=0.829) roc_auc: (test=0.653) total time=   0.9s
# [CV 3/5] END svc__C=167.31997664140698, svc__coef0=0.6940339916443199, svc__degree=2, svc__gamma=0.050791441096756436, svc__kernel=sigmoid, svc__tol=0.022758259176240688; f1_macro: (test=0.547) f1_micro: (test=0.820) roc_auc: (test=0.669) total time=   1.0s
# [CV 4/5] END svc__C=167.31997664140698, svc__coef0=0.6940339916443199, svc__degree=2, svc__gamma=0.050791441096756436, svc__kernel=sigmoid, svc__tol=0.022758259176240688; f1_macro: (test=0.502) f1_micro: (test=0.801) roc_auc: (test=0.487) total time=   1.2s
# [CV 5/5] END svc__C=167.31997664140698, svc__coef0=0.6940339916443199, svc__degree=2, svc__gamma=0.050791441096756436, svc__kernel=sigmoid, svc__tol=0.022758259176240688; f1_macro: (test=0.568) f1_micro: (test=0.819) roc_auc: (test=0.644) total time=   1.0s
# [CV 1/5] END svc__C=0.0015947545012957075, svc__coef0=0.6126150992442608, svc__degree=3, svc__gamma=0.7042452787554013, svc__kernel=poly, svc__tol=0.008161039236557997; f1_macro: (test=0.609) f1_micro: (test=0.858) roc_auc: (test=0.747) total time=   1.5s
# [CV 2/5] END svc__C=0.0015947545012957075, svc__coef0=0.6126150992442608, svc__degree=3, svc__gamma=0.7042452787554013, svc__kernel=poly, svc__tol=0.008161039236557997; f1_macro: (test=0.637) f1_micro: (test=0.861) roc_auc: (test=0.701) total time=   1.6s
# [CV 3/5] END svc__C=0.0015947545012957075, svc__coef0=0.6126150992442608, svc__degree=3, svc__gamma=0.7042452787554013, svc__kernel=poly, svc__tol=0.008161039236557997; f1_macro: (test=0.670) f1_micro: (test=0.880) roc_auc: (test=0.701) total time=   1.6s
# [CV 1/5] END svc__C=560.4138413875675, svc__coef0=0.7591504901990411, svc__degree=4, svc__gamma=0.014341380993211394, svc__kernel=linear, svc__tol=0.04039780635971312; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.767) total time= 8.7min
# [CV 4/5] END svc__C=0.0015947545012957075, svc__coef0=0.6126150992442608, svc__degree=3, svc__gamma=0.7042452787554013, svc__kernel=poly, svc__tol=0.008161039236557997; f1_macro: (test=0.640) f1_micro: (test=0.871) roc_auc: (test=0.694) total time=   1.6s
# [CV 5/5] END svc__C=0.0015947545012957075, svc__coef0=0.6126150992442608, svc__degree=3, svc__gamma=0.7042452787554013, svc__kernel=poly, svc__tol=0.008161039236557997; f1_macro: (test=0.635) f1_micro: (test=0.865) roc_auc: (test=0.708) total time=   1.5s
# [CV 4/5] END svc__C=67.52524975922935, svc__coef0=0.22308384213593646, svc__degree=3, svc__gamma=2.753671760310971, svc__kernel=linear, svc__tol=0.0002045276115807183; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.802) total time=60.3min
# [CV 2/5] END svc__C=0.008033857177163609, svc__coef0=0.8399518401615831, svc__degree=2, svc__gamma=4.091867019600527, svc__kernel=poly, svc__tol=0.0002759385050586905; f1_macro: (test=0.652) f1_micro: (test=0.879) roc_auc: (test=0.723) total time=  16.5s
# [CV 1/5] END svc__C=0.008033857177163609, svc__coef0=0.8399518401615831, svc__degree=2, svc__gamma=4.091867019600527, svc__kernel=poly, svc__tol=0.0002759385050586905; f1_macro: (test=0.628) f1_micro: (test=0.875) roc_auc: (test=0.746) total time=  21.3s
# [CV 4/5] END svc__C=0.008033857177163609, svc__coef0=0.8399518401615831, svc__degree=2, svc__gamma=4.091867019600527, svc__kernel=poly, svc__tol=0.0002759385050586905; f1_macro: (test=0.653) f1_micro: (test=0.878) roc_auc: (test=0.743) total time=  14.2s
# [CV 1/5] END svc__C=0.24414789149850372, svc__coef0=0.9902168554955388, svc__degree=2, svc__gamma=0.0001697135579268079, svc__kernel=poly, svc__tol=0.011955752021522183; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.737) total time=   0.7s
# [CV 2/5] END svc__C=0.24414789149850372, svc__coef0=0.9902168554955388, svc__degree=2, svc__gamma=0.0001697135579268079, svc__kernel=poly, svc__tol=0.011955752021522183; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.745) total time=   0.6s
# [CV 3/5] END svc__C=0.24414789149850372, svc__coef0=0.9902168554955388, svc__degree=2, svc__gamma=0.0001697135579268079, svc__kernel=poly, svc__tol=0.011955752021522183; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.762) total time=   0.6s
# [CV 3/5] END svc__C=0.008033857177163609, svc__coef0=0.8399518401615831, svc__degree=2, svc__gamma=4.091867019600527, svc__kernel=poly, svc__tol=0.0002759385050586905; f1_macro: (test=0.667) f1_micro: (test=0.884) roc_auc: (test=0.727) total time=  21.0s
# [CV 4/5] END svc__C=0.24414789149850372, svc__coef0=0.9902168554955388, svc__degree=2, svc__gamma=0.0001697135579268079, svc__kernel=poly, svc__tol=0.011955752021522183; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.738) total time=   0.6s
# [CV 5/5] END svc__C=0.24414789149850372, svc__coef0=0.9902168554955388, svc__degree=2, svc__gamma=0.0001697135579268079, svc__kernel=poly, svc__tol=0.011955752021522183; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.727) total time=   0.8s
# [CV 5/5] END svc__C=0.008033857177163609, svc__coef0=0.8399518401615831, svc__degree=2, svc__gamma=4.091867019600527, svc__kernel=poly, svc__tol=0.0002759385050586905; f1_macro: (test=0.639) f1_micro: (test=0.873) roc_auc: (test=0.731) total time=  18.9s
# [CV 1/5] END svc__C=0.4707851369073623, svc__coef0=0.556270204982893, svc__degree=2, svc__gamma=1.3291711395045407, svc__kernel=poly, svc__tol=0.018693920287648078; f1_macro: (test=0.608) f1_micro: (test=0.859) roc_auc: (test=0.735) total time=  23.0s
# [CV 2/5] END svc__C=0.4707851369073623, svc__coef0=0.556270204982893, svc__degree=2, svc__gamma=1.3291711395045407, svc__kernel=poly, svc__tol=0.018693920287648078; f1_macro: (test=0.640) f1_micro: (test=0.863) roc_auc: (test=0.708) total time=  26.4s
# [CV 3/5] END svc__C=0.4707851369073623, svc__coef0=0.556270204982893, svc__degree=2, svc__gamma=1.3291711395045407, svc__kernel=poly, svc__tol=0.018693920287648078; f1_macro: (test=0.667) f1_micro: (test=0.875) roc_auc: (test=0.717) total time=  27.5s
# [CV 1/5] END svc__C=0.43027771176680957, svc__coef0=0.3419766060842667, svc__degree=3, svc__gamma=0.5725363000764886, svc__kernel=sigmoid, svc__tol=0.000801610895159665; f1_macro: (test=0.531) f1_micro: (test=0.820) roc_auc: (test=0.546) total time=   1.4s
# [CV 2/5] END svc__C=0.43027771176680957, svc__coef0=0.3419766060842667, svc__degree=3, svc__gamma=0.5725363000764886, svc__kernel=sigmoid, svc__tol=0.000801610895159665; f1_macro: (test=0.519) f1_micro: (test=0.805) roc_auc: (test=0.559) total time=   1.6s
# [CV 3/5] END svc__C=0.43027771176680957, svc__coef0=0.3419766060842667, svc__degree=3, svc__gamma=0.5725363000764886, svc__kernel=sigmoid, svc__tol=0.000801610895159665; f1_macro: (test=0.552) f1_micro: (test=0.815) roc_auc: (test=0.563) total time=   1.3s
# [CV 4/5] END svc__C=0.43027771176680957, svc__coef0=0.3419766060842667, svc__degree=3, svc__gamma=0.5725363000764886, svc__kernel=sigmoid, svc__tol=0.000801610895159665; f1_macro: (test=0.545) f1_micro: (test=0.817) roc_auc: (test=0.564) total time=   1.2s
# [CV 5/5] END svc__C=0.43027771176680957, svc__coef0=0.3419766060842667, svc__degree=3, svc__gamma=0.5725363000764886, svc__kernel=sigmoid, svc__tol=0.000801610895159665; f1_macro: (test=0.555) f1_micro: (test=0.825) roc_auc: (test=0.600) total time=   1.2s
# [CV 4/5] END svc__C=0.4707851369073623, svc__coef0=0.556270204982893, svc__degree=2, svc__gamma=1.3291711395045407, svc__kernel=poly, svc__tol=0.018693920287648078; f1_macro: (test=0.645) f1_micro: (test=0.869) roc_auc: (test=0.720) total time=  28.6s
# [CV 5/5] END svc__C=0.4707851369073623, svc__coef0=0.556270204982893, svc__degree=2, svc__gamma=1.3291711395045407, svc__kernel=poly, svc__tol=0.018693920287648078; f1_macro: (test=0.620) f1_micro: (test=0.858) roc_auc: (test=0.733) total time=  24.9s
# [CV 2/5] END svc__C=213.3159824802431, svc__coef0=0.18858420803313158, svc__degree=2, svc__gamma=3.778240684045574, svc__kernel=linear, svc__tol=0.0008741700930590696; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.800) total time=59.9min
# [CV 2/5] END svc__C=67.52524975922935, svc__coef0=0.22308384213593646, svc__degree=3, svc__gamma=2.753671760310971, svc__kernel=linear, svc__tol=0.0002045276115807183; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.799) total time=63.0min
# [CV 2/5] END svc__C=560.4138413875675, svc__coef0=0.7591504901990411, svc__degree=4, svc__gamma=0.014341380993211394, svc__kernel=linear, svc__tol=0.04039780635971312; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.790) total time= 9.9min
# [CV 1/5] END svc__C=0.0064704217603438, svc__coef0=0.6096971800763078, svc__degree=3, svc__gamma=0.2621910160033984, svc__kernel=linear, svc__tol=0.019448523173610153; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.765) total time=   0.7s
# [CV 2/5] END svc__C=0.0064704217603438, svc__coef0=0.6096971800763078, svc__degree=3, svc__gamma=0.2621910160033984, svc__kernel=linear, svc__tol=0.019448523173610153; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.777) total time=   0.7s
# [CV 3/5] END svc__C=0.0064704217603438, svc__coef0=0.6096971800763078, svc__degree=3, svc__gamma=0.2621910160033984, svc__kernel=linear, svc__tol=0.019448523173610153; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.786) total time=   0.7s
# [CV 4/5] END svc__C=0.0064704217603438, svc__coef0=0.6096971800763078, svc__degree=3, svc__gamma=0.2621910160033984, svc__kernel=linear, svc__tol=0.019448523173610153; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.800) total time=   0.7s
# [CV 5/5] END svc__C=0.0064704217603438, svc__coef0=0.6096971800763078, svc__degree=3, svc__gamma=0.2621910160033984, svc__kernel=linear, svc__tol=0.019448523173610153; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.759) total time=   0.7s
# [CV 3/5] END svc__C=560.4138413875675, svc__coef0=0.7591504901990411, svc__degree=4, svc__gamma=0.014341380993211394, svc__kernel=linear, svc__tol=0.04039780635971312; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.793) total time=10.0min
# [CV 5/5] END svc__C=560.4138413875675, svc__coef0=0.7591504901990411, svc__degree=4, svc__gamma=0.014341380993211394, svc__kernel=linear, svc__tol=0.04039780635971312; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.754) total time= 8.3min
# [CV 4/5] END svc__C=560.4138413875675, svc__coef0=0.7591504901990411, svc__degree=4, svc__gamma=0.014341380993211394, svc__kernel=linear, svc__tol=0.04039780635971312; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.801) total time= 9.6min
# [CV 4/5] END svc__C=375.20591009454404, svc__coef0=0.26988141269516275, svc__degree=4, svc__gamma=0.2986829052620763, svc__kernel=linear, svc__tol=0.0006263256026824329; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.798) total time=62.8min
# [CV 2/5] END svc__C=375.20591009454404, svc__coef0=0.26988141269516275, svc__degree=4, svc__gamma=0.2986829052620763, svc__kernel=linear, svc__tol=0.0006263256026824329; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.802) total time=65.7min
# [CV 3/5] END svc__C=375.20591009454404, svc__coef0=0.26988141269516275, svc__degree=4, svc__gamma=0.2986829052620763, svc__kernel=linear, svc__tol=0.0006263256026824329; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.785) total time=69.1min
# [CV 5/5] END svc__C=207.04276121483977, svc__coef0=0.5752378217995836, svc__degree=2, svc__gamma=2.463733728585466, svc__kernel=linear, svc__tol=0.0002900318495535678; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=39.8min
# [CV 1/5] END svc__C=95.42925903555745, svc__coef0=0.2662103137941727, svc__degree=2, svc__gamma=0.0007058061861697108, svc__kernel=linear, svc__tol=0.00022008715523305148; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.766) total time=29.7min
# [CV 3/5] END svc__C=207.04276121483977, svc__coef0=0.5752378217995836, svc__degree=2, svc__gamma=2.463733728585466, svc__kernel=linear, svc__tol=0.0002900318495535678; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.787) total time=48.9min
# [CV 4/5] END svc__C=207.04276121483977, svc__coef0=0.5752378217995836, svc__degree=2, svc__gamma=2.463733728585466, svc__kernel=linear, svc__tol=0.0002900318495535678; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.799) total time=48.6min
# [CV 5/5] END svc__C=95.42925903555745, svc__coef0=0.2662103137941727, svc__degree=2, svc__gamma=0.0007058061861697108, svc__kernel=linear, svc__tol=0.00022008715523305148; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=32.0min
# [CV 2/5] END svc__C=207.04276121483977, svc__coef0=0.5752378217995836, svc__degree=2, svc__gamma=2.463733728585466, svc__kernel=linear, svc__tol=0.0002900318495535678; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.804) total time=52.5min
# [CV 3/5] END svc__C=95.42925903555745, svc__coef0=0.2662103137941727, svc__degree=2, svc__gamma=0.0007058061861697108, svc__kernel=linear, svc__tol=0.00022008715523305148; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.787) total time=36.5min
# [CV 2/5] END svc__C=95.42925903555745, svc__coef0=0.2662103137941727, svc__degree=2, svc__gamma=0.0007058061861697108, svc__kernel=linear, svc__tol=0.00022008715523305148; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.800) total time=37.3min
# [CV 4/5] END svc__C=95.42925903555745, svc__coef0=0.2662103137941727, svc__degree=2, svc__gamma=0.0007058061861697108, svc__kernel=linear, svc__tol=0.00022008715523305148; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.798) total time=39.3min

# %% [markdown]
# With 10 hyperparameter combinations, it takes more than 30 minutes. With 50, it takes approximately 1h and 30 mins.

# %%
# Load saved pickle
with open('hyperparameter_tuning/svc/svc_noresampling_10comb.pkl', 'rb') as f:
    loaded = pickle.load(f)
    best_params_svc, best_scores_svc = loaded

print('Best parameters of SVC:', best_params_svc, '\n')

print('Best scores of SVC:', best_scores_svc, '\n')
# Out:
# Best parameters of SVC: {'svc__C': 28.536277882830053, 'svc__coef0': 0.5704173584583558, 'svc__degree': 4, 'svc__gamma': 0.001195545404013359, 'svc__kernel': 'rbf', 'svc__tol': 0.0040707502841458585}
#
# Best scores of SVC: {'f1_micro': 0.896875, 'f1_macro': 0.573116856686093, 'roc_auc': 0.8209834794050668}

# %%
# Load saved pickle
with open('hyperparameter_tuning/svc/svc_noresampling_50comb.pkl', 'rb') as f:
    loaded = pickle.load(f)
    best_params_svc, best_scores_svc = loaded

print('Best parameters of SVC:', best_params_svc, '\n')

print('Best scores of SVC:', best_scores_svc, '\n')
# Out:
# Best parameters of SVC: {'svc__C': 28.536277882830053, 'svc__coef0': 0.5704173584583558, 'svc__degree': 4, 'svc__gamma': 0.001195545404013359, 'svc__kernel': 'rbf', 'svc__tol': 0.0040707502841458585}
#
# Best scores of SVC: {'f1_micro': 0.896875, 'f1_macro': 0.573116856686093, 'roc_auc': 0.8209834794050668}

# %% [markdown]
# ## Random Forest

# %% [markdown]
# #### A. No resampling (without considering class imbalance)

# %%
best_params_rf, best_scores_rf = baseline_models(
        df=dfv3, numerical_features=numerical_features, categorical_features=categorical_features,
        target='HOSPITAL_EXPIRE_FLAG', model=RandomForestClassifier, ada_boost = False, 
        n_hyper_comb = 60, num_imputer = "median", refit_score = 'roc_auc', resampling_method = 'none'
)

# Combine dictionaries into a list
combined_rf = [best_params_rf, best_scores_rf]

# Save into a pickle (name of file states model, if resampling technique was
# applied and the number of hyperparameter combinations tried)
with open('hyperparameter_tuning/random_forest/rf_noresampling_60comb.pkl', 'wb') as f:
    pickle.dump(combined_rf, f)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV 4/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.750) total time=  10.8s
# [CV 4/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.727) total time=  12.1s
# [CV 5/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.705) total time=  12.2s
# [CV 5/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.717) total time=  12.1s
# [CV 3/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.740) total time=  12.3s
# [CV 2/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.684) total time=  12.5s
# [CV 3/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.753) total time=  12.5s
# [CV 2/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.724) total time=  12.8s
# [CV 1/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.706) total time=  13.1s
# [CV 1/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.743) total time=  13.5s
# [CV 3/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.817) total time=  13.8s
# [CV 4/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.806) total time=  14.1s
# [CV 5/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.759) total time=  14.5s
# [CV 1/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=  14.8s
# [CV 1/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.783) total time=  16.0s
# [CV 2/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.810) total time=  16.2s
# [CV 4/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.784) total time=   6.9s
# [CV 3/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.768) total time=  10.9s
# [CV 3/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.780) total time=   8.7s
# [CV 2/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.745) total time=  12.7s
# [CV 4/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.772) total time=  11.4s
# [CV 5/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.719) total time=   8.4s
# [CV 5/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.728) total time=  11.6s
# [CV 2/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.768) total time=  10.3s
# [CV 3/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.764) total time=  12.3s
# [CV 1/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.716) total time=  11.1s
# [CV 1/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.757) total time=  13.2s
# [CV 5/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.729) total time=  12.7s
# [CV 4/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.770) total time=  13.1s
# [CV 2/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.740) total time=  15.2s
# [CV 4/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.741) total time=   9.2s
# [CV 5/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.713) total time=   9.3s
# [CV 3/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=  10.4s
# [CV 2/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.704) total time=  11.4s
# [CV 2/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.769) total time=  19.0s
# [CV 1/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.751) total time=  19.4s
# [CV 1/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.709) total time=  12.2s
# [CV 4/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.795) total time=  13.3s
# [CV 3/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.780) total time=  14.8s
# [CV 3/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.814) total time=  11.3s
# [CV 2/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.805) total time=  12.5s
# [CV 4/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.816) total time=  11.7s
# [CV 1/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.691) total time=   9.9s
# [CV 1/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.776) total time=  13.0s
# [CV 5/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.743) total time=  14.9s
# [CV 5/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.757) total time=  12.6s
# [CV 3/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.736) total time=   7.3s
# [CV 4/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.750) total time=   6.6s
# [CV 5/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.706) total time=   7.5s
# [CV 2/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.706) total time=   9.4s
# [CV 3/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.729) total time=   7.2s
# [CV 4/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.737) total time=   6.9s[CV 3/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.740) total time=   5.7s
#
# [CV 4/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.739) total time=   5.7s
# [CV 2/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.684) total time=   8.1s
# [CV 5/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.703) total time=   7.1s
# [CV 1/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.697) total time=   8.5s
# [CV 5/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.706) total time=   6.0s
# [CV 1/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.759) total time=   7.0s
# [CV 1/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.701) total time=   8.3s
# [CV 2/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.692) total time=   8.0s
# [CV 2/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.806) total time=   7.6s
# [CV 3/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.817) total time=   6.1s
# [CV 4/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.820) total time=   6.1s
# [CV 5/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.755) total time=   7.6s
# [CV 2/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.764) total time=   7.7s
# [CV 5/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.724) total time=   7.4s
# [CV 3/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.780) total time=   8.1s
# [CV 4/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.784) total time=   8.1s
# [CV 1/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.729) total time=   9.2s
# [CV 3/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.761) total time=   9.0s
# [CV 4/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.763) total time=   9.4s
# [CV 1/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.747) total time=  10.9s
# [CV 5/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.725) total time=   9.8s
# [CV 2/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.738) total time=  11.4s
# [CV 2/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.796) total time=  19.8s
# [CV 4/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.800) total time=  18.3s
# [CV 1/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.772) total time=  21.1s
# [CV 5/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.751) total time=  19.3s
# [CV 4/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.774) total time=  15.6s
# [CV 3/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.768) total time=  16.5s
# [CV 3/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.802) total time=  21.0s
# [CV 2/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.746) total time=  17.0s
# [CV 3/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.790) total time=  14.2s
# [CV 5/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.731) total time=  16.2s
# [CV 2/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.775) total time=  15.4s
# [CV 4/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.798) total time=  13.9s
# [CV 1/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.755) total time=  18.5s
# [CV 1/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.714) total time=  13.8s
# [CV 1/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=  17.3s
# [CV 5/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.746) total time=  15.3s
# [CV 3/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.769) total time=   7.2s
# [CV 4/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.773) total time=   7.7s
# [CV 5/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.715) total time=   9.0s
# [CV 2/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.747) total time=  10.4s
# [CV 3/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.774) total time=  10.9s
# [CV 1/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.738) total time=  15.1s
# [CV 4/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.780) total time=  10.3s
# [CV 3/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.785) total time=  18.7s
# [CV 2/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.757) total time=  16.2s
# [CV 5/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.745) total time=  19.0s
# [CV 5/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.726) total time=  11.5s
# [CV 2/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.775) total time=  20.3s
# [CV 4/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.804) total time=  20.0s
# [CV 4/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.807) total time=  20.0s
# [CV 1/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.752) total time=  21.8s
# [CV 2/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.787) total time=  21.0s
# [CV 5/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.748) total time=  21.9s
# [CV 3/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.799) total time=  24.6s
# [CV 1/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.703) total time=  17.3s
# [CV 1/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.762) total time=  25.5s
# [CV 3/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.740) total time=   9.3s
# [CV 5/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.707) total time=  10.3s
# [CV 4/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.736) total time=  12.7s
# [CV 2/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.690) total time=  15.0s
# [CV 3/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.751) total time=   8.9s
# [CV 3/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.764) total time=  15.9s
# [CV 3/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.786) total time=  14.1s
# [CV 2/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.745) total time=  17.0s
# [CV 4/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.772) total time=  16.2s
# [CV 1/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.685) total time=  10.9s
# [CV 2/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.727) total time=  10.9s
# [CV 5/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.730) total time=  16.7s
# [CV 1/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.756) total time=  18.2s
# [CV 5/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.702) total time=   7.6s
# [CV 4/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.757) total time=   9.0s
# [CV 2/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.770) total time=  16.8s
# [CV 5/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.745) total time=  12.8s
# [CV 4/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.797) total time=  15.0s
# [CV 1/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.750) total time=  19.3s
# [CV 2/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.727) total time=   6.9s
# [CV 1/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.701) total time=  11.2s
# [CV 5/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.710) total time=   7.4s
# [CV 3/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.756) total time=   8.5s
# [CV 4/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.757) total time=   8.3s
# [CV 4/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.739) total time=   7.6s
# [CV 3/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.731) total time=   8.0s
# [CV 5/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.703) total time=   8.6s
# [CV 1/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.695) total time=   9.8s
# [CV 2/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.688) total time=  10.2s
# [CV 3/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.776) total time=   9.4s
# [CV 4/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.780) total time=   9.8s
# [CV 1/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.756) total time=  11.6s
# [CV 2/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.758) total time=  11.5s
# [CV 5/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.733) total time=  11.3s
# [CV 3/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.753) total time=   8.2s
# [CV 1/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.746) total time=  13.2s
# [CV 3/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.742) total time=  11.8s
# [CV 5/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.712) total time=   8.9s
# [CV 5/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.718) total time=  10.9s
# [CV 2/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.716) total time=  12.9s
# [CV 4/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.742) total time=  11.5s
# [CV 2/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.700) total time=  10.8s
# [CV 4/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.738) total time=   9.6s
# [CV 1/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.709) total time=  11.5s
# [CV 2/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.752) total time=   8.8s
# [CV 1/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.732) total time=  10.2s
# [CV 3/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.771) total time=   8.7s
# [CV 4/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.777) total time=   8.5s
# [CV 5/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.725) total time=   8.5s
# [CV 1/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.748) total time=  12.4s
# [CV 3/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=  10.8s
# [CV 4/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.757) total time=  10.7s
# [CV 5/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.725) total time=  10.2s
# [CV 2/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.730) total time=  12.9s
# [CV 4/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.736) total time=   9.9s[CV 5/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.707) total time=   9.2s
#
# [CV 3/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.770) total time=  11.7s
# [CV 3/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.741) total time=  10.2s
# [CV 5/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.729) total time=  11.8s
# [CV 1/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.704) total time=  11.5s
# [CV 1/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=  12.5s
# [CV 2/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.748) total time=  13.1s
# [CV 4/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.774) total time=  13.1s
# [CV 1/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.721) total time=  10.6s
# [CV 2/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.692) total time=  12.1s
# [CV 4/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.768) total time=   6.1s
# [CV 5/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.716) total time=   6.4s
# [CV 2/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.738) total time=   9.5s
# [CV 3/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.764) total time=   8.0s
# [CV 5/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.716) total time=   4.3s
# [CV 4/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.788) total time=   4.6s
# [CV 3/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.783) total time=   5.5s
# [CV 1/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.713) total time=   6.0s
# [CV 2/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.777) total time=   7.6s
# [CV 3/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.746) total time=  10.1s
# [CV 1/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.731) total time=  11.4s
# [CV 4/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.735) total time=  10.5s
# ...
# [CV 1/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.755) total time=  15.4s
# [CV 2/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.734) total time=  15.5s
# [CV 1/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.697) total time=  14.4s
# [CV 4/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.733) total time=  10.0s
# [CV 3/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.724) total time=  10.3s
# [CV 5/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.703) total time=  10.9s
# [CV 2/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.676) total time=  14.1s
# [CV 4/5] END rfc__max_depth=91, rfc__max_features=3, rfc__max_leaf_nodes=3763, rfc__min_samples_leaf=0.04190784656661256, rfc__min_samples_split=0.17424766854342705; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.818) total time=  10.7s
# [CV 1/5] END rfc__max_depth=91, rfc__max_features=3, rfc__max_leaf_nodes=3763, rfc__min_samples_leaf=0.04190784656661256, rfc__min_samples_split=0.17424766854342705; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.758) total time=  12.6s
# [CV 3/5] END rfc__max_depth=91, rfc__max_features=3, rfc__max_leaf_nodes=3763, rfc__min_samples_leaf=0.04190784656661256, rfc__min_samples_split=0.17424766854342705; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.820) total time=  11.9s
# [CV 5/5] END rfc__max_depth=91, rfc__max_features=3, rfc__max_leaf_nodes=3763, rfc__min_samples_leaf=0.04190784656661256, rfc__min_samples_split=0.17424766854342705; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.753) total time=  12.5s
# [CV 2/5] END rfc__max_depth=91, rfc__max_features=3, rfc__max_leaf_nodes=3763, rfc__min_samples_leaf=0.04190784656661256, rfc__min_samples_split=0.17424766854342705; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.810) total time=  15.0s
# [CV 4/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.507) f1_micro: (test=0.889) roc_auc: (test=0.803) total time=  25.0s
# [CV 3/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.491) f1_micro: (test=0.887) roc_auc: (test=0.817) total time=  27.2s
# [CV 5/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.492) f1_micro: (test=0.888) roc_auc: (test=0.761) total time=  27.0s
# [CV 2/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.502) f1_micro: (test=0.889) roc_auc: (test=0.803) total time=  28.5s
# [CV 4/5] END rfc__max_depth=104, rfc__max_features=23, rfc__max_leaf_nodes=2486, rfc__min_samples_leaf=0.047848408937553426, rfc__min_samples_split=0.12104721470289241; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.811) total time=  18.3s
# [CV 1/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.502) f1_micro: (test=0.889) roc_auc: (test=0.782) total time=  32.0s
# [CV 3/5] END rfc__max_depth=104, rfc__max_features=23, rfc__max_leaf_nodes=2486, rfc__min_samples_leaf=0.047848408937553426, rfc__min_samples_split=0.12104721470289241; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.797) total time=  19.6s
# [CV 1/5] END rfc__max_depth=104, rfc__max_features=23, rfc__max_leaf_nodes=2486, rfc__min_samples_leaf=0.047848408937553426, rfc__min_samples_split=0.12104721470289241; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.763) total time=  21.3s
# [CV 1/5] END rfc__max_depth=38, rfc__max_features=33, rfc__max_leaf_nodes=4198, rfc__min_samples_leaf=0.0077226789154901075, rfc__min_samples_split=0.12291040474960792; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.782) total time=  30.9s
# [CV 1/5] END rfc__max_depth=46, rfc__max_features=29, rfc__max_leaf_nodes=183, rfc__min_samples_leaf=0.07882957394198264, rfc__min_samples_split=0.07268041227841043; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.757) total time=  20.0s
# [CV 2/5] END rfc__max_depth=38, rfc__max_features=33, rfc__max_leaf_nodes=4198, rfc__min_samples_leaf=0.0077226789154901075, rfc__min_samples_split=0.12291040474960792; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.807) total time=  32.6s
# [CV 2/5] END rfc__max_depth=104, rfc__max_features=23, rfc__max_leaf_nodes=2486, rfc__min_samples_leaf=0.047848408937553426, rfc__min_samples_split=0.12104721470289241; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.787) total time=  24.1s
# [CV 5/5] END rfc__max_depth=104, rfc__max_features=23, rfc__max_leaf_nodes=2486, rfc__min_samples_leaf=0.047848408937553426, rfc__min_samples_split=0.12104721470289241; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.751) total time=  21.8s
# [CV 4/5] END rfc__max_depth=38, rfc__max_features=33, rfc__max_leaf_nodes=4198, rfc__min_samples_leaf=0.0077226789154901075, rfc__min_samples_split=0.12291040474960792; f1_macro: (test=0.481) f1_micro: (test=0.887) roc_auc: (test=0.803) total time=  28.3s
# [CV 3/5] END rfc__max_depth=38, rfc__max_features=33, rfc__max_leaf_nodes=4198, rfc__min_samples_leaf=0.0077226789154901075, rfc__min_samples_split=0.12291040474960792; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.818) total time=  28.6s
# [CV 5/5] END rfc__max_depth=38, rfc__max_features=33, rfc__max_leaf_nodes=4198, rfc__min_samples_leaf=0.0077226789154901075, rfc__min_samples_split=0.12291040474960792; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.763) total time=  28.7s
# [CV 3/5] END rfc__max_depth=46, rfc__max_features=29, rfc__max_leaf_nodes=183, rfc__min_samples_leaf=0.07882957394198264, rfc__min_samples_split=0.07268041227841043; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.775) total time=  13.2s
# [CV 2/5] END rfc__max_depth=46, rfc__max_features=29, rfc__max_leaf_nodes=183, rfc__min_samples_leaf=0.07882957394198264, rfc__min_samples_split=0.07268041227841043; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.759) total time=  15.6s
# [CV 5/5] END rfc__max_depth=46, rfc__max_features=29, rfc__max_leaf_nodes=183, rfc__min_samples_leaf=0.07882957394198264, rfc__min_samples_split=0.07268041227841043; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.735) total time=  13.2s
# [CV 4/5] END rfc__max_depth=46, rfc__max_features=29, rfc__max_leaf_nodes=183, rfc__min_samples_leaf=0.07882957394198264, rfc__min_samples_split=0.07268041227841043; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.781) total time=  15.7s
# [CV 4/5] END rfc__max_depth=260, rfc__max_features=5, rfc__max_leaf_nodes=1637, rfc__min_samples_leaf=0.11169777079159572, rfc__min_samples_split=0.15299634556560604; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.783) total time=   8.5s
# [CV 2/5] END rfc__max_depth=260, rfc__max_features=5, rfc__max_leaf_nodes=1637, rfc__min_samples_leaf=0.11169777079159572, rfc__min_samples_split=0.15299634556560604; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.762) total time=   9.8s
# [CV 3/5] END rfc__max_depth=260, rfc__max_features=5, rfc__max_leaf_nodes=1637, rfc__min_samples_leaf=0.11169777079159572, rfc__min_samples_split=0.15299634556560604; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.776) total time=   9.7s
# [CV 1/5] END rfc__max_depth=260, rfc__max_features=5, rfc__max_leaf_nodes=1637, rfc__min_samples_leaf=0.11169777079159572, rfc__min_samples_split=0.15299634556560604; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.721) total time=  10.7s
# [CV 4/5] END rfc__max_depth=5, rfc__max_features=23, rfc__max_leaf_nodes=2893, rfc__min_samples_leaf=0.010142718221853735, rfc__min_samples_split=0.07016556864313371; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.795) total time=  13.3s
# [CV 5/5] END rfc__max_depth=260, rfc__max_features=5, rfc__max_leaf_nodes=1637, rfc__min_samples_leaf=0.11169777079159572, rfc__min_samples_split=0.15299634556560604; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.721) total time=   8.5s
# [CV 1/5] END rfc__max_depth=5, rfc__max_features=23, rfc__max_leaf_nodes=2893, rfc__min_samples_leaf=0.010142718221853735, rfc__min_samples_split=0.07016556864313371; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.769) total time=  15.5s
# [CV 5/5] END rfc__max_depth=5, rfc__max_features=23, rfc__max_leaf_nodes=2893, rfc__min_samples_leaf=0.010142718221853735, rfc__min_samples_split=0.07016556864313371; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.747) total time=  13.4s
# [CV 3/5] END rfc__max_depth=5, rfc__max_features=23, rfc__max_leaf_nodes=2893, rfc__min_samples_leaf=0.010142718221853735, rfc__min_samples_split=0.07016556864313371; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.815) total time=  14.8s
# [CV 2/5] END rfc__max_depth=5, rfc__max_features=23, rfc__max_leaf_nodes=2893, rfc__min_samples_leaf=0.010142718221853735, rfc__min_samples_split=0.07016556864313371; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.803) total time=  16.2s
# [CV 3/5] END rfc__max_depth=4, rfc__max_features=25, rfc__max_leaf_nodes=3974, rfc__min_samples_leaf=0.0944824126366775, rfc__min_samples_split=0.02045847041060272; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.772) total time=  10.0s
# [CV 1/5] END rfc__max_depth=4, rfc__max_features=25, rfc__max_leaf_nodes=3974, rfc__min_samples_leaf=0.0944824126366775, rfc__min_samples_split=0.02045847041060272; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.753) total time=  12.3s
# [CV 4/5] END rfc__max_depth=4, rfc__max_features=25, rfc__max_leaf_nodes=3974, rfc__min_samples_leaf=0.0944824126366775, rfc__min_samples_split=0.02045847041060272; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.775) total time=  10.3s
# [CV 5/5] END rfc__max_depth=4, rfc__max_features=25, rfc__max_leaf_nodes=3974, rfc__min_samples_leaf=0.0944824126366775, rfc__min_samples_split=0.02045847041060272; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.730) total time=   9.5s
# [CV 2/5] END rfc__max_depth=4, rfc__max_features=25, rfc__max_leaf_nodes=3974, rfc__min_samples_leaf=0.0944824126366775, rfc__min_samples_split=0.02045847041060272; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.752) total time=  12.5s
# [CV 1/5] END rfc__max_depth=268, rfc__max_features=16, rfc__max_leaf_nodes=3294, rfc__min_samples_leaf=0.15056056047946378, rfc__min_samples_split=0.016346970876471606; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.719) total time=  11.1s
# [CV 5/5] END rfc__max_depth=268, rfc__max_features=16, rfc__max_leaf_nodes=3294, rfc__min_samples_leaf=0.15056056047946378, rfc__min_samples_split=0.016346970876471606; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.712) total time=   8.0s
# [CV 4/5] END rfc__max_depth=268, rfc__max_features=16, rfc__max_leaf_nodes=3294, rfc__min_samples_leaf=0.15056056047946378, rfc__min_samples_split=0.016346970876471606; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.757) total time=   8.1s
# [CV 3/5] END rfc__max_depth=268, rfc__max_features=16, rfc__max_leaf_nodes=3294, rfc__min_samples_leaf=0.15056056047946378, rfc__min_samples_split=0.016346970876471606; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.759) total time=   9.2s
# [CV 5/5] END rfc__max_depth=125, rfc__max_features=2, rfc__max_leaf_nodes=3270, rfc__min_samples_leaf=0.13706098869762853, rfc__min_samples_split=0.020442470204994893; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.707) total time=   4.4s
# [CV 2/5] END rfc__max_depth=268, rfc__max_features=16, rfc__max_leaf_nodes=3294, rfc__min_samples_leaf=0.15056056047946378, rfc__min_samples_split=0.016346970876471606; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.722) total time=  10.6s
# [CV 1/5] END rfc__max_depth=125, rfc__max_features=2, rfc__max_leaf_nodes=3270, rfc__min_samples_leaf=0.13706098869762853, rfc__min_samples_split=0.020442470204994893; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.699) total time=   8.5s
# [CV 3/5] END rfc__max_depth=125, rfc__max_features=2, rfc__max_leaf_nodes=3270, rfc__min_samples_leaf=0.13706098869762853, rfc__min_samples_split=0.020442470204994893; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.766) total time=   6.0s
# [CV 4/5] END rfc__max_depth=125, rfc__max_features=2, rfc__max_leaf_nodes=3270, rfc__min_samples_leaf=0.13706098869762853, rfc__min_samples_split=0.020442470204994893; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.773) total time=   6.0s
# [CV 4/5] END rfc__max_depth=200, rfc__max_features=29, rfc__max_leaf_nodes=2589, rfc__min_samples_leaf=0.034777681327719544, rfc__min_samples_split=0.11367289667423133; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.812) total time=  10.2s
# [CV 2/5] END rfc__max_depth=125, rfc__max_features=2, rfc__max_leaf_nodes=3270, rfc__min_samples_leaf=0.13706098869762853, rfc__min_samples_split=0.020442470204994893; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.754) total time=   7.0s
# [CV 3/5] END rfc__max_depth=200, rfc__max_features=29, rfc__max_leaf_nodes=2589, rfc__min_samples_leaf=0.034777681327719544, rfc__min_samples_split=0.11367289667423133; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.799) total time=  10.8s
# [CV 1/5] END rfc__max_depth=200, rfc__max_features=29, rfc__max_leaf_nodes=2589, rfc__min_samples_leaf=0.034777681327719544, rfc__min_samples_split=0.11367289667423133; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.768) total time=  11.6s
# [CV 5/5] END rfc__max_depth=200, rfc__max_features=29, rfc__max_leaf_nodes=2589, rfc__min_samples_leaf=0.034777681327719544, rfc__min_samples_split=0.11367289667423133; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.752) total time=  11.0s
# [CV 2/5] END rfc__max_depth=200, rfc__max_features=29, rfc__max_leaf_nodes=2589, rfc__min_samples_leaf=0.034777681327719544, rfc__min_samples_split=0.11367289667423133; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.792) total time=  11.6s

# %% [markdown]
# With 60 hyperparameter combinations, it takes approximately 4 minutes.

# %%
# Load saved pickle
with open('hyperparameter_tuning/random_forest/rf_noresampling_60comb.pkl', 'rb') as f:
    loaded = pickle.load(f)
    best_params_rf, best_scores_rf = loaded

print('Best parameters of RF:', best_params_rf, '\n')

print('Best scores of RF:', best_scores_rf, '\n')
# Out:
# Best parameters of RF: {'rfc__max_depth': 48, 'rfc__max_features': 7, 'rfc__max_leaf_nodes': 3096, 'rfc__min_samples_leaf': 0.0022275055277347616, 'rfc__min_samples_split': 0.039801263866007214}
#
# Best scores of RF: {'f1_micro': 0.890375, 'f1_macro': 0.5097113890181431, 'roc_auc': 0.8229868151826787}

# %% [markdown]
# #### B. Oversampling

# %%
best_params_rf_over, best_scores_rf_over = baseline_models(
        df=dfv3, numerical_features=numerical_features, categorical_features=categorical_features,
        target='HOSPITAL_EXPIRE_FLAG', model=RandomForestClassifier, ada_boost = False, 
        n_hyper_comb = 50, num_imputer = "median", refit_score = 'roc_auc', resampling_method = 'oversample'
)

# Combine dictionaries into a list
combined_rf_over = [best_params_rf_over, best_scores_rf_over]

# Save into a pickle (name of file states model, if resampling technique was
# applied and the number of hyperparameter combinations tried)
with open('hyperparameter_tuning/random_forest/rf_over_50comb.pkl', 'wb') as f:
    pickle.dump(combined_rf_over, f)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 3/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.575) f1_micro: (test=0.691) roc_auc: (test=0.802) total time=  16.4s
# [CV 1/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.556) f1_micro: (test=0.677) roc_auc: (test=0.752) total time=  16.7s
# [CV 3/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.522) f1_micro: (test=0.614) roc_auc: (test=0.751) total time=  16.9s
# [CV 1/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.561) f1_micro: (test=0.693) roc_auc: (test=0.738) total time=  17.5s
# [CV 4/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.530) f1_micro: (test=0.627) roc_auc: (test=0.757) total time=  17.6s
# [CV 2/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.509) f1_micro: (test=0.612) roc_auc: (test=0.728) total time=  18.2s
# [CV 4/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.509) f1_micro: (test=0.598) roc_auc: (test=0.731) total time=  18.4s
# [CV 5/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.565) f1_micro: (test=0.688) roc_auc: (test=0.770) total time=  18.6s
# [CV 1/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.575) f1_micro: (test=0.704) roc_auc: (test=0.774) total time=  18.7s
# [CV 2/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.573) f1_micro: (test=0.691) roc_auc: (test=0.787) total time=  18.7s
# [CV 5/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.518) f1_micro: (test=0.619) roc_auc: (test=0.730) total time=  18.8s
# [CV 3/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.501) f1_micro: (test=0.583) roc_auc: (test=0.734) total time=  19.1s
# [CV 1/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.568) f1_micro: (test=0.694) roc_auc: (test=0.754) total time=  19.1s
# [CV 4/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.590) f1_micro: (test=0.707) roc_auc: (test=0.815) total time=  19.1s
# [CV 2/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.496) f1_micro: (test=0.593) roc_auc: (test=0.720) total time=  19.8s
# [CV 5/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.490) f1_micro: (test=0.576) roc_auc: (test=0.714) total time=  20.0s
# [CV 2/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.575) f1_micro: (test=0.700) roc_auc: (test=0.769) total time=  10.5s
# [CV 1/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.565) f1_micro: (test=0.704) roc_auc: (test=0.720) total time=  10.7s
# [CV 3/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.528) f1_micro: (test=0.621) roc_auc: (test=0.766) total time=  14.4s
# [CV 3/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.586) f1_micro: (test=0.708) roc_auc: (test=0.785) total time=  12.3s
# [CV 4/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.590) f1_micro: (test=0.720) roc_auc: (test=0.787) total time=  12.5s
# [CV 2/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.520) f1_micro: (test=0.627) roc_auc: (test=0.738) total time=  16.4s
# [CV 4/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.539) f1_micro: (test=0.639) roc_auc: (test=0.770) total time=  16.2s
# [CV 5/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.531) f1_micro: (test=0.640) roc_auc: (test=0.744) total time=  15.8s
# [CV 5/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.558) f1_micro: (test=0.688) roc_auc: (test=0.731) total time=  14.2s
# [CV 2/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.509) f1_micro: (test=0.611) roc_auc: (test=0.732) total time=  16.4s
# [CV 3/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.515) f1_micro: (test=0.606) roc_auc: (test=0.756) total time=  16.8s
# [CV 1/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.575) f1_micro: (test=0.704) roc_auc: (test=0.753) total time=  19.7s
# [CV 4/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.530) f1_micro: (test=0.629) roc_auc: (test=0.762) total time=  18.8s
# [CV 5/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.528) f1_micro: (test=0.637) roc_auc: (test=0.740) total time=  21.2s
# [CV 2/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.519) f1_micro: (test=0.626) roc_auc: (test=0.730) total time=  10.9s
# [CV 2/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.534) f1_micro: (test=0.641) roc_auc: (test=0.754) total time=  24.2s
# [CV 1/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.562) f1_micro: (test=0.695) roc_auc: (test=0.735) total time=  14.0s
# [CV 1/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.589) f1_micro: (test=0.725) roc_auc: (test=0.776) total time=  13.4s
# [CV 5/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.534) f1_micro: (test=0.650) roc_auc: (test=0.723) total time=  13.8s
# [CV 1/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.578) f1_micro: (test=0.709) roc_auc: (test=0.758) total time=  27.6s
# [CV 3/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.547) f1_micro: (test=0.663) roc_auc: (test=0.750) total time=  15.0s
# [CV 4/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.545) f1_micro: (test=0.652) roc_auc: (test=0.758) total time=  15.2s
# [CV 3/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.591) f1_micro: (test=0.710) roc_auc: (test=0.809) total time=  14.1s
# [CV 4/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.569) f1_micro: (test=0.686) roc_auc: (test=0.781) total time=  20.2s
# [CV 2/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.592) f1_micro: (test=0.712) roc_auc: (test=0.793) total time=  15.8s
# [CV 1/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.553) f1_micro: (test=0.693) roc_auc: (test=0.710) total time=  11.1s
# [CV 5/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.571) f1_micro: (test=0.694) roc_auc: (test=0.773) total time=  14.4s
# [CV 4/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.603) f1_micro: (test=0.721) roc_auc: (test=0.822) total time=  14.9s
# [CV 3/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.520) f1_micro: (test=0.608) roc_auc: (test=0.764) total time=  22.9s
# [CV 2/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.546) f1_micro: (test=0.671) roc_auc: (test=0.721) total time=  10.2s
# [CV 5/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.539) f1_micro: (test=0.657) roc_auc: (test=0.740) total time=  22.6s
# [CV 3/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.565) f1_micro: (test=0.688) roc_auc: (test=0.746) total time=  10.8s
# [CV 4/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.552) f1_micro: (test=0.672) roc_auc: (test=0.754) total time=  11.6s
# [CV 5/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.544) f1_micro: (test=0.669) roc_auc: (test=0.718) total time=  10.9s
# [CV 2/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.510) f1_micro: (test=0.611) roc_auc: (test=0.709) total time=  10.9s
# [CV 3/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.543) f1_micro: (test=0.661) roc_auc: (test=0.734) total time=  11.6s
# [CV 4/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.514) f1_micro: (test=0.608) roc_auc: (test=0.732) total time=  11.4s
# [CV 1/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.555) f1_micro: (test=0.686) roc_auc: (test=0.729) total time=  10.6s
# [CV 1/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.554) f1_micro: (test=0.688) roc_auc: (test=0.722) total time=  13.2s
# [CV 2/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.602) f1_micro: (test=0.731) roc_auc: (test=0.803) total time=   7.9s
# [CV 1/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.585) f1_micro: (test=0.728) roc_auc: (test=0.763) total time=   8.5s
# [CV 5/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.531) f1_micro: (test=0.645) roc_auc: (test=0.710) total time=  11.8s
# [CV 3/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.545) f1_micro: (test=0.660) roc_auc: (test=0.748) total time=  10.7s
# [CV 3/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.605) f1_micro: (test=0.729) roc_auc: (test=0.816) total time=   8.1s
# [CV 4/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.532) f1_micro: (test=0.637) roc_auc: (test=0.752) total time=  10.1s
# [CV 5/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.534) f1_micro: (test=0.649) roc_auc: (test=0.715) total time=   9.7s
# [CV 2/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.517) f1_micro: (test=0.628) roc_auc: (test=0.718) total time=  11.6s
# [CV 4/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.615) f1_micro: (test=0.745) roc_auc: (test=0.821) total time=   9.1s
# [CV 1/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.580) f1_micro: (test=0.718) roc_auc: (test=0.738) total time=   8.2s
# [CV 5/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.582) f1_micro: (test=0.713) roc_auc: (test=0.766) total time=   9.0s
# [CV 2/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.570) f1_micro: (test=0.697) roc_auc: (test=0.766) total time=  10.2s
# [CV 5/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.558) f1_micro: (test=0.686) roc_auc: (test=0.739) total time=   8.9s
# [CV 4/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.588) f1_micro: (test=0.713) roc_auc: (test=0.789) total time=   9.6s
# [CV 3/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.578) f1_micro: (test=0.696) roc_auc: (test=0.786) total time=  10.5s
# [CV 1/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.565) f1_micro: (test=0.695) roc_auc: (test=0.754) total time=  14.4s
# [CV 2/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.518) f1_micro: (test=0.626) roc_auc: (test=0.734) total time=  14.4s
# [CV 3/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.537) f1_micro: (test=0.637) roc_auc: (test=0.764) total time=  14.6s
# [CV 4/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.537) f1_micro: (test=0.637) roc_auc: (test=0.765) total time=  14.8s
# [CV 5/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.528) f1_micro: (test=0.634) roc_auc: (test=0.735) total time=  16.7s
# [CV 3/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.550) f1_micro: (test=0.652) roc_auc: (test=0.774) total time=  19.6s
# [CV 1/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.566) f1_micro: (test=0.690) roc_auc: (test=0.758) total time=  23.4s
# [CV 2/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.533) f1_micro: (test=0.646) roc_auc: (test=0.759) total time=  23.9s
# [CV 4/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.559) f1_micro: (test=0.666) roc_auc: (test=0.795) total time=  23.9s
# [CV 5/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.550) f1_micro: (test=0.667) roc_auc: (test=0.755) total time=  21.9s
# [CV 1/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.574) f1_micro: (test=0.703) roc_auc: (test=0.752) total time=  21.6s
# [CV 2/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.520) f1_micro: (test=0.630) roc_auc: (test=0.740) total time=  23.0s[CV 1/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.568) f1_micro: (test=0.693) roc_auc: (test=0.762) total time=  19.3s
#
# [CV 1/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.569) f1_micro: (test=0.703) roc_auc: (test=0.724) total time=  11.7s
# [CV 4/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.542) f1_micro: (test=0.648) roc_auc: (test=0.767) total time=  22.7s
# [CV 2/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.563) f1_micro: (test=0.693) roc_auc: (test=0.752) total time=  10.4s
# [CV 5/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.535) f1_micro: (test=0.649) roc_auc: (test=0.744) total time=  22.8s
# [CV 4/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.567) f1_micro: (test=0.679) roc_auc: (test=0.795) total time=  16.9s
# [CV 3/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.521) f1_micro: (test=0.616) roc_auc: (test=0.761) total time=  24.1s
# [CV 2/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.553) f1_micro: (test=0.669) roc_auc: (test=0.763) total time=  18.1s
# [CV 3/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.561) f1_micro: (test=0.670) roc_auc: (test=0.783) total time=  18.0s
# [CV 3/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.566) f1_micro: (test=0.686) roc_auc: (test=0.774) total time=  10.4s
# [CV 5/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.558) f1_micro: (test=0.675) roc_auc: (test=0.756) total time=  20.1s
# [CV 4/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.579) f1_micro: (test=0.704) roc_auc: (test=0.781) total time=  10.4s
# [CV 5/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.548) f1_micro: (test=0.673) roc_auc: (test=0.725) total time=  13.4s
# [CV 1/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.578) f1_micro: (test=0.720) roc_auc: (test=0.745) total time=  15.5s
# [CV 2/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.556) f1_micro: (test=0.681) roc_auc: (test=0.755) total time=  16.7s
# [CV 3/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.571) f1_micro: (test=0.690) roc_auc: (test=0.780) total time=  15.3s
# [CV 4/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.570) f1_micro: (test=0.689) roc_auc: (test=0.784) total time=  15.3s
# [CV 4/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.568) f1_micro: (test=0.688) roc_auc: (test=0.782) total time=  23.1s
# [CV 1/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.572) f1_micro: (test=0.699) roc_auc: (test=0.759) total time=  26.4s
# [CV 2/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.544) f1_micro: (test=0.660) roc_auc: (test=0.755) total time=  25.0s
# [CV 5/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.551) f1_micro: (test=0.675) roc_auc: (test=0.742) total time=  16.8s
# [CV 1/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.550) f1_micro: (test=0.681) roc_auc: (test=0.732) total time=  17.0s
# [CV 3/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.542) f1_micro: (test=0.641) roc_auc: (test=0.770) total time=  28.1s
# [CV 5/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.545) f1_micro: (test=0.666) roc_auc: (test=0.745) total time=  28.2s
# [CV 1/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.582) f1_micro: (test=0.709) roc_auc: (test=0.764) total time=  29.8s
# [CV 4/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.595) f1_micro: (test=0.714) roc_auc: (test=0.799) total time=  29.6s
# [CV 2/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.550) f1_micro: (test=0.665) roc_auc: (test=0.769) total time=  30.6s
# [CV 3/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.553) f1_micro: (test=0.662) roc_auc: (test=0.772) total time=  31.6s
# [CV 2/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.512) f1_micro: (test=0.617) roc_auc: (test=0.723) total time=  15.6s
# [CV 5/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.578) f1_micro: (test=0.699) roc_auc: (test=0.763) total time=  31.5s
# [CV 4/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.529) f1_micro: (test=0.631) roc_auc: (test=0.752) total time=  13.8s
# [CV 3/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.544) f1_micro: (test=0.660) roc_auc: (test=0.747) total time=  15.7s
# [CV 5/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.525) f1_micro: (test=0.640) roc_auc: (test=0.719) total time=  16.4s
# [CV 3/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.564) f1_micro: (test=0.684) roc_auc: (test=0.760) total time=  12.1s
# [CV 4/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.576) f1_micro: (test=0.696) roc_auc: (test=0.766) total time=  12.1s
# [CV 1/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.547) f1_micro: (test=0.682) roc_auc: (test=0.694) total time=  13.6s
# [CV 2/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.551) f1_micro: (test=0.680) roc_auc: (test=0.739) total time=  13.8s
# [CV 5/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.543) f1_micro: (test=0.667) roc_auc: (test=0.706) total time=  13.5s
# [CV 2/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.520) f1_micro: (test=0.629) roc_auc: (test=0.739) total time=  26.7s
# [CV 4/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.551) f1_micro: (test=0.666) roc_auc: (test=0.760) total time=  26.0s
# [CV 1/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.572) f1_micro: (test=0.697) roc_auc: (test=0.759) total time=  22.6s
# [CV 2/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.540) f1_micro: (test=0.651) roc_auc: (test=0.757) total time=  21.5s
# [CV 1/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.569) f1_micro: (test=0.706) roc_auc: (test=0.716) total time=  12.0s
# [CV 1/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.577) f1_micro: (test=0.714) roc_auc: (test=0.751) total time=  28.0s
# [CV 3/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.529) f1_micro: (test=0.628) roc_auc: (test=0.749) total time=  27.8s
# [CV 5/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.548) f1_micro: (test=0.665) roc_auc: (test=0.750) total time=  18.9s
# [CV 4/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.564) f1_micro: (test=0.676) roc_auc: (test=0.788) total time=  20.0s
# [CV 5/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.535) f1_micro: (test=0.659) roc_auc: (test=0.732) total time=  25.9s
# [CV 3/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.545) f1_micro: (test=0.645) roc_auc: (test=0.774) total time=  21.5s
# [CV 3/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.563) f1_micro: (test=0.684) roc_auc: (test=0.764) total time=   8.2s
# [CV 4/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.581) f1_micro: (test=0.703) roc_auc: (test=0.773) total time=   8.4s
# [CV 5/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.544) f1_micro: (test=0.672) roc_auc: (test=0.723) total time=  11.7s
# [CV 2/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.557) f1_micro: (test=0.684) roc_auc: (test=0.741) total time=  13.7s
# [CV 2/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.512) f1_micro: (test=0.616) roc_auc: (test=0.709) total time=  10.9s
# [CV 1/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.553) f1_micro: (test=0.685) roc_auc: (test=0.719) total time=  11.7s
# [CV 3/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.542) f1_micro: (test=0.658) roc_auc: (test=0.737) total time=  11.8s
# [CV 5/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.531) f1_micro: (test=0.645) roc_auc: (test=0.714) total time=  12.2s
# [CV 4/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.521) f1_micro: (test=0.621) roc_auc: (test=0.739) total time=  13.9s
# [CV 5/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.536) f1_micro: (test=0.648) roc_auc: (test=0.748) total time=  15.2s
# [CV 1/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.570) f1_micro: (test=0.696) roc_auc: (test=0.758) total time=  17.4s
# [CV 3/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.544) f1_micro: (test=0.645) roc_auc: (test=0.771) total time=  17.0s
# [CV 2/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.531) f1_micro: (test=0.644) roc_auc: (test=0.750) total time=  17.2s
# [CV 4/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.549) f1_micro: (test=0.655) roc_auc: (test=0.782) total time=  18.0s
# [CV 4/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.515) f1_micro: (test=0.607) roc_auc: (test=0.745) total time=  15.4s
# [CV 2/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.500) f1_micro: (test=0.598) roc_auc: (test=0.719) total time=  18.7s
# [CV 1/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.555) f1_micro: (test=0.667) roc_auc: (test=0.746) total time=  19.9s
# [CV 3/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.546) f1_micro: (test=0.662) roc_auc: (test=0.748) total time=  13.3s
# [CV 1/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.559) f1_micro: (test=0.693) roc_auc: (test=0.735) total time=  14.8s
# [CV 2/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.517) f1_micro: (test=0.623) roc_auc: (test=0.728) total time=  15.0s
# [CV 4/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.543) f1_micro: (test=0.651) roc_auc: (test=0.755) total time=  14.4s
# [CV 3/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.502) f1_micro: (test=0.586) roc_auc: (test=0.738) total time=  20.8s
# [CV 5/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.529) f1_micro: (test=0.644) roc_auc: (test=0.721) total time=  14.3s
# [CV 1/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.579) f1_micro: (test=0.718) roc_auc: (test=0.740) total time=  12.9s
# [CV 2/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.558) f1_micro: (test=0.681) roc_auc: (test=0.752) total time=  12.1s
# [CV 4/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.571) f1_micro: (test=0.693) roc_auc: (test=0.779) total time=  11.9s
# [CV 3/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.574) f1_micro: (test=0.691) roc_auc: (test=0.778) total time=  12.5s
# [CV 5/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.495) f1_micro: (test=0.585) roc_auc: (test=0.723) total time=  21.3s
# [CV 5/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.550) f1_micro: (test=0.677) roc_auc: (test=0.734) total time=  13.2s
# [CV 1/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.560) f1_micro: (test=0.681) roc_auc: (test=0.753) total time=  15.8s
# [CV 2/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.504) f1_micro: (test=0.604) roc_auc: (test=0.726) total time=  16.8s
# [CV 4/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.531) f1_micro: (test=0.629) roc_auc: (test=0.756) total time=  16.2s
# [CV 1/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.553) f1_micro: (test=0.685) roc_auc: (test=0.733) total time=  13.9s
# [CV 3/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.519) f1_micro: (test=0.609) roc_auc: (test=0.761) total time=  15.3s
# [CV 3/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.508) f1_micro: (test=0.594) roc_auc: (test=0.753) total time=  19.5s
# [CV 5/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.511) f1_micro: (test=0.611) roc_auc: (test=0.730) total time=  18.4s
# [CV 2/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.514) f1_micro: (test=0.619) roc_auc: (test=0.737) total time=  17.6s
# [CV 5/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.529) f1_micro: (test=0.639) roc_auc: (test=0.743) total time=  17.0s
# [CV 4/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.532) f1_micro: (test=0.636) roc_auc: (test=0.752) total time=  13.6s
# [CV 3/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.544) f1_micro: (test=0.661) roc_auc: (test=0.747) total time=  14.1s
# [CV 5/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.527) f1_micro: (test=0.639) roc_auc: (test=0.720) total time=  12.8s
# [CV 2/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.513) f1_micro: (test=0.618) roc_auc: (test=0.726) total time=  14.3s
# [CV 1/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.572) f1_micro: (test=0.700) roc_auc: (test=0.754) total time=  19.4s
# [CV 4/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.534) f1_micro: (test=0.632) roc_auc: (test=0.767) total time=  18.0s
# [CV 1/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.574) f1_micro: (test=0.709) roc_auc: (test=0.737) total time=  13.6s
# [CV 2/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.552) f1_micro: (test=0.677) roc_auc: (test=0.744) total time=  11.2s
# [CV 4/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.566) f1_micro: (test=0.683) roc_auc: (test=0.775) total time=  10.4s
# [CV 1/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.562) f1_micro: (test=0.706) roc_auc: (test=0.713) total time=   6.0s
# [CV 3/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.569) f1_micro: (test=0.689) roc_auc: (test=0.769) total time=  11.8s
# [CV 2/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.586) f1_micro: (test=0.715) roc_auc: (test=0.777) total time=   6.7s
# [CV 4/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.595) f1_micro: (test=0.726) roc_auc: (test=0.789) total time=   6.9s
# [CV 3/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.588) f1_micro: (test=0.714) roc_auc: (test=0.781) total time=   7.1s
# [CV 5/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.571) f1_micro: (test=0.708) roc_auc: (test=0.725) total time=   7.1s
# [CV 5/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.549) f1_micro: (test=0.672) roc_auc: (test=0.733) total time=  10.7s
# [CV 2/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.499) f1_micro: (test=0.598) roc_auc: (test=0.733) total time=  14.2s
# [CV 1/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.571) f1_micro: (test=0.704) roc_auc: (test=0.741) total time=  16.5s
# [CV 5/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.490) f1_micro: (test=0.576) roc_auc: (test=0.722) total time=  14.2s
# [CV 4/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.518) f1_micro: (test=0.609) roc_auc: (test=0.740) total time=  15.2s
# [CV 3/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.501) f1_micro: (test=0.583) roc_auc: (test=0.740) total time=  15.6s
# [CV 1/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.630) f1_micro: (test=0.775) roc_auc: (test=0.812) total time=  14.0s
# [CV 2/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.623) f1_micro: (test=0.751) roc_auc: (test=0.829) total time=  14.5s
# [CV 3/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.637) f1_micro: (test=0.765) roc_auc: (test=0.844) total time=  16.9s
# [CV 4/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.645) f1_micro: (test=0.778) roc_auc: (test=0.849) total time=  17.0s
# [CV 5/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.627) f1_micro: (test=0.757) roc_auc: (test=0.810) total time=  17.3s
# [CV 1/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.555) f1_micro: (test=0.671) roc_auc: (test=0.751) total time=  24.5s
# [CV 2/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.510) f1_micro: (test=0.613) roc_auc: (test=0.732) total time=  19.3s
# [CV 2/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.499) f1_micro: (test=0.598) roc_auc: (test=0.721) total time=  22.2s
# [CV 3/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.507) f1_micro: (test=0.594) roc_auc: (test=0.748) total time=  20.9s
# [CV 1/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.570) f1_micro: (test=0.697) roc_auc: (test=0.753) total time=  20.9s
# [CV 4/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.520) f1_micro: (test=0.613) roc_auc: (test=0.753) total time=  22.4s
# [CV 3/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.518) f1_micro: (test=0.606) roc_auc: (test=0.760) total time=  21.2s
# [CV 5/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.507) f1_micro: (test=0.608) roc_auc: (test=0.726) total time=  22.3s
# [CV 4/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.534) f1_micro: (test=0.632) roc_auc: (test=0.762) total time=  20.0s
# [CV 5/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.517) f1_micro: (test=0.619) roc_auc: (test=0.734) total time=  19.7s
# [CV 1/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.570) f1_micro: (test=0.696) roc_auc: (test=0.758) total time=  21.8s
# [CV 4/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.615) f1_micro: (test=0.744) roc_auc: (test=0.813) total time=  37.9s
# [CV 2/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.578) f1_micro: (test=0.698) roc_auc: (test=0.787) total time=  39.8s
# [CV 1/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.584) f1_micro: (test=0.721) roc_auc: (test=0.744) total time=  11.2s
# [CV 2/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.573) f1_micro: (test=0.701) roc_auc: (test=0.776) total time=  11.0s
# [CV 3/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.586) f1_micro: (test=0.708) roc_auc: (test=0.793) total time=  10.7s
# [CV 1/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.595) f1_micro: (test=0.732) roc_auc: (test=0.776) total time=  41.1s
# [CV 2/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.534) f1_micro: (test=0.646) roc_auc: (test=0.750) total time=  15.1s
# [CV 3/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.584) f1_micro: (test=0.707) roc_auc: (test=0.787) total time=  40.6s
# [CV 4/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.598) f1_micro: (test=0.722) roc_auc: (test=0.797) total time=  10.9s
# [CV 5/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.591) f1_micro: (test=0.721) roc_auc: (test=0.780) total time=  40.5s
# [CV 1/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.562) f1_micro: (test=0.699) roc_auc: (test=0.710) total time=   7.3s
# [CV 3/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.546) f1_micro: (test=0.647) roc_auc: (test=0.772) total time=  15.9s
# [CV 4/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.548) f1_micro: (test=0.655) roc_auc: (test=0.783) total time=  16.6s
# [CV 5/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.568) f1_micro: (test=0.696) roc_auc: (test=0.746) total time=  11.4s
# [CV 5/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.537) f1_micro: (test=0.649) roc_auc: (test=0.748) total time=  17.6s
# [CV 2/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.576) f1_micro: (test=0.704) roc_auc: (test=0.770) total time=   7.4s
# [CV 4/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.590) f1_micro: (test=0.721) roc_auc: (test=0.782) total time=   6.0s
# [CV 3/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.587) f1_micro: (test=0.709) roc_auc: (test=0.781) total time=   7.7s
# [CV 5/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.563) f1_micro: (test=0.694) roc_auc: (test=0.720) total time=   6.6s
# [CV 3/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.545) f1_micro: (test=0.648) roc_auc: (test=0.773) total time=  15.9s
# [CV 2/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.539) f1_micro: (test=0.652) roc_auc: (test=0.754) total time=  16.5s
# [CV 5/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.537) f1_micro: (test=0.649) roc_auc: (test=0.748) total time=  16.7s
# [CV 1/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.569) f1_micro: (test=0.694) roc_auc: (test=0.757) total time=  17.2s
# [CV 4/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.545) f1_micro: (test=0.649) roc_auc: (test=0.784) total time=  18.3s
# [CV 2/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.503) f1_micro: (test=0.603) roc_auc: (test=0.728) total time=  17.8s
# [CV 1/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.576) f1_micro: (test=0.706) roc_auc: (test=0.751) total time=  19.3s
# [CV 2/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.513) f1_micro: (test=0.618) roc_auc: (test=0.729) total time=  15.3s
# [CV 3/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.542) f1_micro: (test=0.647) roc_auc: (test=0.754) total time=  15.3s
# [CV 4/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.531) f1_micro: (test=0.631) roc_auc: (test=0.759) total time=  16.0s
# [CV 4/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.529) f1_micro: (test=0.626) roc_auc: (test=0.760) total time=  18.6s
# [CV 1/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.563) f1_micro: (test=0.692) roc_auc: (test=0.751) total time=  16.9s
# [CV 5/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.523) f1_micro: (test=0.627) roc_auc: (test=0.732) total time=  16.2s
# [CV 1/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.550) f1_micro: (test=0.684) roc_auc: (test=0.723) total time=  16.1s
# [CV 3/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.513) f1_micro: (test=0.601) roc_auc: (test=0.755) total time=  20.0s
# [CV 5/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.516) f1_micro: (test=0.619) roc_auc: (test=0.733) total time=  18.9s
# [CV 2/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.498) f1_micro: (test=0.590) roc_auc: (test=0.705) total time=  11.6s
# [CV 5/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.493) f1_micro: (test=0.580) roc_auc: (test=0.710) total time=  11.5s
# [CV 3/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.523) f1_micro: (test=0.615) roc_auc: (test=0.731) total time=  12.5s
# [CV 4/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.501) f1_micro: (test=0.588) roc_auc: (test=0.725) total time=  12.7s
# [CV 2/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.555) f1_micro: (test=0.672) roc_auc: (test=0.768) total time=  12.5s
# [CV 1/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.569) f1_micro: (test=0.693) roc_auc: (test=0.760) total time=  12.9s
# [CV 3/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.561) f1_micro: (test=0.667) roc_auc: (test=0.783) total time=  11.8s
# [CV 5/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.556) f1_micro: (test=0.675) roc_auc: (test=0.761) total time=  11.4s
# [CV 4/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.568) f1_micro: (test=0.681) roc_auc: (test=0.801) total time=  11.5s

# %% [markdown]
# With 50 hyperparameter combinations, it takes approximately 4 minutes.

# %%
# Load saved pickle
with open('hyperparameter_tuning/random_forest/rf_over_50comb.pkl', 'rb') as f:
    loaded = pickle.load(f)
    best_params_rf_over, best_scores_rf_over = loaded

print('Best parameters of RF:', best_params_rf_over, '\n')

print('Best scores of RF:', best_scores_rf_over, '\n')
# Out:
# Best parameters of RF: {'rfc__max_depth': 48, 'rfc__max_features': 7, 'rfc__max_leaf_nodes': 3096, 'rfc__min_samples_leaf': 0.0022275055277347616, 'rfc__min_samples_split': 0.039801263866007214}
#
# Best scores of RF: {'f1_micro': 0.7652499999999999, 'f1_macro': 0.6324690971563267, 'roc_auc': 0.8287546650043126}

# %% [markdown]
# Note how the F1-score for the minority class has increased significantly! (see F1-macro).

# %% [markdown]
# #### C. SMOTE

# %%
# best_params_rf_smote, best_scores_rf_smote = baseline_models(
#         df=dfv3, numerical_features=numerical_features, categorical_features=categorical_features,
#         target='HOSPITAL_EXPIRE_FLAG', model=RandomForestClassifier, ada_boost = False, 
#         n_hyper_comb = 50, num_imputer = "median", refit_score = 'roc_auc', resampling_method = 'smote'
# )

# # Combine dictionaries into a list
# combined_rf_smote = [best_params_rf_smote, best_scores_rf_smote]

# # Save into a pickle (name of file states model, if resampling technique was
# # applied and the number of hyperparameter combinations tried)
# with open('hyperparameter_tuning/random_forest/rf_smote_50comb.pkl', 'wb') as f:
#     pickle.dump(combined_rf_smote, f)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 2/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.494) f1_micro: (test=0.631) roc_auc: (test=0.625) total time=  23.9s
# [CV 1/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.515) f1_micro: (test=0.669) roc_auc: (test=0.635) total time=  26.1s
# [CV 4/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.505) f1_micro: (test=0.641) roc_auc: (test=0.642) total time=  26.9s
# [CV 1/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.506) f1_micro: (test=0.691) roc_auc: (test=0.619) total time=  27.3s
# [CV 2/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.506) f1_micro: (test=0.634) roc_auc: (test=0.651) total time=  27.3s
# [CV 5/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.494) f1_micro: (test=0.623) roc_auc: (test=0.620) total time=  27.3s
# [CV 3/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.528) f1_micro: (test=0.669) roc_auc: (test=0.670) total time=  27.7s
# [CV 5/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.454) f1_micro: (test=0.574) roc_auc: (test=0.590) total time=  28.1s
# [CV 2/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.592) f1_micro: (test=0.788) roc_auc: (test=0.727) total time=  28.8s
# [CV 5/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.595) f1_micro: (test=0.789) roc_auc: (test=0.716) total time=  29.6s
# [CV 4/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.503) f1_micro: (test=0.704) roc_auc: (test=0.613) total time=  30.0s
# [CV 4/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.591) f1_micro: (test=0.807) roc_auc: (test=0.751) total time=  30.4s
# [CV 1/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.523) f1_micro: (test=0.678) roc_auc: (test=0.639) total time=  30.6s
# [CV 3/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.518) f1_micro: (test=0.703) roc_auc: (test=0.648) total time=  31.6s
# [CV 3/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.602) f1_micro: (test=0.794) roc_auc: (test=0.737) total time=  31.6s
# [CV 1/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.561) f1_micro: (test=0.786) roc_auc: (test=0.704) total time=  31.6s
# [CV 2/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.586) f1_micro: (test=0.739) roc_auc: (test=0.743) total time=  13.5s
# [CV 1/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.566) f1_micro: (test=0.724) roc_auc: (test=0.706) total time=  14.3s
# [CV 4/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.580) f1_micro: (test=0.739) roc_auc: (test=0.759) total time=  14.6s
# [CV 2/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.547) f1_micro: (test=0.710) roc_auc: (test=0.660) total time=  21.2s
# [CV 3/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.585) f1_micro: (test=0.735) roc_auc: (test=0.740) total time=  14.8s
# [CV 5/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.566) f1_micro: (test=0.720) roc_auc: (test=0.720) total time=  14.2s
# [CV 3/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.537) f1_micro: (test=0.690) roc_auc: (test=0.683) total time=  24.3s
# [CV 5/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.517) f1_micro: (test=0.674) roc_auc: (test=0.637) total time=  26.4s
# [CV 1/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.514) f1_micro: (test=0.684) roc_auc: (test=0.628) total time=  27.1s
# [CV 4/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.539) f1_micro: (test=0.699) roc_auc: (test=0.661) total time=  27.9s
# [CV 2/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.518) f1_micro: (test=0.674) roc_auc: (test=0.643) total time=  32.2s
# [CV 3/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.537) f1_micro: (test=0.703) roc_auc: (test=0.663) total time=  32.4s
# [CV 5/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.506) f1_micro: (test=0.674) roc_auc: (test=0.615) total time=  32.9s
# [CV 4/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.506) f1_micro: (test=0.698) roc_auc: (test=0.637) total time=  34.2s
# [CV 2/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.516) f1_micro: (test=0.654) roc_auc: (test=0.649) total time=  19.3s
# [CV 3/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.512) f1_micro: (test=0.634) roc_auc: (test=0.682) total time=  19.1s
# [CV 1/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.512) f1_micro: (test=0.658) roc_auc: (test=0.661) total time=  20.4s
# [CV 4/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.512) f1_micro: (test=0.653) roc_auc: (test=0.663) total time=  19.9s
# [CV 1/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.540) f1_micro: (test=0.768) roc_auc: (test=0.659) total time=  41.7s
# [CV 2/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.529) f1_micro: (test=0.696) roc_auc: (test=0.660) total time=  42.1s
# [CV 5/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.503) f1_micro: (test=0.637) roc_auc: (test=0.634) total time=  20.3s
# [CV 1/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.537) f1_micro: (test=0.681) roc_auc: (test=0.680) total time=  12.8s
# [CV 1/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.582) f1_micro: (test=0.779) roc_auc: (test=0.715) total time=  21.4s
# [CV 2/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.543) f1_micro: (test=0.696) roc_auc: (test=0.668) total time=  12.4s
# [CV 2/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.599) f1_micro: (test=0.784) roc_auc: (test=0.743) total time=  22.6s
# [CV 4/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.523) f1_micro: (test=0.671) roc_auc: (test=0.696) total time=  13.3s
# [CV 4/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.594) f1_micro: (test=0.791) roc_auc: (test=0.761) total time=  18.9s
# [CV 3/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.596) f1_micro: (test=0.779) roc_auc: (test=0.745) total time=  19.8s
# [CV 3/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.555) f1_micro: (test=0.696) roc_auc: (test=0.708) total time=  14.4s
# [CV 5/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.606) f1_micro: (test=0.782) roc_auc: (test=0.730) total time=  19.5s
# [CV 3/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.571) f1_micro: (test=0.779) roc_auc: (test=0.673) total time=  39.6s
# [CV 4/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.565) f1_micro: (test=0.805) roc_auc: (test=0.674) total time=  39.8s
# [CV 5/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.524) f1_micro: (test=0.664) roc_auc: (test=0.653) total time=  13.4s
# [CV 5/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.553) f1_micro: (test=0.784) roc_auc: (test=0.667) total time=  42.3s
# [CV 2/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.494) f1_micro: (test=0.631) roc_auc: (test=0.630) total time=  15.3s
# [CV 2/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.521) f1_micro: (test=0.668) roc_auc: (test=0.642) total time=  12.0s
# [CV 3/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.490) f1_micro: (test=0.612) roc_auc: (test=0.655) total time=  17.3s
# [CV 1/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.502) f1_micro: (test=0.634) roc_auc: (test=0.637) total time=  18.2s
# [CV 2/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.613) f1_micro: (test=0.776) roc_auc: (test=0.766) total time=  10.6s
# [CV 4/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.500) f1_micro: (test=0.629) roc_auc: (test=0.644) total time=  16.7s
# [CV 1/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.586) f1_micro: (test=0.755) roc_auc: (test=0.730) total time=  12.6s
# [CV 5/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.491) f1_micro: (test=0.619) roc_auc: (test=0.626) total time=  12.8s
# [CV 4/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.522) f1_micro: (test=0.662) roc_auc: (test=0.670) total time=  13.3s
# [CV 3/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.526) f1_micro: (test=0.655) roc_auc: (test=0.690) total time=  14.0s
# [CV 1/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.516) f1_micro: (test=0.657) roc_auc: (test=0.668) total time=  16.2s
# [CV 5/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.461) f1_micro: (test=0.571) roc_auc: (test=0.600) total time=  17.4s
# [CV 3/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.594) f1_micro: (test=0.761) roc_auc: (test=0.754) total time=  10.5s
# [CV 5/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.581) f1_micro: (test=0.746) roc_auc: (test=0.741) total time=  10.6s
# [CV 4/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.589) f1_micro: (test=0.767) roc_auc: (test=0.778) total time=  11.8s
# [CV 2/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.579) f1_micro: (test=0.742) roc_auc: (test=0.722) total time=  10.5s
# [CV 1/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.556) f1_micro: (test=0.714) roc_auc: (test=0.692) total time=  12.7s
# [CV 3/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.575) f1_micro: (test=0.726) roc_auc: (test=0.721) total time=  12.0s
# [CV 5/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.561) f1_micro: (test=0.713) roc_auc: (test=0.701) total time=  10.7s
# [CV 4/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.563) f1_micro: (test=0.718) roc_auc: (test=0.729) total time=  12.7s
# [CV 2/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.534) f1_micro: (test=0.691) roc_auc: (test=0.660) total time=  16.4s
# [CV 4/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.523) f1_micro: (test=0.669) roc_auc: (test=0.662) total time=  20.5s
# [CV 1/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.515) f1_micro: (test=0.669) roc_auc: (test=0.638) total time=  21.2s
# [CV 3/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.534) f1_micro: (test=0.677) roc_auc: (test=0.679) total time=  22.6s
# [CV 5/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.518) f1_micro: (test=0.674) roc_auc: (test=0.633) total time=  23.9s
# [CV 1/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.560) f1_micro: (test=0.709) roc_auc: (test=0.707) total time=  16.7s
# [CV 1/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.517) f1_micro: (test=0.685) roc_auc: (test=0.638) total time=  38.4s
# [CV 3/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.536) f1_micro: (test=0.703) roc_auc: (test=0.668) total time=  35.2s
# [CV 2/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.588) f1_micro: (test=0.782) roc_auc: (test=0.705) total time=  44.0s
# [CV 2/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.523) f1_micro: (test=0.677) roc_auc: (test=0.644) total time=  37.8s
# [CV 1/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.564) f1_micro: (test=0.759) roc_auc: (test=0.677) total time=  33.6s
# [CV 2/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.566) f1_micro: (test=0.750) roc_auc: (test=0.684) total time=  29.5s
# [CV 3/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.602) f1_micro: (test=0.806) roc_auc: (test=0.720) total time=  45.2s
# [CV 1/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.564) f1_micro: (test=0.791) roc_auc: (test=0.683) total time=  45.7s
# [CV 4/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.516) f1_micro: (test=0.711) roc_auc: (test=0.645) total time=  37.3s
# [CV 5/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.512) f1_micro: (test=0.688) roc_auc: (test=0.621) total time=  36.9s
# [CV 5/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.563) f1_micro: (test=0.793) roc_auc: (test=0.694) total time=  44.9s
# [CV 3/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.578) f1_micro: (test=0.757) roc_auc: (test=0.700) total time=  27.2s
# [CV 4/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.588) f1_micro: (test=0.817) roc_auc: (test=0.731) total time=  47.2s
# [CV 4/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.572) f1_micro: (test=0.771) roc_auc: (test=0.701) total time=  27.7s
# [CV 5/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.565) f1_micro: (test=0.759) roc_auc: (test=0.682) total time=  26.6s
# [CV 2/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.565) f1_micro: (test=0.721) roc_auc: (test=0.719) total time=  13.8s
# [CV 5/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.567) f1_micro: (test=0.709) roc_auc: (test=0.704) total time=   9.5s
# [CV 4/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.559) f1_micro: (test=0.715) roc_auc: (test=0.740) total time=  12.2s
# [CV 3/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.583) f1_micro: (test=0.728) roc_auc: (test=0.727) total time=  13.6s
# [CV 2/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.563) f1_micro: (test=0.731) roc_auc: (test=0.696) total time=  18.2s
# [CV 1/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.532) f1_micro: (test=0.692) roc_auc: (test=0.674) total time=  19.6s
# [CV 4/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.555) f1_micro: (test=0.710) roc_auc: (test=0.697) total time=  18.7s
# [CV 3/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.563) f1_micro: (test=0.711) roc_auc: (test=0.704) total time=  19.0s
# [CV 5/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.544) f1_micro: (test=0.702) roc_auc: (test=0.675) total time=  22.1s
# [CV 1/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.505) f1_micro: (test=0.645) roc_auc: (test=0.655) total time=  25.7s
# [CV 2/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.551) f1_micro: (test=0.728) roc_auc: (test=0.678) total time=  41.8s
# [CV 2/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.494) f1_micro: (test=0.634) roc_auc: (test=0.632) total time=  21.4s
# [CV 1/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.565) f1_micro: (test=0.797) roc_auc: (test=0.661) total time=  43.9s
# [CV 3/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.594) f1_micro: (test=0.802) roc_auc: (test=0.687) total time=  44.8s
# [CV 3/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.517) f1_micro: (test=0.646) roc_auc: (test=0.680) total time=  22.4s
# [CV 4/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.566) f1_micro: (test=0.819) roc_auc: (test=0.697) total time=  45.6s
# [CV 4/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.513) f1_micro: (test=0.649) roc_auc: (test=0.655) total time=  18.5s
# [CV 5/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.558) f1_micro: (test=0.795) roc_auc: (test=0.672) total time=  49.5s
# [CV 5/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.476) f1_micro: (test=0.601) roc_auc: (test=0.612) total time=  22.8s
# [CV 2/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.581) f1_micro: (test=0.792) roc_auc: (test=0.694) total time=  53.1s
# [CV 1/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.562) f1_micro: (test=0.802) roc_auc: (test=0.687) total time= 1.0min
# [CV 3/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.599) f1_micro: (test=0.806) roc_auc: (test=0.703) total time= 1.0min
# [CV 4/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.573) f1_micro: (test=0.807) roc_auc: (test=0.727) total time= 1.0min
# [CV 1/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.554) f1_micro: (test=0.698) roc_auc: (test=0.695) total time=  13.9s
# [CV 2/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.563) f1_micro: (test=0.713) roc_auc: (test=0.721) total time=  15.4s
# [CV 5/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.570) f1_micro: (test=0.787) roc_auc: (test=0.703) total time= 1.1min
# [CV 3/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.583) f1_micro: (test=0.729) roc_auc: (test=0.741) total time=  13.9s
# [CV 4/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.587) f1_micro: (test=0.733) roc_auc: (test=0.752) total time=  15.2s
# [CV 1/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.554) f1_micro: (test=0.702) roc_auc: (test=0.707) total time=  14.1s
# [CV 5/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.550) f1_micro: (test=0.695) roc_auc: (test=0.697) total time=  15.0s
# [CV 2/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.501) f1_micro: (test=0.630) roc_auc: (test=0.634) total time=  43.8s
# [CV 1/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.546) f1_micro: (test=0.807) roc_auc: (test=0.640) total time=  47.8s
# [CV 2/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.545) f1_micro: (test=0.718) roc_auc: (test=0.671) total time=  35.1s
# [CV 1/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.555) f1_micro: (test=0.778) roc_auc: (test=0.668) total time=  35.5s
# [CV 2/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.555) f1_micro: (test=0.707) roc_auc: (test=0.702) total time=  10.6s
# [CV 3/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.580) f1_micro: (test=0.774) roc_auc: (test=0.689) total time=  34.9s
# [CV 4/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.560) f1_micro: (test=0.780) roc_auc: (test=0.686) total time=  35.1s
# [CV 3/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.559) f1_micro: (test=0.806) roc_auc: (test=0.669) total time=  40.4s
# [CV 3/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.578) f1_micro: (test=0.721) roc_auc: (test=0.724) total time=  12.0s
# [CV 5/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.565) f1_micro: (test=0.777) roc_auc: (test=0.674) total time=  33.1s
# [CV 5/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.522) f1_micro: (test=0.817) roc_auc: (test=0.620) total time=  41.5s
# [CV 4/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.543) f1_micro: (test=0.808) roc_auc: (test=0.644) total time=  41.9s
# [CV 4/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.551) f1_micro: (test=0.709) roc_auc: (test=0.725) total time=  11.8s
# [CV 5/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.547) f1_micro: (test=0.688) roc_auc: (test=0.688) total time=  12.8s
# [CV 4/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.519) f1_micro: (test=0.661) roc_auc: (test=0.657) total time=  14.0s
# [CV 2/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.510) f1_micro: (test=0.662) roc_auc: (test=0.632) total time=  15.1s
# [CV 1/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.510) f1_micro: (test=0.651) roc_auc: (test=0.650) total time=  15.5s
# [CV 3/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.511) f1_micro: (test=0.644) roc_auc: (test=0.666) total time=  15.8s
# [CV 5/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.467) f1_micro: (test=0.582) roc_auc: (test=0.615) total time=  15.6s
# [CV 2/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.550) f1_micro: (test=0.720) roc_auc: (test=0.665) total time=  22.2s
# [CV 4/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.565) f1_micro: (test=0.757) roc_auc: (test=0.684) total time=  22.9s
# [CV 1/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.546) f1_micro: (test=0.737) roc_auc: (test=0.656) total time=  25.0s
# [CV 3/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.549) f1_micro: (test=0.717) roc_auc: (test=0.698) total time=  24.4s
# [CV 5/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.546) f1_micro: (test=0.728) roc_auc: (test=0.655) total time=  27.4s
# [CV 1/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.506) f1_micro: (test=0.654) roc_auc: (test=0.655) total time=  20.5s
# [CV 1/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.541) f1_micro: (test=0.697) roc_auc: (test=0.679) total time=  16.6s
# [CV 3/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.514) f1_micro: (test=0.644) roc_auc: (test=0.677) total time=  19.2s
# [CV 2/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.511) f1_micro: (test=0.653) roc_auc: (test=0.645) total time=  19.7s
# [CV 4/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.507) f1_micro: (test=0.646) roc_auc: (test=0.656) total time=  19.3s
# [CV 2/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.482) f1_micro: (test=0.585) roc_auc: (test=0.638) total time=  30.6s
# [CV 5/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.487) f1_micro: (test=0.609) roc_auc: (test=0.624) total time=  19.0s
# [CV 4/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.503) f1_micro: (test=0.704) roc_auc: (test=0.624) total time=  29.4s
# [CV 1/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.506) f1_micro: (test=0.691) roc_auc: (test=0.622) total time=  31.8s
# [CV 3/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.520) f1_micro: (test=0.704) roc_auc: (test=0.652) total time=  30.1s
# [CV 5/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.502) f1_micro: (test=0.697) roc_auc: (test=0.600) total time=  28.2s
# [CV 3/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.571) f1_micro: (test=0.720) roc_auc: (test=0.710) total time=  13.4s
# [CV 2/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.568) f1_micro: (test=0.727) roc_auc: (test=0.700) total time=  15.3s
# [CV 5/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.546) f1_micro: (test=0.699) roc_auc: (test=0.683) total time=  12.8s
# [CV 4/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.552) f1_micro: (test=0.709) roc_auc: (test=0.703) total time=  14.2s
# [CV 1/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.508) f1_micro: (test=0.669) roc_auc: (test=0.624) total time=  22.3s
# [CV 2/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.494) f1_micro: (test=0.634) roc_auc: (test=0.632) total time=  18.5s
# [CV 1/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.507) f1_micro: (test=0.646) roc_auc: (test=0.656) total time=  21.1s
# [CV 5/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.477) f1_micro: (test=0.602) roc_auc: (test=0.612) total time=  18.6s
# [CV 4/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.523) f1_micro: (test=0.677) roc_auc: (test=0.637) total time=  23.9s
# [CV 3/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.535) f1_micro: (test=0.687) roc_auc: (test=0.661) total time=  24.8s
# [CV 4/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.512) f1_micro: (test=0.649) roc_auc: (test=0.654) total time=  19.6s
# [CV 3/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.518) f1_micro: (test=0.650) roc_auc: (test=0.680) total time=  20.0s
# [CV 2/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.515) f1_micro: (test=0.654) roc_auc: (test=0.649) total time=  25.8s
# [CV 1/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.532) f1_micro: (test=0.686) roc_auc: (test=0.686) total time=  18.1s
# [CV 5/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.494) f1_micro: (test=0.639) roc_auc: (test=0.611) total time=  24.5s
# [CV 4/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.529) f1_micro: (test=0.710) roc_auc: (test=0.640) total time=  25.2s
# [CV 1/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.520) f1_micro: (test=0.691) roc_auc: (test=0.638) total time=  26.2s
# [CV 5/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.508) f1_micro: (test=0.677) roc_auc: (test=0.620) total time=  26.1s
# [CV 2/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.528) f1_micro: (test=0.688) roc_auc: (test=0.646) total time=  27.0s
# [CV 3/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.533) f1_micro: (test=0.693) roc_auc: (test=0.670) total time=  27.2s
# [CV 1/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.568) f1_micro: (test=0.723) roc_auc: (test=0.706) total time=   7.4s
# [CV 2/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.554) f1_micro: (test=0.710) roc_auc: (test=0.694) total time=  13.7s
# [CV 2/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.594) f1_micro: (test=0.749) roc_auc: (test=0.764) total time=   9.3s
# [CV 3/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.561) f1_micro: (test=0.704) roc_auc: (test=0.712) total time=  12.6s
# [CV 4/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.615) f1_micro: (test=0.765) roc_auc: (test=0.784) total time=   7.5s
# [CV 3/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.584) f1_micro: (test=0.735) roc_auc: (test=0.750) total time=   8.7s
# [CV 5/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.545) f1_micro: (test=0.689) roc_auc: (test=0.680) total time=  11.9s
# [CV 4/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.539) f1_micro: (test=0.690) roc_auc: (test=0.703) total time=  12.6s
# [CV 5/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.569) f1_micro: (test=0.724) roc_auc: (test=0.730) total time=   8.8s
# [CV 1/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.506) f1_micro: (test=0.691) roc_auc: (test=0.622) total time=  21.2s
# [CV 1/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.620) f1_micro: (test=0.837) roc_auc: (test=0.769) total time=  17.3s
# [CV 4/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.504) f1_micro: (test=0.692) roc_auc: (test=0.628) total time=  20.7s
# [CV 2/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.487) f1_micro: (test=0.616) roc_auc: (test=0.645) total time=  21.6s
# [CV 3/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.527) f1_micro: (test=0.694) roc_auc: (test=0.648) total time=  22.1s
# [CV 5/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.499) f1_micro: (test=0.669) roc_auc: (test=0.597) total time=  23.0s
# [CV 2/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.632) f1_micro: (test=0.835) roc_auc: (test=0.796) total time=  20.0s
# [CV 4/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.644) f1_micro: (test=0.855) roc_auc: (test=0.817) total time=  21.4s
# [CV 3/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.622) f1_micro: (test=0.828) roc_auc: (test=0.785) total time=  22.0s
# [CV 5/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.634) f1_micro: (test=0.837) roc_auc: (test=0.783) total time=  23.4s
# [CV 1/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.514) f1_micro: (test=0.686) roc_auc: (test=0.621) total time=  28.1s
# [CV 1/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.516) f1_micro: (test=0.677) roc_auc: (test=0.630) total time=  28.6s
# [CV 2/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.515) f1_micro: (test=0.662) roc_auc: (test=0.655) total time=  28.5s
# [CV 4/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.503) f1_micro: (test=0.701) roc_auc: (test=0.624) total time=  31.5s
# [CV 3/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.535) f1_micro: (test=0.686) roc_auc: (test=0.668) total time=  28.8s
# [CV 5/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.507) f1_micro: (test=0.674) roc_auc: (test=0.605) total time=  31.5s
# [CV 3/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.522) f1_micro: (test=0.681) roc_auc: (test=0.651) total time=  31.9s
# [CV 2/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.502) f1_micro: (test=0.627) roc_auc: (test=0.642) total time=  32.6s
# [CV 5/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.508) f1_micro: (test=0.659) roc_auc: (test=0.621) total time=  25.8s
# [CV 4/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.536) f1_micro: (test=0.699) roc_auc: (test=0.646) total time=  26.4s
# [CV 1/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.546) f1_micro: (test=0.736) roc_auc: (test=0.657) total time=  27.9s
# [CV 2/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.584) f1_micro: (test=0.747) roc_auc: (test=0.736) total time=  11.0s
# [CV 1/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.566) f1_micro: (test=0.729) roc_auc: (test=0.705) total time=  11.5s
# [CV 3/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.580) f1_micro: (test=0.736) roc_auc: (test=0.728) total time=  11.5s
# [CV 4/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.573) f1_micro: (test=0.737) roc_auc: (test=0.740) total time=  13.5s
# [CV 2/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.550) f1_micro: (test=0.721) roc_auc: (test=0.665) total time=  27.8s
# [CV 5/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.565) f1_micro: (test=0.722) roc_auc: (test=0.716) total time=  13.4s
# [CV 1/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.569) f1_micro: (test=0.723) roc_auc: (test=0.701) total time=  13.4s
# [CV 2/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.583) f1_micro: (test=0.735) roc_auc: (test=0.750) total time=  12.0s
# [CV 3/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.552) f1_micro: (test=0.720) roc_auc: (test=0.698) total time=  23.0s
# [CV 3/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.580) f1_micro: (test=0.730) roc_auc: (test=0.741) total time=  10.7s
# [CV 4/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.563) f1_micro: (test=0.755) roc_auc: (test=0.685) total time=  23.8s
# [CV 5/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.560) f1_micro: (test=0.714) roc_auc: (test=0.721) total time=  11.3s
# [CV 4/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.595) f1_micro: (test=0.745) roc_auc: (test=0.764) total time=  12.5s
# [CV 5/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.547) f1_micro: (test=0.728) roc_auc: (test=0.658) total time=  24.6s
# [CV 2/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.585) f1_micro: (test=0.802) roc_auc: (test=0.716) total time= 1.1min
# [CV 4/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.618) f1_micro: (test=0.847) roc_auc: (test=0.753) total time= 1.3min
# [CV 1/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.603) f1_micro: (test=0.826) roc_auc: (test=0.721) total time= 1.3min
# [CV 5/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.594) f1_micro: (test=0.799) roc_auc: (test=0.730) total time= 1.3min
# [CV 3/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.608) f1_micro: (test=0.818) roc_auc: (test=0.729) total time= 1.3min
# [CV 2/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.571) f1_micro: (test=0.756) roc_auc: (test=0.687) total time=  27.6s
# [CV 3/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.576) f1_micro: (test=0.761) roc_auc: (test=0.703) total time=  26.6s
# [CV 4/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.566) f1_micro: (test=0.782) roc_auc: (test=0.692) total time=  28.1s
# [CV 1/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.547) f1_micro: (test=0.759) roc_auc: (test=0.666) total time=  31.0s
# [CV 1/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.511) f1_micro: (test=0.677) roc_auc: (test=0.623) total time=  28.2s
# [CV 5/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.549) f1_micro: (test=0.752) roc_auc: (test=0.668) total time=  29.4s
# [CV 2/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.520) f1_micro: (test=0.661) roc_auc: (test=0.657) total time=  25.1s
# [CV 1/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.518) f1_micro: (test=0.676) roc_auc: (test=0.640) total time=  26.0s
# [CV 4/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.515) f1_micro: (test=0.686) roc_auc: (test=0.632) total time=  28.5s
# [CV 2/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.518) f1_micro: (test=0.666) roc_auc: (test=0.646) total time=  29.7s
# [CV 3/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.532) f1_micro: (test=0.693) roc_auc: (test=0.656) total time=  29.1s
# [CV 3/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.529) f1_micro: (test=0.668) roc_auc: (test=0.677) total time=  19.9s
# [CV 5/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.499) f1_micro: (test=0.658) roc_auc: (test=0.609) total time=  30.3s
# [CV 4/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.513) f1_micro: (test=0.652) roc_auc: (test=0.649) total time=  22.0s
# [CV 5/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.503) f1_micro: (test=0.641) roc_auc: (test=0.627) total time=  20.2s
# [CV 2/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.494) f1_micro: (test=0.631) roc_auc: (test=0.628) total time=  17.4s
# [CV 1/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.479) f1_micro: (test=0.594) roc_auc: (test=0.627) total time=  22.6s
# [CV 3/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.501) f1_micro: (test=0.632) roc_auc: (test=0.643) total time=  18.5s
# [CV 5/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.458) f1_micro: (test=0.567) roc_auc: (test=0.587) total time=  18.3s
# [CV 4/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.497) f1_micro: (test=0.631) roc_auc: (test=0.634) total time=  19.1s
# [CV 2/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.583) f1_micro: (test=0.776) roc_auc: (test=0.711) total time=  21.0s
# [CV 1/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.563) f1_micro: (test=0.788) roc_auc: (test=0.689) total time=  21.6s
# [CV 4/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.587) f1_micro: (test=0.806) roc_auc: (test=0.739) total time=  21.2s
# [CV 5/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.565) f1_micro: (test=0.787) roc_auc: (test=0.702) total time=  20.4s
# [CV 3/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.596) f1_micro: (test=0.801) roc_auc: (test=0.724) total time=  21.8s

# %% [markdown]
# With 50 hyperparameter combinations, it takes approximately 6 minutes.

# %%
# Load saved pickle
with open('hyperparameter_tuning/random_forest/rf_smote_50comb.pkl', 'rb') as f:
    loaded = pickle.load(f)
    best_params_rf_smote, best_scores_rf_smote = loaded

print('Best parameters of RF:', best_params_rf_smote, '\n')

print('Best scores of RF:', best_scores_rf_smote, '\n')
# Out:
# Best parameters of RF: {'rfc__max_depth': 48, 'rfc__max_features': 7, 'rfc__max_leaf_nodes': 3096, 'rfc__min_samples_leaf': 0.0022275055277347616, 'rfc__min_samples_split': 0.039801263866007214}
#
# Best scores of RF: {'f1_micro': 0.8383749999999999, 'f1_macro': 0.6304874715421158, 'roc_auc': 0.7898840135568947}

# %% [markdown]
# #### D. Undersampling

# %%
# best_params_rf_under, best_scores_rf_under = baseline_models(
#         df=dfv3, numerical_features=numerical_features, categorical_features=categorical_features,
#         target='HOSPITAL_EXPIRE_FLAG', model=RandomForestClassifier, ada_boost = False, 
#         n_hyper_comb = 50, num_imputer = "median", refit_score = 'roc_auc', resampling_method = 'undersample'
# )

# # Combine dictionaries into a list
# combined_rf_under = [best_params_rf_under, best_scores_rf_under]

# # Save into a pickle (name of file states model, if resampling technique was
# # applied and the number of hyperparameter combinations tried)
# with open('hyperparameter_tuning/random_forest/rf_under_50comb.pkl', 'wb') as f:
#     pickle.dump(combined_rf_under, f)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 4/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.548) f1_micro: (test=0.664) roc_auc: (test=0.760) total time=   3.3s
# [CV 5/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.524) f1_micro: (test=0.631) roc_auc: (test=0.736) total time=   3.5s
# [CV 2/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.516) f1_micro: (test=0.625) roc_auc: (test=0.728) total time=   3.6s
# [CV 3/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.560) f1_micro: (test=0.678) roc_auc: (test=0.750) total time=   3.7s
# [CV 5/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.490) f1_micro: (test=0.576) roc_auc: (test=0.714) total time=   3.7s
# [CV 1/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.571) f1_micro: (test=0.715) roc_auc: (test=0.728) total time=   3.9s
# [CV 2/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.496) f1_micro: (test=0.593) roc_auc: (test=0.713) total time=   3.8s
# [CV 4/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.522) f1_micro: (test=0.623) roc_auc: (test=0.736) total time=   3.9s
# [CV 3/5] END rfc__max_depth=112, rfc__max_features=50, rfc__max_leaf_nodes=2192, rfc__min_samples_leaf=0.16900253458405015, rfc__min_samples_split=0.1778840998151315; f1_macro: (test=0.546) f1_micro: (test=0.665) roc_auc: (test=0.734) total time=   3.9s
# [CV 5/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.562) f1_micro: (test=0.671) roc_auc: (test=0.772) total time=   3.8s
# [CV 1/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.579) f1_micro: (test=0.717) roc_auc: (test=0.752) total time=   3.9s
# [CV 1/5] END rfc__max_depth=279, rfc__max_features=32, rfc__max_leaf_nodes=3624, rfc__min_samples_leaf=0.12786665831268354, rfc__min_samples_split=0.11554497585685376; f1_macro: (test=0.569) f1_micro: (test=0.705) roc_auc: (test=0.743) total time=   4.1s[CV 3/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.591) f1_micro: (test=0.705) roc_auc: (test=0.812) total time=   4.1s
#
# [CV 2/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.577) f1_micro: (test=0.693) roc_auc: (test=0.794) total time=   4.0s
# [CV 4/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.595) f1_micro: (test=0.711) roc_auc: (test=0.820) total time=   4.0s
# [CV 1/5] END rfc__max_depth=239, rfc__max_features=18, rfc__max_leaf_nodes=3114, rfc__min_samples_leaf=0.009213240498236963, rfc__min_samples_split=0.1487706779610283; f1_macro: (test=0.595) f1_micro: (test=0.728) roc_auc: (test=0.781) total time=   4.3s
# [CV 4/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.585) f1_micro: (test=0.709) roc_auc: (test=0.788) total time=   2.1s
# [CV 2/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.568) f1_micro: (test=0.693) roc_auc: (test=0.772) total time=   2.3s
# [CV 1/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.569) f1_micro: (test=0.713) roc_auc: (test=0.725) total time=   2.5s
# [CV 2/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.541) f1_micro: (test=0.657) roc_auc: (test=0.746) total time=   3.5s
# [CV 3/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.575) f1_micro: (test=0.694) roc_auc: (test=0.784) total time=   2.7s
# [CV 3/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.569) f1_micro: (test=0.679) roc_auc: (test=0.772) total time=   3.5s
# [CV 5/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.538) f1_micro: (test=0.650) roc_auc: (test=0.748) total time=   3.4s
# [CV 5/5] END rfc__max_depth=167, rfc__max_features=3, rfc__max_leaf_nodes=3117, rfc__min_samples_leaf=0.10540958805243253, rfc__min_samples_split=0.010244984216626282; f1_macro: (test=0.553) f1_micro: (test=0.676) roc_auc: (test=0.730) total time=   2.9s
# [CV 4/5] END rfc__max_depth=263, rfc__max_features=28, rfc__max_leaf_nodes=1834, rfc__min_samples_leaf=0.09802623430513818, rfc__min_samples_split=0.055268465562153764; f1_macro: (test=0.561) f1_micro: (test=0.674) roc_auc: (test=0.780) total time=   4.0s
# [CV 1/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.579) f1_micro: (test=0.713) roc_auc: (test=0.751) total time=   4.4s
# [CV 5/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.528) f1_micro: (test=0.634) roc_auc: (test=0.748) total time=   4.4s
# [CV 4/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.563) f1_micro: (test=0.675) roc_auc: (test=0.774) total time=   4.6s
# [CV 2/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.519) f1_micro: (test=0.626) roc_auc: (test=0.738) total time=   4.7s
# [CV 3/5] END rfc__max_depth=238, rfc__max_features=38, rfc__max_leaf_nodes=4530, rfc__min_samples_leaf=0.09722219623769042, rfc__min_samples_split=0.05731464401054125; f1_macro: (test=0.562) f1_micro: (test=0.670) roc_auc: (test=0.764) total time=   5.1s
# [CV 2/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.534) f1_micro: (test=0.637) roc_auc: (test=0.759) total time=   4.4s
# [CV 1/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.587) f1_micro: (test=0.711) roc_auc: (test=0.763) total time=   4.7s
# [CV 2/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.522) f1_micro: (test=0.636) roc_auc: (test=0.727) total time=   3.2s
# [CV 1/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.571) f1_micro: (test=0.719) roc_auc: (test=0.729) total time=   3.5s
# [CV 3/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.566) f1_micro: (test=0.698) roc_auc: (test=0.745) total time=   3.4s
# [CV 5/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.530) f1_micro: (test=0.639) roc_auc: (test=0.723) total time=   3.3s
# [CV 4/5] END rfc__max_depth=284, rfc__max_features=24, rfc__max_leaf_nodes=1051, rfc__min_samples_leaf=0.1589436428474652, rfc__min_samples_split=0.12310957762141236; f1_macro: (test=0.561) f1_micro: (test=0.684) roc_auc: (test=0.761) total time=   3.6s
# [CV 4/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.573) f1_micro: (test=0.679) roc_auc: (test=0.793) total time=   4.4s
# [CV 3/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.568) f1_micro: (test=0.674) roc_auc: (test=0.779) total time=   4.6s
# [CV 5/5] END rfc__max_depth=284, rfc__max_features=43, rfc__max_leaf_nodes=819, rfc__min_samples_leaf=0.0600545463936808, rfc__min_samples_split=0.1333615781664329; f1_macro: (test=0.537) f1_micro: (test=0.639) roc_auc: (test=0.757) total time=   4.5s
# [CV 1/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.596) f1_micro: (test=0.734) roc_auc: (test=0.779) total time=   3.6s
# [CV 2/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.580) f1_micro: (test=0.698) roc_auc: (test=0.793) total time=   3.4s
# [CV 2/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.545) f1_micro: (test=0.666) roc_auc: (test=0.720) total time=   2.7s
# [CV 3/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.600) f1_micro: (test=0.716) roc_auc: (test=0.811) total time=   3.4s
# [CV 4/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.597) f1_micro: (test=0.716) roc_auc: (test=0.821) total time=   3.4s
# [CV 5/5] END rfc__max_depth=111, rfc__max_features=11, rfc__max_leaf_nodes=4611, rfc__min_samples_leaf=0.032632790168887815, rfc__min_samples_split=0.13567571475488913; f1_macro: (test=0.572) f1_micro: (test=0.689) roc_auc: (test=0.772) total time=   3.4s
# [CV 1/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.559) f1_micro: (test=0.703) roc_auc: (test=0.702) total time=   3.1s
# [CV 3/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.552) f1_micro: (test=0.674) roc_auc: (test=0.738) total time=   3.1s
# [CV 4/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.556) f1_micro: (test=0.673) roc_auc: (test=0.755) total time=   2.6s
# [CV 5/5] END rfc__max_depth=193, rfc__max_features=13, rfc__max_leaf_nodes=789, rfc__min_samples_leaf=0.19275111160955208, rfc__min_samples_split=0.16348128176224438; f1_macro: (test=0.533) f1_micro: (test=0.649) roc_auc: (test=0.715) total time=   2.7s
# [CV 2/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.502) f1_micro: (test=0.606) roc_auc: (test=0.705) total time=   3.3s
# [CV 5/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.531) f1_micro: (test=0.643) roc_auc: (test=0.713) total time=   2.8s
# [CV 1/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.556) f1_micro: (test=0.698) roc_auc: (test=0.719) total time=   3.4s
# [CV 3/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.551) f1_micro: (test=0.682) roc_auc: (test=0.730) total time=   3.3s
# [CV 4/5] END rfc__max_depth=37, rfc__max_features=30, rfc__max_leaf_nodes=540, rfc__min_samples_leaf=0.19219676353688886, rfc__min_samples_split=0.13218187308282833; f1_macro: (test=0.540) f1_micro: (test=0.654) roc_auc: (test=0.733) total time=   3.1s
# [CV 2/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.515) f1_micro: (test=0.627) roc_auc: (test=0.719) total time=   2.8s
# [CV 1/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.586) f1_micro: (test=0.729) roc_auc: (test=0.767) total time=   2.6s
# [CV 4/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.549) f1_micro: (test=0.665) roc_auc: (test=0.751) total time=   2.8s
# [CV 1/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.565) f1_micro: (test=0.710) roc_auc: (test=0.723) total time=   3.3s
# [CV 3/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.601) f1_micro: (test=0.721) roc_auc: (test=0.812) total time=   2.6s
# [CV 5/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.531) f1_micro: (test=0.643) roc_auc: (test=0.719) total time=   2.9s
# [CV 3/5] END rfc__max_depth=105, rfc__max_features=22, rfc__max_leaf_nodes=1549, rfc__min_samples_leaf=0.17765953402524176, rfc__min_samples_split=0.0276551878475828; f1_macro: (test=0.559) f1_micro: (test=0.688) roc_auc: (test=0.741) total time=   3.2s
# [CV 2/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.585) f1_micro: (test=0.711) roc_auc: (test=0.800) total time=   2.8s
# [CV 4/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.604) f1_micro: (test=0.731) roc_auc: (test=0.819) total time=   2.6s
# [CV 5/5] END rfc__max_depth=90, rfc__max_features=4, rfc__max_leaf_nodes=4414, rfc__min_samples_leaf=0.0470417630881238, rfc__min_samples_split=0.16581033966455253; f1_macro: (test=0.574) f1_micro: (test=0.695) roc_auc: (test=0.759) total time=   3.0s
# [CV 1/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.582) f1_micro: (test=0.721) roc_auc: (test=0.738) total time=   3.0s
# [CV 2/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.565) f1_micro: (test=0.690) roc_auc: (test=0.768) total time=   2.8s
# [CV 4/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.586) f1_micro: (test=0.706) roc_auc: (test=0.792) total time=   2.9s
# [CV 5/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.552) f1_micro: (test=0.669) roc_auc: (test=0.740) total time=   2.9s
# [CV 3/5] END rfc__max_depth=142, rfc__max_features=7, rfc__max_leaf_nodes=1858, rfc__min_samples_leaf=0.10444068352099825, rfc__min_samples_split=0.1846196253515208; f1_macro: (test=0.566) f1_micro: (test=0.684) roc_auc: (test=0.783) total time=   3.4s
# [CV 1/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.575) f1_micro: (test=0.714) roc_auc: (test=0.745) total time=   3.6s
# [CV 2/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.541) f1_micro: (test=0.657) roc_auc: (test=0.739) total time=   3.7s
# [CV 3/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.561) f1_micro: (test=0.677) roc_auc: (test=0.764) total time=   3.7s
# [CV 4/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.562) f1_micro: (test=0.681) roc_auc: (test=0.771) total time=   3.8s
# [CV 5/5] END rfc__max_depth=271, rfc__max_features=25, rfc__max_leaf_nodes=2244, rfc__min_samples_leaf=0.11627753147106994, rfc__min_samples_split=0.11657419019225887; f1_macro: (test=0.539) f1_micro: (test=0.653) roc_auc: (test=0.743) total time=   3.9s
# [CV 2/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.554) f1_micro: (test=0.664) roc_auc: (test=0.770) total time=   4.6s
# [CV 3/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.586) f1_micro: (test=0.696) roc_auc: (test=0.792) total time=   4.6s
# [CV 1/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.599) f1_micro: (test=0.731) roc_auc: (test=0.775) total time=   4.7s
# [CV 5/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.549) f1_micro: (test=0.657) roc_auc: (test=0.759) total time=   4.6s
# [CV 4/5] END rfc__max_depth=130, rfc__max_features=33, rfc__max_leaf_nodes=3461, rfc__min_samples_leaf=0.017581754725450607, rfc__min_samples_split=0.1768889793289142; f1_macro: (test=0.581) f1_micro: (test=0.693) roc_auc: (test=0.804) total time=   4.7s
# [CV 1/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.580) f1_micro: (test=0.710) roc_auc: (test=0.754) total time=   5.0s
# [CV 2/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.529) f1_micro: (test=0.640) roc_auc: (test=0.742) total time=   5.0s
# [CV 3/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.562) f1_micro: (test=0.671) roc_auc: (test=0.768) total time=   4.6s
# [CV 4/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.581) f1_micro: (test=0.701) roc_auc: (test=0.782) total time=   2.0s
# [CV 4/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.565) f1_micro: (test=0.677) roc_auc: (test=0.781) total time=   4.6s
# [CV 5/5] END rfc__max_depth=107, rfc__max_features=37, rfc__max_leaf_nodes=247, rfc__min_samples_leaf=0.09082654866231019, rfc__min_samples_split=0.13376342035312883; f1_macro: (test=0.532) f1_micro: (test=0.641) roc_auc: (test=0.751) total time=   4.7s
# [CV 3/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.566) f1_micro: (test=0.686) roc_auc: (test=0.768) total time=   2.3s
# [CV 1/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.572) f1_micro: (test=0.712) roc_auc: (test=0.724) total time=   3.1s
# [CV 1/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.594) f1_micro: (test=0.725) roc_auc: (test=0.767) total time=   4.3s
# [CV 3/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.576) f1_micro: (test=0.686) roc_auc: (test=0.788) total time=   3.9s
# [CV 5/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.549) f1_micro: (test=0.659) roc_auc: (test=0.758) total time=   3.7s
# [CV 4/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.582) f1_micro: (test=0.698) roc_auc: (test=0.800) total time=   4.0s
# [CV 2/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.551) f1_micro: (test=0.679) roc_auc: (test=0.752) total time=   3.1s[CV 2/5] END rfc__max_depth=280, rfc__max_features=22, rfc__max_leaf_nodes=1700, rfc__min_samples_leaf=0.06279344888543215, rfc__min_samples_split=0.14341300852477634; f1_macro: (test=0.554) f1_micro: (test=0.668) roc_auc: (test=0.767) total time=   4.6s
#
# [CV 5/5] END rfc__max_depth=185, rfc__max_features=7, rfc__max_leaf_nodes=3317, rfc__min_samples_leaf=0.1388864799391847, rfc__min_samples_split=0.157231654561522; f1_macro: (test=0.538) f1_micro: (test=0.656) roc_auc: (test=0.727) total time=   3.0s
# [CV 1/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.583) f1_micro: (test=0.713) roc_auc: (test=0.768) total time=   5.6s
# [CV 2/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.541) f1_micro: (test=0.649) roc_auc: (test=0.761) total time=   5.1s
# [CV 3/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.576) f1_micro: (test=0.685) roc_auc: (test=0.783) total time=   4.9s
# [CV 1/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.580) f1_micro: (test=0.719) roc_auc: (test=0.743) total time=   4.4s
# [CV 3/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.571) f1_micro: (test=0.691) roc_auc: (test=0.780) total time=   4.1s
# [CV 2/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.564) f1_micro: (test=0.686) roc_auc: (test=0.760) total time=   4.2s
# [CV 3/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.577) f1_micro: (test=0.686) roc_auc: (test=0.791) total time=   4.7s
# [CV 5/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.550) f1_micro: (test=0.667) roc_auc: (test=0.747) total time=   3.9s
# [CV 1/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.593) f1_micro: (test=0.723) roc_auc: (test=0.775) total time=   5.0s
# [CV 4/5] END rfc__max_depth=250, rfc__max_features=13, rfc__max_leaf_nodes=4802, rfc__min_samples_leaf=0.10362043545931045, rfc__min_samples_split=0.11439518413307452; f1_macro: (test=0.581) f1_micro: (test=0.701) roc_auc: (test=0.788) total time=   4.1s
# [CV 5/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.541) f1_micro: (test=0.649) roc_auc: (test=0.758) total time=   5.1s
# [CV 4/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.581) f1_micro: (test=0.688) roc_auc: (test=0.812) total time=   5.0s
# [CV 4/5] END rfc__max_depth=67, rfc__max_features=39, rfc__max_leaf_nodes=2384, rfc__min_samples_leaf=0.04982910570149025, rfc__min_samples_split=0.14575509059927197; f1_macro: (test=0.570) f1_micro: (test=0.681) roc_auc: (test=0.793) total time=   5.5s
# [CV 5/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.553) f1_micro: (test=0.656) roc_auc: (test=0.766) total time=   5.2s
# [CV 1/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.566) f1_micro: (test=0.711) roc_auc: (test=0.727) total time=   4.5s
# [CV 2/5] END rfc__max_depth=6, rfc__max_features=42, rfc__max_leaf_nodes=3054, rfc__min_samples_leaf=0.032516826596365046, rfc__min_samples_split=0.10854509312009515; f1_macro: (test=0.554) f1_micro: (test=0.669) roc_auc: (test=0.776) total time=   5.5s
# [CV 2/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.510) f1_micro: (test=0.618) roc_auc: (test=0.720) total time=   3.9s
# [CV 3/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.557) f1_micro: (test=0.692) roc_auc: (test=0.740) total time=   3.5s
# [CV 4/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.555) f1_micro: (test=0.672) roc_auc: (test=0.749) total time=   3.5s
# [CV 2/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.549) f1_micro: (test=0.674) roc_auc: (test=0.740) total time=   2.6s
# [CV 5/5] END rfc__max_depth=56, rfc__max_features=27, rfc__max_leaf_nodes=3603, rfc__min_samples_leaf=0.17433835181892754, rfc__min_samples_split=0.14290419538849747; f1_macro: (test=0.531) f1_micro: (test=0.643) roc_auc: (test=0.718) total time=   3.8s
# [CV 1/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.547) f1_micro: (test=0.684) roc_auc: (test=0.695) total time=   3.3s
# [CV 1/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.578) f1_micro: (test=0.706) roc_auc: (test=0.754) total time=   4.6s
# [CV 3/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.557) f1_micro: (test=0.668) roc_auc: (test=0.764) total time=   4.8s
# [CV 5/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.539) f1_micro: (test=0.646) roc_auc: (test=0.753) total time=   4.8s
# [CV 2/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.527) f1_micro: (test=0.636) roc_auc: (test=0.739) total time=   5.0s
# [CV 1/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.589) f1_micro: (test=0.716) roc_auc: (test=0.765) total time=   4.9s
# [CV 4/5] END rfc__max_depth=97, rfc__max_features=48, rfc__max_leaf_nodes=2960, rfc__min_samples_leaf=0.08319946299107568, rfc__min_samples_split=0.10342636144124757; f1_macro: (test=0.559) f1_micro: (test=0.667) roc_auc: (test=0.778) total time=   5.0s
# [CV 3/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.577) f1_micro: (test=0.683) roc_auc: (test=0.784) total time=   4.9s
# [CV 2/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.537) f1_micro: (test=0.645) roc_auc: (test=0.761) total time=   5.0s
# [CV 5/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.538) f1_micro: (test=0.640) roc_auc: (test=0.757) total time=   4.9s
# [CV 3/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.553) f1_micro: (test=0.668) roc_auc: (test=0.756) total time=   3.0s
# [CV 5/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.532) f1_micro: (test=0.650) roc_auc: (test=0.709) total time=   2.4s
# [CV 4/5] END rfc__max_depth=283, rfc__max_features=33, rfc__max_leaf_nodes=4795, rfc__min_samples_leaf=0.0627902191746951, rfc__min_samples_split=0.024757892401732113; f1_macro: (test=0.575) f1_micro: (test=0.683) roc_auc: (test=0.798) total time=   5.3s
# [CV 4/5] END rfc__max_depth=271, rfc__max_features=4, rfc__max_leaf_nodes=3130, rfc__min_samples_leaf=0.17956016771143002, rfc__min_samples_split=0.0991273653787188; f1_macro: (test=0.574) f1_micro: (test=0.696) roc_auc: (test=0.770) total time=   2.8s
# [CV 1/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.562) f1_micro: (test=0.708) roc_auc: (test=0.717) total time=   3.0s
# [CV 2/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.557) f1_micro: (test=0.686) roc_auc: (test=0.742) total time=   3.1s
# [CV 3/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.566) f1_micro: (test=0.691) roc_auc: (test=0.759) total time=   3.0s
# [CV 5/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.536) f1_micro: (test=0.651) roc_auc: (test=0.723) total time=   3.0s
# [CV 4/5] END rfc__max_depth=84, rfc__max_features=10, rfc__max_leaf_nodes=4735, rfc__min_samples_leaf=0.156818218097336, rfc__min_samples_split=0.18963668082250454; f1_macro: (test=0.577) f1_micro: (test=0.699) roc_auc: (test=0.775) total time=   3.3s
# [CV 2/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.515) f1_micro: (test=0.627) roc_auc: (test=0.707) total time=   3.2s
# [CV 3/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.548) f1_micro: (test=0.679) roc_auc: (test=0.729) total time=   3.2s
# [CV 1/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.551) f1_micro: (test=0.691) roc_auc: (test=0.714) total time=   3.4s
# [CV 4/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.545) f1_micro: (test=0.659) roc_auc: (test=0.740) total time=   3.4s
# [CV 5/5] END rfc__max_depth=3, rfc__max_features=24, rfc__max_leaf_nodes=2579, rfc__min_samples_leaf=0.19335940070024352, rfc__min_samples_split=0.09708808025842382; f1_macro: (test=0.537) f1_micro: (test=0.651) roc_auc: (test=0.714) total time=   3.3s
# [CV 1/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.591) f1_micro: (test=0.726) roc_auc: (test=0.759) total time=   4.6s
# [CV 2/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.547) f1_micro: (test=0.662) roc_auc: (test=0.754) total time=   4.3s
# [CV 4/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.573) f1_micro: (test=0.689) roc_auc: (test=0.790) total time=   4.3s
# [CV 3/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.573) f1_micro: (test=0.683) roc_auc: (test=0.778) total time=   4.5s
# [CV 1/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.570) f1_micro: (test=0.706) roc_auc: (test=0.743) total time=   4.4s
# [CV 5/5] END rfc__max_depth=179, rfc__max_features=26, rfc__max_leaf_nodes=4446, rfc__min_samples_leaf=0.08131122500299601, rfc__min_samples_split=0.16888756253836198; f1_macro: (test=0.543) f1_micro: (test=0.652) roc_auc: (test=0.752) total time=   5.0s
# [CV 2/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.501) f1_micro: (test=0.599) roc_auc: (test=0.720) total time=   4.6s
# [CV 1/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.564) f1_micro: (test=0.709) roc_auc: (test=0.727) total time=   3.5s
# [CV 1/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.578) f1_micro: (test=0.720) roc_auc: (test=0.735) total time=   3.0s
# [CV 5/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.529) f1_micro: (test=0.641) roc_auc: (test=0.722) total time=   3.2s
# [CV 3/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.564) f1_micro: (test=0.698) roc_auc: (test=0.743) total time=   3.3s
# [CV 3/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.549) f1_micro: (test=0.661) roc_auc: (test=0.738) total time=   4.8s
# [CV 2/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.516) f1_micro: (test=0.627) roc_auc: (test=0.725) total time=   3.6s
# [CV 4/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.537) f1_micro: (test=0.646) roc_auc: (test=0.751) total time=   4.9s
# [CV 4/5] END rfc__max_depth=124, rfc__max_features=26, rfc__max_leaf_nodes=3845, rfc__min_samples_leaf=0.16302161820895225, rfc__min_samples_split=0.13931337260741966; f1_macro: (test=0.558) f1_micro: (test=0.681) roc_auc: (test=0.757) total time=   3.6s
# [CV 5/5] END rfc__max_depth=76, rfc__max_features=47, rfc__max_leaf_nodes=4944, rfc__min_samples_leaf=0.12914129827245555, rfc__min_samples_split=0.09759439823427754; f1_macro: (test=0.503) f1_micro: (test=0.594) roc_auc: (test=0.732) total time=   4.8s
# [CV 2/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.563) f1_micro: (test=0.686) roc_auc: (test=0.756) total time=   3.1s
# [CV 3/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.565) f1_micro: (test=0.684) roc_auc: (test=0.773) total time=   3.1s
# [CV 5/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.550) f1_micro: (test=0.665) roc_auc: (test=0.740) total time=   2.9s
# [CV 4/5] END rfc__max_depth=25, rfc__max_features=11, rfc__max_leaf_nodes=3662, rfc__min_samples_leaf=0.11703022726639531, rfc__min_samples_split=0.03228469894435498; f1_macro: (test=0.585) f1_micro: (test=0.704) roc_auc: (test=0.783) total time=   3.1s
# [CV 1/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.572) f1_micro: (test=0.709) roc_auc: (test=0.745) total time=   4.3s
# [CV 2/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.515) f1_micro: (test=0.621) roc_auc: (test=0.729) total time=   4.0s
# [CV 3/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.557) f1_micro: (test=0.670) roc_auc: (test=0.752) total time=   4.2s
# [CV 1/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.565) f1_micro: (test=0.709) roc_auc: (test=0.726) total time=   3.5s
# [CV 5/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.514) f1_micro: (test=0.619) roc_auc: (test=0.738) total time=   4.0s
# [CV 4/5] END rfc__max_depth=276, rfc__max_features=34, rfc__max_leaf_nodes=1898, rfc__min_samples_leaf=0.12050095799732752, rfc__min_samples_split=0.07276107607833655; f1_macro: (test=0.550) f1_micro: (test=0.667) roc_auc: (test=0.761) total time=   4.2s
# [CV 3/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.565) f1_micro: (test=0.673) roc_auc: (test=0.771) total time=   4.3s
# [CV 5/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.534) f1_micro: (test=0.641) roc_auc: (test=0.748) total time=   4.1s
# [CV 2/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.509) f1_micro: (test=0.618) roc_auc: (test=0.720) total time=   3.5s
# [CV 1/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.580) f1_micro: (test=0.716) roc_auc: (test=0.754) total time=   4.6s
# [CV 3/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.556) f1_micro: (test=0.690) roc_auc: (test=0.740) total time=   3.4s
# [CV 4/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.560) f1_micro: (test=0.671) roc_auc: (test=0.778) total time=   4.4s
# [CV 4/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.556) f1_micro: (test=0.673) roc_auc: (test=0.750) total time=   3.4s
# [CV 2/5] END rfc__max_depth=94, rfc__max_features=33, rfc__max_leaf_nodes=1199, rfc__min_samples_leaf=0.08918897770113413, rfc__min_samples_split=0.1999116461732323; f1_macro: (test=0.528) f1_micro: (test=0.637) roc_auc: (test=0.744) total time=   4.7s
# [CV 5/5] END rfc__max_depth=266, rfc__max_features=27, rfc__max_leaf_nodes=4368, rfc__min_samples_leaf=0.17266791147233876, rfc__min_samples_split=0.15307533046695163; f1_macro: (test=0.530) f1_micro: (test=0.641) roc_auc: (test=0.718) total time=   3.3s
# [CV 1/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.571) f1_micro: (test=0.713) roc_auc: (test=0.731) total time=   3.6s
# [CV 2/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.561) f1_micro: (test=0.687) roc_auc: (test=0.747) total time=   3.2s
# [CV 3/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.573) f1_micro: (test=0.694) roc_auc: (test=0.766) total time=   3.1s
# [CV 5/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.538) f1_micro: (test=0.651) roc_auc: (test=0.736) total time=   2.8s
# [CV 3/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.581) f1_micro: (test=0.701) roc_auc: (test=0.784) total time=   2.0s
# [CV 4/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.592) f1_micro: (test=0.719) roc_auc: (test=0.792) total time=   2.1s
# [CV 5/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.557) f1_micro: (test=0.687) roc_auc: (test=0.724) total time=   2.1s
# [CV 2/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.591) f1_micro: (test=0.719) roc_auc: (test=0.783) total time=   2.3s
# [CV 4/5] END rfc__max_depth=120, rfc__max_features=13, rfc__max_leaf_nodes=1012, rfc__min_samples_leaf=0.13036918986747892, rfc__min_samples_split=0.14393011102104802; f1_macro: (test=0.578) f1_micro: (test=0.698) roc_auc: (test=0.780) total time=   3.2s
# [CV 1/5] END rfc__max_depth=129, rfc__max_features=1, rfc__max_leaf_nodes=709, rfc__min_samples_leaf=0.0991145484554835, rfc__min_samples_split=0.12050313683600679; f1_macro: (test=0.559) f1_micro: (test=0.708) roc_auc: (test=0.719) total time=   2.3s
# [CV 1/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.574) f1_micro: (test=0.724) roc_auc: (test=0.735) total time=   4.1s
# [CV 3/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.555) f1_micro: (test=0.682) roc_auc: (test=0.739) total time=   4.1s
# [CV 2/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.503) f1_micro: (test=0.602) roc_auc: (test=0.725) total time=   4.9s
# [CV 4/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.542) f1_micro: (test=0.655) roc_auc: (test=0.745) total time=   4.5s
# [CV 1/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.607) f1_micro: (test=0.743) roc_auc: (test=0.808) total time=   4.5s
# [CV 5/5] END rfc__max_depth=9, rfc__max_features=44, rfc__max_leaf_nodes=2709, rfc__min_samples_leaf=0.1482746163226712, rfc__min_samples_split=0.0349597387966941; f1_macro: (test=0.500) f1_micro: (test=0.594) roc_auc: (test=0.722) total time=   4.9s
# [CV 2/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.588) f1_micro: (test=0.707) roc_auc: (test=0.821) total time=   4.5s
# [CV 5/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.591) f1_micro: (test=0.706) roc_auc: (test=0.804) total time=   4.2s
# [CV 3/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.618) f1_micro: (test=0.729) roc_auc: (test=0.838) total time=   4.8s
# [CV 4/5] END rfc__max_depth=48, rfc__max_features=7, rfc__max_leaf_nodes=3096, rfc__min_samples_leaf=0.0022275055277347616, rfc__min_samples_split=0.039801263866007214; f1_macro: (test=0.622) f1_micro: (test=0.742) roc_auc: (test=0.845) total time=   4.7s
# [CV 1/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.572) f1_micro: (test=0.706) roc_auc: (test=0.745) total time=   5.8s
# [CV 4/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.606) f1_micro: (test=0.719) roc_auc: (test=0.824) total time=   6.1s
# [CV 3/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.583) f1_micro: (test=0.694) roc_auc: (test=0.802) total time=   6.2s
# [CV 2/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.575) f1_micro: (test=0.688) roc_auc: (test=0.793) total time=   6.3s
# [CV 1/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.595) f1_micro: (test=0.726) roc_auc: (test=0.786) total time=   6.4s
# [CV 2/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.526) f1_micro: (test=0.637) roc_auc: (test=0.735) total time=   3.9s
# [CV 4/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.541) f1_micro: (test=0.655) roc_auc: (test=0.756) total time=   4.5s
# [CV 5/5] END rfc__max_depth=105, rfc__max_features=47, rfc__max_leaf_nodes=906, rfc__min_samples_leaf=0.02211657639668653, rfc__min_samples_split=0.04177682051298016; f1_macro: (test=0.568) f1_micro: (test=0.676) roc_auc: (test=0.779) total time=   6.5s
# [CV 2/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.506) f1_micro: (test=0.608) roc_auc: (test=0.724) total time=   5.8s
# [CV 3/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.561) f1_micro: (test=0.672) roc_auc: (test=0.761) total time=   4.5s
# [CV 3/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.545) f1_micro: (test=0.652) roc_auc: (test=0.746) total time=   5.8s
# [CV 5/5] END rfc__max_depth=117, rfc__max_features=40, rfc__max_leaf_nodes=4693, rfc__min_samples_leaf=0.12313883772332541, rfc__min_samples_split=0.11966215514347538; f1_macro: (test=0.507) f1_micro: (test=0.601) roc_auc: (test=0.736) total time=   5.5s
# [CV 1/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.577) f1_micro: (test=0.713) roc_auc: (test=0.748) total time=   5.3s
# [CV 5/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.521) f1_micro: (test=0.627) roc_auc: (test=0.742) total time=   4.4s
# [CV 4/5] END rfc__max_depth=295, rfc__max_features=30, rfc__max_leaf_nodes=454, rfc__min_samples_leaf=0.11423195617777357, rfc__min_samples_split=0.019052191895578625; f1_macro: (test=0.556) f1_micro: (test=0.673) roc_auc: (test=0.768) total time=   4.9s
# [CV 1/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.590) f1_micro: (test=0.724) roc_auc: (test=0.759) total time=   4.8s
# [CV 1/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.582) f1_micro: (test=0.723) roc_auc: (test=0.748) total time=   2.8s
# [CV 3/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.574) f1_micro: (test=0.693) roc_auc: (test=0.790) total time=   2.7s
# [CV 2/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.570) f1_micro: (test=0.692) roc_auc: (test=0.780) total time=   2.8s
# [CV 4/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.589) f1_micro: (test=0.711) roc_auc: (test=0.798) total time=   2.9s
# [CV 1/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.560) f1_micro: (test=0.705) roc_auc: (test=0.709) total time=   2.4s
# [CV 3/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.571) f1_micro: (test=0.681) roc_auc: (test=0.778) total time=   3.7s
# [CV 2/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.549) f1_micro: (test=0.664) roc_auc: (test=0.755) total time=   4.0s
# [CV 5/5] END rfc__max_depth=150, rfc__max_features=6, rfc__max_leaf_nodes=3110, rfc__min_samples_leaf=0.08232391736182922, rfc__min_samples_split=0.046496164433862286; f1_macro: (test=0.561) f1_micro: (test=0.680) roc_auc: (test=0.748) total time=   3.0s
# [CV 3/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.577) f1_micro: (test=0.698) roc_auc: (test=0.779) total time=   2.5s
# [CV 4/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.583) f1_micro: (test=0.710) roc_auc: (test=0.782) total time=   2.4s
# [CV 2/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.576) f1_micro: (test=0.701) roc_auc: (test=0.769) total time=   2.7s
# [CV 5/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.543) f1_micro: (test=0.652) roc_auc: (test=0.753) total time=   4.1s
# [CV 4/5] END rfc__max_depth=101, rfc__max_features=26, rfc__max_leaf_nodes=802, rfc__min_samples_leaf=0.08139405545566247, rfc__min_samples_split=0.0498967289710591; f1_macro: (test=0.571) f1_micro: (test=0.688) roc_auc: (test=0.791) total time=   4.2s
# [CV 5/5] END rfc__max_depth=117, rfc__max_features=2, rfc__max_leaf_nodes=2778, rfc__min_samples_leaf=0.1184538540051683, rfc__min_samples_split=0.03506767510893712; f1_macro: (test=0.550) f1_micro: (test=0.677) roc_auc: (test=0.717) total time=   2.7s
# [CV 2/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.555) f1_micro: (test=0.670) roc_auc: (test=0.759) total time=   4.1s
# [CV 1/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.594) f1_micro: (test=0.729) roc_auc: (test=0.764) total time=   4.4s
# [CV 3/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.580) f1_micro: (test=0.692) roc_auc: (test=0.783) total time=   4.3s
# [CV 1/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.571) f1_micro: (test=0.705) roc_auc: (test=0.743) total time=   3.4s
# [CV 1/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.574) f1_micro: (test=0.709) roc_auc: (test=0.748) total time=   4.1s
# [CV 3/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.567) f1_micro: (test=0.688) roc_auc: (test=0.753) total time=   3.5s
# [CV 4/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.567) f1_micro: (test=0.681) roc_auc: (test=0.789) total time=   4.5s
# [CV 5/5] END rfc__max_depth=187, rfc__max_features=27, rfc__max_leaf_nodes=3335, rfc__min_samples_leaf=0.05499288899778739, rfc__min_samples_split=0.19714401509265228; f1_macro: (test=0.541) f1_micro: (test=0.651) roc_auc: (test=0.753) total time=   4.5s
# [CV 2/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.528) f1_micro: (test=0.642) roc_auc: (test=0.730) total time=   3.8s
# [CV 5/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.528) f1_micro: (test=0.637) roc_auc: (test=0.737) total time=   3.6s
# [CV 2/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.518) f1_micro: (test=0.623) roc_auc: (test=0.733) total time=   4.3s
# [CV 4/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.552) f1_micro: (test=0.665) roc_auc: (test=0.767) total time=   4.2s
# [CV 4/5] END rfc__max_depth=288, rfc__max_features=29, rfc__max_leaf_nodes=836, rfc__min_samples_leaf=0.12789682404986966, rfc__min_samples_split=0.019181910536400684; f1_macro: (test=0.551) f1_micro: (test=0.671) roc_auc: (test=0.764) total time=   3.7s
# [CV 3/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.555) f1_micro: (test=0.662) roc_auc: (test=0.760) total time=   4.3s
# [CV 5/5] END rfc__max_depth=263, rfc__max_features=36, rfc__max_leaf_nodes=2583, rfc__min_samples_leaf=0.10840929410300063, rfc__min_samples_split=0.09996410846677758; f1_macro: (test=0.521) f1_micro: (test=0.623) roc_auc: (test=0.743) total time=   4.3s
# [CV 1/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.549) f1_micro: (test=0.681) roc_auc: (test=0.721) total time=   3.7s
# [CV 4/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.538) f1_micro: (test=0.653) roc_auc: (test=0.730) total time=   3.5s
# [CV 2/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.499) f1_micro: (test=0.600) roc_auc: (test=0.702) total time=   3.8s
# [CV 3/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.554) f1_micro: (test=0.687) roc_auc: (test=0.731) total time=   3.7s
# [CV 5/5] END rfc__max_depth=269, rfc__max_features=40, rfc__max_leaf_nodes=1907, rfc__min_samples_leaf=0.1916588769635828, rfc__min_samples_split=0.1520709475496092; f1_macro: (test=0.525) f1_micro: (test=0.637) roc_auc: (test=0.710) total time=   3.6s
# [CV 4/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.585) f1_micro: (test=0.699) roc_auc: (test=0.813) total time=   3.6s
# [CV 1/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.594) f1_micro: (test=0.725) roc_auc: (test=0.780) total time=   3.8s
# [CV 2/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.569) f1_micro: (test=0.682) roc_auc: (test=0.784) total time=   3.7s
# [CV 3/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.590) f1_micro: (test=0.699) roc_auc: (test=0.803) total time=   3.7s
# [CV 5/5] END rfc__max_depth=99, rfc__max_features=30, rfc__max_leaf_nodes=4342, rfc__min_samples_leaf=0.0013856954477621253, rfc__min_samples_split=0.16357386985449388; f1_macro: (test=0.550) f1_micro: (test=0.657) roc_auc: (test=0.766) total time=   3.5s

# %% [markdown]
# With 50 hyperparameter combinations, it takes approximately 1 minute.

# %%
# Load saved pickle
with open('hyperparameter_tuning/random_forest/rf_under_50comb.pkl', 'rb') as f:
    loaded = pickle.load(f)
    best_params_rf_under, best_scores_rf_under = loaded

print('Best parameters of RF:', best_params_rf_under, '\n')

print('Best scores of RF:', best_scores_rf_under, '\n')
# Out:
# Best parameters of RF: {'rfc__max_depth': 48, 'rfc__max_features': 7, 'rfc__max_leaf_nodes': 3096, 'rfc__min_samples_leaf': 0.0022275055277347616, 'rfc__min_samples_split': 0.039801263866007214}
#
# Best scores of RF: {'f1_micro': 0.72525, 'f1_macro': 0.6051164956848396, 'roc_auc': 0.8231712548770524}

# %% [markdown]
# ## GradientBoostingClassifier

# %% [markdown]
# #### A. No resampling (without considering class imbalance)

# %%
best_params_gboost, best_scores_gboost = baseline_models(
        df=dfv3, numerical_features=numerical_features, categorical_features=categorical_features,
        target='HOSPITAL_EXPIRE_FLAG', model=GradientBoostingClassifier, ada_boost = False, 
        n_hyper_comb = 100, num_imputer = "median", refit_score = 'roc_auc', resampling_method = 'none'
)

# Combine dictionaries into a list
combined_gboost = [best_params_gboost, best_scores_gboost]

# Save into a pickle (name of file states model, if resampling technique was
# applied and the number of hyperparameter combinations tried)
with open('hyperparameter_tuning/gboost/gboost_noresampling_100comb.pkl', 'wb') as f:
    pickle.dump(combined_gboost, f)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=144, gbc__max_features=7, gbc__max_leaf_nodes=407, gbc__min_samples_leaf=0.1778840998151315, gbc__min_samples_split=0.16155744462914845, gbc__n_estimators=50, gbc__subsample=0.7308981574420352; f1_macro: (test=0.537) f1_micro: (test=0.887) roc_auc: (test=0.764) total time=   0.2s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=144, gbc__max_features=7, gbc__max_leaf_nodes=407, gbc__min_samples_leaf=0.1778840998151315, gbc__min_samples_split=0.16155744462914845, gbc__n_estimators=50, gbc__subsample=0.7308981574420352; f1_macro: (test=0.544) f1_micro: (test=0.891) roc_auc: (test=0.773) total time=   0.3s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=144, gbc__max_features=7, gbc__max_leaf_nodes=407, gbc__min_samples_leaf=0.1778840998151315, gbc__min_samples_split=0.16155744462914845, gbc__n_estimators=50, gbc__subsample=0.7308981574420352; f1_macro: (test=0.526) f1_micro: (test=0.889) roc_auc: (test=0.799) total time=   0.2s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=144, gbc__max_features=7, gbc__max_leaf_nodes=407, gbc__min_samples_leaf=0.1778840998151315, gbc__min_samples_split=0.16155744462914845, gbc__n_estimators=50, gbc__subsample=0.7308981574420352; f1_macro: (test=0.540) f1_micro: (test=0.886) roc_auc: (test=0.800) total time=   0.2s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=144, gbc__max_features=7, gbc__max_leaf_nodes=407, gbc__min_samples_leaf=0.1778840998151315, gbc__min_samples_split=0.16155744462914845, gbc__n_estimators=50, gbc__subsample=0.7308981574420352; f1_macro: (test=0.535) f1_micro: (test=0.889) roc_auc: (test=0.789) total time=   0.3s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=8, gbc__max_features=2, gbc__max_leaf_nodes=1775, gbc__min_samples_leaf=0.1721248920500644, gbc__min_samples_split=0.009213240498236963, gbc__n_estimators=500, gbc__subsample=0.7180134040946156; f1_macro: (test=0.529) f1_micro: (test=0.887) roc_auc: (test=0.786) total time=   1.0s
# [CV 2/5] END gbc__learning_rate=0.1, gbc__max_depth=8, gbc__max_features=2, gbc__max_leaf_nodes=1775, gbc__min_samples_leaf=0.1721248920500644, gbc__min_samples_split=0.009213240498236963, gbc__n_estimators=500, gbc__subsample=0.7180134040946156; f1_macro: (test=0.524) f1_micro: (test=0.886) roc_auc: (test=0.802) total time=   1.1s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=8, gbc__max_features=2, gbc__max_leaf_nodes=1775, gbc__min_samples_leaf=0.1721248920500644, gbc__min_samples_split=0.009213240498236963, gbc__n_estimators=500, gbc__subsample=0.7180134040946156; f1_macro: (test=0.524) f1_micro: (test=0.887) roc_auc: (test=0.780) total time=   1.1s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=8, gbc__max_features=2, gbc__max_leaf_nodes=1775, gbc__min_samples_leaf=0.1721248920500644, gbc__min_samples_split=0.009213240498236963, gbc__n_estimators=500, gbc__subsample=0.7180134040946156; f1_macro: (test=0.531) f1_micro: (test=0.891) roc_auc: (test=0.803) total time=   1.5s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=8, gbc__max_features=2, gbc__max_leaf_nodes=1775, gbc__min_samples_leaf=0.1721248920500644, gbc__min_samples_split=0.009213240498236963, gbc__n_estimators=500, gbc__subsample=0.7180134040946156; f1_macro: (test=0.529) f1_micro: (test=0.888) roc_auc: (test=0.814) total time=   1.3s
# [CV 2/5] END gbc__learning_rate=0.1, gbc__max_depth=167, gbc__max_features=3, gbc__max_leaf_nodes=3117, gbc__min_samples_leaf=0.10540958805243253, gbc__min_samples_split=0.010244984216626282, gbc__n_estimators=500, gbc__subsample=0.8213800299403904; f1_macro: (test=0.639) f1_micro: (test=0.899) roc_auc: (test=0.833) total time=   1.7s
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=167, gbc__max_features=28, gbc__max_leaf_nodes=1834, gbc__min_samples_leaf=0.09802623430513818, gbc__min_samples_split=0.055268465562153764, gbc__n_estimators=100, gbc__subsample=0.8792539759717153; f1_macro: (test=0.646) f1_micro: (test=0.877) roc_auc: (test=0.804) total time=   1.8s
# [CV 3/5] END gbc__learning_rate=1.0, gbc__max_depth=167, gbc__max_features=28, gbc__max_leaf_nodes=1834, gbc__min_samples_leaf=0.09802623430513818, gbc__min_samples_split=0.055268465562153764, gbc__n_estimators=100, gbc__subsample=0.8792539759717153; f1_macro: (test=0.660) f1_micro: (test=0.877) roc_auc: (test=0.806) total time=   2.0s
# [CV 4/5] END gbc__learning_rate=1.0, gbc__max_depth=167, gbc__max_features=28, gbc__max_leaf_nodes=1834, gbc__min_samples_leaf=0.09802623430513818, gbc__min_samples_split=0.055268465562153764, gbc__n_estimators=100, gbc__subsample=0.8792539759717153; f1_macro: (test=0.655) f1_micro: (test=0.883) roc_auc: (test=0.797) total time=   1.7s
# [CV 1/5] END gbc__learning_rate=1.0, gbc__max_depth=167, gbc__max_features=28, gbc__max_leaf_nodes=1834, gbc__min_samples_leaf=0.09802623430513818, gbc__min_samples_split=0.055268465562153764, gbc__n_estimators=100, gbc__subsample=0.8792539759717153; f1_macro: (test=0.634) f1_micro: (test=0.886) roc_auc: (test=0.791) total time=   2.1s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=167, gbc__max_features=3, gbc__max_leaf_nodes=3117, gbc__min_samples_leaf=0.10540958805243253, gbc__min_samples_split=0.010244984216626282, gbc__n_estimators=500, gbc__subsample=0.8213800299403904; f1_macro: (test=0.668) f1_micro: (test=0.904) roc_auc: (test=0.839) total time=   2.0s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=111, gbc__max_features=11, gbc__max_leaf_nodes=4611, gbc__min_samples_leaf=0.032632790168887815, gbc__min_samples_split=0.13567571475488913, gbc__n_estimators=50, gbc__subsample=0.7669251526407809; f1_macro: (test=0.639) f1_micro: (test=0.890) roc_auc: (test=0.843) total time=   0.7s
# [CV 5/5] END gbc__learning_rate=1.0, gbc__max_depth=167, gbc__max_features=28, gbc__max_leaf_nodes=1834, gbc__min_samples_leaf=0.09802623430513818, gbc__min_samples_split=0.055268465562153764, gbc__n_estimators=100, gbc__subsample=0.8792539759717153; f1_macro: (test=0.620) f1_micro: (test=0.876) roc_auc: (test=0.768) total time=   2.0s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=111, gbc__max_features=11, gbc__max_leaf_nodes=4611, gbc__min_samples_leaf=0.032632790168887815, gbc__min_samples_split=0.13567571475488913, gbc__n_estimators=50, gbc__subsample=0.7669251526407809; f1_macro: (test=0.678) f1_micro: (test=0.898) roc_auc: (test=0.839) total time=   0.6s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=167, gbc__max_features=3, gbc__max_leaf_nodes=3117, gbc__min_samples_leaf=0.10540958805243253, gbc__min_samples_split=0.010244984216626282, gbc__n_estimators=500, gbc__subsample=0.8213800299403904; f1_macro: (test=0.610) f1_micro: (test=0.895) roc_auc: (test=0.838) total time=   2.1s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=167, gbc__max_features=3, gbc__max_leaf_nodes=3117, gbc__min_samples_leaf=0.10540958805243253, gbc__min_samples_split=0.010244984216626282, gbc__n_estimators=500, gbc__subsample=0.8213800299403904; f1_macro: (test=0.633) f1_micro: (test=0.901) roc_auc: (test=0.844) total time=   2.3s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=167, gbc__max_features=3, gbc__max_leaf_nodes=3117, gbc__min_samples_leaf=0.10540958805243253, gbc__min_samples_split=0.010244984216626282, gbc__n_estimators=500, gbc__subsample=0.8213800299403904; f1_macro: (test=0.603) f1_micro: (test=0.892) roc_auc: (test=0.820) total time=   2.3s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=111, gbc__max_features=11, gbc__max_leaf_nodes=4611, gbc__min_samples_leaf=0.032632790168887815, gbc__min_samples_split=0.13567571475488913, gbc__n_estimators=50, gbc__subsample=0.7669251526407809; f1_macro: (test=0.687) f1_micro: (test=0.899) roc_auc: (test=0.829) total time=   0.6s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=111, gbc__max_features=11, gbc__max_leaf_nodes=4611, gbc__min_samples_leaf=0.032632790168887815, gbc__min_samples_split=0.13567571475488913, gbc__n_estimators=50, gbc__subsample=0.7669251526407809; f1_macro: (test=0.674) f1_micro: (test=0.896) roc_auc: (test=0.838) total time=   0.7s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=111, gbc__max_features=11, gbc__max_leaf_nodes=4611, gbc__min_samples_leaf=0.032632790168887815, gbc__min_samples_split=0.13567571475488913, gbc__n_estimators=50, gbc__subsample=0.7669251526407809; f1_macro: (test=0.641) f1_micro: (test=0.889) roc_auc: (test=0.817) total time=   0.6s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=61, gbc__max_features=9, gbc__max_leaf_nodes=436, gbc__min_samples_leaf=0.1438894015470255, gbc__min_samples_split=0.059171153546323574, gbc__n_estimators=500, gbc__subsample=0.9381059942424098; f1_macro: (test=0.640) f1_micro: (test=0.887) roc_auc: (test=0.804) total time=   3.3s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=272, gbc__max_features=27, gbc__max_leaf_nodes=3550, gbc__min_samples_leaf=0.09251479184029074, gbc__min_samples_split=0.15287446873025504, gbc__n_estimators=100, gbc__subsample=0.9156328249673303; f1_macro: (test=0.666) f1_micro: (test=0.896) roc_auc: (test=0.832) total time=   1.7s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=61, gbc__max_features=9, gbc__max_leaf_nodes=436, gbc__min_samples_leaf=0.1438894015470255, gbc__min_samples_split=0.059171153546323574, gbc__n_estimators=500, gbc__subsample=0.9381059942424098; f1_macro: (test=0.654) f1_micro: (test=0.892) roc_auc: (test=0.795) total time=   3.0s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=272, gbc__max_features=27, gbc__max_leaf_nodes=3550, gbc__min_samples_leaf=0.09251479184029074, gbc__min_samples_split=0.15287446873025504, gbc__n_estimators=100, gbc__subsample=0.9156328249673303; f1_macro: (test=0.627) f1_micro: (test=0.886) roc_auc: (test=0.835) total time=   2.0s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=272, gbc__max_features=27, gbc__max_leaf_nodes=3550, gbc__min_samples_leaf=0.09251479184029074, gbc__min_samples_split=0.15287446873025504, gbc__n_estimators=100, gbc__subsample=0.9156328249673303; f1_macro: (test=0.685) f1_micro: (test=0.899) roc_auc: (test=0.842) total time=   2.1s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=61, gbc__max_features=9, gbc__max_leaf_nodes=436, gbc__min_samples_leaf=0.1438894015470255, gbc__min_samples_split=0.059171153546323574, gbc__n_estimators=500, gbc__subsample=0.9381059942424098; f1_macro: (test=0.660) f1_micro: (test=0.890) roc_auc: (test=0.820) total time=   3.2s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=272, gbc__max_features=27, gbc__max_leaf_nodes=3550, gbc__min_samples_leaf=0.09251479184029074, gbc__min_samples_split=0.15287446873025504, gbc__n_estimators=100, gbc__subsample=0.9156328249673303; f1_macro: (test=0.665) f1_micro: (test=0.889) roc_auc: (test=0.832) total time=   1.9s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=272, gbc__max_features=27, gbc__max_leaf_nodes=3550, gbc__min_samples_leaf=0.09251479184029074, gbc__min_samples_split=0.15287446873025504, gbc__n_estimators=100, gbc__subsample=0.9156328249673303; f1_macro: (test=0.652) f1_micro: (test=0.887) roc_auc: (test=0.809) total time=   1.9s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=61, gbc__max_features=9, gbc__max_leaf_nodes=436, gbc__min_samples_leaf=0.1438894015470255, gbc__min_samples_split=0.059171153546323574, gbc__n_estimators=500, gbc__subsample=0.9381059942424098; f1_macro: (test=0.611) f1_micro: (test=0.884) roc_auc: (test=0.804) total time=   3.0s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=61, gbc__max_features=9, gbc__max_leaf_nodes=436, gbc__min_samples_leaf=0.1438894015470255, gbc__min_samples_split=0.059171153546323574, gbc__n_estimators=500, gbc__subsample=0.9381059942424098; f1_macro: (test=0.656) f1_micro: (test=0.886) roc_auc: (test=0.805) total time=   3.3s
# [CV 1/5] END gbc__learning_rate=1.0, gbc__max_depth=185, gbc__max_features=2, gbc__max_leaf_nodes=896, gbc__min_samples_leaf=0.04029131172522138, gbc__min_samples_split=0.017581754725450607, gbc__n_estimators=100, gbc__subsample=0.7493957244210605; f1_macro: (test=0.628) f1_micro: (test=0.861) roc_auc: (test=0.769) total time=   0.4s
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=185, gbc__max_features=2, gbc__max_leaf_nodes=896, gbc__min_samples_leaf=0.04029131172522138, gbc__min_samples_split=0.017581754725450607, gbc__n_estimators=100, gbc__subsample=0.7493957244210605; f1_macro: (test=0.697) f1_micro: (test=0.884) roc_auc: (test=0.816) total time=   0.4s
# [CV 3/5] END gbc__learning_rate=1.0, gbc__max_depth=185, gbc__max_features=2, gbc__max_leaf_nodes=896, gbc__min_samples_leaf=0.04029131172522138, gbc__min_samples_split=0.017581754725450607, gbc__n_estimators=100, gbc__subsample=0.7493957244210605; f1_macro: (test=0.639) f1_micro: (test=0.865) roc_auc: (test=0.783) total time=   0.4s
# [CV 4/5] END gbc__learning_rate=1.0, gbc__max_depth=185, gbc__max_features=2, gbc__max_leaf_nodes=896, gbc__min_samples_leaf=0.04029131172522138, gbc__min_samples_split=0.017581754725450607, gbc__n_estimators=100, gbc__subsample=0.7493957244210605; f1_macro: (test=0.642) f1_micro: (test=0.868) roc_auc: (test=0.771) total time=   0.4s
# [CV 5/5] END gbc__learning_rate=1.0, gbc__max_depth=185, gbc__max_features=2, gbc__max_leaf_nodes=896, gbc__min_samples_leaf=0.04029131172522138, gbc__min_samples_split=0.017581754725450607, gbc__n_estimators=100, gbc__subsample=0.7493957244210605; f1_macro: (test=0.617) f1_micro: (test=0.866) roc_auc: (test=0.757) total time=   0.4s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=196, gbc__max_features=3, gbc__max_leaf_nodes=761, gbc__min_samples_leaf=0.13376342035312883, gbc__min_samples_split=0.07922487675017734, gbc__n_estimators=100, gbc__subsample=0.9175460099664028; f1_macro: (test=0.517) f1_micro: (test=0.890) roc_auc: (test=0.800) total time=   0.4s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=196, gbc__max_features=3, gbc__max_leaf_nodes=761, gbc__min_samples_leaf=0.13376342035312883, gbc__min_samples_split=0.07922487675017734, gbc__n_estimators=100, gbc__subsample=0.9175460099664028; f1_macro: (test=0.517) f1_micro: (test=0.889) roc_auc: (test=0.825) total time=   0.4s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=196, gbc__max_features=3, gbc__max_leaf_nodes=761, gbc__min_samples_leaf=0.13376342035312883, gbc__min_samples_split=0.07922487675017734, gbc__n_estimators=100, gbc__subsample=0.9175460099664028; f1_macro: (test=0.518) f1_micro: (test=0.891) roc_auc: (test=0.827) total time=   0.4s
# [CV 2/5] END gbc__learning_rate=0.1, gbc__max_depth=196, gbc__max_features=3, gbc__max_leaf_nodes=761, gbc__min_samples_leaf=0.13376342035312883, gbc__min_samples_split=0.07922487675017734, gbc__n_estimators=100, gbc__subsample=0.9175460099664028; f1_macro: (test=0.535) f1_micro: (test=0.889) roc_auc: (test=0.817) total time=   0.4s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=196, gbc__max_features=3, gbc__max_leaf_nodes=761, gbc__min_samples_leaf=0.13376342035312883, gbc__min_samples_split=0.07922487675017734, gbc__n_estimators=100, gbc__subsample=0.9175460099664028; f1_macro: (test=0.528) f1_micro: (test=0.892) roc_auc: (test=0.790) total time=   0.4s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=185, gbc__max_features=7, gbc__max_leaf_nodes=3317, gbc__min_samples_leaf=0.1388864799391847, gbc__min_samples_split=0.157231654561522, gbc__n_estimators=50, gbc__subsample=0.9876972128902197; f1_macro: (test=0.584) f1_micro: (test=0.889) roc_auc: (test=0.825) total time=   0.3s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=185, gbc__max_features=7, gbc__max_leaf_nodes=3317, gbc__min_samples_leaf=0.1388864799391847, gbc__min_samples_split=0.157231654561522, gbc__n_estimators=50, gbc__subsample=0.9876972128902197; f1_macro: (test=0.642) f1_micro: (test=0.896) roc_auc: (test=0.826) total time=   0.4s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=185, gbc__max_features=7, gbc__max_leaf_nodes=3317, gbc__min_samples_leaf=0.1388864799391847, gbc__min_samples_split=0.157231654561522, gbc__n_estimators=50, gbc__subsample=0.9876972128902197; f1_macro: (test=0.597) f1_micro: (test=0.895) roc_auc: (test=0.835) total time=   0.3s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=185, gbc__max_features=7, gbc__max_leaf_nodes=3317, gbc__min_samples_leaf=0.1388864799391847, gbc__min_samples_split=0.157231654561522, gbc__n_estimators=50, gbc__subsample=0.9876972128902197; f1_macro: (test=0.650) f1_micro: (test=0.900) roc_auc: (test=0.829) total time=   0.3s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=142, gbc__max_features=7, gbc__max_leaf_nodes=1858, gbc__min_samples_leaf=0.10444068352099825, gbc__min_samples_split=0.1846196253515208, gbc__n_estimators=500, gbc__subsample=0.7197106965754255; f1_macro: (test=0.640) f1_micro: (test=0.891) roc_auc: (test=0.817) total time=   2.7s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=185, gbc__max_features=7, gbc__max_leaf_nodes=3317, gbc__min_samples_leaf=0.1388864799391847, gbc__min_samples_split=0.157231654561522, gbc__n_estimators=50, gbc__subsample=0.9876972128902197; f1_macro: (test=0.572) f1_micro: (test=0.885) roc_auc: (test=0.807) total time=   0.4s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=142, gbc__max_features=7, gbc__max_leaf_nodes=1858, gbc__min_samples_leaf=0.10444068352099825, gbc__min_samples_split=0.1846196253515208, gbc__n_estimators=500, gbc__subsample=0.7197106965754255; f1_macro: (test=0.692) f1_micro: (test=0.897) roc_auc: (test=0.830) total time=   2.3s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=142, gbc__max_features=7, gbc__max_leaf_nodes=1858, gbc__min_samples_leaf=0.10444068352099825, gbc__min_samples_split=0.1846196253515208, gbc__n_estimators=500, gbc__subsample=0.7197106965754255; f1_macro: (test=0.672) f1_micro: (test=0.884) roc_auc: (test=0.827) total time=   2.1s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=142, gbc__max_features=7, gbc__max_leaf_nodes=1858, gbc__min_samples_leaf=0.10444068352099825, gbc__min_samples_split=0.1846196253515208, gbc__n_estimators=500, gbc__subsample=0.7197106965754255; f1_macro: (test=0.660) f1_micro: (test=0.889) roc_auc: (test=0.814) total time=   2.3s
# [CV 1/5] END gbc__learning_rate=1.0, gbc__max_depth=250, gbc__max_features=13, gbc__max_leaf_nodes=4802, gbc__min_samples_leaf=0.10362043545931045, gbc__min_samples_split=0.11439518413307452, gbc__n_estimators=100, gbc__subsample=0.8094945285458958; f1_macro: (test=0.619) f1_micro: (test=0.880) roc_auc: (test=0.779) total time=   0.8s
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=250, gbc__max_features=13, gbc__max_leaf_nodes=4802, gbc__min_samples_leaf=0.10362043545931045, gbc__min_samples_split=0.11439518413307452, gbc__n_estimators=100, gbc__subsample=0.8094945285458958; f1_macro: (test=0.680) f1_micro: (test=0.886) roc_auc: (test=0.796) total time=   1.0s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=142, gbc__max_features=7, gbc__max_leaf_nodes=1858, gbc__min_samples_leaf=0.10444068352099825, gbc__min_samples_split=0.1846196253515208, gbc__n_estimators=500, gbc__subsample=0.7197106965754255; f1_macro: (test=0.631) f1_micro: (test=0.881) roc_auc: (test=0.805) total time=   2.4s
# [CV 3/5] END gbc__learning_rate=1.0, gbc__max_depth=250, gbc__max_features=13, gbc__max_leaf_nodes=4802, gbc__min_samples_leaf=0.10362043545931045, gbc__min_samples_split=0.11439518413307452, gbc__n_estimators=100, gbc__subsample=0.8094945285458958; f1_macro: (test=0.660) f1_micro: (test=0.884) roc_auc: (test=0.789) total time=   0.8s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=56, gbc__max_features=27, gbc__max_leaf_nodes=3603, gbc__min_samples_leaf=0.17433835181892754, gbc__min_samples_split=0.14290419538849747, gbc__n_estimators=50, gbc__subsample=0.7373967032662481; f1_macro: (test=0.550) f1_micro: (test=0.889) roc_auc: (test=0.797) total time=   0.6s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=282, gbc__max_features=42, gbc__max_leaf_nodes=3436, gbc__min_samples_leaf=0.19614625640432354, gbc__min_samples_split=0.050823526107130854, gbc__n_estimators=100, gbc__subsample=0.8922624488333484; f1_macro: (test=0.517) f1_micro: (test=0.889) roc_auc: (test=0.778) total time=   1.6s
# [CV 2/5] END gbc__learning_rate=0.1, gbc__max_depth=282, gbc__max_features=42, gbc__max_leaf_nodes=3436, gbc__min_samples_leaf=0.19614625640432354, gbc__min_samples_split=0.050823526107130854, gbc__n_estimators=100, gbc__subsample=0.8922624488333484; f1_macro: (test=0.486) f1_micro: (test=0.887) roc_auc: (test=0.799) total time=   1.7s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=56, gbc__max_features=27, gbc__max_leaf_nodes=3603, gbc__min_samples_leaf=0.17433835181892754, gbc__min_samples_split=0.14290419538849747, gbc__n_estimators=50, gbc__subsample=0.7373967032662481; f1_macro: (test=0.551) f1_micro: (test=0.889) roc_auc: (test=0.801) total time=   0.5s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=282, gbc__max_features=42, gbc__max_leaf_nodes=3436, gbc__min_samples_leaf=0.19614625640432354, gbc__min_samples_split=0.050823526107130854, gbc__n_estimators=100, gbc__subsample=0.8922624488333484; f1_macro: (test=0.497) f1_micro: (test=0.888) roc_auc: (test=0.803) total time=   1.6s
# [CV 5/5] END gbc__learning_rate=1.0, gbc__max_depth=250, gbc__max_features=13, gbc__max_leaf_nodes=4802, gbc__min_samples_leaf=0.10362043545931045, gbc__min_samples_split=0.11439518413307452, gbc__n_estimators=100, gbc__subsample=0.8094945285458958; f1_macro: (test=0.632) f1_micro: (test=0.882) roc_auc: (test=0.782) total time=   0.8s
# [CV 4/5] END gbc__learning_rate=1.0, gbc__max_depth=250, gbc__max_features=13, gbc__max_leaf_nodes=4802, gbc__min_samples_leaf=0.10362043545931045, gbc__min_samples_split=0.11439518413307452, gbc__n_estimators=100, gbc__subsample=0.8094945285458958; f1_macro: (test=0.642) f1_micro: (test=0.873) roc_auc: (test=0.788) total time=   0.9s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=282, gbc__max_features=42, gbc__max_leaf_nodes=3436, gbc__min_samples_leaf=0.19614625640432354, gbc__min_samples_split=0.050823526107130854, gbc__n_estimators=100, gbc__subsample=0.8922624488333484; f1_macro: (test=0.491) f1_micro: (test=0.887) roc_auc: (test=0.812) total time=   1.7s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=282, gbc__max_features=42, gbc__max_leaf_nodes=3436, gbc__min_samples_leaf=0.19614625640432354, gbc__min_samples_split=0.050823526107130854, gbc__n_estimators=100, gbc__subsample=0.8922624488333484; f1_macro: (test=0.507) f1_micro: (test=0.888) roc_auc: (test=0.786) total time=   1.7s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=56, gbc__max_features=27, gbc__max_leaf_nodes=3603, gbc__min_samples_leaf=0.17433835181892754, gbc__min_samples_split=0.14290419538849747, gbc__n_estimators=50, gbc__subsample=0.7373967032662481; f1_macro: (test=0.554) f1_micro: (test=0.893) roc_auc: (test=0.795) total time=   0.5s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=56, gbc__max_features=27, gbc__max_leaf_nodes=3603, gbc__min_samples_leaf=0.17433835181892754, gbc__min_samples_split=0.14290419538849747, gbc__n_estimators=50, gbc__subsample=0.7373967032662481; f1_macro: (test=0.577) f1_micro: (test=0.893) roc_auc: (test=0.807) total time=   0.5s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=56, gbc__max_features=27, gbc__max_leaf_nodes=3603, gbc__min_samples_leaf=0.17433835181892754, gbc__min_samples_split=0.14290419538849747, gbc__n_estimators=50, gbc__subsample=0.7373967032662481; f1_macro: (test=0.532) f1_micro: (test=0.886) roc_auc: (test=0.777) total time=   0.5s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=234, gbc__max_features=19, gbc__max_leaf_nodes=2909, gbc__min_samples_leaf=0.169461757528293, gbc__min_samples_split=0.17191354931253242, gbc__n_estimators=100, gbc__subsample=0.735815918193566; f1_macro: (test=0.564) f1_micro: (test=0.891) roc_auc: (test=0.792) total time=   0.7s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=234, gbc__max_features=19, gbc__max_leaf_nodes=2909, gbc__min_samples_leaf=0.169461757528293, gbc__min_samples_split=0.17191354931253242, gbc__n_estimators=100, gbc__subsample=0.735815918193566; f1_macro: (test=0.579) f1_micro: (test=0.891) roc_auc: (test=0.809) total time=   0.7s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=234, gbc__max_features=19, gbc__max_leaf_nodes=2909, gbc__min_samples_leaf=0.169461757528293, gbc__min_samples_split=0.17191354931253242, gbc__n_estimators=100, gbc__subsample=0.735815918193566; f1_macro: (test=0.601) f1_micro: (test=0.898) roc_auc: (test=0.796) total time=   0.7s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=234, gbc__max_features=19, gbc__max_leaf_nodes=2909, gbc__min_samples_leaf=0.169461757528293, gbc__min_samples_split=0.17191354931253242, gbc__n_estimators=100, gbc__subsample=0.735815918193566; f1_macro: (test=0.544) f1_micro: (test=0.882) roc_auc: (test=0.783) total time=   0.7s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=234, gbc__max_features=19, gbc__max_leaf_nodes=2909, gbc__min_samples_leaf=0.169461757528293, gbc__min_samples_split=0.17191354931253242, gbc__n_estimators=100, gbc__subsample=0.735815918193566; f1_macro: (test=0.613) f1_micro: (test=0.895) roc_auc: (test=0.812) total time=   0.7s
# [CV 1/5] END gbc__learning_rate=1.0, gbc__max_depth=206, gbc__max_features=4, gbc__max_leaf_nodes=3917, gbc__min_samples_leaf=0.1984629560541059, gbc__min_samples_split=0.08837478819138002, gbc__n_estimators=50, gbc__subsample=0.9346083274084134; f1_macro: (test=0.552) f1_micro: (test=0.882) roc_auc: (test=0.789) total time=   0.2s
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=206, gbc__max_features=4, gbc__max_leaf_nodes=3917, gbc__min_samples_leaf=0.1984629560541059, gbc__min_samples_split=0.08837478819138002, gbc__n_estimators=50, gbc__subsample=0.9346083274084134; f1_macro: (test=0.571) f1_micro: (test=0.887) roc_auc: (test=0.792) total time=   0.2s
# [CV 3/5] END gbc__learning_rate=1.0, gbc__max_depth=206, gbc__max_features=4, gbc__max_leaf_nodes=3917, gbc__min_samples_leaf=0.1984629560541059, gbc__min_samples_split=0.08837478819138002, gbc__n_estimators=50, gbc__subsample=0.9346083274084134; f1_macro: (test=0.556) f1_micro: (test=0.882) roc_auc: (test=0.782) total time=   0.2s
# [CV 4/5] END gbc__learning_rate=1.0, gbc__max_depth=206, gbc__max_features=4, gbc__max_leaf_nodes=3917, gbc__min_samples_leaf=0.1984629560541059, gbc__min_samples_split=0.08837478819138002, gbc__n_estimators=50, gbc__subsample=0.9346083274084134; f1_macro: (test=0.612) f1_micro: (test=0.890) roc_auc: (test=0.778) total time=   0.2s
# [CV 5/5] END gbc__learning_rate=1.0, gbc__max_depth=206, gbc__max_features=4, gbc__max_leaf_nodes=3917, gbc__min_samples_leaf=0.1984629560541059, gbc__min_samples_split=0.08837478819138002, gbc__n_estimators=50, gbc__subsample=0.9346083274084134; f1_macro: (test=0.542) f1_micro: (test=0.879) roc_auc: (test=0.752) total time=   0.2s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=118, gbc__max_features=26, gbc__max_leaf_nodes=3845, gbc__min_samples_leaf=0.16302161820895225, gbc__min_samples_split=0.13931337260741966, gbc__n_estimators=50, gbc__subsample=0.8347600123732597; f1_macro: (test=0.475) f1_micro: (test=0.887) roc_auc: (test=0.778) total time=   0.7s
# [CV 2/5] END gbc__learning_rate=0.1, gbc__max_depth=118, gbc__max_features=26, gbc__max_leaf_nodes=3845, gbc__min_samples_leaf=0.16302161820895225, gbc__min_samples_split=0.13931337260741966, gbc__n_estimators=50, gbc__subsample=0.8347600123732597; f1_macro: (test=0.475) f1_micro: (test=0.887) roc_auc: (test=0.789) total time=   0.6s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=118, gbc__max_features=26, gbc__max_leaf_nodes=3845, gbc__min_samples_leaf=0.16302161820895225, gbc__min_samples_split=0.13931337260741966, gbc__n_estimators=50, gbc__subsample=0.8347600123732597; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.798) total time=   0.6s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=118, gbc__max_features=26, gbc__max_leaf_nodes=3845, gbc__min_samples_leaf=0.16302161820895225, gbc__min_samples_split=0.13931337260741966, gbc__n_estimators=50, gbc__subsample=0.8347600123732597; f1_macro: (test=0.470) f1_micro: (test=0.886) roc_auc: (test=0.806) total time=   0.7s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=118, gbc__max_features=26, gbc__max_leaf_nodes=3845, gbc__min_samples_leaf=0.16302161820895225, gbc__min_samples_split=0.13931337260741966, gbc__n_estimators=50, gbc__subsample=0.8347600123732597; f1_macro: (test=0.475) f1_micro: (test=0.885) roc_auc: (test=0.774) total time=   0.6s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=3, gbc__max_features=24, gbc__max_leaf_nodes=2579, gbc__min_samples_leaf=0.19335940070024352, gbc__min_samples_split=0.09708808025842382, gbc__n_estimators=500, gbc__subsample=0.8547347621124382; f1_macro: (test=0.638) f1_micro: (test=0.887) roc_auc: (test=0.809) total time=   4.2s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=3, gbc__max_features=24, gbc__max_leaf_nodes=2579, gbc__min_samples_leaf=0.19335940070024352, gbc__min_samples_split=0.09708808025842382, gbc__n_estimators=500, gbc__subsample=0.8547347621124382; f1_macro: (test=0.612) f1_micro: (test=0.892) roc_auc: (test=0.795) total time=   4.5s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=3, gbc__max_features=24, gbc__max_leaf_nodes=2579, gbc__min_samples_leaf=0.19335940070024352, gbc__min_samples_split=0.09708808025842382, gbc__n_estimators=500, gbc__subsample=0.8547347621124382; f1_macro: (test=0.591) f1_micro: (test=0.881) roc_auc: (test=0.780) total time=   4.2s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=3, gbc__max_features=24, gbc__max_leaf_nodes=2579, gbc__min_samples_leaf=0.19335940070024352, gbc__min_samples_split=0.09708808025842382, gbc__n_estimators=500, gbc__subsample=0.8547347621124382; f1_macro: (test=0.637) f1_micro: (test=0.894) roc_auc: (test=0.802) total time=   4.5s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=3, gbc__max_features=24, gbc__max_leaf_nodes=2579, gbc__min_samples_leaf=0.19335940070024352, gbc__min_samples_split=0.09708808025842382, gbc__n_estimators=500, gbc__subsample=0.8547347621124382; f1_macro: (test=0.618) f1_micro: (test=0.886) roc_auc: (test=0.780) total time=   4.7s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=78, gbc__max_features=32, gbc__max_leaf_nodes=611, gbc__min_samples_leaf=0.12147532486634591, gbc__min_samples_split=0.188730068324278, gbc__n_estimators=100, gbc__subsample=0.8801521979859208; f1_macro: (test=0.625) f1_micro: (test=0.896) roc_auc: (test=0.834) total time=   1.7s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=78, gbc__max_features=32, gbc__max_leaf_nodes=611, gbc__min_samples_leaf=0.12147532486634591, gbc__min_samples_split=0.188730068324278, gbc__n_estimators=100, gbc__subsample=0.8801521979859208; f1_macro: (test=0.623) f1_micro: (test=0.891) roc_auc: (test=0.830) total time=   1.7s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=78, gbc__max_features=32, gbc__max_leaf_nodes=611, gbc__min_samples_leaf=0.12147532486634591, gbc__min_samples_split=0.188730068324278, gbc__n_estimators=100, gbc__subsample=0.8801521979859208; f1_macro: (test=0.644) f1_micro: (test=0.888) roc_auc: (test=0.825) total time=   1.8s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=78, gbc__max_features=32, gbc__max_leaf_nodes=611, gbc__min_samples_leaf=0.12147532486634591, gbc__min_samples_split=0.188730068324278, gbc__n_estimators=100, gbc__subsample=0.8801521979859208; f1_macro: (test=0.597) f1_micro: (test=0.882) roc_auc: (test=0.804) total time=   1.7s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=78, gbc__max_features=32, gbc__max_leaf_nodes=611, gbc__min_samples_leaf=0.12147532486634591, gbc__min_samples_split=0.188730068324278, gbc__n_estimators=100, gbc__subsample=0.8801521979859208; f1_macro: (test=0.625) f1_micro: (test=0.889) roc_auc: (test=0.828) total time=   1.9s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=13, gbc__max_features=18, gbc__max_leaf_nodes=794, gbc__min_samples_leaf=0.0276551878475828, gbc__min_samples_split=0.15561794154051048, gbc__n_estimators=500, gbc__subsample=0.9487914291725283; f1_macro: (test=0.651) f1_micro: (test=0.886) roc_auc: (test=0.819) total time=  11.4s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=13, gbc__max_features=18, gbc__max_leaf_nodes=794, gbc__min_samples_leaf=0.0276551878475828, gbc__min_samples_split=0.15561794154051048, gbc__n_estimators=500, gbc__subsample=0.9487914291725283; f1_macro: (test=0.679) f1_micro: (test=0.895) roc_auc: (test=0.818) total time=  11.6s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=13, gbc__max_features=18, gbc__max_leaf_nodes=794, gbc__min_samples_leaf=0.0276551878475828, gbc__min_samples_split=0.15561794154051048, gbc__n_estimators=500, gbc__subsample=0.9487914291725283; f1_macro: (test=0.668) f1_micro: (test=0.890) roc_auc: (test=0.838) total time=  11.9s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=94, gbc__max_features=33, gbc__max_leaf_nodes=1199, gbc__min_samples_leaf=0.08918897770113413, gbc__min_samples_split=0.1999116461732323, gbc__n_estimators=100, gbc__subsample=0.9375127954289361; f1_macro: (test=0.618) f1_micro: (test=0.890) roc_auc: (test=0.842) total time=   2.2s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=13, gbc__max_features=18, gbc__max_leaf_nodes=794, gbc__min_samples_leaf=0.0276551878475828, gbc__min_samples_split=0.15561794154051048, gbc__n_estimators=500, gbc__subsample=0.9487914291725283; f1_macro: (test=0.649) f1_micro: (test=0.892) roc_auc: (test=0.824) total time=  12.0s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=13, gbc__max_features=18, gbc__max_leaf_nodes=794, gbc__min_samples_leaf=0.0276551878475828, gbc__min_samples_split=0.15561794154051048, gbc__n_estimators=500, gbc__subsample=0.9487914291725283; f1_macro: (test=0.681) f1_micro: (test=0.897) roc_auc: (test=0.827) total time=  12.6s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=94, gbc__max_features=33, gbc__max_leaf_nodes=1199, gbc__min_samples_leaf=0.08918897770113413, gbc__min_samples_split=0.1999116461732323, gbc__n_estimators=100, gbc__subsample=0.9375127954289361; f1_macro: (test=0.677) f1_micro: (test=0.895) roc_auc: (test=0.835) total time=   2.3s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=44, gbc__max_features=21, gbc__max_leaf_nodes=539, gbc__min_samples_leaf=0.0349597387966941, gbc__min_samples_split=0.17166220479505742, gbc__n_estimators=50, gbc__subsample=0.9839315662463655; f1_macro: (test=0.585) f1_micro: (test=0.894) roc_auc: (test=0.841) total time=   1.3s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=94, gbc__max_features=33, gbc__max_leaf_nodes=1199, gbc__min_samples_leaf=0.08918897770113413, gbc__min_samples_split=0.1999116461732323, gbc__n_estimators=100, gbc__subsample=0.9375127954289361; f1_macro: (test=0.675) f1_micro: (test=0.899) roc_auc: (test=0.834) total time=   2.5s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=94, gbc__max_features=33, gbc__max_leaf_nodes=1199, gbc__min_samples_leaf=0.08918897770113413, gbc__min_samples_split=0.1999116461732323, gbc__n_estimators=100, gbc__subsample=0.9375127954289361; f1_macro: (test=0.624) f1_micro: (test=0.880) roc_auc: (test=0.812) total time=   2.5s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=94, gbc__max_features=33, gbc__max_leaf_nodes=1199, gbc__min_samples_leaf=0.08918897770113413, gbc__min_samples_split=0.1999116461732323, gbc__n_estimators=100, gbc__subsample=0.9375127954289361; f1_macro: (test=0.672) f1_micro: (test=0.894) roc_auc: (test=0.835) total time=   2.6s
# [CV 2/5] END gbc__learning_rate=0.1, gbc__max_depth=44, gbc__max_features=21, gbc__max_leaf_nodes=539, gbc__min_samples_leaf=0.0349597387966941, gbc__min_samples_split=0.17166220479505742, gbc__n_estimators=50, gbc__subsample=0.9839315662463655; f1_macro: (test=0.638) f1_micro: (test=0.907) roc_auc: (test=0.858) total time=   1.2s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=44, gbc__max_features=21, gbc__max_leaf_nodes=539, gbc__min_samples_leaf=0.0349597387966941, gbc__min_samples_split=0.17166220479505742, gbc__n_estimators=50, gbc__subsample=0.9839315662463655; f1_macro: (test=0.608) f1_micro: (test=0.899) roc_auc: (test=0.850) total time=   1.2s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=44, gbc__max_features=21, gbc__max_leaf_nodes=539, gbc__min_samples_leaf=0.0349597387966941, gbc__min_samples_split=0.17166220479505742, gbc__n_estimators=50, gbc__subsample=0.9839315662463655; f1_macro: (test=0.630) f1_micro: (test=0.904) roc_auc: (test=0.860) total time=   1.4s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=44, gbc__max_features=21, gbc__max_leaf_nodes=539, gbc__min_samples_leaf=0.0349597387966941, gbc__min_samples_split=0.17166220479505742, gbc__n_estimators=50, gbc__subsample=0.9839315662463655; f1_macro: (test=0.602) f1_micro: (test=0.894) roc_auc: (test=0.813) total time=   1.4s
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=68, gbc__max_features=40, gbc__max_leaf_nodes=1256, gbc__min_samples_leaf=0.10139102608032664, gbc__min_samples_split=0.07365960622869082, gbc__n_estimators=500, gbc__subsample=0.8749240069417424; f1_macro: (test=0.653) f1_micro: (test=0.875) roc_auc: (test=0.802) total time=  11.6s
# [CV 5/5] END gbc__learning_rate=1.0, gbc__max_depth=68, gbc__max_features=40, gbc__max_leaf_nodes=1256, gbc__min_samples_leaf=0.10139102608032664, gbc__min_samples_split=0.07365960622869082, gbc__n_estimators=500, gbc__subsample=0.8749240069417424; f1_macro: (test=0.634) f1_micro: (test=0.875) roc_auc: (test=0.774) total time=  11.6s
# [CV 3/5] END gbc__learning_rate=1.0, gbc__max_depth=68, gbc__max_features=40, gbc__max_leaf_nodes=1256, gbc__min_samples_leaf=0.10139102608032664, gbc__min_samples_split=0.07365960622869082, gbc__n_estimators=500, gbc__subsample=0.8749240069417424; f1_macro: (test=0.619) f1_micro: (test=0.864) roc_auc: (test=0.788) total time=  11.7s
# [CV 1/5] END gbc__learning_rate=1.0, gbc__max_depth=68, gbc__max_features=40, gbc__max_leaf_nodes=1256, gbc__min_samples_leaf=0.10139102608032664, gbc__min_samples_split=0.07365960622869082, gbc__n_estimators=500, gbc__subsample=0.8749240069417424; f1_macro: (test=0.637) f1_micro: (test=0.879) roc_auc: (test=0.784) total time=  11.9s
# [CV 4/5] END gbc__learning_rate=1.0, gbc__max_depth=68, gbc__max_features=40, gbc__max_leaf_nodes=1256, gbc__min_samples_leaf=0.10139102608032664, gbc__min_samples_split=0.07365960622869082, gbc__n_estimators=500, gbc__subsample=0.8749240069417424; f1_macro: (test=0.644) f1_micro: (test=0.871) roc_auc: (test=0.797) total time=  11.9s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=97, gbc__max_features=39, gbc__max_leaf_nodes=2855, gbc__min_samples_leaf=0.02911818681604166, gbc__min_samples_split=0.11423195617777357, gbc__n_estimators=50, gbc__subsample=0.8200672030867898; f1_macro: (test=0.583) f1_micro: (test=0.892) roc_auc: (test=0.850) total time=   2.1s
# [CV 2/5] END gbc__learning_rate=0.1, gbc__max_depth=97, gbc__max_features=39, gbc__max_leaf_nodes=2855, gbc__min_samples_leaf=0.02911818681604166, gbc__min_samples_split=0.11423195617777357, gbc__n_estimators=50, gbc__subsample=0.8200672030867898; f1_macro: (test=0.651) f1_micro: (test=0.907) roc_auc: (test=0.861) total time=   2.2s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=97, gbc__max_features=39, gbc__max_leaf_nodes=2855, gbc__min_samples_leaf=0.02911818681604166, gbc__min_samples_split=0.11423195617777357, gbc__n_estimators=50, gbc__subsample=0.8200672030867898; f1_macro: (test=0.639) f1_micro: (test=0.904) roc_auc: (test=0.861) total time=   2.2s
# [CV 2/5] END gbc__learning_rate=0.1, gbc__max_depth=129, gbc__max_features=17, gbc__max_leaf_nodes=3161, gbc__min_samples_leaf=0.04222684992789613, gbc__min_samples_split=0.1912814661369777, gbc__n_estimators=500, gbc__subsample=0.9488136530060358; f1_macro: (test=0.686) f1_micro: (test=0.902) roc_auc: (test=0.856) total time=   9.5s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=129, gbc__max_features=17, gbc__max_leaf_nodes=3161, gbc__min_samples_leaf=0.04222684992789613, gbc__min_samples_split=0.1912814661369777, gbc__n_estimators=500, gbc__subsample=0.9488136530060358; f1_macro: (test=0.665) f1_micro: (test=0.898) roc_auc: (test=0.852) total time=   9.6s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=129, gbc__max_features=17, gbc__max_leaf_nodes=3161, gbc__min_samples_leaf=0.04222684992789613, gbc__min_samples_split=0.1912814661369777, gbc__n_estimators=500, gbc__subsample=0.9488136530060358; f1_macro: (test=0.674) f1_micro: (test=0.901) roc_auc: (test=0.850) total time=   9.9s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=129, gbc__max_features=17, gbc__max_leaf_nodes=3161, gbc__min_samples_leaf=0.04222684992789613, gbc__min_samples_split=0.1912814661369777, gbc__n_estimators=500, gbc__subsample=0.9488136530060358; f1_macro: (test=0.660) f1_micro: (test=0.893) roc_auc: (test=0.838) total time=   9.5s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=129, gbc__max_features=17, gbc__max_leaf_nodes=3161, gbc__min_samples_leaf=0.04222684992789613, gbc__min_samples_split=0.1912814661369777, gbc__n_estimators=500, gbc__subsample=0.9488136530060358; f1_macro: (test=0.629) f1_micro: (test=0.886) roc_auc: (test=0.829) total time=   9.5s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=290, gbc__max_features=10, gbc__max_leaf_nodes=1552, gbc__min_samples_leaf=0.0498967289710591, gbc__min_samples_split=0.1494714531944152, gbc__n_estimators=100, gbc__subsample=0.8225988703947174; f1_macro: (test=0.608) f1_micro: (test=0.896) roc_auc: (test=0.853) total time=   1.0s
# [CV 2/5] END gbc__learning_rate=0.1, gbc__max_depth=290, gbc__max_features=10, gbc__max_leaf_nodes=1552, gbc__min_samples_leaf=0.0498967289710591, gbc__min_samples_split=0.1494714531944152, gbc__n_estimators=100, gbc__subsample=0.8225988703947174; f1_macro: (test=0.663) f1_micro: (test=0.905) roc_auc: (test=0.862) total time=   1.0s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=290, gbc__max_features=10, gbc__max_leaf_nodes=1552, gbc__min_samples_leaf=0.0498967289710591, gbc__min_samples_split=0.1494714531944152, gbc__n_estimators=100, gbc__subsample=0.8225988703947174; f1_macro: (test=0.651) f1_micro: (test=0.906) roc_auc: (test=0.858) total time=   1.0s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=97, gbc__max_features=39, gbc__max_leaf_nodes=2855, gbc__min_samples_leaf=0.02911818681604166, gbc__min_samples_split=0.11423195617777357, gbc__n_estimators=50, gbc__subsample=0.8200672030867898; f1_macro: (test=0.613) f1_micro: (test=0.896) roc_auc: (test=0.850) total time=   2.1s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=290, gbc__max_features=10, gbc__max_leaf_nodes=1552, gbc__min_samples_leaf=0.0498967289710591, gbc__min_samples_split=0.1494714531944152, gbc__n_estimators=100, gbc__subsample=0.8225988703947174; f1_macro: (test=0.594) f1_micro: (test=0.890) roc_auc: (test=0.832) total time=   1.1s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=290, gbc__max_features=10, gbc__max_leaf_nodes=1552, gbc__min_samples_leaf=0.0498967289710591, gbc__min_samples_split=0.1494714531944152, gbc__n_estimators=100, gbc__subsample=0.8225988703947174; f1_macro: (test=0.639) f1_micro: (test=0.899) roc_auc: (test=0.851) total time=   1.2s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=97, gbc__max_features=39, gbc__max_leaf_nodes=2855, gbc__min_samples_leaf=0.02911818681604166, gbc__min_samples_split=0.11423195617777357, gbc__n_estimators=50, gbc__subsample=0.8200672030867898; f1_macro: (test=0.593) f1_micro: (test=0.892) roc_auc: (test=0.818) total time=   2.4s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=201, gbc__max_features=2, gbc__max_leaf_nodes=2778, gbc__min_samples_leaf=0.1184538540051683, gbc__min_samples_split=0.03506767510893712, gbc__n_estimators=500, gbc__subsample=0.7349007030690745; f1_macro: (test=0.606) f1_micro: (test=0.882) roc_auc: (test=0.812) total time=   1.3s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=201, gbc__max_features=2, gbc__max_leaf_nodes=2778, gbc__min_samples_leaf=0.1184538540051683, gbc__min_samples_split=0.03506767510893712, gbc__n_estimators=500, gbc__subsample=0.7349007030690745; f1_macro: (test=0.664) f1_micro: (test=0.896) roc_auc: (test=0.808) total time=   1.2s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=201, gbc__max_features=2, gbc__max_leaf_nodes=2778, gbc__min_samples_leaf=0.1184538540051683, gbc__min_samples_split=0.03506767510893712, gbc__n_estimators=500, gbc__subsample=0.7349007030690745; f1_macro: (test=0.652) f1_micro: (test=0.894) roc_auc: (test=0.804) total time=   1.4s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=201, gbc__max_features=2, gbc__max_leaf_nodes=2778, gbc__min_samples_leaf=0.1184538540051683, gbc__min_samples_split=0.03506767510893712, gbc__n_estimators=500, gbc__subsample=0.7349007030690745; f1_macro: (test=0.638) f1_micro: (test=0.887) roc_auc: (test=0.810) total time=   1.3s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=201, gbc__max_features=2, gbc__max_leaf_nodes=2778, gbc__min_samples_leaf=0.1184538540051683, gbc__min_samples_split=0.03506767510893712, gbc__n_estimators=500, gbc__subsample=0.7349007030690745; f1_macro: (test=0.596) f1_micro: (test=0.884) roc_auc: (test=0.799) total time=   1.4s
# [CV 1/5] END gbc__learning_rate=1.0, gbc__max_depth=172, gbc__max_features=40, gbc__max_leaf_nodes=4871, gbc__min_samples_leaf=0.057543549756521734, gbc__min_samples_split=0.16791722985661992, gbc__n_estimators=50, gbc__subsample=0.7270700266170368; f1_macro: (test=0.642) f1_micro: (test=0.876) roc_auc: (test=0.792) total time=   1.3s
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=172, gbc__max_features=40, gbc__max_leaf_nodes=4871, gbc__min_samples_leaf=0.057543549756521734, gbc__min_samples_split=0.16791722985661992, gbc__n_estimators=50, gbc__subsample=0.7270700266170368; f1_macro: (test=0.656) f1_micro: (test=0.879) roc_auc: (test=0.799) total time=   1.2s
# [CV 3/5] END gbc__learning_rate=1.0, gbc__max_depth=172, gbc__max_features=40, gbc__max_leaf_nodes=4871, gbc__min_samples_leaf=0.057543549756521734, gbc__min_samples_split=0.16791722985661992, gbc__n_estimators=50, gbc__subsample=0.7270700266170368; f1_macro: (test=0.651) f1_micro: (test=0.882) roc_auc: (test=0.818) total time=   1.2s
# [CV 4/5] END gbc__learning_rate=1.0, gbc__max_depth=172, gbc__max_features=40, gbc__max_leaf_nodes=4871, gbc__min_samples_leaf=0.057543549756521734, gbc__min_samples_split=0.16791722985661992, gbc__n_estimators=50, gbc__subsample=0.7270700266170368; f1_macro: (test=0.641) f1_micro: (test=0.872) roc_auc: (test=0.806) total time=   1.3s
# [CV 5/5] END gbc__learning_rate=1.0, gbc__max_depth=172, gbc__max_features=40, gbc__max_leaf_nodes=4871, gbc__min_samples_leaf=0.057543549756521734, gbc__min_samples_split=0.16791722985661992, gbc__n_estimators=50, gbc__subsample=0.7270700266170368; f1_macro: (test=0.609) f1_micro: (test=0.864) roc_auc: (test=0.777) total time=   1.3s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=99, gbc__max_features=30, gbc__max_leaf_nodes=4342, gbc__min_samples_leaf=0.0013856954477621253, gbc__min_samples_split=0.16357386985449388, gbc__n_estimators=50, gbc__subsample=0.716589147242517; f1_macro: (test=0.600) f1_micro: (test=0.892) roc_auc: (test=0.834) total time=   2.1s
# [CV 1/5] END gbc__learning_rate=1.0, gbc__max_depth=48, gbc__max_features=43, gbc__max_leaf_nodes=617, gbc__min_samples_leaf=0.063463610311384, gbc__min_samples_split=0.02211657639668653, gbc__n_estimators=500, gbc__subsample=0.797655518893684; f1_macro: (test=0.641) f1_micro: (test=0.877) roc_auc: (test=0.805) total time=  15.9s
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=48, gbc__max_features=43, gbc__max_leaf_nodes=617, gbc__min_samples_leaf=0.063463610311384, gbc__min_samples_split=0.02211657639668653, gbc__n_estimators=500, gbc__subsample=0.797655518893684; f1_macro: (test=0.661) f1_micro: (test=0.877) roc_auc: (test=0.807) total time=  15.0s
# ...
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=160, gbc__max_features=2, gbc__max_leaf_nodes=1468, gbc__min_samples_leaf=0.14216082672374425, gbc__min_samples_split=0.013348491296427192, gbc__n_estimators=100, gbc__subsample=0.8244343198129969; f1_macro: (test=0.630) f1_micro: (test=0.889) roc_auc: (test=0.793) total time=   0.3s
# [CV 4/5] END gbc__learning_rate=1.0, gbc__max_depth=160, gbc__max_features=2, gbc__max_leaf_nodes=1468, gbc__min_samples_leaf=0.14216082672374425, gbc__min_samples_split=0.013348491296427192, gbc__n_estimators=100, gbc__subsample=0.8244343198129969; f1_macro: (test=0.621) f1_micro: (test=0.884) roc_auc: (test=0.797) total time=   0.3s
# [CV 5/5] END gbc__learning_rate=1.0, gbc__max_depth=160, gbc__max_features=2, gbc__max_leaf_nodes=1468, gbc__min_samples_leaf=0.14216082672374425, gbc__min_samples_split=0.013348491296427192, gbc__n_estimators=100, gbc__subsample=0.8244343198129969; f1_macro: (test=0.593) f1_micro: (test=0.884) roc_auc: (test=0.783) total time=   0.3s
# [CV 3/5] END gbc__learning_rate=1.0, gbc__max_depth=160, gbc__max_features=2, gbc__max_leaf_nodes=1468, gbc__min_samples_leaf=0.14216082672374425, gbc__min_samples_split=0.013348491296427192, gbc__n_estimators=100, gbc__subsample=0.8244343198129969; f1_macro: (test=0.625) f1_micro: (test=0.891) roc_auc: (test=0.801) total time=   0.3s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=96, gbc__max_features=23, gbc__max_leaf_nodes=2141, gbc__min_samples_leaf=0.18017515564585876, gbc__min_samples_split=0.13294085911713252, gbc__n_estimators=100, gbc__subsample=0.8317908278120589; f1_macro: (test=0.497) f1_micro: (test=0.888) roc_auc: (test=0.803) total time=   1.1s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=96, gbc__max_features=23, gbc__max_leaf_nodes=2141, gbc__min_samples_leaf=0.18017515564585876, gbc__min_samples_split=0.13294085911713252, gbc__n_estimators=100, gbc__subsample=0.8317908278120589; f1_macro: (test=0.496) f1_micro: (test=0.887) roc_auc: (test=0.814) total time=   1.0s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=96, gbc__max_features=23, gbc__max_leaf_nodes=2141, gbc__min_samples_leaf=0.18017515564585876, gbc__min_samples_split=0.13294085911713252, gbc__n_estimators=100, gbc__subsample=0.8317908278120589; f1_macro: (test=0.507) f1_micro: (test=0.888) roc_auc: (test=0.783) total time=   1.0s
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=281, gbc__max_features=4, gbc__max_leaf_nodes=3077, gbc__min_samples_leaf=0.07081797425555955, gbc__min_samples_split=0.1936554602197183, gbc__n_estimators=100, gbc__subsample=0.8989870998472056; f1_macro: (test=0.675) f1_micro: (test=0.887) roc_auc: (test=0.825) total time=   0.5s
# [CV 1/5] END gbc__learning_rate=1.0, gbc__max_depth=281, gbc__max_features=4, gbc__max_leaf_nodes=3077, gbc__min_samples_leaf=0.07081797425555955, gbc__min_samples_split=0.1936554602197183, gbc__n_estimators=100, gbc__subsample=0.8989870998472056; f1_macro: (test=0.642) f1_micro: (test=0.883) roc_auc: (test=0.813) total time=   0.5s
# [CV 3/5] END gbc__learning_rate=1.0, gbc__max_depth=281, gbc__max_features=4, gbc__max_leaf_nodes=3077, gbc__min_samples_leaf=0.07081797425555955, gbc__min_samples_split=0.1936554602197183, gbc__n_estimators=100, gbc__subsample=0.8989870998472056; f1_macro: (test=0.649) f1_micro: (test=0.878) roc_auc: (test=0.809) total time=   0.5s
# [CV 4/5] END gbc__learning_rate=1.0, gbc__max_depth=281, gbc__max_features=4, gbc__max_leaf_nodes=3077, gbc__min_samples_leaf=0.07081797425555955, gbc__min_samples_split=0.1936554602197183, gbc__n_estimators=100, gbc__subsample=0.8989870998472056; f1_macro: (test=0.652) f1_micro: (test=0.876) roc_auc: (test=0.807) total time=   0.5s
# [CV 5/5] END gbc__learning_rate=1.0, gbc__max_depth=281, gbc__max_features=4, gbc__max_leaf_nodes=3077, gbc__min_samples_leaf=0.07081797425555955, gbc__min_samples_split=0.1936554602197183, gbc__n_estimators=100, gbc__subsample=0.8989870998472056; f1_macro: (test=0.617) f1_micro: (test=0.871) roc_auc: (test=0.777) total time=   0.5s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=253, gbc__max_features=38, gbc__max_leaf_nodes=4551, gbc__min_samples_leaf=0.1909191607289794, gbc__min_samples_split=0.12222492956081625, gbc__n_estimators=50, gbc__subsample=0.9641280581069285; f1_macro: (test=0.578) f1_micro: (test=0.894) roc_auc: (test=0.812) total time=   0.9s
# [CV 1/5] END gbc__learning_rate=0.1, gbc__max_depth=235, gbc__max_features=49, gbc__max_leaf_nodes=2440, gbc__min_samples_leaf=0.1118949624395006, gbc__min_samples_split=0.18706832242997923, gbc__n_estimators=500, gbc__subsample=0.9874254426586675; f1_macro: (test=0.631) f1_micro: (test=0.898) roc_auc: (test=0.840) total time=  17.0s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=253, gbc__max_features=38, gbc__max_leaf_nodes=4551, gbc__min_samples_leaf=0.1909191607289794, gbc__min_samples_split=0.12222492956081625, gbc__n_estimators=50, gbc__subsample=0.9641280581069285; f1_macro: (test=0.593) f1_micro: (test=0.894) roc_auc: (test=0.814) total time=   0.9s
# [CV 2/5] END gbc__learning_rate=0.1, gbc__max_depth=235, gbc__max_features=49, gbc__max_leaf_nodes=2440, gbc__min_samples_leaf=0.1118949624395006, gbc__min_samples_split=0.18706832242997923, gbc__n_estimators=500, gbc__subsample=0.9874254426586675; f1_macro: (test=0.645) f1_micro: (test=0.894) roc_auc: (test=0.828) total time=  17.0s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=253, gbc__max_features=38, gbc__max_leaf_nodes=4551, gbc__min_samples_leaf=0.1909191607289794, gbc__min_samples_split=0.12222492956081625, gbc__n_estimators=50, gbc__subsample=0.9641280581069285; f1_macro: (test=0.549) f1_micro: (test=0.887) roc_auc: (test=0.801) total time=   0.9s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=253, gbc__max_features=38, gbc__max_leaf_nodes=4551, gbc__min_samples_leaf=0.1909191607289794, gbc__min_samples_split=0.12222492956081625, gbc__n_estimators=50, gbc__subsample=0.9641280581069285; f1_macro: (test=0.577) f1_micro: (test=0.892) roc_auc: (test=0.810) total time=   0.9s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=253, gbc__max_features=38, gbc__max_leaf_nodes=4551, gbc__min_samples_leaf=0.1909191607289794, gbc__min_samples_split=0.12222492956081625, gbc__n_estimators=50, gbc__subsample=0.9641280581069285; f1_macro: (test=0.613) f1_micro: (test=0.893) roc_auc: (test=0.829) total time=   0.9s
# [CV 4/5] END gbc__learning_rate=0.1, gbc__max_depth=235, gbc__max_features=49, gbc__max_leaf_nodes=2440, gbc__min_samples_leaf=0.1118949624395006, gbc__min_samples_split=0.18706832242997923, gbc__n_estimators=500, gbc__subsample=0.9874254426586675; f1_macro: (test=0.653) f1_micro: (test=0.895) roc_auc: (test=0.828) total time=  16.7s
# [CV 3/5] END gbc__learning_rate=0.1, gbc__max_depth=235, gbc__max_features=49, gbc__max_leaf_nodes=2440, gbc__min_samples_leaf=0.1118949624395006, gbc__min_samples_split=0.18706832242997923, gbc__n_estimators=500, gbc__subsample=0.9874254426586675; f1_macro: (test=0.668) f1_micro: (test=0.902) roc_auc: (test=0.829) total time=  18.1s
# [CV 5/5] END gbc__learning_rate=0.1, gbc__max_depth=235, gbc__max_features=49, gbc__max_leaf_nodes=2440, gbc__min_samples_leaf=0.1118949624395006, gbc__min_samples_split=0.18706832242997923, gbc__n_estimators=500, gbc__subsample=0.9874254426586675; f1_macro: (test=0.632) f1_micro: (test=0.892) roc_auc: (test=0.819) total time=  17.8s
# [CV 1/5] END gbc__learning_rate=1.0, gbc__max_depth=280, gbc__max_features=30, gbc__max_leaf_nodes=3122, gbc__min_samples_leaf=0.1372549456690588, gbc__min_samples_split=0.025687965014480136, gbc__n_estimators=100, gbc__subsample=0.9577738749371376; f1_macro: (test=0.624) f1_micro: (test=0.882) roc_auc: (test=0.807) total time=   1.8s
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=280, gbc__max_features=30, gbc__max_leaf_nodes=3122, gbc__min_samples_leaf=0.1372549456690588, gbc__min_samples_split=0.025687965014480136, gbc__n_estimators=100, gbc__subsample=0.9577738749371376; f1_macro: (test=0.655) f1_micro: (test=0.885) roc_auc: (test=0.815) total time=   1.9s
# [CV 4/5] END gbc__learning_rate=1.0, gbc__max_depth=280, gbc__max_features=30, gbc__max_leaf_nodes=3122, gbc__min_samples_leaf=0.1372549456690588, gbc__min_samples_split=0.025687965014480136, gbc__n_estimators=100, gbc__subsample=0.9577738749371376; f1_macro: (test=0.648) f1_micro: (test=0.881) roc_auc: (test=0.814) total time=   1.7s
# [CV 3/5] END gbc__learning_rate=1.0, gbc__max_depth=280, gbc__max_features=30, gbc__max_leaf_nodes=3122, gbc__min_samples_leaf=0.1372549456690588, gbc__min_samples_split=0.025687965014480136, gbc__n_estimators=100, gbc__subsample=0.9577738749371376; f1_macro: (test=0.642) f1_micro: (test=0.886) roc_auc: (test=0.797) total time=   1.9s
# [CV 5/5] END gbc__learning_rate=1.0, gbc__max_depth=280, gbc__max_features=30, gbc__max_leaf_nodes=3122, gbc__min_samples_leaf=0.1372549456690588, gbc__min_samples_split=0.025687965014480136, gbc__n_estimators=100, gbc__subsample=0.9577738749371376; f1_macro: (test=0.617) f1_micro: (test=0.880) roc_auc: (test=0.794) total time=   2.0s
# [CV 1/5] END gbc__learning_rate=1.0, gbc__max_depth=110, gbc__max_features=20, gbc__max_leaf_nodes=4275, gbc__min_samples_leaf=0.009852962643879623, gbc__min_samples_split=0.16503759798217554, gbc__n_estimators=100, gbc__subsample=0.7987631693516266; f1_macro: (test=0.647) f1_micro: (test=0.870) roc_auc: (test=0.786) total time=   3.2s
# [CV 2/5] END gbc__learning_rate=1.0, gbc__max_depth=110, gbc__max_features=20, gbc__max_leaf_nodes=4275, gbc__min_samples_leaf=0.009852962643879623, gbc__min_samples_split=0.16503759798217554, gbc__n_estimators=100, gbc__subsample=0.7987631693516266; f1_macro: (test=0.637) f1_micro: (test=0.865) roc_auc: (test=0.796) total time=   2.8s
# [CV 3/5] END gbc__learning_rate=1.0, gbc__max_depth=110, gbc__max_features=20, gbc__max_leaf_nodes=4275, gbc__min_samples_leaf=0.009852962643879623, gbc__min_samples_split=0.16503759798217554, gbc__n_estimators=100, gbc__subsample=0.7987631693516266; f1_macro: (test=0.663) f1_micro: (test=0.880) roc_auc: (test=0.787) total time=   2.8s
# [CV 4/5] END gbc__learning_rate=1.0, gbc__max_depth=110, gbc__max_features=20, gbc__max_leaf_nodes=4275, gbc__min_samples_leaf=0.009852962643879623, gbc__min_samples_split=0.16503759798217554, gbc__n_estimators=100, gbc__subsample=0.7987631693516266; f1_macro: (test=0.660) f1_micro: (test=0.871) roc_auc: (test=0.775) total time=   2.8s
# [CV 5/5] END gbc__learning_rate=1.0, gbc__max_depth=110, gbc__max_features=20, gbc__max_leaf_nodes=4275, gbc__min_samples_leaf=0.009852962643879623, gbc__min_samples_split=0.16503759798217554, gbc__n_estimators=100, gbc__subsample=0.7987631693516266; f1_macro: (test=0.657) f1_micro: (test=0.873) roc_auc: (test=0.813) total time=   3.1s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=61, gbc__max_features=33, gbc__max_leaf_nodes=2012, gbc__min_samples_leaf=0.0947687165509702, gbc__min_samples_split=0.0784330619496187, gbc__n_estimators=500, gbc__subsample=0.770849019989645; f1_macro: (test=0.621) f1_micro: (test=0.879) roc_auc: (test=0.796) total time=   8.4s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=61, gbc__max_features=33, gbc__max_leaf_nodes=2012, gbc__min_samples_leaf=0.0947687165509702, gbc__min_samples_split=0.0784330619496187, gbc__n_estimators=500, gbc__subsample=0.770849019989645; f1_macro: (test=0.655) f1_micro: (test=0.885) roc_auc: (test=0.811) total time=   8.5s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=61, gbc__max_features=33, gbc__max_leaf_nodes=2012, gbc__min_samples_leaf=0.0947687165509702, gbc__min_samples_split=0.0784330619496187, gbc__n_estimators=500, gbc__subsample=0.770849019989645; f1_macro: (test=0.628) f1_micro: (test=0.879) roc_auc: (test=0.790) total time=   8.4s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=61, gbc__max_features=33, gbc__max_leaf_nodes=2012, gbc__min_samples_leaf=0.0947687165509702, gbc__min_samples_split=0.0784330619496187, gbc__n_estimators=500, gbc__subsample=0.770849019989645; f1_macro: (test=0.651) f1_micro: (test=0.886) roc_auc: (test=0.821) total time=   8.6s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=61, gbc__max_features=33, gbc__max_leaf_nodes=2012, gbc__min_samples_leaf=0.0947687165509702, gbc__min_samples_split=0.0784330619496187, gbc__n_estimators=500, gbc__subsample=0.770849019989645; f1_macro: (test=0.640) f1_micro: (test=0.871) roc_auc: (test=0.789) total time=   8.5s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=184, gbc__max_features=21, gbc__max_leaf_nodes=3467, gbc__min_samples_leaf=0.07257810940023805, gbc__min_samples_split=0.1487140019233447, gbc__n_estimators=500, gbc__subsample=0.7999948033435165; f1_macro: (test=0.664) f1_micro: (test=0.891) roc_auc: (test=0.806) total time=   6.8s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=184, gbc__max_features=21, gbc__max_leaf_nodes=3467, gbc__min_samples_leaf=0.07257810940023805, gbc__min_samples_split=0.1487140019233447, gbc__n_estimators=500, gbc__subsample=0.7999948033435165; f1_macro: (test=0.657) f1_micro: (test=0.888) roc_auc: (test=0.816) total time=   6.3s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=184, gbc__max_features=21, gbc__max_leaf_nodes=3467, gbc__min_samples_leaf=0.07257810940023805, gbc__min_samples_split=0.1487140019233447, gbc__n_estimators=500, gbc__subsample=0.7999948033435165; f1_macro: (test=0.650) f1_micro: (test=0.879) roc_auc: (test=0.806) total time=   6.4s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=184, gbc__max_features=21, gbc__max_leaf_nodes=3467, gbc__min_samples_leaf=0.07257810940023805, gbc__min_samples_split=0.1487140019233447, gbc__n_estimators=500, gbc__subsample=0.7999948033435165; f1_macro: (test=0.669) f1_micro: (test=0.884) roc_auc: (test=0.823) total time=   6.6s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=184, gbc__max_features=21, gbc__max_leaf_nodes=3467, gbc__min_samples_leaf=0.07257810940023805, gbc__min_samples_split=0.1487140019233447, gbc__n_estimators=500, gbc__subsample=0.7999948033435165; f1_macro: (test=0.663) f1_micro: (test=0.889) roc_auc: (test=0.801) total time=   7.1s
# [CV 2/5] END gbc__learning_rate=0.5, gbc__max_depth=198, gbc__max_features=28, gbc__max_leaf_nodes=1544, gbc__min_samples_leaf=0.020442470204994893, gbc__min_samples_split=0.14794722141290298, gbc__n_estimators=500, gbc__subsample=0.9828556727422029; f1_macro: (test=0.688) f1_micro: (test=0.896) roc_auc: (test=0.844) total time=  21.5s
# [CV 4/5] END gbc__learning_rate=0.5, gbc__max_depth=198, gbc__max_features=28, gbc__max_leaf_nodes=1544, gbc__min_samples_leaf=0.020442470204994893, gbc__min_samples_split=0.14794722141290298, gbc__n_estimators=500, gbc__subsample=0.9828556727422029; f1_macro: (test=0.667) f1_micro: (test=0.891) roc_auc: (test=0.815) total time=  21.5s
# [CV 1/5] END gbc__learning_rate=0.5, gbc__max_depth=198, gbc__max_features=28, gbc__max_leaf_nodes=1544, gbc__min_samples_leaf=0.020442470204994893, gbc__min_samples_split=0.14794722141290298, gbc__n_estimators=500, gbc__subsample=0.9828556727422029; f1_macro: (test=0.657) f1_micro: (test=0.892) roc_auc: (test=0.827) total time=  23.0s
# [CV 3/5] END gbc__learning_rate=0.5, gbc__max_depth=198, gbc__max_features=28, gbc__max_leaf_nodes=1544, gbc__min_samples_leaf=0.020442470204994893, gbc__min_samples_split=0.14794722141290298, gbc__n_estimators=500, gbc__subsample=0.9828556727422029; f1_macro: (test=0.659) f1_micro: (test=0.891) roc_auc: (test=0.835) total time=  22.0s
# [CV 5/5] END gbc__learning_rate=0.5, gbc__max_depth=198, gbc__max_features=28, gbc__max_leaf_nodes=1544, gbc__min_samples_leaf=0.020442470204994893, gbc__min_samples_split=0.14794722141290298, gbc__n_estimators=500, gbc__subsample=0.9828556727422029; f1_macro: (test=0.656) f1_micro: (test=0.889) roc_auc: (test=0.818) total time=  22.6s

# %% [markdown]
# With 40 hyperparameter combinations, it takes approximately 2 minutes.

# %%
# Load saved pickle
with open('hyperparameter_tuning/gboost/gboost_noresampling_50comb.pkl', 'rb') as f:
    loaded = pickle.load(f)
    best_params_gboost, best_scores_gboost = loaded

print('Best parameters of Gradient Boosting:', best_params_gboost, '\n')

print('Best scores of Gradient Boosting:', best_scores_gboost, '\n')
# Out:
# Best parameters of Gradient Boosting: {'gbc__learning_rate': 0.1, 'gbc__max_depth': 290, 'gbc__max_features': 10, 'gbc__max_leaf_nodes': 1552, 'gbc__min_samples_leaf': 0.0498967289710591, 'gbc__min_samples_split': 0.1494714531944152, 'gbc__n_estimators': 100, 'gbc__subsample': 0.8225988703947174}
#
# Best scores of Gradient Boosting: {'f1_micro': 0.89925, 'f1_macro': 0.6308805699227621, 'roc_auc': 0.8512078940716947}

# %% [markdown]
# ## LGBMClassifier

# %% [markdown]
# #### A. No resampling (without considering class imbalance)

# %%
best_params_lgbm, best_scores_lgbm = baseline_models(
        df=dfv3, numerical_features=numerical_features, categorical_features=categorical_features,
        target='HOSPITAL_EXPIRE_FLAG', model=LGBMClassifier, ada_boost = False, 
        n_hyper_comb = 100, num_imputer = "median", refit_score = 'roc_auc', resampling_method = 'none'
)

# Combine dictionaries into a list
combined_lgbm = [best_params_lgbm, best_scores_lgbm]

# Save into a pickle (name of file states model, if resampling technique was
# applied and the number of hyperparameter combinations tried)
with open('hyperparameter_tuning/lgbm/lgbm_noresampling_100comb.pkl', 'wb') as f:
    pickle.dump(combined_lgbm, f)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5514969290700589, lgb__learning_rate=0.01, lgb__min_child_samples=12, lgb__min_split_gain=0.06297576132346906, lgb__num_leaves=31, lgb__reg_lambda=0.35781360448354893; f1_macro: (test=0.497) f1_micro: (test=0.889) roc_auc: (test=0.817) total time=   5.8s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5908888858951135, lgb__learning_rate=0.3, lgb__min_child_samples=27, lgb__min_split_gain=0.08888648231916156, lgb__num_leaves=31, lgb__reg_lambda=0.7869854599999133; f1_macro: (test=0.642) f1_micro: (test=0.897) roc_auc: (test=0.822) total time=   5.9s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.871283110454845, lgb__learning_rate=0.3, lgb__min_child_samples=11, lgb__min_split_gain=0.021551321485037845, lgb__num_leaves=31, lgb__reg_lambda=0.6524186154656548; f1_macro: (test=0.640) f1_micro: (test=0.894) roc_auc: (test=0.820) total time=   6.4s[CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5908888858951135, lgb__learning_rate=0.3, lgb__min_child_samples=27, lgb__min_split_gain=0.08888648231916156, lgb__num_leaves=31, lgb__reg_lambda=0.7869854599999133; f1_macro: (test=0.596) f1_micro: (test=0.891) roc_auc: (test=0.792) total time=   6.5s
#
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5514969290700589, lgb__learning_rate=0.01, lgb__min_child_samples=12, lgb__min_split_gain=0.06297576132346906, lgb__num_leaves=31, lgb__reg_lambda=0.35781360448354893; f1_macro: (test=0.539) f1_micro: (test=0.894) roc_auc: (test=0.817) total time=   6.8s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5514969290700589, lgb__learning_rate=0.01, lgb__min_child_samples=12, lgb__min_split_gain=0.06297576132346906, lgb__num_leaves=31, lgb__reg_lambda=0.35781360448354893; f1_macro: (test=0.534) f1_micro: (test=0.894) roc_auc: (test=0.846) total time=   6.8s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.871283110454845, lgb__learning_rate=0.3, lgb__min_child_samples=11, lgb__min_split_gain=0.021551321485037845, lgb__num_leaves=31, lgb__reg_lambda=0.6524186154656548; f1_macro: (test=0.631) f1_micro: (test=0.891) roc_auc: (test=0.831) total time=   6.8s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5908888858951135, lgb__learning_rate=0.3, lgb__min_child_samples=27, lgb__min_split_gain=0.08888648231916156, lgb__num_leaves=31, lgb__reg_lambda=0.7869854599999133; f1_macro: (test=0.678) f1_micro: (test=0.908) roc_auc: (test=0.826) total time=   7.3s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5908888858951135, lgb__learning_rate=0.3, lgb__min_child_samples=27, lgb__min_split_gain=0.08888648231916156, lgb__num_leaves=31, lgb__reg_lambda=0.7869854599999133; f1_macro: (test=0.627) f1_micro: (test=0.901) roc_auc: (test=0.842) total time=   7.7s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.871283110454845, lgb__learning_rate=0.3, lgb__min_child_samples=11, lgb__min_split_gain=0.021551321485037845, lgb__num_leaves=31, lgb__reg_lambda=0.6524186154656548; f1_macro: (test=0.689) f1_micro: (test=0.904) roc_auc: (test=0.840) total time=   7.7s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.871283110454845, lgb__learning_rate=0.3, lgb__min_child_samples=11, lgb__min_split_gain=0.021551321485037845, lgb__num_leaves=31, lgb__reg_lambda=0.6524186154656548; f1_macro: (test=0.673) f1_micro: (test=0.901) roc_auc: (test=0.851) total time=   7.7s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5514969290700589, lgb__learning_rate=0.01, lgb__min_child_samples=12, lgb__min_split_gain=0.06297576132346906, lgb__num_leaves=31, lgb__reg_lambda=0.35781360448354893; f1_macro: (test=0.508) f1_micro: (test=0.890) roc_auc: (test=0.847) total time=   7.9s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5514969290700589, lgb__learning_rate=0.01, lgb__min_child_samples=12, lgb__min_split_gain=0.06297576132346906, lgb__num_leaves=31, lgb__reg_lambda=0.35781360448354893; f1_macro: (test=0.523) f1_micro: (test=0.891) roc_auc: (test=0.858) total time=   8.1s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5908888858951135, lgb__learning_rate=0.3, lgb__min_child_samples=27, lgb__min_split_gain=0.08888648231916156, lgb__num_leaves=31, lgb__reg_lambda=0.7869854599999133; f1_macro: (test=0.610) f1_micro: (test=0.890) roc_auc: (test=0.792) total time=   8.3s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.871283110454845, lgb__learning_rate=0.3, lgb__min_child_samples=11, lgb__min_split_gain=0.021551321485037845, lgb__num_leaves=31, lgb__reg_lambda=0.6524186154656548; f1_macro: (test=0.665) f1_micro: (test=0.901) roc_auc: (test=0.837) total time=   9.7s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5411698746062403, lgb__learning_rate=0.3, lgb__min_child_samples=7, lgb__min_split_gain=0.015895874456727545, lgb__num_leaves=31, lgb__reg_lambda=0.804911033201756; f1_macro: (test=0.595) f1_micro: (test=0.893) roc_auc: (test=0.790) total time=   5.9s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.559531716993128, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.037785405876478675, lgb__num_leaves=63, lgb__reg_lambda=0.29772571830177164; f1_macro: (test=0.631) f1_micro: (test=0.896) roc_auc: (test=0.836) total time=  15.6s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8325667793126454, lgb__learning_rate=0.3, lgb__min_child_samples=28, lgb__min_split_gain=0.019877387220034307, lgb__num_leaves=63, lgb__reg_lambda=0.7936866474746995; f1_macro: (test=0.630) f1_micro: (test=0.893) roc_auc: (test=0.835) total time=   9.4s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8325667793126454, lgb__learning_rate=0.3, lgb__min_child_samples=28, lgb__min_split_gain=0.019877387220034307, lgb__num_leaves=63, lgb__reg_lambda=0.7936866474746995; f1_macro: (test=0.630) f1_micro: (test=0.891) roc_auc: (test=0.833) total time=   9.5s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.559531716993128, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.037785405876478675, lgb__num_leaves=63, lgb__reg_lambda=0.29772571830177164; f1_macro: (test=0.660) f1_micro: (test=0.901) roc_auc: (test=0.870) total time=  13.5s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8325667793126454, lgb__learning_rate=0.3, lgb__min_child_samples=28, lgb__min_split_gain=0.019877387220034307, lgb__num_leaves=63, lgb__reg_lambda=0.7936866474746995; f1_macro: (test=0.676) f1_micro: (test=0.900) roc_auc: (test=0.857) total time=  11.7s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8325667793126454, lgb__learning_rate=0.3, lgb__min_child_samples=28, lgb__min_split_gain=0.019877387220034307, lgb__num_leaves=63, lgb__reg_lambda=0.7936866474746995; f1_macro: (test=0.675) f1_micro: (test=0.899) roc_auc: (test=0.840) total time=  11.8s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8325667793126454, lgb__learning_rate=0.3, lgb__min_child_samples=28, lgb__min_split_gain=0.019877387220034307, lgb__num_leaves=63, lgb__reg_lambda=0.7936866474746995; f1_macro: (test=0.649) f1_micro: (test=0.899) roc_auc: (test=0.847) total time=  12.4s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.559531716993128, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.037785405876478675, lgb__num_leaves=63, lgb__reg_lambda=0.29772571830177164; f1_macro: (test=0.656) f1_micro: (test=0.901) roc_auc: (test=0.832) total time=  14.7s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.559531716993128, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.037785405876478675, lgb__num_leaves=63, lgb__reg_lambda=0.29772571830177164; f1_macro: (test=0.659) f1_micro: (test=0.904) roc_auc: (test=0.859) total time=  16.5s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5411698746062403, lgb__learning_rate=0.3, lgb__min_child_samples=7, lgb__min_split_gain=0.015895874456727545, lgb__num_leaves=31, lgb__reg_lambda=0.804911033201756; f1_macro: (test=0.626) f1_micro: (test=0.902) roc_auc: (test=0.842) total time=   7.0s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.559531716993128, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.037785405876478675, lgb__num_leaves=63, lgb__reg_lambda=0.29772571830177164; f1_macro: (test=0.627) f1_micro: (test=0.897) roc_auc: (test=0.831) total time=  16.4s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5411698746062403, lgb__learning_rate=0.3, lgb__min_child_samples=7, lgb__min_split_gain=0.015895874456727545, lgb__num_leaves=31, lgb__reg_lambda=0.804911033201756; f1_macro: (test=0.673) f1_micro: (test=0.908) roc_auc: (test=0.826) total time=   8.0s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5411698746062403, lgb__learning_rate=0.3, lgb__min_child_samples=7, lgb__min_split_gain=0.015895874456727545, lgb__num_leaves=31, lgb__reg_lambda=0.804911033201756; f1_macro: (test=0.649) f1_micro: (test=0.901) roc_auc: (test=0.828) total time=   7.5s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5411698746062403, lgb__learning_rate=0.3, lgb__min_child_samples=7, lgb__min_split_gain=0.015895874456727545, lgb__num_leaves=31, lgb__reg_lambda=0.804911033201756; f1_macro: (test=0.607) f1_micro: (test=0.891) roc_auc: (test=0.796) total time=   7.5s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.762335648372946, lgb__learning_rate=0.15, lgb__min_child_samples=29, lgb__min_split_gain=0.032508951737347525, lgb__num_leaves=127, lgb__reg_lambda=0.14390392077532788; f1_macro: (test=0.653) f1_micro: (test=0.902) roc_auc: (test=0.860) total time=  19.9s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.762335648372946, lgb__learning_rate=0.15, lgb__min_child_samples=29, lgb__min_split_gain=0.032508951737347525, lgb__num_leaves=127, lgb__reg_lambda=0.14390392077532788; f1_macro: (test=0.622) f1_micro: (test=0.893) roc_auc: (test=0.832) total time=  20.1s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.762335648372946, lgb__learning_rate=0.15, lgb__min_child_samples=29, lgb__min_split_gain=0.032508951737347525, lgb__num_leaves=127, lgb__reg_lambda=0.14390392077532788; f1_macro: (test=0.669) f1_micro: (test=0.902) roc_auc: (test=0.832) total time=  20.7s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.762335648372946, lgb__learning_rate=0.15, lgb__min_child_samples=29, lgb__min_split_gain=0.032508951737347525, lgb__num_leaves=127, lgb__reg_lambda=0.14390392077532788; f1_macro: (test=0.632) f1_micro: (test=0.896) roc_auc: (test=0.830) total time=  20.8s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5250290808036032, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.0009888059554519879, lgb__num_leaves=31, lgb__reg_lambda=0.13394566757579296; f1_macro: (test=0.639) f1_micro: (test=0.894) roc_auc: (test=0.828) total time=   6.5s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5250290808036032, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.0009888059554519879, lgb__num_leaves=31, lgb__reg_lambda=0.13394566757579296; f1_macro: (test=0.608) f1_micro: (test=0.894) roc_auc: (test=0.789) total time=   7.8s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5250290808036032, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.0009888059554519879, lgb__num_leaves=31, lgb__reg_lambda=0.13394566757579296; f1_macro: (test=0.687) f1_micro: (test=0.908) roc_auc: (test=0.829) total time=   7.9s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.762335648372946, lgb__learning_rate=0.15, lgb__min_child_samples=29, lgb__min_split_gain=0.032508951737347525, lgb__num_leaves=127, lgb__reg_lambda=0.14390392077532788; f1_macro: (test=0.665) f1_micro: (test=0.903) roc_auc: (test=0.870) total time=  24.1s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5250290808036032, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.0009888059554519879, lgb__num_leaves=31, lgb__reg_lambda=0.13394566757579296; f1_macro: (test=0.639) f1_micro: (test=0.901) roc_auc: (test=0.844) total time=   8.2s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7224980330600344, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.03276879867015684, lgb__num_leaves=127, lgb__reg_lambda=0.9607877564667782; f1_macro: (test=0.625) f1_micro: (test=0.893) roc_auc: (test=0.830) total time=  12.3s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5250290808036032, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.0009888059554519879, lgb__num_leaves=31, lgb__reg_lambda=0.13394566757579296; f1_macro: (test=0.612) f1_micro: (test=0.890) roc_auc: (test=0.797) total time=   7.9s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7224980330600344, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.03276879867015684, lgb__num_leaves=127, lgb__reg_lambda=0.9607877564667782; f1_macro: (test=0.665) f1_micro: (test=0.903) roc_auc: (test=0.837) total time=  12.7s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7224980330600344, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.03276879867015684, lgb__num_leaves=127, lgb__reg_lambda=0.9607877564667782; f1_macro: (test=0.635) f1_micro: (test=0.894) roc_auc: (test=0.827) total time=  12.9s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.789642038872035, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.09543378655569243, lgb__num_leaves=15, lgb__reg_lambda=0.2256229824075504; f1_macro: (test=0.587) f1_micro: (test=0.886) roc_auc: (test=0.762) total time=   3.7s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7224980330600344, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.03276879867015684, lgb__num_leaves=127, lgb__reg_lambda=0.9607877564667782; f1_macro: (test=0.664) f1_micro: (test=0.899) roc_auc: (test=0.855) total time=  16.1s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.789642038872035, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.09543378655569243, lgb__num_leaves=15, lgb__reg_lambda=0.2256229824075504; f1_macro: (test=0.664) f1_micro: (test=0.902) roc_auc: (test=0.800) total time=   3.9s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7224980330600344, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.03276879867015684, lgb__num_leaves=127, lgb__reg_lambda=0.9607877564667782; f1_macro: (test=0.633) f1_micro: (test=0.897) roc_auc: (test=0.847) total time=  17.2s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.789642038872035, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.09543378655569243, lgb__num_leaves=15, lgb__reg_lambda=0.2256229824075504; f1_macro: (test=0.623) f1_micro: (test=0.894) roc_auc: (test=0.810) total time=   5.3s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.789642038872035, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.09543378655569243, lgb__num_leaves=15, lgb__reg_lambda=0.2256229824075504; f1_macro: (test=0.637) f1_micro: (test=0.892) roc_auc: (test=0.793) total time=   4.6s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.789642038872035, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.09543378655569243, lgb__num_leaves=15, lgb__reg_lambda=0.2256229824075504; f1_macro: (test=0.603) f1_micro: (test=0.887) roc_auc: (test=0.752) total time=   4.6s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7603175317556659, lgb__learning_rate=0.15, lgb__min_child_samples=19, lgb__min_split_gain=0.013042928220861906, lgb__num_leaves=63, lgb__reg_lambda=0.010695636761950844; f1_macro: (test=0.695) f1_micro: (test=0.902) roc_auc: (test=0.820) total time=  11.7s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7603175317556659, lgb__learning_rate=0.15, lgb__min_child_samples=19, lgb__min_split_gain=0.013042928220861906, lgb__num_leaves=63, lgb__reg_lambda=0.010695636761950844; f1_macro: (test=0.628) f1_micro: (test=0.883) roc_auc: (test=0.799) total time=  12.8s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7603175317556659, lgb__learning_rate=0.15, lgb__min_child_samples=19, lgb__min_split_gain=0.013042928220861906, lgb__num_leaves=63, lgb__reg_lambda=0.010695636761950844; f1_macro: (test=0.669) f1_micro: (test=0.892) roc_auc: (test=0.823) total time=  12.1s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9419321088666186, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.07955946473535244, lgb__num_leaves=63, lgb__reg_lambda=0.4513896917704029; f1_macro: (test=0.629) f1_micro: (test=0.892) roc_auc: (test=0.832) total time=   8.5s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9419321088666186, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.07955946473535244, lgb__num_leaves=63, lgb__reg_lambda=0.4513896917704029; f1_macro: (test=0.682) f1_micro: (test=0.904) roc_auc: (test=0.848) total time=   7.8s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7603175317556659, lgb__learning_rate=0.15, lgb__min_child_samples=19, lgb__min_split_gain=0.013042928220861906, lgb__num_leaves=63, lgb__reg_lambda=0.010695636761950844; f1_macro: (test=0.646) f1_micro: (test=0.893) roc_auc: (test=0.842) total time=  13.8s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9419321088666186, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.07955946473535244, lgb__num_leaves=63, lgb__reg_lambda=0.4513896917704029; f1_macro: (test=0.667) f1_micro: (test=0.897) roc_auc: (test=0.833) total time=   6.5s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9419321088666186, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.07955946473535244, lgb__num_leaves=63, lgb__reg_lambda=0.4513896917704029; f1_macro: (test=0.672) f1_micro: (test=0.903) roc_auc: (test=0.851) total time=   7.8s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7603175317556659, lgb__learning_rate=0.15, lgb__min_child_samples=19, lgb__min_split_gain=0.013042928220861906, lgb__num_leaves=63, lgb__reg_lambda=0.010695636761950844; f1_macro: (test=0.630) f1_micro: (test=0.881) roc_auc: (test=0.801) total time=  14.3s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9419321088666186, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.07955946473535244, lgb__num_leaves=63, lgb__reg_lambda=0.4513896917704029; f1_macro: (test=0.628) f1_micro: (test=0.894) roc_auc: (test=0.819) total time=   8.5s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5413677446267017, lgb__learning_rate=0.3, lgb__min_child_samples=29, lgb__min_split_gain=0.08585246688775272, lgb__num_leaves=63, lgb__reg_lambda=0.5243967382988608; f1_macro: (test=0.666) f1_micro: (test=0.904) roc_auc: (test=0.836) total time=   7.3s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5413677446267017, lgb__learning_rate=0.3, lgb__min_child_samples=29, lgb__min_split_gain=0.08585246688775272, lgb__num_leaves=63, lgb__reg_lambda=0.5243967382988608; f1_macro: (test=0.637) f1_micro: (test=0.892) roc_auc: (test=0.815) total time=   8.2s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9613169276639503, lgb__learning_rate=0.3, lgb__min_child_samples=8, lgb__min_split_gain=0.0029156996519808854, lgb__num_leaves=127, lgb__reg_lambda=0.2882989975605308; f1_macro: (test=0.630) f1_micro: (test=0.864) roc_auc: (test=0.790) total time=  27.1s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5413677446267017, lgb__learning_rate=0.3, lgb__min_child_samples=29, lgb__min_split_gain=0.08585246688775272, lgb__num_leaves=63, lgb__reg_lambda=0.5243967382988608; f1_macro: (test=0.673) f1_micro: (test=0.902) roc_auc: (test=0.853) total time=   8.3s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9613169276639503, lgb__learning_rate=0.3, lgb__min_child_samples=8, lgb__min_split_gain=0.0029156996519808854, lgb__num_leaves=127, lgb__reg_lambda=0.2882989975605308; f1_macro: (test=0.650) f1_micro: (test=0.866) roc_auc: (test=0.782) total time=  26.2s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5413677446267017, lgb__learning_rate=0.3, lgb__min_child_samples=29, lgb__min_split_gain=0.08585246688775272, lgb__num_leaves=63, lgb__reg_lambda=0.5243967382988608; f1_macro: (test=0.640) f1_micro: (test=0.891) roc_auc: (test=0.835) total time=   8.6s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9613169276639503, lgb__learning_rate=0.3, lgb__min_child_samples=8, lgb__min_split_gain=0.0029156996519808854, lgb__num_leaves=127, lgb__reg_lambda=0.2882989975605308; f1_macro: (test=0.645) f1_micro: (test=0.863) roc_auc: (test=0.796) total time=  26.4s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5413677446267017, lgb__learning_rate=0.3, lgb__min_child_samples=29, lgb__min_split_gain=0.08585246688775272, lgb__num_leaves=63, lgb__reg_lambda=0.5243967382988608; f1_macro: (test=0.657) f1_micro: (test=0.894) roc_auc: (test=0.831) total time=   9.5s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.6766406258903097, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.024537239045975004, lgb__num_leaves=31, lgb__reg_lambda=0.15913789767122088; f1_macro: (test=0.606) f1_micro: (test=0.887) roc_auc: (test=0.778) total time=   7.4s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9613169276639503, lgb__learning_rate=0.3, lgb__min_child_samples=8, lgb__min_split_gain=0.0029156996519808854, lgb__num_leaves=127, lgb__reg_lambda=0.2882989975605308; f1_macro: (test=0.623) f1_micro: (test=0.854) roc_auc: (test=0.767) total time=  27.3s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7268687309711035, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.010616885236333874, lgb__num_leaves=15, lgb__reg_lambda=0.6098765802409186; f1_macro: (test=0.622) f1_micro: (test=0.897) roc_auc: (test=0.816) total time=   2.8s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7268687309711035, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.010616885236333874, lgb__num_leaves=15, lgb__reg_lambda=0.6098765802409186; f1_macro: (test=0.589) f1_micro: (test=0.888) roc_auc: (test=0.762) total time=   4.6s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7268687309711035, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.010616885236333874, lgb__num_leaves=15, lgb__reg_lambda=0.6098765802409186; f1_macro: (test=0.609) f1_micro: (test=0.892) roc_auc: (test=0.757) total time=   3.2s[CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7268687309711035, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.010616885236333874, lgb__num_leaves=15, lgb__reg_lambda=0.6098765802409186; f1_macro: (test=0.651) f1_micro: (test=0.902) roc_auc: (test=0.800) total time=   3.7s
#
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7268687309711035, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.010616885236333874, lgb__num_leaves=15, lgb__reg_lambda=0.6098765802409186; f1_macro: (test=0.639) f1_micro: (test=0.897) roc_auc: (test=0.798) total time=   4.0s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9613169276639503, lgb__learning_rate=0.3, lgb__min_child_samples=8, lgb__min_split_gain=0.0029156996519808854, lgb__num_leaves=127, lgb__reg_lambda=0.2882989975605308; f1_macro: (test=0.649) f1_micro: (test=0.868) roc_auc: (test=0.815) total time=  32.2s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.6766406258903097, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.024537239045975004, lgb__num_leaves=31, lgb__reg_lambda=0.15913789767122088; f1_macro: (test=0.686) f1_micro: (test=0.906) roc_auc: (test=0.816) total time=   7.0s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.6766406258903097, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.024537239045975004, lgb__num_leaves=31, lgb__reg_lambda=0.15913789767122088; f1_macro: (test=0.650) f1_micro: (test=0.901) roc_auc: (test=0.836) total time=   6.7s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.6766406258903097, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.024537239045975004, lgb__num_leaves=31, lgb__reg_lambda=0.15913789767122088; f1_macro: (test=0.623) f1_micro: (test=0.887) roc_auc: (test=0.786) total time=   7.4s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.6766406258903097, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.024537239045975004, lgb__num_leaves=31, lgb__reg_lambda=0.15913789767122088; f1_macro: (test=0.653) f1_micro: (test=0.895) roc_auc: (test=0.816) total time=   9.4s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.540075668932015, lgb__learning_rate=0.3, lgb__min_child_samples=13, lgb__min_split_gain=0.07130864089874243, lgb__num_leaves=15, lgb__reg_lambda=0.12465567755416018; f1_macro: (test=0.605) f1_micro: (test=0.894) roc_auc: (test=0.764) total time=   4.0s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.540075668932015, lgb__learning_rate=0.3, lgb__min_child_samples=13, lgb__min_split_gain=0.07130864089874243, lgb__num_leaves=15, lgb__reg_lambda=0.12465567755416018; f1_macro: (test=0.625) f1_micro: (test=0.900) roc_auc: (test=0.832) total time=   3.6s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9580550431947776, lgb__learning_rate=0.15, lgb__min_child_samples=12, lgb__min_split_gain=0.023638112638259948, lgb__num_leaves=127, lgb__reg_lambda=0.912999173370326; f1_macro: (test=0.640) f1_micro: (test=0.900) roc_auc: (test=0.841) total time=  23.4s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.540075668932015, lgb__learning_rate=0.3, lgb__min_child_samples=13, lgb__min_split_gain=0.07130864089874243, lgb__num_leaves=15, lgb__reg_lambda=0.12465567755416018; f1_macro: (test=0.673) f1_micro: (test=0.908) roc_auc: (test=0.810) total time=   4.5s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.540075668932015, lgb__learning_rate=0.3, lgb__min_child_samples=13, lgb__min_split_gain=0.07130864089874243, lgb__num_leaves=15, lgb__reg_lambda=0.12465567755416018; f1_macro: (test=0.635) f1_micro: (test=0.896) roc_auc: (test=0.807) total time=   4.9s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.540075668932015, lgb__learning_rate=0.3, lgb__min_child_samples=13, lgb__min_split_gain=0.07130864089874243, lgb__num_leaves=15, lgb__reg_lambda=0.12465567755416018; f1_macro: (test=0.616) f1_micro: (test=0.892) roc_auc: (test=0.761) total time=   5.0s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9580550431947776, lgb__learning_rate=0.15, lgb__min_child_samples=12, lgb__min_split_gain=0.023638112638259948, lgb__num_leaves=127, lgb__reg_lambda=0.912999173370326; f1_macro: (test=0.669) f1_micro: (test=0.901) roc_auc: (test=0.867) total time=  23.5s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9580550431947776, lgb__learning_rate=0.15, lgb__min_child_samples=12, lgb__min_split_gain=0.023638112638259948, lgb__num_leaves=127, lgb__reg_lambda=0.912999173370326; f1_macro: (test=0.616) f1_micro: (test=0.892) roc_auc: (test=0.819) total time=  24.4s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.75784029009877, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09880066615714264, lgb__num_leaves=63, lgb__reg_lambda=0.6222051270167803; f1_macro: (test=0.611) f1_micro: (test=0.889) roc_auc: (test=0.802) total time=  13.4s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.75784029009877, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09880066615714264, lgb__num_leaves=63, lgb__reg_lambda=0.6222051270167803; f1_macro: (test=0.688) f1_micro: (test=0.906) roc_auc: (test=0.830) total time=  12.1s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9580550431947776, lgb__learning_rate=0.15, lgb__min_child_samples=12, lgb__min_split_gain=0.023638112638259948, lgb__num_leaves=127, lgb__reg_lambda=0.912999173370326; f1_macro: (test=0.668) f1_micro: (test=0.902) roc_auc: (test=0.840) total time=  26.5s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.75784029009877, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09880066615714264, lgb__num_leaves=63, lgb__reg_lambda=0.6222051270167803; f1_macro: (test=0.636) f1_micro: (test=0.895) roc_auc: (test=0.842) total time=  13.3s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9580550431947776, lgb__learning_rate=0.15, lgb__min_child_samples=12, lgb__min_split_gain=0.023638112638259948, lgb__num_leaves=127, lgb__reg_lambda=0.912999173370326; f1_macro: (test=0.640) f1_micro: (test=0.900) roc_auc: (test=0.859) total time=  28.2s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.75784029009877, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09880066615714264, lgb__num_leaves=63, lgb__reg_lambda=0.6222051270167803; f1_macro: (test=0.621) f1_micro: (test=0.892) roc_auc: (test=0.805) total time=  14.4s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7465511692932634, lgb__learning_rate=0.15, lgb__min_child_samples=7, lgb__min_split_gain=0.06602489038035729, lgb__num_leaves=15, lgb__reg_lambda=0.9479230192085655; f1_macro: (test=0.642) f1_micro: (test=0.902) roc_auc: (test=0.799) total time=   3.0s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7465511692932634, lgb__learning_rate=0.15, lgb__min_child_samples=7, lgb__min_split_gain=0.06602489038035729, lgb__num_leaves=15, lgb__reg_lambda=0.9479230192085655; f1_macro: (test=0.594) f1_micro: (test=0.890) roc_auc: (test=0.760) total time=   3.6s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.75784029009877, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09880066615714264, lgb__num_leaves=63, lgb__reg_lambda=0.6222051270167803; f1_macro: (test=0.645) f1_micro: (test=0.889) roc_auc: (test=0.819) total time=  16.4s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7465511692932634, lgb__learning_rate=0.15, lgb__min_child_samples=7, lgb__min_split_gain=0.06602489038035729, lgb__num_leaves=15, lgb__reg_lambda=0.9479230192085655; f1_macro: (test=0.619) f1_micro: (test=0.897) roc_auc: (test=0.817) total time=   4.0s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7465511692932634, lgb__learning_rate=0.15, lgb__min_child_samples=7, lgb__min_split_gain=0.06602489038035729, lgb__num_leaves=15, lgb__reg_lambda=0.9479230192085655; f1_macro: (test=0.649) f1_micro: (test=0.899) roc_auc: (test=0.798) total time=   4.7s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7465511692932634, lgb__learning_rate=0.15, lgb__min_child_samples=7, lgb__min_split_gain=0.06602489038035729, lgb__num_leaves=15, lgb__reg_lambda=0.9479230192085655; f1_macro: (test=0.607) f1_micro: (test=0.887) roc_auc: (test=0.757) total time=   5.1s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8724896056084032, lgb__learning_rate=0.15, lgb__min_child_samples=28, lgb__min_split_gain=0.05147053338756159, lgb__num_leaves=127, lgb__reg_lambda=0.1323335830782506; f1_macro: (test=0.606) f1_micro: (test=0.871) roc_auc: (test=0.785) total time=  21.7s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8724896056084032, lgb__learning_rate=0.15, lgb__min_child_samples=28, lgb__min_split_gain=0.05147053338756159, lgb__num_leaves=127, lgb__reg_lambda=0.1323335830782506; f1_macro: (test=0.646) f1_micro: (test=0.882) roc_auc: (test=0.832) total time=  21.9s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8724896056084032, lgb__learning_rate=0.15, lgb__min_child_samples=28, lgb__min_split_gain=0.05147053338756159, lgb__num_leaves=127, lgb__reg_lambda=0.1323335830782506; f1_macro: (test=0.668) f1_micro: (test=0.887) roc_auc: (test=0.813) total time=  22.4s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8303248124611105, lgb__learning_rate=0.15, lgb__min_child_samples=13, lgb__min_split_gain=0.0049894936134145754, lgb__num_leaves=63, lgb__reg_lambda=0.4828546746654463; f1_macro: (test=0.666) f1_micro: (test=0.896) roc_auc: (test=0.809) total time=  11.9s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8303248124611105, lgb__learning_rate=0.15, lgb__min_child_samples=13, lgb__min_split_gain=0.0049894936134145754, lgb__num_leaves=63, lgb__reg_lambda=0.4828546746654463; f1_macro: (test=0.651) f1_micro: (test=0.892) roc_auc: (test=0.816) total time=  10.2s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8724896056084032, lgb__learning_rate=0.15, lgb__min_child_samples=28, lgb__min_split_gain=0.05147053338756159, lgb__num_leaves=127, lgb__reg_lambda=0.1323335830782506; f1_macro: (test=0.610) f1_micro: (test=0.874) roc_auc: (test=0.787) total time=  22.4s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.757891270187397, lgb__learning_rate=0.3, lgb__min_child_samples=18, lgb__min_split_gain=0.0843656093157598, lgb__num_leaves=127, lgb__reg_lambda=0.8881705659558571; f1_macro: (test=0.627) f1_micro: (test=0.897) roc_auc: (test=0.834) total time=   8.9s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8303248124611105, lgb__learning_rate=0.15, lgb__min_child_samples=13, lgb__min_split_gain=0.0049894936134145754, lgb__num_leaves=63, lgb__reg_lambda=0.4828546746654463; f1_macro: (test=0.609) f1_micro: (test=0.884) roc_auc: (test=0.794) total time=  13.8s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8724896056084032, lgb__learning_rate=0.15, lgb__min_child_samples=28, lgb__min_split_gain=0.05147053338756159, lgb__num_leaves=127, lgb__reg_lambda=0.1323335830782506; f1_macro: (test=0.654) f1_micro: (test=0.884) roc_auc: (test=0.793) total time=  23.5s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8303248124611105, lgb__learning_rate=0.15, lgb__min_child_samples=13, lgb__min_split_gain=0.0049894936134145754, lgb__num_leaves=63, lgb__reg_lambda=0.4828546746654463; f1_macro: (test=0.627) f1_micro: (test=0.889) roc_auc: (test=0.835) total time=  13.3s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6552518069715958, lgb__learning_rate=0.01, lgb__min_child_samples=6, lgb__min_split_gain=0.052095948133050074, lgb__num_leaves=127, lgb__reg_lambda=0.1522720001435821; f1_macro: (test=0.534) f1_micro: (test=0.894) roc_auc: (test=0.822) total time=  25.3s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6552518069715958, lgb__learning_rate=0.01, lgb__min_child_samples=6, lgb__min_split_gain=0.052095948133050074, lgb__num_leaves=127, lgb__reg_lambda=0.1522720001435821; f1_macro: (test=0.543) f1_micro: (test=0.895) roc_auc: (test=0.850) total time=  25.6s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8303248124611105, lgb__learning_rate=0.15, lgb__min_child_samples=13, lgb__min_split_gain=0.0049894936134145754, lgb__num_leaves=63, lgb__reg_lambda=0.4828546746654463; f1_macro: (test=0.619) f1_micro: (test=0.884) roc_auc: (test=0.792) total time=  17.2s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6552518069715958, lgb__learning_rate=0.01, lgb__min_child_samples=6, lgb__min_split_gain=0.052095948133050074, lgb__num_leaves=127, lgb__reg_lambda=0.1522720001435821; f1_macro: (test=0.528) f1_micro: (test=0.892) roc_auc: (test=0.863) total time=  27.9s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.757891270187397, lgb__learning_rate=0.3, lgb__min_child_samples=18, lgb__min_split_gain=0.0843656093157598, lgb__num_leaves=127, lgb__reg_lambda=0.8881705659558571; f1_macro: (test=0.666) f1_micro: (test=0.902) roc_auc: (test=0.862) total time=   9.9s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.757891270187397, lgb__learning_rate=0.3, lgb__min_child_samples=18, lgb__min_split_gain=0.0843656093157598, lgb__num_leaves=127, lgb__reg_lambda=0.8881705659558571; f1_macro: (test=0.655) f1_micro: (test=0.896) roc_auc: (test=0.830) total time=   8.8s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9694431378767928, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09290449450991957, lgb__num_leaves=31, lgb__reg_lambda=0.04137510667874644; f1_macro: (test=0.539) f1_micro: (test=0.894) roc_auc: (test=0.810) total time=   8.7s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9694431378767928, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09290449450991957, lgb__num_leaves=31, lgb__reg_lambda=0.04137510667874644; f1_macro: (test=0.533) f1_micro: (test=0.892) roc_auc: (test=0.836) total time=   7.5s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9694431378767928, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09290449450991957, lgb__num_leaves=31, lgb__reg_lambda=0.04137510667874644; f1_macro: (test=0.512) f1_micro: (test=0.890) roc_auc: (test=0.811) total time=   7.0s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6552518069715958, lgb__learning_rate=0.01, lgb__min_child_samples=6, lgb__min_split_gain=0.052095948133050074, lgb__num_leaves=127, lgb__reg_lambda=0.1522720001435821; f1_macro: (test=0.538) f1_micro: (test=0.893) roc_auc: (test=0.839) total time=  25.8s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.757891270187397, lgb__learning_rate=0.3, lgb__min_child_samples=18, lgb__min_split_gain=0.0843656093157598, lgb__num_leaves=127, lgb__reg_lambda=0.8881705659558571; f1_macro: (test=0.627) f1_micro: (test=0.894) roc_auc: (test=0.829) total time=   9.6s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9694431378767928, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09290449450991957, lgb__num_leaves=31, lgb__reg_lambda=0.04137510667874644; f1_macro: (test=0.557) f1_micro: (test=0.896) roc_auc: (test=0.831) total time=   8.8s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6552518069715958, lgb__learning_rate=0.01, lgb__min_child_samples=6, lgb__min_split_gain=0.052095948133050074, lgb__num_leaves=127, lgb__reg_lambda=0.1522720001435821; f1_macro: (test=0.512) f1_micro: (test=0.890) roc_auc: (test=0.838) total time=  25.8s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.757891270187397, lgb__learning_rate=0.3, lgb__min_child_samples=18, lgb__min_split_gain=0.0843656093157598, lgb__num_leaves=127, lgb__reg_lambda=0.8881705659558571; f1_macro: (test=0.655) f1_micro: (test=0.903) roc_auc: (test=0.837) total time=  10.7s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9694431378767928, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09290449450991957, lgb__num_leaves=31, lgb__reg_lambda=0.04137510667874644; f1_macro: (test=0.523) f1_micro: (test=0.891) roc_auc: (test=0.850) total time=  10.0s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5786047712169723, lgb__learning_rate=0.15, lgb__min_child_samples=6, lgb__min_split_gain=0.03704075485505709, lgb__num_leaves=15, lgb__reg_lambda=0.3606084225042038; f1_macro: (test=0.689) f1_micro: (test=0.912) roc_auc: (test=0.864) total time=   3.8s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5786047712169723, lgb__learning_rate=0.15, lgb__min_child_samples=6, lgb__min_split_gain=0.03704075485505709, lgb__num_leaves=15, lgb__reg_lambda=0.3606084225042038; f1_macro: (test=0.689) f1_micro: (test=0.907) roc_auc: (test=0.862) total time=   4.0s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5786047712169723, lgb__learning_rate=0.15, lgb__min_child_samples=6, lgb__min_split_gain=0.03704075485505709, lgb__num_leaves=15, lgb__reg_lambda=0.3606084225042038; f1_macro: (test=0.629) f1_micro: (test=0.896) roc_auc: (test=0.843) total time=   4.2s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5786047712169723, lgb__learning_rate=0.15, lgb__min_child_samples=6, lgb__min_split_gain=0.03704075485505709, lgb__num_leaves=15, lgb__reg_lambda=0.3606084225042038; f1_macro: (test=0.619) f1_micro: (test=0.891) roc_auc: (test=0.838) total time=   4.6s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5786047712169723, lgb__learning_rate=0.15, lgb__min_child_samples=6, lgb__min_split_gain=0.03704075485505709, lgb__num_leaves=15, lgb__reg_lambda=0.3606084225042038; f1_macro: (test=0.671) f1_micro: (test=0.904) roc_auc: (test=0.850) total time=   4.7s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7787287210943045, lgb__learning_rate=0.01, lgb__min_child_samples=10, lgb__min_split_gain=0.09995560109207652, lgb__num_leaves=31, lgb__reg_lambda=0.7917093180964536; f1_macro: (test=0.667) f1_micro: (test=0.903) roc_auc: (test=0.808) total time=   6.8s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7787287210943045, lgb__learning_rate=0.01, lgb__min_child_samples=10, lgb__min_split_gain=0.09995560109207652, lgb__num_leaves=31, lgb__reg_lambda=0.7917093180964536; f1_macro: (test=0.595) f1_micro: (test=0.888) roc_auc: (test=0.777) total time=   7.5s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8475210367020594, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.09533026918410359, lgb__num_leaves=63, lgb__reg_lambda=0.6902722312738483; f1_macro: (test=0.523) f1_micro: (test=0.892) roc_auc: (test=0.811) total time=  14.9s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7787287210943045, lgb__learning_rate=0.01, lgb__min_child_samples=10, lgb__min_split_gain=0.09995560109207652, lgb__num_leaves=31, lgb__reg_lambda=0.7917093180964536; f1_macro: (test=0.638) f1_micro: (test=0.897) roc_auc: (test=0.829) total time=   7.9s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7787287210943045, lgb__learning_rate=0.01, lgb__min_child_samples=10, lgb__min_split_gain=0.09995560109207652, lgb__num_leaves=31, lgb__reg_lambda=0.7917093180964536; f1_macro: (test=0.663) f1_micro: (test=0.896) roc_auc: (test=0.813) total time=   7.7s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7787287210943045, lgb__learning_rate=0.01, lgb__min_child_samples=10, lgb__min_split_gain=0.09995560109207652, lgb__num_leaves=31, lgb__reg_lambda=0.7917093180964536; f1_macro: (test=0.610) f1_micro: (test=0.881) roc_auc: (test=0.781) total time=   7.4s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8475210367020594, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.09533026918410359, lgb__num_leaves=63, lgb__reg_lambda=0.6902722312738483; f1_macro: (test=0.518) f1_micro: (test=0.891) roc_auc: (test=0.855) total time=  13.0s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8475210367020594, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.09533026918410359, lgb__num_leaves=63, lgb__reg_lambda=0.6902722312738483; f1_macro: (test=0.512) f1_micro: (test=0.890) roc_auc: (test=0.818) total time=  11.5s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8475210367020594, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.09533026918410359, lgb__num_leaves=63, lgb__reg_lambda=0.6902722312738483; f1_macro: (test=0.543) f1_micro: (test=0.894) roc_auc: (test=0.845) total time=  16.6s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9287995095353201, lgb__learning_rate=0.01, lgb__min_child_samples=5, lgb__min_split_gain=0.04302289257625767, lgb__num_leaves=15, lgb__reg_lambda=0.493037931937103; f1_macro: (test=0.584) f1_micro: (test=0.883) roc_auc: (test=0.754) total time=   3.5s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9287995095353201, lgb__learning_rate=0.01, lgb__min_child_samples=5, lgb__min_split_gain=0.04302289257625767, lgb__num_leaves=15, lgb__reg_lambda=0.493037931937103; f1_macro: (test=0.640) f1_micro: (test=0.898) roc_auc: (test=0.778) total time=   3.9s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9287995095353201, lgb__learning_rate=0.01, lgb__min_child_samples=5, lgb__min_split_gain=0.04302289257625767, lgb__num_leaves=15, lgb__reg_lambda=0.493037931937103; f1_macro: (test=0.622) f1_micro: (test=0.882) roc_auc: (test=0.791) total time=   3.4s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8475210367020594, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.09533026918410359, lgb__num_leaves=63, lgb__reg_lambda=0.6902722312738483; f1_macro: (test=0.512) f1_micro: (test=0.890) roc_auc: (test=0.836) total time=  15.3s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9287995095353201, lgb__learning_rate=0.01, lgb__min_child_samples=5, lgb__min_split_gain=0.04302289257625767, lgb__num_leaves=15, lgb__reg_lambda=0.493037931937103; f1_macro: (test=0.621) f1_micro: (test=0.894) roc_auc: (test=0.796) total time=   4.6s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9287995095353201, lgb__learning_rate=0.01, lgb__min_child_samples=5, lgb__min_split_gain=0.04302289257625767, lgb__num_leaves=15, lgb__reg_lambda=0.493037931937103; f1_macro: (test=0.611) f1_micro: (test=0.884) roc_auc: (test=0.736) total time=   4.1s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8543538320066387, lgb__learning_rate=0.01, lgb__min_child_samples=16, lgb__min_split_gain=0.0632448162061768, lgb__num_leaves=63, lgb__reg_lambda=0.8587971938450034; f1_macro: (test=0.529) f1_micro: (test=0.893) roc_auc: (test=0.811) total time=  12.9s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8543538320066387, lgb__learning_rate=0.01, lgb__min_child_samples=16, lgb__min_split_gain=0.0632448162061768, lgb__num_leaves=63, lgb__reg_lambda=0.8587971938450034; f1_macro: (test=0.512) f1_micro: (test=0.890) roc_auc: (test=0.816) total time=  11.6s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8543538320066387, lgb__learning_rate=0.01, lgb__min_child_samples=16, lgb__min_split_gain=0.0632448162061768, lgb__num_leaves=63, lgb__reg_lambda=0.8587971938450034; f1_macro: (test=0.518) f1_micro: (test=0.891) roc_auc: (test=0.838) total time=  13.8s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8543538320066387, lgb__learning_rate=0.01, lgb__min_child_samples=16, lgb__min_split_gain=0.0632448162061768, lgb__num_leaves=63, lgb__reg_lambda=0.8587971938450034; f1_macro: (test=0.543) f1_micro: (test=0.895) roc_auc: (test=0.841) total time=  14.9s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8543538320066387, lgb__learning_rate=0.01, lgb__min_child_samples=16, lgb__min_split_gain=0.0632448162061768, lgb__num_leaves=63, lgb__reg_lambda=0.8587971938450034; f1_macro: (test=0.518) f1_micro: (test=0.891) roc_auc: (test=0.853) total time=  15.3s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7839244686334211, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.041414113332935015, lgb__num_leaves=63, lgb__reg_lambda=0.829378843353453; f1_macro: (test=0.632) f1_micro: (test=0.894) roc_auc: (test=0.833) total time=  12.2s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7839244686334211, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.041414113332935015, lgb__num_leaves=63, lgb__reg_lambda=0.829378843353453; f1_macro: (test=0.657) f1_micro: (test=0.899) roc_auc: (test=0.840) total time=  11.8s
# ...
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8185852126029444, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.010100931782057078, lgb__num_leaves=31, lgb__reg_lambda=0.008293219332036972; f1_macro: (test=0.683) f1_micro: (test=0.901) roc_auc: (test=0.809) total time=   5.9s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8185852126029444, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.010100931782057078, lgb__num_leaves=31, lgb__reg_lambda=0.008293219332036972; f1_macro: (test=0.600) f1_micro: (test=0.882) roc_auc: (test=0.770) total time=   6.6s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.949967773832094, lgb__learning_rate=0.01, lgb__min_child_samples=11, lgb__min_split_gain=0.06952355987257289, lgb__num_leaves=63, lgb__reg_lambda=0.5233781111217284; f1_macro: (test=0.534) f1_micro: (test=0.894) roc_auc: (test=0.812) total time=  14.2s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8185852126029444, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.010100931782057078, lgb__num_leaves=31, lgb__reg_lambda=0.008293219332036972; f1_macro: (test=0.642) f1_micro: (test=0.891) roc_auc: (test=0.823) total time=   6.9s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.949967773832094, lgb__learning_rate=0.01, lgb__min_child_samples=11, lgb__min_split_gain=0.06952355987257289, lgb__num_leaves=63, lgb__reg_lambda=0.5233781111217284; f1_macro: (test=0.548) f1_micro: (test=0.895) roc_auc: (test=0.837) total time=  13.9s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8185852126029444, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.010100931782057078, lgb__num_leaves=31, lgb__reg_lambda=0.008293219332036972; f1_macro: (test=0.645) f1_micro: (test=0.886) roc_auc: (test=0.801) total time=   6.5s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8185852126029444, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.010100931782057078, lgb__num_leaves=31, lgb__reg_lambda=0.008293219332036972; f1_macro: (test=0.621) f1_micro: (test=0.883) roc_auc: (test=0.778) total time=   7.2s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.949967773832094, lgb__learning_rate=0.01, lgb__min_child_samples=11, lgb__min_split_gain=0.06952355987257289, lgb__num_leaves=63, lgb__reg_lambda=0.5233781111217284; f1_macro: (test=0.507) f1_micro: (test=0.889) roc_auc: (test=0.820) total time=  14.0s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.949967773832094, lgb__learning_rate=0.01, lgb__min_child_samples=11, lgb__min_split_gain=0.06952355987257289, lgb__num_leaves=63, lgb__reg_lambda=0.5233781111217284; f1_macro: (test=0.538) f1_micro: (test=0.893) roc_auc: (test=0.851) total time=  15.8s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.949967773832094, lgb__learning_rate=0.01, lgb__min_child_samples=11, lgb__min_split_gain=0.06952355987257289, lgb__num_leaves=63, lgb__reg_lambda=0.5233781111217284; f1_macro: (test=0.533) f1_micro: (test=0.892) roc_auc: (test=0.838) total time=  16.3s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5784794483990299, lgb__learning_rate=0.15, lgb__min_child_samples=8, lgb__min_split_gain=0.0527094204498551, lgb__num_leaves=127, lgb__reg_lambda=0.48093180670409197; f1_macro: (test=0.635) f1_micro: (test=0.899) roc_auc: (test=0.858) total time=  17.6s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5784794483990299, lgb__learning_rate=0.15, lgb__min_child_samples=8, lgb__min_split_gain=0.0527094204498551, lgb__num_leaves=127, lgb__reg_lambda=0.48093180670409197; f1_macro: (test=0.632) f1_micro: (test=0.896) roc_auc: (test=0.836) total time=  19.2s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7923304968806538, lgb__learning_rate=0.3, lgb__min_child_samples=19, lgb__min_split_gain=0.05721229552630659, lgb__num_leaves=31, lgb__reg_lambda=0.11275052461082491; f1_macro: (test=0.597) f1_micro: (test=0.879) roc_auc: (test=0.770) total time=   6.3s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5784794483990299, lgb__learning_rate=0.15, lgb__min_child_samples=8, lgb__min_split_gain=0.0527094204498551, lgb__num_leaves=127, lgb__reg_lambda=0.48093180670409197; f1_macro: (test=0.656) f1_micro: (test=0.902) roc_auc: (test=0.861) total time=  22.5s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5784794483990299, lgb__learning_rate=0.15, lgb__min_child_samples=8, lgb__min_split_gain=0.0527094204498551, lgb__num_leaves=127, lgb__reg_lambda=0.48093180670409197; f1_macro: (test=0.617) f1_micro: (test=0.896) roc_auc: (test=0.817) total time=  21.0s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5784794483990299, lgb__learning_rate=0.15, lgb__min_child_samples=8, lgb__min_split_gain=0.0527094204498551, lgb__num_leaves=127, lgb__reg_lambda=0.48093180670409197; f1_macro: (test=0.635) f1_micro: (test=0.899) roc_auc: (test=0.844) total time=  22.2s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7923304968806538, lgb__learning_rate=0.3, lgb__min_child_samples=19, lgb__min_split_gain=0.05721229552630659, lgb__num_leaves=31, lgb__reg_lambda=0.11275052461082491; f1_macro: (test=0.672) f1_micro: (test=0.901) roc_auc: (test=0.801) total time=   7.7s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7923304968806538, lgb__learning_rate=0.3, lgb__min_child_samples=19, lgb__min_split_gain=0.05721229552630659, lgb__num_leaves=31, lgb__reg_lambda=0.11275052461082491; f1_macro: (test=0.645) f1_micro: (test=0.892) roc_auc: (test=0.822) total time=   7.2s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7923304968806538, lgb__learning_rate=0.3, lgb__min_child_samples=19, lgb__min_split_gain=0.05721229552630659, lgb__num_leaves=31, lgb__reg_lambda=0.11275052461082491; f1_macro: (test=0.643) f1_micro: (test=0.887) roc_auc: (test=0.807) total time=   5.5s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7842007218731424, lgb__learning_rate=0.01, lgb__min_child_samples=24, lgb__min_split_gain=0.07614028595817374, lgb__num_leaves=127, lgb__reg_lambda=0.5690481516490171; f1_macro: (test=0.611) f1_micro: (test=0.889) roc_auc: (test=0.807) total time=  21.0s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7923304968806538, lgb__learning_rate=0.3, lgb__min_child_samples=19, lgb__min_split_gain=0.05721229552630659, lgb__num_leaves=31, lgb__reg_lambda=0.11275052461082491; f1_macro: (test=0.619) f1_micro: (test=0.884) roc_auc: (test=0.777) total time=   8.1s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7842007218731424, lgb__learning_rate=0.01, lgb__min_child_samples=24, lgb__min_split_gain=0.07614028595817374, lgb__num_leaves=127, lgb__reg_lambda=0.5690481516490171; f1_macro: (test=0.650) f1_micro: (test=0.891) roc_auc: (test=0.820) total time=  20.5s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7842007218731424, lgb__learning_rate=0.01, lgb__min_child_samples=24, lgb__min_split_gain=0.07614028595817374, lgb__num_leaves=127, lgb__reg_lambda=0.5690481516490171; f1_macro: (test=0.677) f1_micro: (test=0.902) roc_auc: (test=0.828) total time=  23.2s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7842007218731424, lgb__learning_rate=0.01, lgb__min_child_samples=24, lgb__min_split_gain=0.07614028595817374, lgb__num_leaves=127, lgb__reg_lambda=0.5690481516490171; f1_macro: (test=0.652) f1_micro: (test=0.897) roc_auc: (test=0.838) total time=  23.4s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9323039721934986, lgb__learning_rate=0.15, lgb__min_child_samples=14, lgb__min_split_gain=0.08177239017876248, lgb__num_leaves=127, lgb__reg_lambda=0.0045723582858926415; f1_macro: (test=0.633) f1_micro: (test=0.859) roc_auc: (test=0.784) total time=  22.1s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7842007218731424, lgb__learning_rate=0.01, lgb__min_child_samples=24, lgb__min_split_gain=0.07614028595817374, lgb__num_leaves=127, lgb__reg_lambda=0.5690481516490171; f1_macro: (test=0.631) f1_micro: (test=0.894) roc_auc: (test=0.810) total time=  23.6s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9323039721934986, lgb__learning_rate=0.15, lgb__min_child_samples=14, lgb__min_split_gain=0.08177239017876248, lgb__num_leaves=127, lgb__reg_lambda=0.0045723582858926415; f1_macro: (test=0.651) f1_micro: (test=0.863) roc_auc: (test=0.799) total time=  23.4s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9323039721934986, lgb__learning_rate=0.15, lgb__min_child_samples=14, lgb__min_split_gain=0.08177239017876248, lgb__num_leaves=127, lgb__reg_lambda=0.0045723582858926415; f1_macro: (test=0.674) f1_micro: (test=0.881) roc_auc: (test=0.799) total time=  24.2s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9323039721934986, lgb__learning_rate=0.15, lgb__min_child_samples=14, lgb__min_split_gain=0.08177239017876248, lgb__num_leaves=127, lgb__reg_lambda=0.0045723582858926415; f1_macro: (test=0.614) f1_micro: (test=0.856) roc_auc: (test=0.787) total time=  23.7s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9323039721934986, lgb__learning_rate=0.15, lgb__min_child_samples=14, lgb__min_split_gain=0.08177239017876248, lgb__num_leaves=127, lgb__reg_lambda=0.0045723582858926415; f1_macro: (test=0.660) f1_micro: (test=0.858) roc_auc: (test=0.779) total time=  24.9s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6928860412938613, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.0023922000044225844, lgb__num_leaves=63, lgb__reg_lambda=0.5330309484404907; f1_macro: (test=0.523) f1_micro: (test=0.892) roc_auc: (test=0.819) total time=  12.5s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7684737847109464, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.033315235868187666, lgb__num_leaves=15, lgb__reg_lambda=0.135380093016772; f1_macro: (test=0.615) f1_micro: (test=0.890) roc_auc: (test=0.837) total time=   3.0s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6928860412938613, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.0023922000044225844, lgb__num_leaves=63, lgb__reg_lambda=0.5330309484404907; f1_macro: (test=0.512) f1_micro: (test=0.890) roc_auc: (test=0.822) total time=  11.2s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7684737847109464, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.033315235868187666, lgb__num_leaves=15, lgb__reg_lambda=0.135380093016772; f1_macro: (test=0.660) f1_micro: (test=0.903) roc_auc: (test=0.854) total time=   3.2s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8895849571906607, lgb__learning_rate=0.3, lgb__min_child_samples=25, lgb__min_split_gain=0.012134019525780871, lgb__num_leaves=127, lgb__reg_lambda=0.5357596957155019; f1_macro: (test=0.609) f1_micro: (test=0.877) roc_auc: (test=0.790) total time=  21.1s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6928860412938613, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.0023922000044225844, lgb__num_leaves=63, lgb__reg_lambda=0.5330309484404907; f1_macro: (test=0.539) f1_micro: (test=0.894) roc_auc: (test=0.850) total time=  13.9s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7684737847109464, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.033315235868187666, lgb__num_leaves=15, lgb__reg_lambda=0.135380093016772; f1_macro: (test=0.696) f1_micro: (test=0.907) roc_auc: (test=0.866) total time=   4.3s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8895849571906607, lgb__learning_rate=0.3, lgb__min_child_samples=25, lgb__min_split_gain=0.012134019525780871, lgb__num_leaves=127, lgb__reg_lambda=0.5357596957155019; f1_macro: (test=0.657) f1_micro: (test=0.889) roc_auc: (test=0.808) total time=  21.7s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6928860412938613, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.0023922000044225844, lgb__num_leaves=63, lgb__reg_lambda=0.5330309484404907; f1_macro: (test=0.512) f1_micro: (test=0.890) roc_auc: (test=0.840) total time=  13.3s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7684737847109464, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.033315235868187666, lgb__num_leaves=15, lgb__reg_lambda=0.135380093016772; f1_macro: (test=0.678) f1_micro: (test=0.902) roc_auc: (test=0.852) total time=   2.1s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6928860412938613, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.0023922000044225844, lgb__num_leaves=63, lgb__reg_lambda=0.5330309484404907; f1_macro: (test=0.518) f1_micro: (test=0.891) roc_auc: (test=0.857) total time=  14.9s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8895849571906607, lgb__learning_rate=0.3, lgb__min_child_samples=25, lgb__min_split_gain=0.012134019525780871, lgb__num_leaves=127, lgb__reg_lambda=0.5357596957155019; f1_macro: (test=0.650) f1_micro: (test=0.884) roc_auc: (test=0.823) total time=  20.7s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7684737847109464, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.033315235868187666, lgb__num_leaves=15, lgb__reg_lambda=0.135380093016772; f1_macro: (test=0.647) f1_micro: (test=0.897) roc_auc: (test=0.834) total time=   2.9s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8895849571906607, lgb__learning_rate=0.3, lgb__min_child_samples=25, lgb__min_split_gain=0.012134019525780871, lgb__num_leaves=127, lgb__reg_lambda=0.5357596957155019; f1_macro: (test=0.614) f1_micro: (test=0.873) roc_auc: (test=0.796) total time=  20.6s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8895849571906607, lgb__learning_rate=0.3, lgb__min_child_samples=25, lgb__min_split_gain=0.012134019525780871, lgb__num_leaves=127, lgb__reg_lambda=0.5357596957155019; f1_macro: (test=0.640) f1_micro: (test=0.883) roc_auc: (test=0.797) total time=  21.0s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7556862227657044, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.05228319559864933, lgb__num_leaves=127, lgb__reg_lambda=0.26088236459345004; f1_macro: (test=0.543) f1_micro: (test=0.895) roc_auc: (test=0.852) total time=  15.7s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7556862227657044, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.05228319559864933, lgb__num_leaves=127, lgb__reg_lambda=0.26088236459345004; f1_macro: (test=0.518) f1_micro: (test=0.891) roc_auc: (test=0.831) total time=  13.5s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7556862227657044, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.05228319559864933, lgb__num_leaves=127, lgb__reg_lambda=0.26088236459345004; f1_macro: (test=0.523) f1_micro: (test=0.892) roc_auc: (test=0.857) total time=  15.9s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7556862227657044, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.05228319559864933, lgb__num_leaves=127, lgb__reg_lambda=0.26088236459345004; f1_macro: (test=0.538) f1_micro: (test=0.894) roc_auc: (test=0.819) total time=  17.3s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7556862227657044, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.05228319559864933, lgb__num_leaves=127, lgb__reg_lambda=0.26088236459345004; f1_macro: (test=0.517) f1_micro: (test=0.890) roc_auc: (test=0.838) total time=  14.7s

# %% [markdown]
# With 100 hyperparameter combinations, it takes approximately 6.5 minutes.

# %%
# Load saved pickle
with open('hyperparameter_tuning/lgbm/lgbm_noresampling_100comb.pkl', 'rb') as f:
    loaded = pickle.load(f)
    best_params_lgbm, best_scores_lgbm = loaded

print('Best parameters of LightGBM:', best_params_lgbm, '\n')

print('Best scores of LightGBM:', best_scores_lgbm, '\n')
# Out:
# Best parameters of LightGBM: {'lgb__boosting_type': 'gbdt', 'lgb__feature_fraction': 0.5786047712169723, 'lgb__learning_rate': 0.15, 'lgb__min_child_samples': 6, 'lgb__min_split_gain': 0.03704075485505709, 'lgb__num_leaves': 15, 'lgb__reg_lambda': 0.3606084225042038}
#
# Best scores of LightGBM: {'f1_micro': 0.9019999999999999, 'f1_macro': 0.659453339505749, 'roc_auc': 0.8512450135095173}

# %% [markdown]
# #### B. Oversampling

# %%
# best_params_lgbm_over, best_scores_lgbm_over = baseline_models(
#         df=dfv3, numerical_features=numerical_features, categorical_features=categorical_features,
#         target='HOSPITAL_EXPIRE_FLAG', model=LGBMClassifier, ada_boost = False, 
#         n_hyper_comb = 100, num_imputer = "median", refit_score = 'roc_auc', resampling_method = 'oversample'
# )

# # Combine dictionaries into a list
# combined_lgbm_over = [best_params_lgbm, best_scores_lgbm]

# # Save into a pickle (name of file states model, if resampling technique was
# # applied and the number of hyperparameter combinations tried)
# with open('hyperparameter_tuning/lgbm/lgbm_over_100comb.pkl', 'wb') as f:
#     pickle.dump(combined_lgbm_over, f)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5908888858951135, lgb__learning_rate=0.3, lgb__min_child_samples=27, lgb__min_split_gain=0.08888648231916156, lgb__num_leaves=31, lgb__reg_lambda=0.7869854599999133; f1_macro: (test=0.623) f1_micro: (test=0.772) roc_auc: (test=0.804) total time=   0.7s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5908888858951135, lgb__learning_rate=0.3, lgb__min_child_samples=27, lgb__min_split_gain=0.08888648231916156, lgb__num_leaves=31, lgb__reg_lambda=0.7869854599999133; f1_macro: (test=0.648) f1_micro: (test=0.782) roc_auc: (test=0.838) total time=   6.1s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5908888858951135, lgb__learning_rate=0.3, lgb__min_child_samples=27, lgb__min_split_gain=0.08888648231916156, lgb__num_leaves=31, lgb__reg_lambda=0.7869854599999133; f1_macro: (test=0.625) f1_micro: (test=0.764) roc_auc: (test=0.806) total time=   6.9s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.871283110454845, lgb__learning_rate=0.3, lgb__min_child_samples=11, lgb__min_split_gain=0.021551321485037845, lgb__num_leaves=31, lgb__reg_lambda=0.6524186154656548; f1_macro: (test=0.675) f1_micro: (test=0.881) roc_auc: (test=0.828) total time=   6.1s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.871283110454845, lgb__learning_rate=0.3, lgb__min_child_samples=11, lgb__min_split_gain=0.021551321485037845, lgb__num_leaves=31, lgb__reg_lambda=0.6524186154656548; f1_macro: (test=0.684) f1_micro: (test=0.886) roc_auc: (test=0.837) total time=   6.3s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5908888858951135, lgb__learning_rate=0.3, lgb__min_child_samples=27, lgb__min_split_gain=0.08888648231916156, lgb__num_leaves=31, lgb__reg_lambda=0.7869854599999133; f1_macro: (test=0.635) f1_micro: (test=0.762) roc_auc: (test=0.841) total time=   7.1s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5908888858951135, lgb__learning_rate=0.3, lgb__min_child_samples=27, lgb__min_split_gain=0.08888648231916156, lgb__num_leaves=31, lgb__reg_lambda=0.7869854599999133; f1_macro: (test=0.627) f1_micro: (test=0.762) roc_auc: (test=0.832) total time=   7.8s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5514969290700589, lgb__learning_rate=0.01, lgb__min_child_samples=12, lgb__min_split_gain=0.06297576132346906, lgb__num_leaves=31, lgb__reg_lambda=0.35781360448354893; f1_macro: (test=0.653) f1_micro: (test=0.801) roc_auc: (test=0.824) total time=   7.5s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.871283110454845, lgb__learning_rate=0.3, lgb__min_child_samples=11, lgb__min_split_gain=0.021551321485037845, lgb__num_leaves=31, lgb__reg_lambda=0.6524186154656548; f1_macro: (test=0.655) f1_micro: (test=0.873) roc_auc: (test=0.821) total time=   7.2s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5514969290700589, lgb__learning_rate=0.01, lgb__min_child_samples=12, lgb__min_split_gain=0.06297576132346906, lgb__num_leaves=31, lgb__reg_lambda=0.35781360448354893; f1_macro: (test=0.665) f1_micro: (test=0.797) roc_auc: (test=0.851) total time=   8.2s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5514969290700589, lgb__learning_rate=0.01, lgb__min_child_samples=12, lgb__min_split_gain=0.06297576132346906, lgb__num_leaves=31, lgb__reg_lambda=0.35781360448354893; f1_macro: (test=0.645) f1_micro: (test=0.782) roc_auc: (test=0.847) total time=   8.3s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.871283110454845, lgb__learning_rate=0.3, lgb__min_child_samples=11, lgb__min_split_gain=0.021551321485037845, lgb__num_leaves=31, lgb__reg_lambda=0.6524186154656548; f1_macro: (test=0.676) f1_micro: (test=0.880) roc_auc: (test=0.830) total time=   7.3s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.871283110454845, lgb__learning_rate=0.3, lgb__min_child_samples=11, lgb__min_split_gain=0.021551321485037845, lgb__num_leaves=31, lgb__reg_lambda=0.6524186154656548; f1_macro: (test=0.669) f1_micro: (test=0.887) roc_auc: (test=0.834) total time=   8.5s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5514969290700589, lgb__learning_rate=0.01, lgb__min_child_samples=12, lgb__min_split_gain=0.06297576132346906, lgb__num_leaves=31, lgb__reg_lambda=0.35781360448354893; f1_macro: (test=0.659) f1_micro: (test=0.800) roc_auc: (test=0.849) total time=   9.3s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.559531716993128, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.037785405876478675, lgb__num_leaves=63, lgb__reg_lambda=0.29772571830177164; f1_macro: (test=0.656) f1_micro: (test=0.887) roc_auc: (test=0.838) total time=  13.2s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5514969290700589, lgb__learning_rate=0.01, lgb__min_child_samples=12, lgb__min_split_gain=0.06297576132346906, lgb__num_leaves=31, lgb__reg_lambda=0.35781360448354893; f1_macro: (test=0.648) f1_micro: (test=0.784) roc_auc: (test=0.818) total time=  13.9s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.559531716993128, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.037785405876478675, lgb__num_leaves=63, lgb__reg_lambda=0.29772571830177164; f1_macro: (test=0.715) f1_micro: (test=0.898) roc_auc: (test=0.855) total time=  17.1s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.559531716993128, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.037785405876478675, lgb__num_leaves=63, lgb__reg_lambda=0.29772571830177164; f1_macro: (test=0.667) f1_micro: (test=0.892) roc_auc: (test=0.844) total time=  14.6s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.559531716993128, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.037785405876478675, lgb__num_leaves=63, lgb__reg_lambda=0.29772571830177164; f1_macro: (test=0.654) f1_micro: (test=0.886) roc_auc: (test=0.827) total time=  15.4s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5411698746062403, lgb__learning_rate=0.3, lgb__min_child_samples=7, lgb__min_split_gain=0.015895874456727545, lgb__num_leaves=31, lgb__reg_lambda=0.804911033201756; f1_macro: (test=0.626) f1_micro: (test=0.776) roc_auc: (test=0.807) total time=   8.0s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.559531716993128, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.037785405876478675, lgb__num_leaves=63, lgb__reg_lambda=0.29772571830177164; f1_macro: (test=0.668) f1_micro: (test=0.888) roc_auc: (test=0.832) total time=  16.5s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5411698746062403, lgb__learning_rate=0.3, lgb__min_child_samples=7, lgb__min_split_gain=0.015895874456727545, lgb__num_leaves=31, lgb__reg_lambda=0.804911033201756; f1_macro: (test=0.633) f1_micro: (test=0.769) roc_auc: (test=0.833) total time=   8.5s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5411698746062403, lgb__learning_rate=0.3, lgb__min_child_samples=7, lgb__min_split_gain=0.015895874456727545, lgb__num_leaves=31, lgb__reg_lambda=0.804911033201756; f1_macro: (test=0.649) f1_micro: (test=0.777) roc_auc: (test=0.844) total time=   7.9s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8325667793126454, lgb__learning_rate=0.3, lgb__min_child_samples=28, lgb__min_split_gain=0.019877387220034307, lgb__num_leaves=63, lgb__reg_lambda=0.7936866474746995; f1_macro: (test=0.699) f1_micro: (test=0.901) roc_auc: (test=0.831) total time=  14.3s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8325667793126454, lgb__learning_rate=0.3, lgb__min_child_samples=28, lgb__min_split_gain=0.019877387220034307, lgb__num_leaves=63, lgb__reg_lambda=0.7936866474746995; f1_macro: (test=0.703) f1_micro: (test=0.899) roc_auc: (test=0.832) total time=  15.0s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8325667793126454, lgb__learning_rate=0.3, lgb__min_child_samples=28, lgb__min_split_gain=0.019877387220034307, lgb__num_leaves=63, lgb__reg_lambda=0.7936866474746995; f1_macro: (test=0.687) f1_micro: (test=0.897) roc_auc: (test=0.860) total time=  15.5s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8325667793126454, lgb__learning_rate=0.3, lgb__min_child_samples=28, lgb__min_split_gain=0.019877387220034307, lgb__num_leaves=63, lgb__reg_lambda=0.7936866474746995; f1_macro: (test=0.667) f1_micro: (test=0.895) roc_auc: (test=0.825) total time=  15.7s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.762335648372946, lgb__learning_rate=0.15, lgb__min_child_samples=29, lgb__min_split_gain=0.032508951737347525, lgb__num_leaves=127, lgb__reg_lambda=0.14390392077532788; f1_macro: (test=0.653) f1_micro: (test=0.893) roc_auc: (test=0.823) total time=  18.9s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8325667793126454, lgb__learning_rate=0.3, lgb__min_child_samples=28, lgb__min_split_gain=0.019877387220034307, lgb__num_leaves=63, lgb__reg_lambda=0.7936866474746995; f1_macro: (test=0.670) f1_micro: (test=0.891) roc_auc: (test=0.829) total time=  17.0s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.762335648372946, lgb__learning_rate=0.15, lgb__min_child_samples=29, lgb__min_split_gain=0.032508951737347525, lgb__num_leaves=127, lgb__reg_lambda=0.14390392077532788; f1_macro: (test=0.682) f1_micro: (test=0.897) roc_auc: (test=0.832) total time=  21.3s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.762335648372946, lgb__learning_rate=0.15, lgb__min_child_samples=29, lgb__min_split_gain=0.032508951737347525, lgb__num_leaves=127, lgb__reg_lambda=0.14390392077532788; f1_macro: (test=0.634) f1_micro: (test=0.890) roc_auc: (test=0.832) total time=  23.5s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5411698746062403, lgb__learning_rate=0.3, lgb__min_child_samples=7, lgb__min_split_gain=0.015895874456727545, lgb__num_leaves=31, lgb__reg_lambda=0.804911033201756; f1_macro: (test=0.631) f1_micro: (test=0.770) roc_auc: (test=0.808) total time=   8.9s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5411698746062403, lgb__learning_rate=0.3, lgb__min_child_samples=7, lgb__min_split_gain=0.015895874456727545, lgb__num_leaves=31, lgb__reg_lambda=0.804911033201756; f1_macro: (test=0.651) f1_micro: (test=0.787) roc_auc: (test=0.839) total time=  11.1s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5250290808036032, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.0009888059554519879, lgb__num_leaves=31, lgb__reg_lambda=0.13394566757579296; f1_macro: (test=0.625) f1_micro: (test=0.779) roc_auc: (test=0.808) total time=   8.9s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5250290808036032, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.0009888059554519879, lgb__num_leaves=31, lgb__reg_lambda=0.13394566757579296; f1_macro: (test=0.637) f1_micro: (test=0.772) roc_auc: (test=0.834) total time=   9.0s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5250290808036032, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.0009888059554519879, lgb__num_leaves=31, lgb__reg_lambda=0.13394566757579296; f1_macro: (test=0.655) f1_micro: (test=0.783) roc_auc: (test=0.845) total time=   9.0s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.762335648372946, lgb__learning_rate=0.15, lgb__min_child_samples=29, lgb__min_split_gain=0.032508951737347525, lgb__num_leaves=127, lgb__reg_lambda=0.14390392077532788; f1_macro: (test=0.706) f1_micro: (test=0.904) roc_auc: (test=0.856) total time=  26.5s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.762335648372946, lgb__learning_rate=0.15, lgb__min_child_samples=29, lgb__min_split_gain=0.032508951737347525, lgb__num_leaves=127, lgb__reg_lambda=0.14390392077532788; f1_macro: (test=0.693) f1_micro: (test=0.905) roc_auc: (test=0.851) total time=  26.6s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5250290808036032, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.0009888059554519879, lgb__num_leaves=31, lgb__reg_lambda=0.13394566757579296; f1_macro: (test=0.658) f1_micro: (test=0.792) roc_auc: (test=0.840) total time=   9.5s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.5250290808036032, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.0009888059554519879, lgb__num_leaves=31, lgb__reg_lambda=0.13394566757579296; f1_macro: (test=0.628) f1_micro: (test=0.768) roc_auc: (test=0.809) total time=  10.2s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7224980330600344, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.03276879867015684, lgb__num_leaves=127, lgb__reg_lambda=0.9607877564667782; f1_macro: (test=0.627) f1_micro: (test=0.882) roc_auc: (test=0.832) total time=  16.4s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7224980330600344, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.03276879867015684, lgb__num_leaves=127, lgb__reg_lambda=0.9607877564667782; f1_macro: (test=0.686) f1_micro: (test=0.897) roc_auc: (test=0.831) total time=  17.3s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7224980330600344, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.03276879867015684, lgb__num_leaves=127, lgb__reg_lambda=0.9607877564667782; f1_macro: (test=0.708) f1_micro: (test=0.902) roc_auc: (test=0.856) total time=  18.0s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.789642038872035, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.09543378655569243, lgb__num_leaves=15, lgb__reg_lambda=0.2256229824075504; f1_macro: (test=0.589) f1_micro: (test=0.719) roc_auc: (test=0.783) total time=   4.1s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7224980330600344, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.03276879867015684, lgb__num_leaves=127, lgb__reg_lambda=0.9607877564667782; f1_macro: (test=0.648) f1_micro: (test=0.886) roc_auc: (test=0.818) total time=  18.2s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7224980330600344, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.03276879867015684, lgb__num_leaves=127, lgb__reg_lambda=0.9607877564667782; f1_macro: (test=0.705) f1_micro: (test=0.906) roc_auc: (test=0.859) total time=  20.1s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.789642038872035, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.09543378655569243, lgb__num_leaves=15, lgb__reg_lambda=0.2256229824075504; f1_macro: (test=0.586) f1_micro: (test=0.706) roc_auc: (test=0.804) total time=   5.2s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.789642038872035, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.09543378655569243, lgb__num_leaves=15, lgb__reg_lambda=0.2256229824075504; f1_macro: (test=0.593) f1_micro: (test=0.709) roc_auc: (test=0.806) total time=   4.5s[CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.789642038872035, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.09543378655569243, lgb__num_leaves=15, lgb__reg_lambda=0.2256229824075504; f1_macro: (test=0.618) f1_micro: (test=0.749) roc_auc: (test=0.816) total time=   4.3s
#
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7603175317556659, lgb__learning_rate=0.15, lgb__min_child_samples=19, lgb__min_split_gain=0.013042928220861906, lgb__num_leaves=63, lgb__reg_lambda=0.010695636761950844; f1_macro: (test=0.627) f1_micro: (test=0.792) roc_auc: (test=0.801) total time=  12.4s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7603175317556659, lgb__learning_rate=0.15, lgb__min_child_samples=19, lgb__min_split_gain=0.013042928220861906, lgb__num_leaves=63, lgb__reg_lambda=0.010695636761950844; f1_macro: (test=0.656) f1_micro: (test=0.794) roc_auc: (test=0.837) total time=  15.5s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.789642038872035, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.09543378655569243, lgb__num_leaves=15, lgb__reg_lambda=0.2256229824075504; f1_macro: (test=0.585) f1_micro: (test=0.714) roc_auc: (test=0.774) total time=   7.4s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7603175317556659, lgb__learning_rate=0.15, lgb__min_child_samples=19, lgb__min_split_gain=0.013042928220861906, lgb__num_leaves=63, lgb__reg_lambda=0.010695636761950844; f1_macro: (test=0.634) f1_micro: (test=0.780) roc_auc: (test=0.828) total time=  17.2s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7603175317556659, lgb__learning_rate=0.15, lgb__min_child_samples=19, lgb__min_split_gain=0.013042928220861906, lgb__num_leaves=63, lgb__reg_lambda=0.010695636761950844; f1_macro: (test=0.651) f1_micro: (test=0.796) roc_auc: (test=0.833) total time=  16.9s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9419321088666186, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.07955946473535244, lgb__num_leaves=63, lgb__reg_lambda=0.4513896917704029; f1_macro: (test=0.656) f1_micro: (test=0.887) roc_auc: (test=0.827) total time=  10.3s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9419321088666186, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.07955946473535244, lgb__num_leaves=63, lgb__reg_lambda=0.4513896917704029; f1_macro: (test=0.709) f1_micro: (test=0.896) roc_auc: (test=0.848) total time=  10.2s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9419321088666186, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.07955946473535244, lgb__num_leaves=63, lgb__reg_lambda=0.4513896917704029; f1_macro: (test=0.681) f1_micro: (test=0.895) roc_auc: (test=0.840) total time=  11.1s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9419321088666186, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.07955946473535244, lgb__num_leaves=63, lgb__reg_lambda=0.4513896917704029; f1_macro: (test=0.676) f1_micro: (test=0.892) roc_auc: (test=0.825) total time=  10.1s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7603175317556659, lgb__learning_rate=0.15, lgb__min_child_samples=19, lgb__min_split_gain=0.013042928220861906, lgb__num_leaves=63, lgb__reg_lambda=0.010695636761950844; f1_macro: (test=0.639) f1_micro: (test=0.794) roc_auc: (test=0.810) total time=  19.4s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9613169276639503, lgb__learning_rate=0.3, lgb__min_child_samples=8, lgb__min_split_gain=0.0029156996519808854, lgb__num_leaves=127, lgb__reg_lambda=0.2882989975605308; f1_macro: (test=0.595) f1_micro: (test=0.748) roc_auc: (test=0.782) total time=  25.0s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9419321088666186, lgb__learning_rate=0.3, lgb__min_child_samples=9, lgb__min_split_gain=0.07955946473535244, lgb__num_leaves=63, lgb__reg_lambda=0.4513896917704029; f1_macro: (test=0.651) f1_micro: (test=0.885) roc_auc: (test=0.821) total time=  12.3s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9613169276639503, lgb__learning_rate=0.3, lgb__min_child_samples=8, lgb__min_split_gain=0.0029156996519808854, lgb__num_leaves=127, lgb__reg_lambda=0.2882989975605308; f1_macro: (test=0.599) f1_micro: (test=0.744) roc_auc: (test=0.795) total time=  29.5s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5413677446267017, lgb__learning_rate=0.3, lgb__min_child_samples=29, lgb__min_split_gain=0.08585246688775272, lgb__num_leaves=63, lgb__reg_lambda=0.5243967382988608; f1_macro: (test=0.696) f1_micro: (test=0.897) roc_auc: (test=0.852) total time=  10.0s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9613169276639503, lgb__learning_rate=0.3, lgb__min_child_samples=8, lgb__min_split_gain=0.0029156996519808854, lgb__num_leaves=127, lgb__reg_lambda=0.2882989975605308; f1_macro: (test=0.585) f1_micro: (test=0.732) roc_auc: (test=0.776) total time=  32.8s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9613169276639503, lgb__learning_rate=0.3, lgb__min_child_samples=8, lgb__min_split_gain=0.0029156996519808854, lgb__num_leaves=127, lgb__reg_lambda=0.2882989975605308; f1_macro: (test=0.588) f1_micro: (test=0.746) roc_auc: (test=0.757) total time=  31.0s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5413677446267017, lgb__learning_rate=0.3, lgb__min_child_samples=29, lgb__min_split_gain=0.08585246688775272, lgb__num_leaves=63, lgb__reg_lambda=0.5243967382988608; f1_macro: (test=0.644) f1_micro: (test=0.883) roc_auc: (test=0.834) total time=  12.4s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9613169276639503, lgb__learning_rate=0.3, lgb__min_child_samples=8, lgb__min_split_gain=0.0029156996519808854, lgb__num_leaves=127, lgb__reg_lambda=0.2882989975605308; f1_macro: (test=0.588) f1_micro: (test=0.766) roc_auc: (test=0.756) total time=  35.5s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.6766406258903097, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.024537239045975004, lgb__num_leaves=31, lgb__reg_lambda=0.15913789767122088; f1_macro: (test=0.615) f1_micro: (test=0.762) roc_auc: (test=0.802) total time=   8.2s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5413677446267017, lgb__learning_rate=0.3, lgb__min_child_samples=29, lgb__min_split_gain=0.08585246688775272, lgb__num_leaves=63, lgb__reg_lambda=0.5243967382988608; f1_macro: (test=0.661) f1_micro: (test=0.887) roc_auc: (test=0.824) total time=  11.1s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.6766406258903097, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.024537239045975004, lgb__num_leaves=31, lgb__reg_lambda=0.15913789767122088; f1_macro: (test=0.637) f1_micro: (test=0.769) roc_auc: (test=0.830) total time=   9.4s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5413677446267017, lgb__learning_rate=0.3, lgb__min_child_samples=29, lgb__min_split_gain=0.08585246688775272, lgb__num_leaves=63, lgb__reg_lambda=0.5243967382988608; f1_macro: (test=0.674) f1_micro: (test=0.888) roc_auc: (test=0.820) total time=  11.9s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7268687309711035, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.010616885236333874, lgb__num_leaves=15, lgb__reg_lambda=0.6098765802409186; f1_macro: (test=0.599) f1_micro: (test=0.731) roc_auc: (test=0.788) total time=   3.9s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5413677446267017, lgb__learning_rate=0.3, lgb__min_child_samples=29, lgb__min_split_gain=0.08585246688775272, lgb__num_leaves=63, lgb__reg_lambda=0.5243967382988608; f1_macro: (test=0.691) f1_micro: (test=0.899) roc_auc: (test=0.842) total time=  13.3s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7268687309711035, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.010616885236333874, lgb__num_leaves=15, lgb__reg_lambda=0.6098765802409186; f1_macro: (test=0.596) f1_micro: (test=0.716) roc_auc: (test=0.812) total time=   4.2s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7268687309711035, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.010616885236333874, lgb__num_leaves=15, lgb__reg_lambda=0.6098765802409186; f1_macro: (test=0.619) f1_micro: (test=0.748) roc_auc: (test=0.823) total time=   4.8s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7268687309711035, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.010616885236333874, lgb__num_leaves=15, lgb__reg_lambda=0.6098765802409186; f1_macro: (test=0.606) f1_micro: (test=0.724) roc_auc: (test=0.813) total time=   5.6s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9580550431947776, lgb__learning_rate=0.15, lgb__min_child_samples=12, lgb__min_split_gain=0.023638112638259948, lgb__num_leaves=127, lgb__reg_lambda=0.912999173370326; f1_macro: (test=0.646) f1_micro: (test=0.893) roc_auc: (test=0.837) total time=  25.2s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.6766406258903097, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.024537239045975004, lgb__num_leaves=31, lgb__reg_lambda=0.15913789767122088; f1_macro: (test=0.634) f1_micro: (test=0.759) roc_auc: (test=0.833) total time=  11.6s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7268687309711035, lgb__learning_rate=0.15, lgb__min_child_samples=5, lgb__min_split_gain=0.010616885236333874, lgb__num_leaves=15, lgb__reg_lambda=0.6098765802409186; f1_macro: (test=0.592) f1_micro: (test=0.724) roc_auc: (test=0.783) total time=   4.7s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.6766406258903097, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.024537239045975004, lgb__num_leaves=31, lgb__reg_lambda=0.15913789767122088; f1_macro: (test=0.643) f1_micro: (test=0.777) roc_auc: (test=0.835) total time=   8.1s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.6766406258903097, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.024537239045975004, lgb__num_leaves=31, lgb__reg_lambda=0.15913789767122088; f1_macro: (test=0.624) f1_micro: (test=0.760) roc_auc: (test=0.806) total time=   8.9s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.540075668932015, lgb__learning_rate=0.3, lgb__min_child_samples=13, lgb__min_split_gain=0.07130864089874243, lgb__num_leaves=15, lgb__reg_lambda=0.12465567755416018; f1_macro: (test=0.611) f1_micro: (test=0.749) roc_auc: (test=0.792) total time=   4.0s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.540075668932015, lgb__learning_rate=0.3, lgb__min_child_samples=13, lgb__min_split_gain=0.07130864089874243, lgb__num_leaves=15, lgb__reg_lambda=0.12465567755416018; f1_macro: (test=0.610) f1_micro: (test=0.733) roc_auc: (test=0.820) total time=   5.4s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.540075668932015, lgb__learning_rate=0.3, lgb__min_child_samples=13, lgb__min_split_gain=0.07130864089874243, lgb__num_leaves=15, lgb__reg_lambda=0.12465567755416018; f1_macro: (test=0.615) f1_micro: (test=0.736) roc_auc: (test=0.831) total time=   5.2s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.540075668932015, lgb__learning_rate=0.3, lgb__min_child_samples=13, lgb__min_split_gain=0.07130864089874243, lgb__num_leaves=15, lgb__reg_lambda=0.12465567755416018; f1_macro: (test=0.629) f1_micro: (test=0.759) roc_auc: (test=0.833) total time=   5.7s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.540075668932015, lgb__learning_rate=0.3, lgb__min_child_samples=13, lgb__min_split_gain=0.07130864089874243, lgb__num_leaves=15, lgb__reg_lambda=0.12465567755416018; f1_macro: (test=0.606) f1_micro: (test=0.739) roc_auc: (test=0.791) total time=   5.7s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9580550431947776, lgb__learning_rate=0.15, lgb__min_child_samples=12, lgb__min_split_gain=0.023638112638259948, lgb__num_leaves=127, lgb__reg_lambda=0.912999173370326; f1_macro: (test=0.670) f1_micro: (test=0.897) roc_auc: (test=0.851) total time=  29.3s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9580550431947776, lgb__learning_rate=0.15, lgb__min_child_samples=12, lgb__min_split_gain=0.023638112638259948, lgb__num_leaves=127, lgb__reg_lambda=0.912999173370326; f1_macro: (test=0.707) f1_micro: (test=0.901) roc_auc: (test=0.854) total time=  31.3s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9580550431947776, lgb__learning_rate=0.15, lgb__min_child_samples=12, lgb__min_split_gain=0.023638112638259948, lgb__num_leaves=127, lgb__reg_lambda=0.912999173370326; f1_macro: (test=0.695) f1_micro: (test=0.899) roc_auc: (test=0.837) total time=  29.5s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.75784029009877, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09880066615714264, lgb__num_leaves=63, lgb__reg_lambda=0.6222051270167803; f1_macro: (test=0.650) f1_micro: (test=0.790) roc_auc: (test=0.834) total time=  13.7s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.75784029009877, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09880066615714264, lgb__num_leaves=63, lgb__reg_lambda=0.6222051270167803; f1_macro: (test=0.650) f1_micro: (test=0.795) roc_auc: (test=0.834) total time=  14.1s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.75784029009877, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09880066615714264, lgb__num_leaves=63, lgb__reg_lambda=0.6222051270167803; f1_macro: (test=0.630) f1_micro: (test=0.794) roc_auc: (test=0.802) total time=  16.3s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.75784029009877, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09880066615714264, lgb__num_leaves=63, lgb__reg_lambda=0.6222051270167803; f1_macro: (test=0.639) f1_micro: (test=0.782) roc_auc: (test=0.832) total time=  16.0s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.75784029009877, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09880066615714264, lgb__num_leaves=63, lgb__reg_lambda=0.6222051270167803; f1_macro: (test=0.640) f1_micro: (test=0.791) roc_auc: (test=0.810) total time=  14.7s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9580550431947776, lgb__learning_rate=0.15, lgb__min_child_samples=12, lgb__min_split_gain=0.023638112638259948, lgb__num_leaves=127, lgb__reg_lambda=0.912999173370326; f1_macro: (test=0.652) f1_micro: (test=0.889) roc_auc: (test=0.832) total time=  34.9s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7465511692932634, lgb__learning_rate=0.15, lgb__min_child_samples=7, lgb__min_split_gain=0.06602489038035729, lgb__num_leaves=15, lgb__reg_lambda=0.9479230192085655; f1_macro: (test=0.591) f1_micro: (test=0.724) roc_auc: (test=0.787) total time=   5.7s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7465511692932634, lgb__learning_rate=0.15, lgb__min_child_samples=7, lgb__min_split_gain=0.06602489038035729, lgb__num_leaves=15, lgb__reg_lambda=0.9479230192085655; f1_macro: (test=0.593) f1_micro: (test=0.716) roc_auc: (test=0.809) total time=   5.1s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7465511692932634, lgb__learning_rate=0.15, lgb__min_child_samples=7, lgb__min_split_gain=0.06602489038035729, lgb__num_leaves=15, lgb__reg_lambda=0.9479230192085655; f1_macro: (test=0.620) f1_micro: (test=0.749) roc_auc: (test=0.822) total time=   4.2s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7465511692932634, lgb__learning_rate=0.15, lgb__min_child_samples=7, lgb__min_split_gain=0.06602489038035729, lgb__num_leaves=15, lgb__reg_lambda=0.9479230192085655; f1_macro: (test=0.591) f1_micro: (test=0.724) roc_auc: (test=0.781) total time=   4.7s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7465511692932634, lgb__learning_rate=0.15, lgb__min_child_samples=7, lgb__min_split_gain=0.06602489038035729, lgb__num_leaves=15, lgb__reg_lambda=0.9479230192085655; f1_macro: (test=0.603) f1_micro: (test=0.721) roc_auc: (test=0.809) total time=   5.0s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8724896056084032, lgb__learning_rate=0.15, lgb__min_child_samples=28, lgb__min_split_gain=0.05147053338756159, lgb__num_leaves=127, lgb__reg_lambda=0.1323335830782506; f1_macro: (test=0.648) f1_micro: (test=0.801) roc_auc: (test=0.822) total time=  25.9s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8724896056084032, lgb__learning_rate=0.15, lgb__min_child_samples=28, lgb__min_split_gain=0.05147053338756159, lgb__num_leaves=127, lgb__reg_lambda=0.1323335830782506; f1_macro: (test=0.618) f1_micro: (test=0.813) roc_auc: (test=0.782) total time=  26.9s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.757891270187397, lgb__learning_rate=0.3, lgb__min_child_samples=18, lgb__min_split_gain=0.0843656093157598, lgb__num_leaves=127, lgb__reg_lambda=0.8881705659558571; f1_macro: (test=0.671) f1_micro: (test=0.892) roc_auc: (test=0.830) total time=  10.4s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8303248124611105, lgb__learning_rate=0.15, lgb__min_child_samples=13, lgb__min_split_gain=0.0049894936134145754, lgb__num_leaves=63, lgb__reg_lambda=0.4828546746654463; f1_macro: (test=0.626) f1_micro: (test=0.789) roc_auc: (test=0.792) total time=  13.6s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8303248124611105, lgb__learning_rate=0.15, lgb__min_child_samples=13, lgb__min_split_gain=0.0049894936134145754, lgb__num_leaves=63, lgb__reg_lambda=0.4828546746654463; f1_macro: (test=0.641) f1_micro: (test=0.777) roc_auc: (test=0.829) total time=  12.8s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8303248124611105, lgb__learning_rate=0.15, lgb__min_child_samples=13, lgb__min_split_gain=0.0049894936134145754, lgb__num_leaves=63, lgb__reg_lambda=0.4828546746654463; f1_macro: (test=0.645) f1_micro: (test=0.785) roc_auc: (test=0.831) total time=  13.8s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8724896056084032, lgb__learning_rate=0.15, lgb__min_child_samples=28, lgb__min_split_gain=0.05147053338756159, lgb__num_leaves=127, lgb__reg_lambda=0.1323335830782506; f1_macro: (test=0.641) f1_micro: (test=0.808) roc_auc: (test=0.818) total time=  25.3s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8303248124611105, lgb__learning_rate=0.15, lgb__min_child_samples=13, lgb__min_split_gain=0.0049894936134145754, lgb__num_leaves=63, lgb__reg_lambda=0.4828546746654463; f1_macro: (test=0.620) f1_micro: (test=0.767) roc_auc: (test=0.812) total time=  14.3s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8724896056084032, lgb__learning_rate=0.15, lgb__min_child_samples=28, lgb__min_split_gain=0.05147053338756159, lgb__num_leaves=127, lgb__reg_lambda=0.1323335830782506; f1_macro: (test=0.642) f1_micro: (test=0.815) roc_auc: (test=0.804) total time=  28.5s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6552518069715958, lgb__learning_rate=0.01, lgb__min_child_samples=6, lgb__min_split_gain=0.052095948133050074, lgb__num_leaves=127, lgb__reg_lambda=0.1522720001435821; f1_macro: (test=0.686) f1_micro: (test=0.852) roc_auc: (test=0.846) total time=  29.9s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6552518069715958, lgb__learning_rate=0.01, lgb__min_child_samples=6, lgb__min_split_gain=0.052095948133050074, lgb__num_leaves=127, lgb__reg_lambda=0.1522720001435821; f1_macro: (test=0.677) f1_micro: (test=0.863) roc_auc: (test=0.826) total time=  27.4s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9694431378767928, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09290449450991957, lgb__num_leaves=31, lgb__reg_lambda=0.04137510667874644; f1_macro: (test=0.625) f1_micro: (test=0.761) roc_auc: (test=0.828) total time=   7.3s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8724896056084032, lgb__learning_rate=0.15, lgb__min_child_samples=28, lgb__min_split_gain=0.05147053338756159, lgb__num_leaves=127, lgb__reg_lambda=0.1323335830782506; f1_macro: (test=0.627) f1_micro: (test=0.807) roc_auc: (test=0.786) total time=  32.0s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8303248124611105, lgb__learning_rate=0.15, lgb__min_child_samples=13, lgb__min_split_gain=0.0049894936134145754, lgb__num_leaves=63, lgb__reg_lambda=0.4828546746654463; f1_macro: (test=0.634) f1_micro: (test=0.783) roc_auc: (test=0.799) total time=  20.6s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6552518069715958, lgb__learning_rate=0.01, lgb__min_child_samples=6, lgb__min_split_gain=0.052095948133050074, lgb__num_leaves=127, lgb__reg_lambda=0.1522720001435821; f1_macro: (test=0.664) f1_micro: (test=0.851) roc_auc: (test=0.837) total time=  30.1s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9694431378767928, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09290449450991957, lgb__num_leaves=31, lgb__reg_lambda=0.04137510667874644; f1_macro: (test=0.645) f1_micro: (test=0.784) roc_auc: (test=0.837) total time=   8.4s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6552518069715958, lgb__learning_rate=0.01, lgb__min_child_samples=6, lgb__min_split_gain=0.052095948133050074, lgb__num_leaves=127, lgb__reg_lambda=0.1522720001435821; f1_macro: (test=0.698) f1_micro: (test=0.867) roc_auc: (test=0.851) total time=  32.4s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9694431378767928, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09290449450991957, lgb__num_leaves=31, lgb__reg_lambda=0.04137510667874644; f1_macro: (test=0.635) f1_micro: (test=0.769) roc_auc: (test=0.828) total time=   9.6s[CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6552518069715958, lgb__learning_rate=0.01, lgb__min_child_samples=6, lgb__min_split_gain=0.052095948133050074, lgb__num_leaves=127, lgb__reg_lambda=0.1522720001435821; f1_macro: (test=0.668) f1_micro: (test=0.863) roc_auc: (test=0.821) total time=  33.6s
#
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9694431378767928, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09290449450991957, lgb__num_leaves=31, lgb__reg_lambda=0.04137510667874644; f1_macro: (test=0.633) f1_micro: (test=0.784) roc_auc: (test=0.821) total time=  10.5s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.757891270187397, lgb__learning_rate=0.3, lgb__min_child_samples=18, lgb__min_split_gain=0.0843656093157598, lgb__num_leaves=127, lgb__reg_lambda=0.8881705659558571; f1_macro: (test=0.680) f1_micro: (test=0.891) roc_auc: (test=0.820) total time=  12.7s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.9694431378767928, lgb__learning_rate=0.01, lgb__min_child_samples=26, lgb__min_split_gain=0.09290449450991957, lgb__num_leaves=31, lgb__reg_lambda=0.04137510667874644; f1_macro: (test=0.628) f1_micro: (test=0.764) roc_auc: (test=0.811) total time=   9.0s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5786047712169723, lgb__learning_rate=0.15, lgb__min_child_samples=6, lgb__min_split_gain=0.03704075485505709, lgb__num_leaves=15, lgb__reg_lambda=0.3606084225042038; f1_macro: (test=0.684) f1_micro: (test=0.840) roc_auc: (test=0.859) total time=   2.4s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.757891270187397, lgb__learning_rate=0.3, lgb__min_child_samples=18, lgb__min_split_gain=0.0843656093157598, lgb__num_leaves=127, lgb__reg_lambda=0.8881705659558571; f1_macro: (test=0.701) f1_micro: (test=0.902) roc_auc: (test=0.838) total time=  14.7s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.757891270187397, lgb__learning_rate=0.3, lgb__min_child_samples=18, lgb__min_split_gain=0.0843656093157598, lgb__num_leaves=127, lgb__reg_lambda=0.8881705659558571; f1_macro: (test=0.642) f1_micro: (test=0.883) roc_auc: (test=0.816) total time=  14.0s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.757891270187397, lgb__learning_rate=0.3, lgb__min_child_samples=18, lgb__min_split_gain=0.0843656093157598, lgb__num_leaves=127, lgb__reg_lambda=0.8881705659558571; f1_macro: (test=0.702) f1_micro: (test=0.894) roc_auc: (test=0.854) total time=  15.6s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5786047712169723, lgb__learning_rate=0.15, lgb__min_child_samples=6, lgb__min_split_gain=0.03704075485505709, lgb__num_leaves=15, lgb__reg_lambda=0.3606084225042038; f1_macro: (test=0.680) f1_micro: (test=0.841) roc_auc: (test=0.844) total time=   4.3s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5786047712169723, lgb__learning_rate=0.15, lgb__min_child_samples=6, lgb__min_split_gain=0.03704075485505709, lgb__num_leaves=15, lgb__reg_lambda=0.3606084225042038; f1_macro: (test=0.659) f1_micro: (test=0.827) roc_auc: (test=0.831) total time=   4.9s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5786047712169723, lgb__learning_rate=0.15, lgb__min_child_samples=6, lgb__min_split_gain=0.03704075485505709, lgb__num_leaves=15, lgb__reg_lambda=0.3606084225042038; f1_macro: (test=0.702) f1_micro: (test=0.848) roc_auc: (test=0.855) total time=   5.2s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5786047712169723, lgb__learning_rate=0.15, lgb__min_child_samples=6, lgb__min_split_gain=0.03704075485505709, lgb__num_leaves=15, lgb__reg_lambda=0.3606084225042038; f1_macro: (test=0.701) f1_micro: (test=0.852) roc_auc: (test=0.860) total time=   5.4s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7787287210943045, lgb__learning_rate=0.01, lgb__min_child_samples=10, lgb__min_split_gain=0.09995560109207652, lgb__num_leaves=31, lgb__reg_lambda=0.7917093180964536; f1_macro: (test=0.638) f1_micro: (test=0.768) roc_auc: (test=0.824) total time=   6.8s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7787287210943045, lgb__learning_rate=0.01, lgb__min_child_samples=10, lgb__min_split_gain=0.09995560109207652, lgb__num_leaves=31, lgb__reg_lambda=0.7917093180964536; f1_macro: (test=0.621) f1_micro: (test=0.749) roc_auc: (test=0.823) total time=   8.6s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8475210367020594, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.09533026918410359, lgb__num_leaves=63, lgb__reg_lambda=0.6902722312738483; f1_macro: (test=0.651) f1_micro: (test=0.801) roc_auc: (test=0.842) total time=  12.6s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7787287210943045, lgb__learning_rate=0.01, lgb__min_child_samples=10, lgb__min_split_gain=0.09995560109207652, lgb__num_leaves=31, lgb__reg_lambda=0.7917093180964536; f1_macro: (test=0.628) f1_micro: (test=0.762) roc_auc: (test=0.832) total time=   7.8s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7787287210943045, lgb__learning_rate=0.01, lgb__min_child_samples=10, lgb__min_split_gain=0.09995560109207652, lgb__num_leaves=31, lgb__reg_lambda=0.7917093180964536; f1_macro: (test=0.613) f1_micro: (test=0.750) roc_auc: (test=0.799) total time=   7.5s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7787287210943045, lgb__learning_rate=0.01, lgb__min_child_samples=10, lgb__min_split_gain=0.09995560109207652, lgb__num_leaves=31, lgb__reg_lambda=0.7917093180964536; f1_macro: (test=0.606) f1_micro: (test=0.754) roc_auc: (test=0.796) total time=  10.2s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8475210367020594, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.09533026918410359, lgb__num_leaves=63, lgb__reg_lambda=0.6902722312738483; f1_macro: (test=0.673) f1_micro: (test=0.827) roc_auc: (test=0.839) total time=  15.6s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8475210367020594, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.09533026918410359, lgb__num_leaves=63, lgb__reg_lambda=0.6902722312738483; f1_macro: (test=0.668) f1_micro: (test=0.818) roc_auc: (test=0.833) total time=  16.3s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9287995095353201, lgb__learning_rate=0.01, lgb__min_child_samples=5, lgb__min_split_gain=0.04302289257625767, lgb__num_leaves=15, lgb__reg_lambda=0.493037931937103; f1_macro: (test=0.560) f1_micro: (test=0.676) roc_auc: (test=0.774) total time=   4.8s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8475210367020594, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.09533026918410359, lgb__num_leaves=63, lgb__reg_lambda=0.6902722312738483; f1_macro: (test=0.654) f1_micro: (test=0.810) roc_auc: (test=0.822) total time=  17.5s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9287995095353201, lgb__learning_rate=0.01, lgb__min_child_samples=5, lgb__min_split_gain=0.04302289257625767, lgb__num_leaves=15, lgb__reg_lambda=0.493037931937103; f1_macro: (test=0.558) f1_micro: (test=0.667) roc_auc: (test=0.788) total time=   5.3s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8475210367020594, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.09533026918410359, lgb__num_leaves=63, lgb__reg_lambda=0.6902722312738483; f1_macro: (test=0.654) f1_micro: (test=0.820) roc_auc: (test=0.822) total time=  19.6s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9287995095353201, lgb__learning_rate=0.01, lgb__min_child_samples=5, lgb__min_split_gain=0.04302289257625767, lgb__num_leaves=15, lgb__reg_lambda=0.493037931937103; f1_macro: (test=0.553) f1_micro: (test=0.646) roc_auc: (test=0.784) total time=   4.5s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9287995095353201, lgb__learning_rate=0.01, lgb__min_child_samples=5, lgb__min_split_gain=0.04302289257625767, lgb__num_leaves=15, lgb__reg_lambda=0.493037931937103; f1_macro: (test=0.606) f1_micro: (test=0.736) roc_auc: (test=0.802) total time=   4.8s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8543538320066387, lgb__learning_rate=0.01, lgb__min_child_samples=16, lgb__min_split_gain=0.0632448162061768, lgb__num_leaves=63, lgb__reg_lambda=0.8587971938450034; f1_macro: (test=0.659) f1_micro: (test=0.807) roc_auc: (test=0.841) total time=  11.5s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9287995095353201, lgb__learning_rate=0.01, lgb__min_child_samples=5, lgb__min_split_gain=0.04302289257625767, lgb__num_leaves=15, lgb__reg_lambda=0.493037931937103; f1_macro: (test=0.556) f1_micro: (test=0.671) roc_auc: (test=0.753) total time=   5.1s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8543538320066387, lgb__learning_rate=0.01, lgb__min_child_samples=16, lgb__min_split_gain=0.0632448162061768, lgb__num_leaves=63, lgb__reg_lambda=0.8587971938450034; f1_macro: (test=0.658) f1_micro: (test=0.823) roc_auc: (test=0.824) total time=  16.3s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8543538320066387, lgb__learning_rate=0.01, lgb__min_child_samples=16, lgb__min_split_gain=0.0632448162061768, lgb__num_leaves=63, lgb__reg_lambda=0.8587971938450034; f1_macro: (test=0.670) f1_micro: (test=0.823) roc_auc: (test=0.839) total time=  14.0s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8543538320066387, lgb__learning_rate=0.01, lgb__min_child_samples=16, lgb__min_split_gain=0.0632448162061768, lgb__num_leaves=63, lgb__reg_lambda=0.8587971938450034; f1_macro: (test=0.658) f1_micro: (test=0.811) roc_auc: (test=0.823) total time=  14.4s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.8543538320066387, lgb__learning_rate=0.01, lgb__min_child_samples=16, lgb__min_split_gain=0.0632448162061768, lgb__num_leaves=63, lgb__reg_lambda=0.8587971938450034; f1_macro: (test=0.659) f1_micro: (test=0.810) roc_auc: (test=0.832) total time=  15.2s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7839244686334211, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.041414113332935015, lgb__num_leaves=63, lgb__reg_lambda=0.829378843353453; f1_macro: (test=0.654) f1_micro: (test=0.882) roc_auc: (test=0.831) total time=  13.9s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7839244686334211, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.041414113332935015, lgb__num_leaves=63, lgb__reg_lambda=0.829378843353453; f1_macro: (test=0.711) f1_micro: (test=0.896) roc_auc: (test=0.855) total time=  14.2s
# ...
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.949967773832094, lgb__learning_rate=0.01, lgb__min_child_samples=11, lgb__min_split_gain=0.06952355987257289, lgb__num_leaves=63, lgb__reg_lambda=0.5233781111217284; f1_macro: (test=0.653) f1_micro: (test=0.818) roc_auc: (test=0.822) total time=  11.1s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.949967773832094, lgb__learning_rate=0.01, lgb__min_child_samples=11, lgb__min_split_gain=0.06952355987257289, lgb__num_leaves=63, lgb__reg_lambda=0.5233781111217284; f1_macro: (test=0.647) f1_micro: (test=0.794) roc_auc: (test=0.834) total time=  10.9s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.949967773832094, lgb__learning_rate=0.01, lgb__min_child_samples=11, lgb__min_split_gain=0.06952355987257289, lgb__num_leaves=63, lgb__reg_lambda=0.5233781111217284; f1_macro: (test=0.653) f1_micro: (test=0.805) roc_auc: (test=0.826) total time=  10.4s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7244773404229523, lgb__learning_rate=0.15, lgb__min_child_samples=9, lgb__min_split_gain=0.037213268079626514, lgb__num_leaves=127, lgb__reg_lambda=0.9885254415339283; f1_macro: (test=0.687) f1_micro: (test=0.900) roc_auc: (test=0.853) total time=  25.8s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.949967773832094, lgb__learning_rate=0.01, lgb__min_child_samples=11, lgb__min_split_gain=0.06952355987257289, lgb__num_leaves=63, lgb__reg_lambda=0.5233781111217284; f1_macro: (test=0.662) f1_micro: (test=0.816) roc_auc: (test=0.829) total time=  10.7s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8185852126029444, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.010100931782057078, lgb__num_leaves=31, lgb__reg_lambda=0.008293219332036972; f1_macro: (test=0.622) f1_micro: (test=0.751) roc_auc: (test=0.819) total time=   6.3s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8185852126029444, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.010100931782057078, lgb__num_leaves=31, lgb__reg_lambda=0.008293219332036972; f1_macro: (test=0.610) f1_micro: (test=0.735) roc_auc: (test=0.816) total time=   6.5s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.949967773832094, lgb__learning_rate=0.01, lgb__min_child_samples=11, lgb__min_split_gain=0.06952355987257289, lgb__num_leaves=63, lgb__reg_lambda=0.5233781111217284; f1_macro: (test=0.658) f1_micro: (test=0.807) roc_auc: (test=0.818) total time=  12.6s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8185852126029444, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.010100931782057078, lgb__num_leaves=31, lgb__reg_lambda=0.008293219332036972; f1_macro: (test=0.630) f1_micro: (test=0.765) roc_auc: (test=0.829) total time=   6.6s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8185852126029444, lgb__learning_rate=0.3, lgb__min_child_samples=20, lgb__min_split_gain=0.010100931782057078, lgb__num_leaves=31, lgb__reg_lambda=0.008293219332036972; f1_macro: (test=0.604) f1_micro: (test=0.742) roc_auc: (test=0.793) total time=   6.9s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5784794483990299, lgb__learning_rate=0.15, lgb__min_child_samples=8, lgb__min_split_gain=0.0527094204498551, lgb__num_leaves=127, lgb__reg_lambda=0.48093180670409197; f1_macro: (test=0.679) f1_micro: (test=0.903) roc_auc: (test=0.858) total time=  17.6s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5784794483990299, lgb__learning_rate=0.15, lgb__min_child_samples=8, lgb__min_split_gain=0.0527094204498551, lgb__num_leaves=127, lgb__reg_lambda=0.48093180670409197; f1_macro: (test=0.711) f1_micro: (test=0.906) roc_auc: (test=0.865) total time=  18.2s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7923304968806538, lgb__learning_rate=0.3, lgb__min_child_samples=19, lgb__min_split_gain=0.05721229552630659, lgb__num_leaves=31, lgb__reg_lambda=0.11275052461082491; f1_macro: (test=0.608) f1_micro: (test=0.756) roc_auc: (test=0.795) total time=   5.9s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5784794483990299, lgb__learning_rate=0.15, lgb__min_child_samples=8, lgb__min_split_gain=0.0527094204498551, lgb__num_leaves=127, lgb__reg_lambda=0.48093180670409197; f1_macro: (test=0.638) f1_micro: (test=0.891) roc_auc: (test=0.831) total time=  20.2s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5784794483990299, lgb__learning_rate=0.15, lgb__min_child_samples=8, lgb__min_split_gain=0.0527094204498551, lgb__num_leaves=127, lgb__reg_lambda=0.48093180670409197; f1_macro: (test=0.679) f1_micro: (test=0.897) roc_auc: (test=0.830) total time=  19.5s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.5784794483990299, lgb__learning_rate=0.15, lgb__min_child_samples=8, lgb__min_split_gain=0.0527094204498551, lgb__num_leaves=127, lgb__reg_lambda=0.48093180670409197; f1_macro: (test=0.666) f1_micro: (test=0.894) roc_auc: (test=0.827) total time=  19.4s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7923304968806538, lgb__learning_rate=0.3, lgb__min_child_samples=19, lgb__min_split_gain=0.05721229552630659, lgb__num_leaves=31, lgb__reg_lambda=0.11275052461082491; f1_macro: (test=0.609) f1_micro: (test=0.734) roc_auc: (test=0.819) total time=   4.8s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7923304968806538, lgb__learning_rate=0.3, lgb__min_child_samples=19, lgb__min_split_gain=0.05721229552630659, lgb__num_leaves=31, lgb__reg_lambda=0.11275052461082491; f1_macro: (test=0.631) f1_micro: (test=0.759) roc_auc: (test=0.822) total time=   6.2s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7923304968806538, lgb__learning_rate=0.3, lgb__min_child_samples=19, lgb__min_split_gain=0.05721229552630659, lgb__num_leaves=31, lgb__reg_lambda=0.11275052461082491; f1_macro: (test=0.630) f1_micro: (test=0.765) roc_auc: (test=0.830) total time=   5.3s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7842007218731424, lgb__learning_rate=0.01, lgb__min_child_samples=24, lgb__min_split_gain=0.07614028595817374, lgb__num_leaves=127, lgb__reg_lambda=0.5690481516490171; f1_macro: (test=0.637) f1_micro: (test=0.831) roc_auc: (test=0.804) total time=  18.9s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7923304968806538, lgb__learning_rate=0.3, lgb__min_child_samples=19, lgb__min_split_gain=0.05721229552630659, lgb__num_leaves=31, lgb__reg_lambda=0.11275052461082491; f1_macro: (test=0.608) f1_micro: (test=0.746) roc_auc: (test=0.798) total time=   6.1s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7842007218731424, lgb__learning_rate=0.01, lgb__min_child_samples=24, lgb__min_split_gain=0.07614028595817374, lgb__num_leaves=127, lgb__reg_lambda=0.5690481516490171; f1_macro: (test=0.660) f1_micro: (test=0.829) roc_auc: (test=0.833) total time=  19.3s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7842007218731424, lgb__learning_rate=0.01, lgb__min_child_samples=24, lgb__min_split_gain=0.07614028595817374, lgb__num_leaves=127, lgb__reg_lambda=0.5690481516490171; f1_macro: (test=0.660) f1_micro: (test=0.833) roc_auc: (test=0.828) total time=  19.6s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9323039721934986, lgb__learning_rate=0.15, lgb__min_child_samples=14, lgb__min_split_gain=0.08177239017876248, lgb__num_leaves=127, lgb__reg_lambda=0.0045723582858926415; f1_macro: (test=0.594) f1_micro: (test=0.772) roc_auc: (test=0.768) total time=  20.3s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7842007218731424, lgb__learning_rate=0.01, lgb__min_child_samples=24, lgb__min_split_gain=0.07614028595817374, lgb__num_leaves=127, lgb__reg_lambda=0.5690481516490171; f1_macro: (test=0.653) f1_micro: (test=0.831) roc_auc: (test=0.804) total time=  21.7s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9323039721934986, lgb__learning_rate=0.15, lgb__min_child_samples=14, lgb__min_split_gain=0.08177239017876248, lgb__num_leaves=127, lgb__reg_lambda=0.0045723582858926415; f1_macro: (test=0.634) f1_micro: (test=0.781) roc_auc: (test=0.820) total time=  21.3s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9323039721934986, lgb__learning_rate=0.15, lgb__min_child_samples=14, lgb__min_split_gain=0.08177239017876248, lgb__num_leaves=127, lgb__reg_lambda=0.0045723582858926415; f1_macro: (test=0.623) f1_micro: (test=0.782) roc_auc: (test=0.792) total time=  20.1s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.7842007218731424, lgb__learning_rate=0.01, lgb__min_child_samples=24, lgb__min_split_gain=0.07614028595817374, lgb__num_leaves=127, lgb__reg_lambda=0.5690481516490171; f1_macro: (test=0.669) f1_micro: (test=0.825) roc_auc: (test=0.836) total time=  24.5s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9323039721934986, lgb__learning_rate=0.15, lgb__min_child_samples=14, lgb__min_split_gain=0.08177239017876248, lgb__num_leaves=127, lgb__reg_lambda=0.0045723582858926415; f1_macro: (test=0.606) f1_micro: (test=0.772) roc_auc: (test=0.766) total time=  21.5s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.9323039721934986, lgb__learning_rate=0.15, lgb__min_child_samples=14, lgb__min_split_gain=0.08177239017876248, lgb__num_leaves=127, lgb__reg_lambda=0.0045723582858926415; f1_macro: (test=0.608) f1_micro: (test=0.761) roc_auc: (test=0.789) total time=  22.4s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6928860412938613, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.0023922000044225844, lgb__num_leaves=63, lgb__reg_lambda=0.5330309484404907; f1_macro: (test=0.662) f1_micro: (test=0.809) roc_auc: (test=0.847) total time=  10.7s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6928860412938613, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.0023922000044225844, lgb__num_leaves=63, lgb__reg_lambda=0.5330309484404907; f1_macro: (test=0.660) f1_micro: (test=0.826) roc_auc: (test=0.820) total time=  11.2s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7684737847109464, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.033315235868187666, lgb__num_leaves=15, lgb__reg_lambda=0.135380093016772; f1_macro: (test=0.669) f1_micro: (test=0.839) roc_auc: (test=0.843) total time=   3.2s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6928860412938613, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.0023922000044225844, lgb__num_leaves=63, lgb__reg_lambda=0.5330309484404907; f1_macro: (test=0.682) f1_micro: (test=0.828) roc_auc: (test=0.849) total time=  12.2s
# [CV 1/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8895849571906607, lgb__learning_rate=0.3, lgb__min_child_samples=25, lgb__min_split_gain=0.012134019525780871, lgb__num_leaves=127, lgb__reg_lambda=0.5357596957155019; f1_macro: (test=0.610) f1_micro: (test=0.807) roc_auc: (test=0.789) total time=  19.1s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6928860412938613, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.0023922000044225844, lgb__num_leaves=63, lgb__reg_lambda=0.5330309484404907; f1_macro: (test=0.675) f1_micro: (test=0.829) roc_auc: (test=0.847) total time=  11.8s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7684737847109464, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.033315235868187666, lgb__num_leaves=15, lgb__reg_lambda=0.135380093016772; f1_macro: (test=0.681) f1_micro: (test=0.840) roc_auc: (test=0.857) total time=   3.2s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.6928860412938613, lgb__learning_rate=0.01, lgb__min_child_samples=29, lgb__min_split_gain=0.0023922000044225844, lgb__num_leaves=63, lgb__reg_lambda=0.5330309484404907; f1_macro: (test=0.657) f1_micro: (test=0.811) roc_auc: (test=0.824) total time=  10.7s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7684737847109464, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.033315235868187666, lgb__num_leaves=15, lgb__reg_lambda=0.135380093016772; f1_macro: (test=0.698) f1_micro: (test=0.845) roc_auc: (test=0.853) total time=   3.3s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7684737847109464, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.033315235868187666, lgb__num_leaves=15, lgb__reg_lambda=0.135380093016772; f1_macro: (test=0.685) f1_micro: (test=0.846) roc_auc: (test=0.851) total time=   3.2s
# [CV 5/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8895849571906607, lgb__learning_rate=0.3, lgb__min_child_samples=25, lgb__min_split_gain=0.012134019525780871, lgb__num_leaves=127, lgb__reg_lambda=0.5357596957155019; f1_macro: (test=0.625) f1_micro: (test=0.804) roc_auc: (test=0.786) total time=  17.3s
# [CV 3/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8895849571906607, lgb__learning_rate=0.3, lgb__min_child_samples=25, lgb__min_split_gain=0.012134019525780871, lgb__num_leaves=127, lgb__reg_lambda=0.5357596957155019; f1_macro: (test=0.639) f1_micro: (test=0.810) roc_auc: (test=0.805) total time=  18.7s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7684737847109464, lgb__learning_rate=0.15, lgb__min_child_samples=21, lgb__min_split_gain=0.033315235868187666, lgb__num_leaves=15, lgb__reg_lambda=0.135380093016772; f1_macro: (test=0.681) f1_micro: (test=0.843) roc_auc: (test=0.834) total time=   2.8s
# [CV 2/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8895849571906607, lgb__learning_rate=0.3, lgb__min_child_samples=25, lgb__min_split_gain=0.012134019525780871, lgb__num_leaves=127, lgb__reg_lambda=0.5357596957155019; f1_macro: (test=0.649) f1_micro: (test=0.802) roc_auc: (test=0.825) total time=  21.2s
# [CV 4/5] END lgb__boosting_type=rf, lgb__feature_fraction=0.8895849571906607, lgb__learning_rate=0.3, lgb__min_child_samples=25, lgb__min_split_gain=0.012134019525780871, lgb__num_leaves=127, lgb__reg_lambda=0.5357596957155019; f1_macro: (test=0.634) f1_micro: (test=0.802) roc_auc: (test=0.813) total time=  18.2s
# [CV 1/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7556862227657044, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.05228319559864933, lgb__num_leaves=127, lgb__reg_lambda=0.26088236459345004; f1_macro: (test=0.655) f1_micro: (test=0.851) roc_auc: (test=0.814) total time=  13.3s
# [CV 3/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7556862227657044, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.05228319559864933, lgb__num_leaves=127, lgb__reg_lambda=0.26088236459345004; f1_macro: (test=0.674) f1_micro: (test=0.855) roc_auc: (test=0.843) total time=  12.4s
# [CV 2/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7556862227657044, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.05228319559864933, lgb__num_leaves=127, lgb__reg_lambda=0.26088236459345004; f1_macro: (test=0.686) f1_micro: (test=0.851) roc_auc: (test=0.846) total time=  13.6s
# [CV 4/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7556862227657044, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.05228319559864933, lgb__num_leaves=127, lgb__reg_lambda=0.26088236459345004; f1_macro: (test=0.684) f1_micro: (test=0.860) roc_auc: (test=0.838) total time=  12.6s
# [CV 5/5] END lgb__boosting_type=gbdt, lgb__feature_fraction=0.7556862227657044, lgb__learning_rate=0.01, lgb__min_child_samples=23, lgb__min_split_gain=0.05228319559864933, lgb__num_leaves=127, lgb__reg_lambda=0.26088236459345004; f1_macro: (test=0.673) f1_micro: (test=0.858) roc_auc: (test=0.824) total time=  10.6s

# %% [markdown]
# With 100 hyperparameter combinations, it takes approximately 6.5 minutes.

# %%
# Load saved pickle
with open('hyperparameter_tuning/lgbm/lgbm_over_100comb.pkl', 'rb') as f:
    loaded = pickle.load(f)
    best_params_lgbm_over, best_scores_lgbm_over = loaded

print('Best parameters of LightGBM:', best_params_lgbm_over, '\n')

print('Best scores of LightGBM:', best_scores_lgbm_over, '\n')
# Out:
# Best parameters of LightGBM: {'lgb__boosting_type': 'gbdt', 'lgb__feature_fraction': 0.5786047712169723, 'lgb__learning_rate': 0.15, 'lgb__min_child_samples': 6, 'lgb__min_split_gain': 0.03704075485505709, 'lgb__num_leaves': 15, 'lgb__reg_lambda': 0.3606084225042038}
#
# Best scores of LightGBM: {'f1_micro': 0.9019999999999999, 'f1_macro': 0.659453339505749, 'roc_auc': 0.8512450135095173}

# %% [markdown]
# # Conclusions
# - Overall, *LightGBM* is the best performer in this case, followed closely by *Gradient Boosting*.
# - In terms of resampling, either no resampling or oversampling seem to be giving the best results (in terms of the highest ROC-AUC score). For the random forest model, it can be clearly observed that oversampling increases the F1-macro (which is an F1 measure which computes the average, unweighted F1-score for all of the classes in the outcome), but reduces the overall performance (see F1-micro and ROC-AUC).
